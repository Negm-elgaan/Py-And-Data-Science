# %% [markdown]
# <div align="right" style=" font-size: 80%; text-align: center; margin: 0 auto">
# <img src="https://raw.githubusercontent.com/Explore-AI/Pictures/master/ExploreAI_logos/Logo blue_dark.png"  style="width:25px" align="right";/>
# </div>

# %% [markdown]
# # Union
# © ExploreAI Academy

# %% [markdown]
# In this notebook, we will learn how to merge and consolidate data from multiple tables efficiently by combining query results and creating comprehensive summaries using the UNION operator.

# %% [markdown]
# > ⚠️ This notebook will not run on Google Colab because it cannot connect to a local database. Please make sure that this notebook is running on the same local machine as your MySQL Workbench installation and MySQL `united_nations` database.

# %% [markdown]
# ## Learning objectives
#
# By the end of this train, you will:
# - Understand the concept of UNION and its significance in combining multiple query results.
# - Know how to use the UNION operator to merge data from different tables with similar structures.
# - Comprehend the process of creating a summary by merging results from multiple SELECT statements.

# %% [markdown]
# ## Overview
#
# Suppose we want a summary of estimated unemployment rates per country for each given time period, and we expect that certain data entries of the unemployment rates might be missing.
#
# To address this issue, we intend to replace the absent values by using the regional estimated unemployment rates available in the table below, in order to enhance the completeness of our summary.
#
# |Region|Pct_regional_unemployment|
# |---|---|
# |Central and Southern Asia|     19.59    |
# |Eastern and South-Eastern Asia|  22.64  |
# |Europe and Northern America|     24.43   |
# |Latin America and the Caribbean|  24.23 |
# |Northern Africa and Western Asia| 17.84 |
# |Oceania|                          4.98 |
# |Sub-Saharan Africa|              33.65  |
#
# *Table 1: Regional estimated unemployment rates.*

# %% [markdown]
# To put it differently, according to the flow chart's instructions, for every country belonging to the Central and Southern Asia region, if there is no recorded percentage for the unemployment rate, we should substitute it with the regional data, which is `19.59` in this specific instance.
#
# The same procedure applies to other regions as well, where each missing unemployment rate should be replaced with its respective regional data.
#
# <div align="center" style=" font-size: 80%; text-align: center; margin: 0 auto">
# <img src="https://raw.githubusercontent.com/Explore-AI/Pictures/master/Union_flow_chart.png"  style="background-color:white;";/>
# <br>
# <br>
#     <em>Figure 1: Union flow chart</em>
# </div>

# %% [markdown]
# ## Connecting to the MySQL database
#
# We'll start by connecting to the `united_nations` database. To connect to the MySQL server, run the cells below.

# %%
# Load and activate the SQL extension to allow us to execute SQL in a Jupyter notebook. 
# If you get an error here, make sure that mysql and pymysql are installed correctly. 

# %load_ext sql

# %%
# Establish a connection to the local database using the '%sql' magic command.
# Replace 'password' with our connection password and `db_name` with our database name. 
# If you get an error here, please make sure the database name or password is correct.

# %sql mysql+pymysql://root:Omar2003negm*@localhost:3306/united_nations
# Out:
# 'Connected: root@united_nations'

# %% [markdown]
# We'll be working with two tables: `Geographic_Location`, which contains information about countries and their regions, and `Economic_Indicators`, which holds data on unemployment rates for each country over time.
#
#
# Let’s fetch a list of countries belonging to the **Central and Southern Asia region**.
#
# **NOTE:** Each region will eventually have its own `SELECT` statement and this region is simply the starting point to illustrate the process.

# %%
# %%sql
#
# SELECT
# 	loc.Country_name
# FROM
# 	united_nations.Geographic_Location AS loc
# WHERE REGION LIKE '%Central and Southern Asia%';
# Out:
#  * mysql+pymysql://root:***@localhost:3306/united_nations
# 14 rows affected.
# [('Afghanistan',),
#  ('Bangladesh',),
#  ('Bhutan',),
#  ('India',),
#  ('Iran (Islamic Republic of)',),
#  ('Kazakhstan',),
#  ('Kyrgyzstan',),
#  ('Maldives',),
#  ('Nepal',),
#  ('Pakistan',),
#  ('Sri Lanka',),
#  ('Tajikistan',),
#  ('Turkmenistan',),
#  ('Uzbekistan',)]

# %% [markdown]
# ## Exercise

# %% [markdown]
# ### 1. Join tables
#
# Obtain `Time_period` and `Pct_unemployment` columns for each country by combining the `Geographic_Location` and `Economic_Indicators` tables based on the `Country_name`.

# %%
# %%sql
# # Add your code here
# SELECT
#     Time_period,Pct_unemployment,Geographic_Location.Country_name
# FROM
#     Economic_Indicators
# LEFT JOIN
#     Geographic_Location
# ON
#     Geographic_Location.country_name = Economic_Indicators.country_name
# WHERE
#     REGION LIKE '%Central and Southern Asia%';
# Out:
#  * mysql+pymysql://root:***@localhost:3306/united_nations
# 84 rows affected.
# [(2015, None, 'Afghanistan'),
#  (2016, None, 'Afghanistan'),
#  (2017, Decimal('11.18'), 'Afghanistan'),
#  (2018, None, 'Afghanistan'),
#  (2019, None, 'Afghanistan'),
#  (2020, Decimal('11.71'), 'Afghanistan'),
#  (2015, None, 'Bangladesh'),
#  (2016, Decimal('4.35'), 'Bangladesh'),
#  (2017, Decimal('4.37'), 'Bangladesh'),
#  (2018, None, 'Bangladesh'),
#  (2019, None, 'Bangladesh'),
#  (2020, None, 'Bangladesh'),
#  (2015, Decimal('2.45'), 'Bhutan'),
#  (2016, None, 'Bhutan'),
#  (2017, None, 'Bhutan'),
#  (2018, Decimal('3.35'), 'Bhutan'),
#  (2019, Decimal('2.72'), 'Bhutan'),
#  (2020, Decimal('5.03'), 'Bhutan'),
#  (2015, None, 'India'),
#  (2016, None, 'India'),
#  (2017, None, 'India'),
#  (2018, Decimal('7.65'), 'India'),
#  (2019, Decimal('6.51'), 'India'),
#  (2020, Decimal('7.86'), 'India'),
#  (2015, None, 'Iran (Islamic Republic of)'),
#  (2016, None, 'Iran (Islamic Republic of)'),
#  (2017, None, 'Iran (Islamic Republic of)'),
#  (2018, None, 'Iran (Islamic Republic of)'),
#  (2019, None, 'Iran (Islamic Republic of)'),
#  (2020, None, 'Iran (Islamic Republic of)'),
#  (2015, Decimal('4.93'), 'Kazakhstan'),
#  (2016, Decimal('4.96'), 'Kazakhstan'),
#  (2017, Decimal('4.90'), 'Kazakhstan'),
#  (2018, Decimal('4.85'), 'Kazakhstan'),
#  (2019, Decimal('4.80'), 'Kazakhstan'),
#  (2020, Decimal('4.89'), 'Kazakhstan'),
#  (2015, None, 'Kyrgyzstan'),
#  (2016, None, 'Kyrgyzstan'),
#  (2017, None, 'Kyrgyzstan'),
#  (2018, None, 'Kyrgyzstan'),
#  (2019, None, 'Kyrgyzstan'),
#  (2020, None, 'Kyrgyzstan'),
#  (2015, None, 'Maldives'),
#  (2016, Decimal('5.77'), 'Maldives'),
#  (2017, None, 'Maldives'),
#  (2018, None, 'Maldives'),
#  (2019, Decimal('4.56'), 'Maldives'),
#  (2020, None, 'Maldives'),
#  (2015, Decimal('3.10'), 'Nepal'),
#  (2016, None, 'Nepal'),
#  (2017, Decimal('10.66'), 'Nepal'),
#  (2018, None, 'Nepal'),
#  (2019, None, 'Nepal'),
#  (2020, None, 'Nepal'),
#  (2015, Decimal('3.57'), 'Pakistan'),
#  (2016, None, 'Pakistan'),
#  (2017, None, 'Pakistan'),
#  (2018, Decimal('4.08'), 'Pakistan'),
#  (2019, Decimal('4.83'), 'Pakistan'),
#  (2020, None, 'Pakistan'),
#  (2015, Decimal('4.52'), 'Sri Lanka'),
#  (2016, Decimal('4.24'), 'Sri Lanka'),
#  (2017, Decimal('4.05'), 'Sri Lanka'),
#  (2018, Decimal('4.32'), 'Sri Lanka'),
#  (2019, Decimal('4.67'), 'Sri Lanka'),
#  (2020, Decimal('5.36'), 'Sri Lanka'),
#  (2015, None, 'Tajikistan'),
#  (2016, Decimal('6.90'), 'Tajikistan'),
#  (2017, None, 'Tajikistan'),
#  (2018, None, 'Tajikistan'),
#  (2019, None, 'Tajikistan'),
#  (2020, None, 'Tajikistan'),
#  (2015, None, 'Turkmenistan'),
#  (2016, None, 'Turkmenistan'),
#  (2017, None, 'Turkmenistan'),
#  (2018, None, 'Turkmenistan'),
#  (2019, None, 'Turkmenistan'),
#  (2020, None, 'Turkmenistan'),
#  (2015, Decimal('5.15'), 'Uzbekistan'),
#  (2016, Decimal('5.16'), 'Uzbekistan'),
#  (2017, Decimal('5.83'), 'Uzbekistan'),
#  (2018, Decimal('9.35'), 'Uzbekistan'),
#  (2019, Decimal('8.98'), 'Uzbekistan'),
#  (2020, Decimal('5.29'), 'Uzbekistan')]

# %% [markdown]
# ### 2. Impute `NULL` values
#
# To enhance the completeness of our summary, we'll address missing unemployment rate values. If any unemployment rate is absent, we'll replace it with the regional data, which is 19.59 in this case. We will then save this column as `Pct_unemployment_imputed`.

# %%
# %%sql
# # Add your code here
# SELECT
#     Time_period,
#     Pct_unemployment,
#     IFNULL(Pct_unemployment , 19.59) AS Pct_unemployment_imputed,
#     Geographic_Location.Country_name
# FROM
#     Economic_Indicators
# LEFT JOIN
#     Geographic_Location
# ON
#     Geographic_Location.country_name = Economic_Indicators.country_name
# WHERE
#     REGION LIKE '%Central and Southern Asia%'
# Out:
#  * mysql+pymysql://root:***@localhost:3306/united_nations
# 84 rows affected.
# [(2015, None, Decimal('19.59'), 'Afghanistan'),
#  (2016, None, Decimal('19.59'), 'Afghanistan'),
#  (2017, Decimal('11.18'), Decimal('11.18'), 'Afghanistan'),
#  (2018, None, Decimal('19.59'), 'Afghanistan'),
#  (2019, None, Decimal('19.59'), 'Afghanistan'),
#  (2020, Decimal('11.71'), Decimal('11.71'), 'Afghanistan'),
#  (2015, None, Decimal('19.59'), 'Bangladesh'),
#  (2016, Decimal('4.35'), Decimal('4.35'), 'Bangladesh'),
#  (2017, Decimal('4.37'), Decimal('4.37'), 'Bangladesh'),
#  (2018, None, Decimal('19.59'), 'Bangladesh'),
#  (2019, None, Decimal('19.59'), 'Bangladesh'),
#  (2020, None, Decimal('19.59'), 'Bangladesh'),
#  (2015, Decimal('2.45'), Decimal('2.45'), 'Bhutan'),
#  (2016, None, Decimal('19.59'), 'Bhutan'),
#  (2017, None, Decimal('19.59'), 'Bhutan'),
#  (2018, Decimal('3.35'), Decimal('3.35'), 'Bhutan'),
#  (2019, Decimal('2.72'), Decimal('2.72'), 'Bhutan'),
#  (2020, Decimal('5.03'), Decimal('5.03'), 'Bhutan'),
#  (2015, None, Decimal('19.59'), 'India'),
#  (2016, None, Decimal('19.59'), 'India'),
#  (2017, None, Decimal('19.59'), 'India'),
#  (2018, Decimal('7.65'), Decimal('7.65'), 'India'),
#  (2019, Decimal('6.51'), Decimal('6.51'), 'India'),
#  (2020, Decimal('7.86'), Decimal('7.86'), 'India'),
#  (2015, None, Decimal('19.59'), 'Iran (Islamic Republic of)'),
#  (2016, None, Decimal('19.59'), 'Iran (Islamic Republic of)'),
#  (2017, None, Decimal('19.59'), 'Iran (Islamic Republic of)'),
#  (2018, None, Decimal('19.59'), 'Iran (Islamic Republic of)'),
#  (2019, None, Decimal('19.59'), 'Iran (Islamic Republic of)'),
#  (2020, None, Decimal('19.59'), 'Iran (Islamic Republic of)'),
#  (2015, Decimal('4.93'), Decimal('4.93'), 'Kazakhstan'),
#  (2016, Decimal('4.96'), Decimal('4.96'), 'Kazakhstan'),
#  (2017, Decimal('4.90'), Decimal('4.90'), 'Kazakhstan'),
#  (2018, Decimal('4.85'), Decimal('4.85'), 'Kazakhstan'),
#  (2019, Decimal('4.80'), Decimal('4.80'), 'Kazakhstan'),
#  (2020, Decimal('4.89'), Decimal('4.89'), 'Kazakhstan'),
#  (2015, None, Decimal('19.59'), 'Kyrgyzstan'),
#  (2016, None, Decimal('19.59'), 'Kyrgyzstan'),
#  (2017, None, Decimal('19.59'), 'Kyrgyzstan'),
#  (2018, None, Decimal('19.59'), 'Kyrgyzstan'),
#  (2019, None, Decimal('19.59'), 'Kyrgyzstan'),
#  (2020, None, Decimal('19.59'), 'Kyrgyzstan'),
#  (2015, None, Decimal('19.59'), 'Maldives'),
#  (2016, Decimal('5.77'), Decimal('5.77'), 'Maldives'),
#  (2017, None, Decimal('19.59'), 'Maldives'),
#  (2018, None, Decimal('19.59'), 'Maldives'),
#  (2019, Decimal('4.56'), Decimal('4.56'), 'Maldives'),
#  (2020, None, Decimal('19.59'), 'Maldives'),
#  (2015, Decimal('3.10'), Decimal('3.10'), 'Nepal'),
#  (2016, None, Decimal('19.59'), 'Nepal'),
#  (2017, Decimal('10.66'), Decimal('10.66'), 'Nepal'),
#  (2018, None, Decimal('19.59'), 'Nepal'),
#  (2019, None, Decimal('19.59'), 'Nepal'),
#  (2020, None, Decimal('19.59'), 'Nepal'),
#  (2015, Decimal('3.57'), Decimal('3.57'), 'Pakistan'),
#  (2016, None, Decimal('19.59'), 'Pakistan'),
#  (2017, None, Decimal('19.59'), 'Pakistan'),
#  (2018, Decimal('4.08'), Decimal('4.08'), 'Pakistan'),
#  (2019, Decimal('4.83'), Decimal('4.83'), 'Pakistan'),
#  (2020, None, Decimal('19.59'), 'Pakistan'),
#  (2015, Decimal('4.52'), Decimal('4.52'), 'Sri Lanka'),
#  (2016, Decimal('4.24'), Decimal('4.24'), 'Sri Lanka'),
#  (2017, Decimal('4.05'), Decimal('4.05'), 'Sri Lanka'),
#  (2018, Decimal('4.32'), Decimal('4.32'), 'Sri Lanka'),
#  (2019, Decimal('4.67'), Decimal('4.67'), 'Sri Lanka'),
#  (2020, Decimal('5.36'), Decimal('5.36'), 'Sri Lanka'),
#  (2015, None, Decimal('19.59'), 'Tajikistan'),
#  (2016, Decimal('6.90'), Decimal('6.90'), 'Tajikistan'),
#  (2017, None, Decimal('19.59'), 'Tajikistan'),
#  (2018, None, Decimal('19.59'), 'Tajikistan'),
#  (2019, None, Decimal('19.59'), 'Tajikistan'),
#  (2020, None, Decimal('19.59'), 'Tajikistan'),
#  (2015, None, Decimal('19.59'), 'Turkmenistan'),
#  (2016, None, Decimal('19.59'), 'Turkmenistan'),
#  (2017, None, Decimal('19.59'), 'Turkmenistan'),
#  (2018, None, Decimal('19.59'), 'Turkmenistan'),
#  (2019, None, Decimal('19.59'), 'Turkmenistan'),
#  (2020, None, Decimal('19.59'), 'Turkmenistan'),
#  (2015, Decimal('5.15'), Decimal('5.15'), 'Uzbekistan'),
#  (2016, Decimal('5.16'), Decimal('5.16'), 'Uzbekistan'),
#  (2017, Decimal('5.83'), Decimal('5.83'), 'Uzbekistan'),
#  (2018, Decimal('9.35'), Decimal('9.35'), 'Uzbekistan'),
#  (2019, Decimal('8.98'), Decimal('8.98'), 'Uzbekistan'),
#  (2020, Decimal('5.29'), Decimal('5.29'), 'Uzbekistan')]

# %% [markdown]
# ### 3. Repeat for other regions
#
# We can now repeat this process for various regions. We will use the `UNION` operator to combine the `SELECT` statements.

# %%
# %%sql
#
# SELECT DISTINCT
#     REGION
# FROM
#     Geographic_location
# Out:
#  * mysql+pymysql://root:***@localhost:3306/united_nations
# 7 rows affected.
# [('Central and Southern Asia',),
#  ('Northern Africa and Western Asia',),
#  ('Oceania',),
#  ('Sub-Saharan Africa',),
#  ('Latin America and the Caribbean',),
#  ('Europe and Northern America',),
#  ('Eastern and South-Eastern Asia',)]

# %%
# %%sql
# # Add your code here
# SELECT
#     Time_period,
#     Pct_unemployment,
#     IFNULL(Pct_unemployment , 19.59) AS Pct_unemployment_imputed,
#     Geographic_Location.Country_name
# FROM
#     Economic_Indicators
# LEFT JOIN
#     Geographic_Location
# ON
#     Geographic_Location.country_name = Economic_Indicators.country_name
# WHERE
#     REGION LIKE '%Central and Southern Asia%'
# UNION
# SELECT
#     Time_period,
#     Pct_unemployment,
#     IFNULL(Pct_unemployment , 17.84) AS Pct_unemployment_imputed,
#     Geographic_Location.Country_name
# FROM
#     Economic_Indicators
# LEFT JOIN
#     Geographic_Location
# ON
#     Geographic_Location.country_name = Economic_Indicators.country_name
# WHERE
#     REGION LIKE '%Northern Africa and Western Asia%'
# UNION
# SELECT
#     Time_period,
#     Pct_unemployment,
#     IFNULL(Pct_unemployment , 4.98) AS Pct_unemployment_imputed,
#     Geographic_Location.Country_name
# FROM
#     Economic_Indicators
# LEFT JOIN
#     Geographic_Location
# ON
#     Geographic_Location.country_name = Economic_Indicators.country_name
# WHERE
#     REGION LIKE '%Oceania%'
# UNION
# SELECT
#     Time_period,
#     Pct_unemployment,
#     IFNULL(Pct_unemployment , 33.65) AS Pct_unemployment_imputed,
#     Geographic_Location.Country_name
# FROM
#     Economic_Indicators
# LEFT JOIN
#     Geographic_Location
# ON
#     Geographic_Location.country_name = Economic_Indicators.country_name
# WHERE
#     REGION LIKE '%Sub-Saharan Africa%'
# UNION
# SELECT
#     Time_period,
#     Pct_unemployment,
#     IFNULL(Pct_unemployment , 24.23) AS Pct_unemployment_imputed,
#     Geographic_Location.Country_name
# FROM
#     Economic_Indicators
# LEFT JOIN
#     Geographic_Location
# ON
#     Geographic_Location.country_name = Economic_Indicators.country_name
# WHERE
#     REGION LIKE '%Latin America and the Caribbean%'
# UNION
# SELECT
#     Time_period,
#     Pct_unemployment,
#     IFNULL(Pct_unemployment , 24.43) AS Pct_unemployment_imputed,
#     Geographic_Location.Country_name
# FROM
#     Economic_Indicators
# LEFT JOIN
#     Geographic_Location
# ON
#     Geographic_Location.country_name = Economic_Indicators.country_name
# WHERE
#     REGION LIKE '%Europe and Northern America%'
# UNION
# SELECT
#     Time_period,
#     Pct_unemployment,
#     IFNULL(Pct_unemployment , 22.64) AS Pct_unemployment_imputed,
#     Geographic_Location.Country_name
# FROM
#     Economic_Indicators
# LEFT JOIN
#     Geographic_Location
# ON
#     Geographic_Location.country_name = Economic_Indicators.country_name
# WHERE
#     REGION LIKE '%Eastern and South-Eastern Asia%'
# Out:
#  * mysql+pymysql://root:***@localhost:3306/united_nations
# 1048 rows affected.
# [(2015, None, Decimal('19.59'), 'Afghanistan'),
#  (2016, None, Decimal('19.59'), 'Afghanistan'),
#  (2017, Decimal('11.18'), Decimal('11.18'), 'Afghanistan'),
#  (2018, None, Decimal('19.59'), 'Afghanistan'),
#  (2019, None, Decimal('19.59'), 'Afghanistan'),
#  (2020, Decimal('11.71'), Decimal('11.71'), 'Afghanistan'),
#  (2015, None, Decimal('19.59'), 'Bangladesh'),
#  (2016, Decimal('4.35'), Decimal('4.35'), 'Bangladesh'),
#  (2017, Decimal('4.37'), Decimal('4.37'), 'Bangladesh'),
#  (2018, None, Decimal('19.59'), 'Bangladesh'),
#  (2019, None, Decimal('19.59'), 'Bangladesh'),
#  (2020, None, Decimal('19.59'), 'Bangladesh'),
#  (2015, Decimal('2.45'), Decimal('2.45'), 'Bhutan'),
#  (2016, None, Decimal('19.59'), 'Bhutan'),
#  (2017, None, Decimal('19.59'), 'Bhutan'),
#  (2018, Decimal('3.35'), Decimal('3.35'), 'Bhutan'),
#  (2019, Decimal('2.72'), Decimal('2.72'), 'Bhutan'),
#  (2020, Decimal('5.03'), Decimal('5.03'), 'Bhutan'),
#  (2015, None, Decimal('19.59'), 'India'),
#  (2016, None, Decimal('19.59'), 'India'),
#  (2017, None, Decimal('19.59'), 'India'),
#  (2018, Decimal('7.65'), Decimal('7.65'), 'India'),
#  (2019, Decimal('6.51'), Decimal('6.51'), 'India'),
#  (2020, Decimal('7.86'), Decimal('7.86'), 'India'),
#  (2015, None, Decimal('19.59'), 'Iran (Islamic Republic of)'),
#  (2016, None, Decimal('19.59'), 'Iran (Islamic Republic of)'),
#  (2017, None, Decimal('19.59'), 'Iran (Islamic Republic of)'),
#  (2018, None, Decimal('19.59'), 'Iran (Islamic Republic of)'),
#  (2019, None, Decimal('19.59'), 'Iran (Islamic Republic of)'),
#  (2020, None, Decimal('19.59'), 'Iran (Islamic Republic of)'),
#  (2015, Decimal('4.93'), Decimal('4.93'), 'Kazakhstan'),
#  (2016, Decimal('4.96'), Decimal('4.96'), 'Kazakhstan'),
#  (2017, Decimal('4.90'), Decimal('4.90'), 'Kazakhstan'),
#  (2018, Decimal('4.85'), Decimal('4.85'), 'Kazakhstan'),
#  (2019, Decimal('4.80'), Decimal('4.80'), 'Kazakhstan'),
#  (2020, Decimal('4.89'), Decimal('4.89'), 'Kazakhstan'),
#  (2015, None, Decimal('19.59'), 'Kyrgyzstan'),
#  (2016, None, Decimal('19.59'), 'Kyrgyzstan'),
#  (2017, None, Decimal('19.59'), 'Kyrgyzstan'),
#  (2018, None, Decimal('19.59'), 'Kyrgyzstan'),
#  (2019, None, Decimal('19.59'), 'Kyrgyzstan'),
#  (2020, None, Decimal('19.59'), 'Kyrgyzstan'),
#  (2015, None, Decimal('19.59'), 'Maldives'),
#  (2016, Decimal('5.77'), Decimal('5.77'), 'Maldives'),
#  (2017, None, Decimal('19.59'), 'Maldives'),
#  (2018, None, Decimal('19.59'), 'Maldives'),
#  (2019, Decimal('4.56'), Decimal('4.56'), 'Maldives'),
#  (2020, None, Decimal('19.59'), 'Maldives'),
#  (2015, Decimal('3.10'), Decimal('3.10'), 'Nepal'),
#  (2016, None, Decimal('19.59'), 'Nepal'),
#  (2017, Decimal('10.66'), Decimal('10.66'), 'Nepal'),
#  (2018, None, Decimal('19.59'), 'Nepal'),
#  (2019, None, Decimal('19.59'), 'Nepal'),
#  (2020, None, Decimal('19.59'), 'Nepal'),
#  (2015, Decimal('3.57'), Decimal('3.57'), 'Pakistan'),
#  (2016, None, Decimal('19.59'), 'Pakistan'),
#  (2017, None, Decimal('19.59'), 'Pakistan'),
#  (2018, Decimal('4.08'), Decimal('4.08'), 'Pakistan'),
#  (2019, Decimal('4.83'), Decimal('4.83'), 'Pakistan'),
#  (2020, None, Decimal('19.59'), 'Pakistan'),
#  (2015, Decimal('4.52'), Decimal('4.52'), 'Sri Lanka'),
#  (2016, Decimal('4.24'), Decimal('4.24'), 'Sri Lanka'),
#  (2017, Decimal('4.05'), Decimal('4.05'), 'Sri Lanka'),
#  (2018, Decimal('4.32'), Decimal('4.32'), 'Sri Lanka'),
#  (2019, Decimal('4.67'), Decimal('4.67'), 'Sri Lanka'),
#  (2020, Decimal('5.36'), Decimal('5.36'), 'Sri Lanka'),
#  (2015, None, Decimal('19.59'), 'Tajikistan'),
#  (2016, Decimal('6.90'), Decimal('6.90'), 'Tajikistan'),
#  (2017, None, Decimal('19.59'), 'Tajikistan'),
#  (2018, None, Decimal('19.59'), 'Tajikistan'),
#  (2019, None, Decimal('19.59'), 'Tajikistan'),
#  (2020, None, Decimal('19.59'), 'Tajikistan'),
#  (2015, None, Decimal('19.59'), 'Turkmenistan'),
#  (2016, None, Decimal('19.59'), 'Turkmenistan'),
#  (2017, None, Decimal('19.59'), 'Turkmenistan'),
#  (2018, None, Decimal('19.59'), 'Turkmenistan'),
#  (2019, None, Decimal('19.59'), 'Turkmenistan'),
#  (2020, None, Decimal('19.59'), 'Turkmenistan'),
#  (2015, Decimal('5.15'), Decimal('5.15'), 'Uzbekistan'),
#  (2016, Decimal('5.16'), Decimal('5.16'), 'Uzbekistan'),
#  (2017, Decimal('5.83'), Decimal('5.83'), 'Uzbekistan'),
#  (2018, Decimal('9.35'), Decimal('9.35'), 'Uzbekistan'),
#  (2019, Decimal('8.98'), Decimal('8.98'), 'Uzbekistan'),
#  (2020, Decimal('5.29'), Decimal('5.29'), 'Uzbekistan'),
#  (2015, Decimal('11.21'), Decimal('11.21'), 'Algeria'),
#  (2016, Decimal('10.20'), Decimal('10.20'), 'Algeria'),
#  (2017, Decimal('12.00'), Decimal('12.00'), 'Algeria'),
#  (2018, None, Decimal('17.84'), 'Algeria'),
#  (2019, None, Decimal('17.84'), 'Algeria'),
#  (2020, None, Decimal('17.84'), 'Algeria'),
#  (2015, Decimal('18.26'), Decimal('18.26'), 'Armenia'),
#  (2016, Decimal('17.62'), Decimal('17.62'), 'Armenia'),
#  (2017, Decimal('17.70'), Decimal('17.70'), 'Armenia'),
#  (2018, Decimal('13.21'), Decimal('13.21'), 'Armenia'),
#  (2019, Decimal('12.20'), Decimal('12.20'), 'Armenia'),
#  (2020, Decimal('12.18'), Decimal('12.18'), 'Armenia'),
#  (2015, Decimal('4.96'), Decimal('4.96'), 'Azerbaijan'),
#  (2016, Decimal('5.00'), Decimal('5.00'), 'Azerbaijan'),
#  (2017, Decimal('4.96'), Decimal('4.96'), 'Azerbaijan'),
#  (2018, Decimal('4.94'), Decimal('4.94'), 'Azerbaijan'),
#  (2019, Decimal('4.85'), Decimal('4.85'), 'Azerbaijan'),
#  (2020, Decimal('7.16'), Decimal('7.16'), 'Azerbaijan'),
#  (2015, None, Decimal('17.84'), 'Bahrain'),
#  (2016, None, Decimal('17.84'), 'Bahrain'),
#  (2017, None, Decimal('17.84'), 'Bahrain'),
#  (2018, None, Decimal('17.84'), 'Bahrain'),
#  (2019, None, Decimal('17.84'), 'Bahrain'),
#  (2020, None, Decimal('17.84'), 'Bahrain'),
#  (2015, Decimal('15.03'), Decimal('15.03'), 'Cyprus'),
#  (2016, Decimal('13.01'), Decimal('13.01'), 'Cyprus'),
#  (2017, Decimal('11.16'), Decimal('11.16'), 'Cyprus'),
#  (2018, Decimal('8.50'), Decimal('8.50'), 'Cyprus'),
#  (2019, Decimal('7.15'), Decimal('7.15'), 'Cyprus'),
#  (2020, Decimal('7.76'), Decimal('7.76'), 'Cyprus'),
#  (2015, None, Decimal('17.84'), 'Egypt'),
#  (2016, None, Decimal('17.84'), 'Egypt'),
#  (2017, None, Decimal('17.84'), 'Egypt'),
#  (2018, None, Decimal('17.84'), 'Egypt'),
#  (2019, None, Decimal('17.84'), 'Egypt'),
#  (2020, None, Decimal('17.84'), 'Egypt'),
#  (2015, Decimal('16.51'), Decimal('16.51'), 'Georgia'),
#  (2016, Decimal('16.60'), Decimal('16.60'), 'Georgia'),
#  (2017, Decimal('13.94'), Decimal('13.94'), 'Georgia'),
#  (2018, Decimal('12.67'), Decimal('12.67'), 'Georgia'),
#  (2019, Decimal('11.57'), Decimal('11.57'), 'Georgia'),
#  (2020, Decimal('11.73'), Decimal('11.73'), 'Georgia'),
#  (2015, None, Decimal('17.84'), 'Iraq'),
#  (2016, Decimal('10.82'), Decimal('10.82'), 'Iraq'),
#  (2017, Decimal('13.02'), Decimal('13.02'), 'Iraq'),
#  (2018, None, Decimal('17.84'), 'Iraq'),
#  (2019, None, Decimal('17.84'), 'Iraq'),
#  (2020, None, Decimal('17.84'), 'Iraq'),
#  (2015, Decimal('5.18'), Decimal('5.18'), 'Israel'),
#  (2016, Decimal('4.72'), Decimal('4.72'), 'Israel'),
#  (2017, Decimal('4.14'), Decimal('4.14'), 'Israel'),
#  (2018, Decimal('3.92'), Decimal('3.92'), 'Israel'),
#  (2019, Decimal('3.73'), Decimal('3.73'), 'Israel'),
#  (2020, Decimal('4.17'), Decimal('4.17'), 'Israel'),
#  (2015, Decimal('13.08'), Decimal('13.08'), 'Jordan'),
#  (2016, Decimal('15.28'), Decimal('15.28'), 'Jordan'),
#  (2017, Decimal('18.12'), Decimal('18.12'), 'Jordan'),
#  (2018, Decimal('18.26'), Decimal('18.26'), 'Jordan'),
#  (2019, Decimal('16.80'), Decimal('16.80'), 'Jordan'),
#  (2020, Decimal('19.21'), Decimal('19.21'), 'Jordan'),
#  (2015, Decimal('2.20'), Decimal('2.20'), 'Kuwait'),
#  (2016, Decimal('2.16'), Decimal('2.16'), 'Kuwait'),
#  (2017, None, Decimal('17.84'), 'Kuwait'),
#  (2018, None, Decimal('17.84'), 'Kuwait'),
#  (2019, None, Decimal('17.84'), 'Kuwait'),
#  (2020, None, Decimal('17.84'), 'Kuwait'),
#  (2015, None, Decimal('17.84'), 'Lebanon'),
#  (2016, None, Decimal('17.84'), 'Lebanon'),
#  (2017, None, Decimal('17.84'), 'Lebanon'),
#  (2018, None, Decimal('17.84'), 'Lebanon'),
#  (2019, Decimal('11.30'), Decimal('11.30'), 'Lebanon'),
#  (2020, None, Decimal('17.84'), 'Lebanon'),
#  (2015, None, Decimal('17.84'), 'Libya'),
#  (2016, None, Decimal('17.84'), 'Libya'),
#  (2017, None, Decimal('17.84'), 'Libya'),
#  (2018, None, Decimal('17.84'), 'Libya'),
#  (2019, None, Decimal('17.84'), 'Libya'),
#  (2020, None, Decimal('17.84'), 'Libya'),
#  (2015, Decimal('9.46'), Decimal('9.46'), 'Morocco'),
#  (2016, Decimal('9.30'), Decimal('9.30'), 'Morocco'),
#  (2017, None, Decimal('17.84'), 'Morocco'),
#  (2018, None, Decimal('17.84'), 'Morocco'),
#  (2019, None, Decimal('17.84'), 'Morocco'),
#  (2020, None, Decimal('17.84'), 'Morocco'),
#  (2015, None, Decimal('17.84'), 'Oman'),
#  (2016, Decimal('3.27'), Decimal('3.27'), 'Oman'),
#  (2017, None, Decimal('17.84'), 'Oman'),
#  (2018, Decimal('1.80'), Decimal('1.80'), 'Oman'),
#  (2019, None, Decimal('17.84'), 'Oman'),
#  (2020, Decimal('2.94'), Decimal('2.94'), 'Oman'),
#  (2015, Decimal('0.17'), Decimal('0.17'), 'Qatar'),
#  (2016, Decimal('0.15'), Decimal('0.15'), 'Qatar'),
#  (2017, Decimal('0.14'), Decimal('0.14'), 'Qatar'),
#  (2018, Decimal('0.11'), Decimal('0.11'), 'Qatar'),
#  (2019, Decimal('0.10'), Decimal('0.10'), 'Qatar'),
#  (2020, Decimal('0.14'), Decimal('0.14'), 'Qatar'),
#  (2015, Decimal('5.60'), Decimal('5.60'), 'Saudi Arabia'),
#  (2016, Decimal('5.60'), Decimal('5.60'), 'Saudi Arabia'),
#  (2017, Decimal('5.89'), Decimal('5.89'), 'Saudi Arabia'),
#  (2018, Decimal('6.03'), Decimal('6.03'), 'Saudi Arabia'),
#  (2019, Decimal('5.64'), Decimal('5.64'), 'Saudi Arabia'),
#  (2020, Decimal('7.66'), Decimal('7.66'), 'Saudi Arabia'),
#  (2015, None, Decimal('17.84'), 'State of Palestine'),
#  (2016, None, Decimal('17.84'), 'State of Palestine'),
#  (2017, None, Decimal('17.84'), 'State of Palestine'),
#  (2018, None, Decimal('17.84'), 'State of Palestine'),
#  (2019, None, Decimal('17.84'), 'State of Palestine'),
#  (2020, None, Decimal('17.84'), 'State of Palestine'),
#  (2015, None, Decimal('17.84'), 'Sudan'),
#  (2016, None, Decimal('17.84'), 'Sudan'),
#  (2017, None, Decimal('17.84'), 'Sudan'),
#  (2018, None, Decimal('17.84'), 'Sudan'),
#  (2019, None, Decimal('17.84'), 'Sudan'),
#  (2020, None, Decimal('17.84'), 'Sudan'),
#  (2015, None, Decimal('17.84'), 'Syrian Arab Republic'),
#  (2016, None, Decimal('17.84'), 'Syrian Arab Republic'),
#  (2017, None, Decimal('17.84'), 'Syrian Arab Republic'),
#  (2018, None, Decimal('17.84'), 'Syrian Arab Republic'),
#  (2019, None, Decimal('17.84'), 'Syrian Arab Republic'),
#  (2020, None, Decimal('17.84'), 'Syrian Arab Republic'),
#  (2015, Decimal('15.16'), Decimal('15.16'), 'Tunisia'),
#  (2016, Decimal('15.56'), Decimal('15.56'), 'Tunisia'),
#  (2017, Decimal('15.33'), Decimal('15.33'), 'Tunisia'),
#  (2018, Decimal('15.46'), Decimal('15.46'), 'Tunisia'),
#  (2019, Decimal('15.13'), Decimal('15.13'), 'Tunisia'),
#  (2020, None, Decimal('17.84'), 'Tunisia'),
#  (2015, None, Decimal('17.84'), 'Türkiye'),
#  (2016, None, Decimal('17.84'), 'Türkiye'),
#  (2017, None, Decimal('17.84'), 'Türkiye'),
#  (2018, None, Decimal('17.84'), 'Türkiye'),
#  (2019, None, Decimal('17.84'), 'Türkiye'),
#  (2020, None, Decimal('17.84'), 'Türkiye'),
#  (2015, None, Decimal('17.84'), 'United Arab Emirates'),
#  (2016, Decimal('1.64'), Decimal('1.64'), 'United Arab Emirates'),
#  (2017, Decimal('2.46'), Decimal('2.46'), 'United Arab Emirates'),
#  (2018, Decimal('2.24'), Decimal('2.24'), 'United Arab Emirates'),
#  (2019, Decimal('2.33'), Decimal('2.33'), 'United Arab Emirates'),
#  (2020, Decimal('4.29'), Decimal('4.29'), 'United Arab Emirates'),
#  (2015, None, Decimal('17.84'), 'Yemen'),
#  (2016, None, Decimal('17.84'), 'Yemen'),
#  (2017, None, Decimal('17.84'), 'Yemen'),
#  (2018, None, Decimal('17.84'), 'Yemen'),
#  (2019, None, Decimal('17.84'), 'Yemen'),
#  (2020, None, Decimal('17.84'), 'Yemen'),
#  (2015, None, Decimal('4.98'), 'American Samoa'),
#  (2016, None, Decimal('4.98'), 'American Samoa'),
#  (2017, None, Decimal('4.98'), 'American Samoa'),
#  (2018, None, Decimal('4.98'), 'American Samoa'),
#  (2019, None, Decimal('4.98'), 'American Samoa'),
#  (2020, None, Decimal('4.98'), 'American Samoa'),
#  (2015, Decimal('6.06'), Decimal('6.06'), 'Australia'),
#  (2016, Decimal('5.71'), Decimal('5.71'), 'Australia'),
#  (2017, Decimal('5.59'), Decimal('5.59'), 'Australia'),
#  (2018, Decimal('5.30'), Decimal('5.30'), 'Australia'),
#  (2019, Decimal('5.16'), Decimal('5.16'), 'Australia'),
#  (2020, Decimal('6.46'), Decimal('6.46'), 'Australia'),
#  (2015, None, Decimal('4.98'), 'Cook Islands'),
#  (2016, None, Decimal('4.98'), 'Cook Islands'),
#  (2017, None, Decimal('4.98'), 'Cook Islands'),
#  (2018, None, Decimal('4.98'), 'Cook Islands'),
#  (2019, None, Decimal('4.98'), 'Cook Islands'),
#  (2020, None, Decimal('4.98'), 'Cook Islands'),
#  (2015, None, Decimal('4.98'), 'Fiji'),
#  (2016, Decimal('4.32'), Decimal('4.32'), 'Fiji'),
#  (2017, None, Decimal('4.98'), 'Fiji'),
#  (2018, None, Decimal('4.98'), 'Fiji'),
#  (2019, None, Decimal('4.98'), 'Fiji'),
#  (2020, None, Decimal('4.98'), 'Fiji'),
#  (2015, None, Decimal('4.98'), 'French Polynesia'),
#  (2016, None, Decimal('4.98'), 'French Polynesia'),
#  (2017, None, Decimal('4.98'), 'French Polynesia'),
#  (2018, None, Decimal('4.98'), 'French Polynesia'),
#  (2019, None, Decimal('4.98'), 'French Polynesia'),
#  (2020, None, Decimal('4.98'), 'French Polynesia'),
#  (2015, Decimal('6.90'), Decimal('6.90'), 'Guam'),
#  (2016, Decimal('5.40'), Decimal('5.40'), 'Guam'),
#  (2017, None, Decimal('4.98'), 'Guam'),
#  (2018, None, Decimal('4.98'), 'Guam'),
#  (2019, None, Decimal('4.98'), 'Guam'),
#  (2020, None, Decimal('4.98'), 'Guam'),
#  (2015, Decimal('9.33'), Decimal('9.33'), 'Kiribati'),
#  (2016, None, Decimal('4.98'), 'Kiribati'),
#  (2017, None, Decimal('4.98'), 'Kiribati'),
#  (2018, None, Decimal('4.98'), 'Kiribati'),
#  (2019, Decimal('8.56'), Decimal('8.56'), 'Kiribati'),
#  (2020, Decimal('10.97'), Decimal('10.97'), 'Kiribati'),
#  (2015, None, Decimal('4.98'), 'Marshall Islands'),
#  (2016, None, Decimal('4.98'), 'Marshall Islands'),
#  (2017, None, Decimal('4.98'), 'Marshall Islands'),
#  (2018, None, Decimal('4.98'), 'Marshall Islands'),
#  (2019, Decimal('6.34'), Decimal('6.34'), 'Marshall Islands'),
#  (2020, None, Decimal('4.98'), 'Marshall Islands'),
#  (2015, None, Decimal('4.98'), 'Micronesia (Federated States of)'),
#  (2016, None, Decimal('4.98'), 'Micronesia (Federated States of)'),
#  (2017, None, Decimal('4.98'), 'Micronesia (Federated States of)'),
#  (2018, None, Decimal('4.98'), 'Micronesia (Federated States of)'),
#  (2019, None, Decimal('4.98'), 'Micronesia (Federated States of)'),
#  (2015, None, Decimal('4.98'), 'Nauru'),
#  (2016, None, Decimal('4.98'), 'Nauru'),
#  (2017, None, Decimal('4.98'), 'Nauru'),
#  (2018, None, Decimal('4.98'), 'Nauru'),
#  (2019, None, Decimal('4.98'), 'Nauru'),
#  (2020, None, Decimal('4.98'), 'Nauru'),
#  (2015, None, Decimal('4.98'), 'New Caledonia'),
#  (2016, None, Decimal('4.98'), 'New Caledonia'),
#  (2017, Decimal('11.68'), Decimal('11.68'), 'New Caledonia'),
#  (2018, Decimal('11.70'), Decimal('11.70'), 'New Caledonia'),
#  (2019, Decimal('10.88'), Decimal('10.88'), 'New Caledonia'),
#  (2020, Decimal('13.56'), Decimal('13.56'), 'New Caledonia'),
#  (2015, Decimal('5.42'), Decimal('5.42'), 'New Zealand'),
#  (2016, Decimal('5.15'), Decimal('5.15'), 'New Zealand'),
#  (2017, Decimal('4.74'), Decimal('4.74'), 'New Zealand'),
#  (2018, Decimal('4.34'), Decimal('4.34'), 'New Zealand'),
#  (2019, Decimal('4.11'), Decimal('4.11'), 'New Zealand'),
#  (2020, Decimal('4.60'), Decimal('4.60'), 'New Zealand'),
#  (2015, None, Decimal('4.98'), 'Niue'),
#  (2016, None, Decimal('4.98'), 'Niue'),
#  (2017, None, Decimal('4.98'), 'Niue'),
#  (2018, None, Decimal('4.98'), 'Niue'),
#  (2019, None, Decimal('4.98'), 'Niue'),
#  (2020, None, Decimal('4.98'), 'Niue'),
#  (2015, None, Decimal('4.98'), 'Northern Mariana Islands'),
#  (2016, None, Decimal('4.98'), 'Northern Mariana Islands'),
#  (2017, None, Decimal('4.98'), 'Northern Mariana Islands'),
#  (2018, None, Decimal('4.98'), 'Northern Mariana Islands'),
#  (2019, None, Decimal('4.98'), 'Northern Mariana Islands'),
#  (2020, None, Decimal('4.98'), 'Northern Mariana Islands'),
#  (2015, None, Decimal('4.98'), 'Palau'),
#  (2016, None, Decimal('4.98'), 'Palau'),
#  (2017, None, Decimal('4.98'), 'Palau'),
#  (2018, None, Decimal('4.98'), 'Palau'),
#  (2019, None, Decimal('4.98'), 'Palau'),
#  (2020, Decimal('0.77'), Decimal('0.77'), 'Palau'),
#  (2015, None, Decimal('4.98'), 'Papua New Guinea'),
#  (2016, None, Decimal('4.98'), 'Papua New Guinea'),
#  (2017, None, Decimal('4.98'), 'Papua New Guinea'),
#  (2018, None, Decimal('4.98'), 'Papua New Guinea'),
#  (2019, None, Decimal('4.98'), 'Papua New Guinea'),
#  (2020, None, Decimal('4.98'), 'Papua New Guinea'),
#  (2015, None, Decimal('4.98'), 'Samoa'),
#  (2016, None, Decimal('4.98'), 'Samoa'),
#  (2017, Decimal('9.40'), Decimal('9.40'), 'Samoa'),
#  (2018, None, Decimal('4.98'), 'Samoa'),
#  (2019, None, Decimal('4.98'), 'Samoa'),
#  (2020, None, Decimal('4.98'), 'Samoa'),
#  (2015, None, Decimal('4.98'), 'Solomon Islands'),
#  (2016, None, Decimal('4.98'), 'Solomon Islands'),
#  (2017, None, Decimal('4.98'), 'Solomon Islands'),
#  (2018, None, Decimal('4.98'), 'Solomon Islands'),
#  (2019, None, Decimal('4.98'), 'Solomon Islands'),
#  (2020, None, Decimal('4.98'), 'Solomon Islands'),
#  (2015, None, Decimal('4.98'), 'Tokelau'),
#  (2016, None, Decimal('4.98'), 'Tokelau'),
#  (2017, None, Decimal('4.98'), 'Tokelau'),
#  (2018, None, Decimal('4.98'), 'Tokelau'),
#  (2019, None, Decimal('4.98'), 'Tokelau'),
#  (2020, None, Decimal('4.98'), 'Tokelau'),
#  (2015, None, Decimal('4.98'), 'Tonga'),
#  (2016, None, Decimal('4.98'), 'Tonga'),
#  (2017, None, Decimal('4.98'), 'Tonga'),
#  (2018, Decimal('2.25'), Decimal('2.25'), 'Tonga'),
#  (2019, None, Decimal('4.98'), 'Tonga'),
#  (2020, None, Decimal('4.98'), 'Tonga'),
#  (2015, None, Decimal('4.98'), 'Tuvalu'),
#  (2016, Decimal('8.49'), Decimal('8.49'), 'Tuvalu'),
#  (2017, Decimal('26.55'), Decimal('26.55'), 'Tuvalu'),
#  (2018, None, Decimal('4.98'), 'Tuvalu'),
#  (2019, None, Decimal('4.98'), 'Tuvalu'),
#  (2020, None, Decimal('4.98'), 'Tuvalu'),
#  (2015, None, Decimal('4.98'), 'Vanuatu'),
#  (2016, None, Decimal('4.98'), 'Vanuatu'),
#  (2017, None, Decimal('4.98'), 'Vanuatu'),
#  (2018, None, Decimal('4.98'), 'Vanuatu'),
#  (2019, Decimal('5.44'), Decimal('5.44'), 'Vanuatu'),
#  (2020, Decimal('4.05'), Decimal('4.05'), 'Vanuatu'),
#  (2015, None, Decimal('4.98'), 'Wallis and Futuna Islands'),
#  (2016, None, Decimal('4.98'), 'Wallis and Futuna Islands'),
#  (2017, None, Decimal('4.98'), 'Wallis and Futuna Islands'),
#  (2018, None, Decimal('4.98'), 'Wallis and Futuna Islands'),
#  (2019, None, Decimal('4.98'), 'Wallis and Futuna Islands'),
#  (2020, None, Decimal('4.98'), 'Wallis and Futuna Islands'),
#  (2015, None, Decimal('33.65'), 'Angola'),
#  (2016, None, Decimal('33.65'), 'Angola'),
#  (2017, None, Decimal('33.65'), 'Angola'),
#  (2018, None, Decimal('33.65'), 'Angola'),
#  (2019, Decimal('16.50'), Decimal('16.50'), 'Angola'),
#  (2020, None, Decimal('33.65'), 'Angola'),
#  (2015, None, Decimal('33.65'), 'Benin'),
#  (2016, None, Decimal('33.65'), 'Benin'),
#  (2017, None, Decimal('33.65'), 'Benin'),
#  (2018, Decimal('1.47'), Decimal('1.47'), 'Benin'),
#  (2019, None, Decimal('33.65'), 'Benin'),
#  (2020, None, Decimal('33.65'), 'Benin'),
#  (2015, None, Decimal('33.65'), 'Botswana'),
#  (2016, None, Decimal('33.65'), 'Botswana'),
#  (2017, None, Decimal('33.65'), 'Botswana'),
#  (2018, None, Decimal('33.65'), 'Botswana'),
#  (2019, Decimal('20.09'), Decimal('20.09'), 'Botswana'),
#  (2020, Decimal('21.02'), Decimal('21.02'), 'Botswana'),
#  (2015, None, Decimal('33.65'), 'Burkina Faso'),
#  (2016, None, Decimal('33.65'), 'Burkina Faso'),
#  (2017, None, Decimal('33.65'), 'Burkina Faso'),
#  (2018, Decimal('4.69'), Decimal('4.69'), 'Burkina Faso'),
#  (2019, None, Decimal('33.65'), 'Burkina Faso'),
#  (2020, None, Decimal('33.65'), 'Burkina Faso'),
#  (2015, None, Decimal('33.65'), 'Burundi'),
#  (2016, None, Decimal('33.65'), 'Burundi'),
#  (2017, None, Decimal('33.65'), 'Burundi'),
#  (2018, None, Decimal('33.65'), 'Burundi'),
#  (2019, None, Decimal('33.65'), 'Burundi'),
#  (2020, Decimal('1.03'), Decimal('1.03'), 'Burundi'),
#  (2015, Decimal('31.31'), Decimal('31.31'), 'Cabo Verde'),
#  (2016, None, Decimal('33.65'), 'Cabo Verde'),
#  (2017, Decimal('12.24'), Decimal('12.24'), 'Cabo Verde'),
#  (2018, Decimal('12.17'), Decimal('12.17'), 'Cabo Verde'),
#  (2019, Decimal('11.29'), Decimal('11.29'), 'Cabo Verde'),
#  (2020, None, Decimal('33.65'), 'Cabo Verde'),
#  (2015, None, Decimal('33.65'), 'Cameroon'),
#  (2016, None, Decimal('33.65'), 'Cameroon'),
#  (2017, None, Decimal('33.65'), 'Cameroon'),
#  (2018, None, Decimal('33.65'), 'Cameroon'),
#  (2019, None, Decimal('33.65'), 'Cameroon'),
#  (2020, None, Decimal('33.65'), 'Cameroon'),
#  (2015, None, Decimal('33.65'), 'Central African Republic'),
#  (2016, None, Decimal('33.65'), 'Central African Republic'),
#  (2017, None, Decimal('33.65'), 'Central African Republic'),
#  (2018, None, Decimal('33.65'), 'Central African Republic'),
#  (2019, None, Decimal('33.65'), 'Central African Republic'),
#  (2020, None, Decimal('33.65'), 'Central African Republic'),
#  (2015, None, Decimal('33.65'), 'Chad'),
#  (2016, None, Decimal('33.65'), 'Chad'),
#  (2017, None, Decimal('33.65'), 'Chad'),
#  (2018, Decimal('1.13'), Decimal('1.13'), 'Chad'),
#  (2019, None, Decimal('33.65'), 'Chad'),
#  (2020, None, Decimal('33.65'), 'Chad'),
#  (2015, None, Decimal('33.65'), 'Comoros'),
#  (2016, None, Decimal('33.65'), 'Comoros'),
#  (2017, None, Decimal('33.65'), 'Comoros'),
#  (2018, None, Decimal('33.65'), 'Comoros'),
#  (2019, None, Decimal('33.65'), 'Comoros'),
#  (2015, None, Decimal('33.65'), 'Congo'),
#  (2016, None, Decimal('33.65'), 'Congo'),
#  (2017, None, Decimal('33.65'), 'Congo'),
#  (2018, None, Decimal('33.65'), 'Congo'),
#  (2019, None, Decimal('33.65'), 'Congo'),
#  (2020, None, Decimal('33.65'), 'Congo'),
#  (2015, None, Decimal('33.65'), "Côte d'Ivoire"),
#  (2016, None, Decimal('33.65'), "Côte d'Ivoire"),
#  (2017, None, Decimal('33.65'), "Côte d'Ivoire"),
#  (2018, None, Decimal('33.65'), "Côte d'Ivoire"),
#  (2019, None, Decimal('33.65'), "Côte d'Ivoire"),
#  (2020, None, Decimal('33.65'), "Côte d'Ivoire"),
#  (2015, None, Decimal('33.65'), 'Democratic Republic of the Congo'),
#  (2016, None, Decimal('33.65'), 'Democratic Republic of the Congo'),
#  (2017, None, Decimal('33.65'), 'Democratic Republic of the Congo'),
#  (2018, None, Decimal('33.65'), 'Democratic Republic of the Congo'),
#  (2019, None, Decimal('33.65'), 'Democratic Republic of the Congo'),
#  (2020, None, Decimal('33.65'), 'Democratic Republic of the Congo'),
#  (2015, None, Decimal('33.65'), 'Djibouti'),
#  (2016, None, Decimal('33.65'), 'Djibouti'),
#  (2017, Decimal('26.06'), Decimal('26.06'), 'Djibouti'),
#  (2018, None, Decimal('33.65'), 'Djibouti'),
#  (2019, None, Decimal('33.65'), 'Djibouti'),
#  (2020, None, Decimal('33.65'), 'Djibouti'),
#  (2015, None, Decimal('33.65'), 'Equatorial Guinea'),
#  (2016, None, Decimal('33.65'), 'Equatorial Guinea'),
#  (2017, None, Decimal('33.65'), 'Equatorial Guinea'),
#  (2015, None, Decimal('33.65'), 'Eritrea'),
#  (2016, None, Decimal('33.65'), 'Eritrea'),
#  (2015, None, Decimal('33.65'), 'Eswatini'),
#  (2016, Decimal('22.72'), Decimal('22.72'), 'Eswatini'),
#  (2017, None, Decimal('33.65'), 'Eswatini'),
#  (2018, None, Decimal('33.65'), 'Eswatini'),
#  (2019, None, Decimal('33.65'), 'Eswatini'),
#  (2020, None, Decimal('33.65'), 'Eswatini'),
#  (2015, None, Decimal('33.65'), 'Ethiopia'),
#  (2016, None, Decimal('33.65'), 'Ethiopia'),
#  (2017, None, Decimal('33.65'), 'Ethiopia'),
#  (2018, None, Decimal('33.65'), 'Ethiopia'),
#  (2019, None, Decimal('33.65'), 'Ethiopia'),
#  (2020, None, Decimal('33.65'), 'Ethiopia'),
#  (2015, None, Decimal('33.65'), 'Gabon'),
#  (2016, None, Decimal('33.65'), 'Gabon'),
#  (2017, None, Decimal('33.65'), 'Gabon'),
#  (2018, None, Decimal('33.65'), 'Gabon'),
#  (2019, None, Decimal('33.65'), 'Gabon'),
#  (2020, None, Decimal('33.65'), 'Gabon'),
#  (2015, None, Decimal('33.65'), 'Gambia'),
#  (2016, None, Decimal('33.65'), 'Gambia'),
#  (2017, None, Decimal('33.65'), 'Gambia'),
#  (2018, None, Decimal('33.65'), 'Gambia'),
#  (2019, None, Decimal('33.65'), 'Gambia'),
#  (2020, None, Decimal('33.65'), 'Gambia'),
#  (2015, Decimal('6.81'), Decimal('6.81'), 'Ghana'),
#  (2016, None, Decimal('33.65'), 'Ghana'),
#  (2017, Decimal('3.37'), Decimal('3.37'), 'Ghana'),
#  (2018, None, Decimal('33.65'), 'Ghana'),
#  (2019, None, Decimal('33.65'), 'Ghana'),
#  (2020, None, Decimal('33.65'), 'Ghana'),
#  (2015, None, Decimal('33.65'), 'Guinea'),
#  (2016, None, Decimal('33.65'), 'Guinea'),
#  (2017, None, Decimal('33.65'), 'Guinea'),
#  (2018, None, Decimal('33.65'), 'Guinea'),
#  (2019, Decimal('5.02'), Decimal('5.02'), 'Guinea'),
#  (2020, None, Decimal('33.65'), 'Guinea'),
#  (2015, None, Decimal('33.65'), 'Guinea-Bissau'),
#  (2016, None, Decimal('33.65'), 'Guinea-Bissau'),
#  (2017, None, Decimal('33.65'), 'Guinea-Bissau'),
#  (2018, Decimal('3.20'), Decimal('3.20'), 'Guinea-Bissau'),
#  (2019, None, Decimal('33.65'), 'Guinea-Bissau'),
#  (2020, None, Decimal('33.65'), 'Guinea-Bissau'),
#  (2015, None, Decimal('33.65'), 'Kenya'),
#  (2016, Decimal('2.76'), Decimal('2.76'), 'Kenya'),
#  (2017, None, Decimal('33.65'), 'Kenya'),
#  (2018, None, Decimal('33.65'), 'Kenya'),
#  (2019, Decimal('5.01'), Decimal('5.01'), 'Kenya'),
#  (2020, None, Decimal('33.65'), 'Kenya'),
#  (2015, None, Decimal('33.65'), 'Lesotho'),
#  (2016, None, Decimal('33.65'), 'Lesotho'),
#  (2017, None, Decimal('33.65'), 'Lesotho'),
#  (2018, None, Decimal('33.65'), 'Lesotho'),
#  (2019, Decimal('16.88'), Decimal('16.88'), 'Lesotho'),
#  (2020, None, Decimal('33.65'), 'Lesotho'),
#  (2015, None, Decimal('33.65'), 'Liberia'),
#  (2016, Decimal('3.08'), Decimal('3.08'), 'Liberia'),
#  (2017, Decimal('5.95'), Decimal('5.95'), 'Liberia'),
#  (2018, None, Decimal('33.65'), 'Liberia'),
#  (2019, None, Decimal('33.65'), 'Liberia'),
#  (2020, None, Decimal('33.65'), 'Liberia'),
#  (2015, Decimal('1.79'), Decimal('1.79'), 'Madagascar'),
#  (2016, None, Decimal('33.65'), 'Madagascar'),
#  (2017, None, Decimal('33.65'), 'Madagascar'),
#  (2018, None, Decimal('33.65'), 'Madagascar'),
#  (2019, None, Decimal('33.65'), 'Madagascar'),
#  (2020, None, Decimal('33.65'), 'Madagascar'),
#  (2015, None, Decimal('33.65'), 'Malawi'),
#  (2016, None, Decimal('33.65'), 'Malawi'),
#  (2017, Decimal('3.54'), Decimal('3.54'), 'Malawi'),
#  (2018, None, Decimal('33.65'), 'Malawi'),
#  (2019, None, Decimal('33.65'), 'Malawi'),
#  (2020, Decimal('0.91'), Decimal('0.91'), 'Malawi'),
#  (2015, Decimal('7.73'), Decimal('7.73'), 'Mali'),
#  (2016, Decimal('1.37'), Decimal('1.37'), 'Mali'),
#  (2017, Decimal('7.41'), Decimal('7.41'), 'Mali'),
#  (2018, Decimal('1.62'), Decimal('1.62'), 'Mali'),
#  (2019, None, Decimal('33.65'), 'Mali'),
#  (2020, Decimal('3.53'), Decimal('3.53'), 'Mali'),
#  (2015, None, Decimal('33.65'), 'Mauritania'),
#  (2016, None, Decimal('33.65'), 'Mauritania'),
#  (2017, Decimal('10.34'), Decimal('10.34'), 'Mauritania'),
#  (2018, None, Decimal('33.65'), 'Mauritania'),
#  (2019, Decimal('10.42'), Decimal('10.42'), 'Mauritania'),
#  (2020, None, Decimal('33.65'), 'Mauritania'),
#  (2015, Decimal('7.41'), Decimal('7.41'), 'Mauritius'),
#  (2016, Decimal('6.81'), Decimal('6.81'), 'Mauritius'),
#  (2017, Decimal('6.75'), Decimal('6.75'), 'Mauritius'),
#  (2018, Decimal('6.43'), Decimal('6.43'), 'Mauritius'),
#  (2019, Decimal('6.33'), Decimal('6.33'), 'Mauritius'),
#  (2020, Decimal('8.63'), Decimal('8.63'), 'Mauritius'),
#  (2015, None, Decimal('33.65'), 'Mayotte'),
#  (2016, None, Decimal('33.65'), 'Mayotte'),
#  (2017, None, Decimal('33.65'), 'Mayotte'),
#  (2018, None, Decimal('33.65'), 'Mayotte'),
#  (2019, None, Decimal('33.65'), 'Mayotte'),
#  (2020, None, Decimal('33.65'), 'Mayotte'),
#  (2015, Decimal('3.43'), Decimal('3.43'), 'Mozambique'),
#  (2016, None, Decimal('33.65'), 'Mozambique'),
#  (2017, None, Decimal('33.65'), 'Mozambique'),
#  (2018, None, Decimal('33.65'), 'Mozambique'),
#  (2019, None, Decimal('33.65'), 'Mozambique'),
#  (2020, None, Decimal('33.65'), 'Mozambique'),
#  (2015, None, Decimal('33.65'), 'Namibia'),
#  (2016, Decimal('23.35'), Decimal('23.35'), 'Namibia'),
#  (2017, None, Decimal('33.65'), 'Namibia'),
#  (2018, Decimal('19.88'), Decimal('19.88'), 'Namibia'),
#  (2019, None, Decimal('33.65'), 'Namibia'),
#  (2020, None, Decimal('33.65'), 'Namibia'),
#  (2015, None, Decimal('33.65'), 'Niger'),
#  (2016, None, Decimal('33.65'), 'Niger'),
#  (2017, Decimal('7.77'), Decimal('7.77'), 'Niger'),
#  (2018, None, Decimal('33.65'), 'Niger'),
#  (2019, None, Decimal('33.65'), 'Niger'),
#  (2020, None, Decimal('33.65'), 'Niger'),
#  (2015, Decimal('4.31'), Decimal('4.31'), 'Nigeria'),
#  (2016, Decimal('7.06'), Decimal('7.06'), 'Nigeria'),
#  (2017, Decimal('8.39'), Decimal('8.39'), 'Nigeria'),
#  (2018, None, Decimal('33.65'), 'Nigeria'),
#  (2019, Decimal('10.70'), Decimal('10.70'), 'Nigeria'),
#  (2020, None, Decimal('33.65'), 'Nigeria'),
#  (2015, None, Decimal('33.65'), 'Réunion'),
#  (2016, None, Decimal('33.65'), 'Réunion'),
#  (2017, None, Decimal('33.65'), 'Réunion'),
#  (2018, None, Decimal('33.65'), 'Réunion'),
#  (2019, None, Decimal('33.65'), 'Réunion'),
#  (2020, None, Decimal('33.65'), 'Réunion'),
#  (2015, None, Decimal('33.65'), 'Rwanda'),
#  (2016, None, Decimal('33.65'), 'Rwanda'),
#  (2017, Decimal('11.88'), Decimal('11.88'), 'Rwanda'),
#  (2018, Decimal('10.76'), Decimal('10.76'), 'Rwanda'),
#  (2019, Decimal('11.24'), Decimal('11.24'), 'Rwanda'),
#  (2020, Decimal('11.83'), Decimal('11.83'), 'Rwanda'),
#  (2015, None, Decimal('33.65'), 'Saint Helena'),
#  (2016, None, Decimal('33.65'), 'Saint Helena'),
#  (2017, None, Decimal('33.65'), 'Saint Helena'),
#  (2018, None, Decimal('33.65'), 'Saint Helena'),
#  (2019, None, Decimal('33.65'), 'Saint Helena'),
#  (2020, None, Decimal('33.65'), 'Saint Helena'),
#  (2015, None, Decimal('33.65'), 'Sao Tome and Principe'),
#  (2016, None, Decimal('33.65'), 'Sao Tome and Principe'),
#  (2017, None, Decimal('33.65'), 'Sao Tome and Principe'),
#  (2018, None, Decimal('33.65'), 'Sao Tome and Principe'),
#  (2019, None, Decimal('33.65'), 'Sao Tome and Principe'),
#  (2020, None, Decimal('33.65'), 'Sao Tome and Principe'),
#  (2015, Decimal('6.76'), Decimal('6.76'), 'Senegal'),
#  (2016, Decimal('4.46'), Decimal('4.46'), 'Senegal'),
#  (2017, Decimal('4.08'), Decimal('4.08'), 'Senegal'),
#  (2018, Decimal('3.57'), Decimal('3.57'), 'Senegal'),
#  (2019, Decimal('2.86'), Decimal('2.86'), 'Senegal'),
#  (2020, None, Decimal('33.65'), 'Senegal'),
#  (2015, Decimal('4.15'), Decimal('4.15'), 'Seychelles'),
#  (2016, Decimal('3.96'), Decimal('3.96'), 'Seychelles'),
#  (2017, Decimal('3.71'), Decimal('3.71'), 'Seychelles'),
#  (2018, Decimal('3.53'), Decimal('3.53'), 'Seychelles'),
#  (2019, Decimal('2.97'), Decimal('2.97'), 'Seychelles'),
#  (2015, None, Decimal('33.65'), 'Sierra Leone'),
#  (2016, None, Decimal('33.65'), 'Sierra Leone'),
#  (2017, None, Decimal('33.65'), 'Sierra Leone'),
#  (2018, Decimal('3.19'), Decimal('3.19'), 'Sierra Leone'),
#  (2019, None, Decimal('33.65'), 'Sierra Leone'),
#  (2020, None, Decimal('33.65'), 'Sierra Leone'),
#  (2015, None, Decimal('33.65'), 'Somalia'),
#  (2016, None, Decimal('33.65'), 'Somalia'),
#  (2017, None, Decimal('33.65'), 'Somalia'),
#  (2018, None, Decimal('33.65'), 'Somalia'),
#  (2019, Decimal('18.83'), Decimal('18.83'), 'Somalia'),
#  (2020, None, Decimal('33.65'), 'Somalia'),
#  (2015, Decimal('22.87'), Decimal('22.87'), 'South Africa'),
#  (2016, Decimal('24.02'), Decimal('24.02'), 'South Africa'),
#  (2017, Decimal('23.99'), Decimal('23.99'), 'South Africa'),
#  (2018, Decimal('24.22'), Decimal('24.22'), 'South Africa'),
#  (2019, Decimal('25.54'), Decimal('25.54'), 'South Africa'),
#  (2020, Decimal('24.34'), Decimal('24.34'), 'South Africa'),
#  (2015, None, Decimal('33.65'), 'South Sudan'),
#  (2016, None, Decimal('33.65'), 'South Sudan'),
#  (2017, None, Decimal('33.65'), 'South Sudan'),
#  (2018, None, Decimal('33.65'), 'South Sudan'),
#  (2019, None, Decimal('33.65'), 'South Sudan'),
#  (2020, None, Decimal('33.65'), 'South Sudan'),
#  (2015, Decimal('2.20'), Decimal('2.20'), 'Togo'),
#  (2016, None, Decimal('33.65'), 'Togo'),
#  (2017, Decimal('3.74'), Decimal('3.74'), 'Togo'),
#  (2018, None, Decimal('33.65'), 'Togo'),
#  (2019, None, Decimal('33.65'), 'Togo'),
#  (2020, None, Decimal('33.65'), 'Togo'),
#  (2015, None, Decimal('33.65'), 'Uganda'),
#  (2016, None, Decimal('33.65'), 'Uganda'),
#  (2017, Decimal('3.64'), Decimal('3.64'), 'Uganda'),
#  (2018, None, Decimal('33.65'), 'Uganda'),
#  (2019, None, Decimal('33.65'), 'Uganda'),
#  (2020, None, Decimal('33.65'), 'Uganda'),
#  (2015, None, Decimal('33.65'), 'United Republic of Tanzania'),
#  (2016, None, Decimal('33.65'), 'United Republic of Tanzania'),
#  (2017, None, Decimal('33.65'), 'United Republic of Tanzania'),
#  (2018, None, Decimal('33.65'), 'United Republic of Tanzania'),
#  (2019, None, Decimal('33.65'), 'United Republic of Tanzania'),
#  (2020, None, Decimal('33.65'), 'United Republic of Tanzania'),
#  (2015, None, Decimal('33.65'), 'Zambia'),
#  (2016, None, Decimal('33.65'), 'Zambia'),
#  (2017, Decimal('8.52'), Decimal('8.52'), 'Zambia'),
#  (2018, Decimal('5.03'), Decimal('5.03'), 'Zambia'),
#  (2019, Decimal('5.54'), Decimal('5.54'), 'Zambia'),
#  (2020, Decimal('6.03'), Decimal('6.03'), 'Zambia'),
#  (2015, None, Decimal('33.65'), 'Zimbabwe'),
#  (2016, None, Decimal('33.65'), 'Zimbabwe'),
#  (2017, None, Decimal('33.65'), 'Zimbabwe'),
#  (2018, None, Decimal('33.65'), 'Zimbabwe'),
#  (2019, Decimal('7.37'), Decimal('7.37'), 'Zimbabwe'),
#  (2020, None, Decimal('33.65'), 'Zimbabwe'),
#  (2015, None, Decimal('24.23'), 'Anguilla'),
#  (2016, None, Decimal('24.23'), 'Anguilla'),
#  (2017, None, Decimal('24.23'), 'Anguilla'),
#  (2015, None, Decimal('24.23'), 'Antigua and Barbuda'),
#  (2016, None, Decimal('24.23'), 'Antigua and Barbuda'),
#  (2017, None, Decimal('24.23'), 'Antigua and Barbuda'),
#  (2015, None, Decimal('24.23'), 'Argentina'),
#  (2016, None, Decimal('24.23'), 'Argentina'),
#  (2017, Decimal('8.35'), Decimal('8.35'), 'Argentina'),
#  (2018, Decimal('9.22'), Decimal('9.22'), 'Argentina'),
#  (2019, Decimal('9.84'), Decimal('9.84'), 'Argentina'),
#  (2020, Decimal('11.46'), Decimal('11.46'), 'Argentina'),
#  (2015, None, Decimal('24.23'), 'Aruba'),
#  (2016, None, Decimal('24.23'), 'Aruba'),
#  (2015, None, Decimal('24.23'), 'Bahamas'),
#  (2016, None, Decimal('24.23'), 'Bahamas'),
#  (2017, None, Decimal('24.23'), 'Bahamas'),
#  (2018, None, Decimal('24.23'), 'Bahamas'),
#  (2019, None, Decimal('24.23'), 'Bahamas'),
#  (2015, Decimal('9.80'), Decimal('9.80'), 'Barbados'),
#  (2016, Decimal('8.25'), Decimal('8.25'), 'Barbados'),
#  (2017, Decimal('8.62'), Decimal('8.62'), 'Barbados'),
#  (2018, Decimal('8.32'), Decimal('8.32'), 'Barbados'),
#  (2019, Decimal('8.41'), Decimal('8.41'), 'Barbados'),
#  (2020, None, Decimal('24.23'), 'Barbados'),
#  (2015, Decimal('7.58'), Decimal('7.58'), 'Belize'),
#  (2016, Decimal('7.00'), Decimal('7.00'), 'Belize'),
#  (2017, Decimal('6.60'), Decimal('6.60'), 'Belize'),
#  (2018, None, Decimal('24.23'), 'Belize'),
#  (2019, Decimal('9.05'), Decimal('9.05'), 'Belize'),
#  (2020, None, Decimal('24.23'), 'Belize'),
#  (2015, None, Decimal('24.23'), 'Bolivia (Plurinational State of)'),
#  (2016, None, Decimal('24.23'), 'Bolivia (Plurinational State of)'),
#  (2017, None, Decimal('24.23'), 'Bolivia (Plurinational State of)'),
#  (2018, None, Decimal('24.23'), 'Bolivia (Plurinational State of)'),
#  (2019, None, Decimal('24.23'), 'Bolivia (Plurinational State of)'),
#  (2020, None, Decimal('24.23'), 'Bolivia (Plurinational State of)'),
#  (2015, Decimal('8.54'), Decimal('8.54'), 'Brazil'),
#  (2016, Decimal('11.58'), Decimal('11.58'), 'Brazil'),
#  (2017, Decimal('12.79'), Decimal('12.79'), 'Brazil'),
#  (2018, Decimal('12.33'), Decimal('12.33'), 'Brazil'),
#  (2019, Decimal('11.94'), Decimal('11.94'), 'Brazil'),
#  (2020, Decimal('13.70'), Decimal('13.70'), 'Brazil'),
#  (2015, None, Decimal('24.23'), 'British Virgin Islands'),
#  (2016, None, Decimal('24.23'), 'British Virgin Islands'),
#  (2017, None, Decimal('24.23'), 'British Virgin Islands'),
#  (2018, None, Decimal('24.23'), 'British Virgin Islands'),
#  (2019, None, Decimal('24.23'), 'British Virgin Islands'),
#  (2020, None, Decimal('24.23'), 'British Virgin Islands'),
#  (2015, Decimal('4.24'), Decimal('4.24'), 'Cayman Islands'),
#  (2016, None, Decimal('24.23'), 'Cayman Islands'),
#  (2015, Decimal('6.49'), Decimal('6.49'), 'Chile'),
#  (2016, Decimal('6.73'), Decimal('6.73'), 'Chile'),
#  (2017, Decimal('6.95'), Decimal('6.95'), 'Chile'),
#  (2018, Decimal('7.21'), Decimal('7.21'), 'Chile'),
#  (2019, Decimal('7.27'), Decimal('7.27'), 'Chile'),
#  (2020, Decimal('10.94'), Decimal('10.94'), 'Chile'),
#  (2015, Decimal('8.57'), Decimal('8.57'), 'Colombia'),
#  (2016, Decimal('8.92'), Decimal('8.92'), 'Colombia'),
#  (2017, Decimal('9.09'), Decimal('9.09'), 'Colombia'),
#  (2018, Decimal('9.36'), Decimal('9.36'), 'Colombia'),
#  (2019, Decimal('10.28'), Decimal('10.28'), 'Colombia'),
#  (2020, Decimal('15.98'), Decimal('15.98'), 'Colombia'),
#  (2015, Decimal('8.42'), Decimal('8.42'), 'Costa Rica'),
#  (2016, Decimal('8.09'), Decimal('8.09'), 'Costa Rica'),
#  (2017, Decimal('7.73'), Decimal('7.73'), 'Costa Rica'),
#  (2018, Decimal('9.01'), Decimal('9.01'), 'Costa Rica'),
#  (2019, Decimal('10.81'), Decimal('10.81'), 'Costa Rica'),
#  (2020, Decimal('16.43'), Decimal('16.43'), 'Costa Rica'),
#  (2015, Decimal('2.40'), Decimal('2.40'), 'Cuba'),
#  (2016, Decimal('2.00'), Decimal('2.00'), 'Cuba'),
#  (2017, Decimal('1.70'), Decimal('1.70'), 'Cuba'),
#  (2018, Decimal('1.70'), Decimal('1.70'), 'Cuba'),
#  (2019, None, Decimal('24.23'), 'Cuba'),
#  (2020, None, Decimal('24.23'), 'Cuba'),
#  (2015, None, Decimal('24.23'), 'Curaçao'),
#  (2016, None, Decimal('24.23'), 'Curaçao'),
#  (2017, None, Decimal('24.23'), 'Curaçao'),
#  (2015, None, Decimal('24.23'), 'Dominica'),
#  (2016, None, Decimal('24.23'), 'Dominica'),
#  (2017, None, Decimal('24.23'), 'Dominica'),
#  (2015, Decimal('7.61'), Decimal('7.61'), 'Dominican Republic'),
#  (2016, Decimal('7.28'), Decimal('7.28'), 'Dominican Republic'),
#  (2017, Decimal('5.83'), Decimal('5.83'), 'Dominican Republic'),
#  (2018, Decimal('5.86'), Decimal('5.86'), 'Dominican Republic'),
#  (2019, Decimal('6.18'), Decimal('6.18'), 'Dominican Republic'),
#  (2020, Decimal('6.13'), Decimal('6.13'), 'Dominican Republic'),
#  (2015, Decimal('3.62'), Decimal('3.62'), 'Ecuador'),
#  (2016, Decimal('4.60'), Decimal('4.60'), 'Ecuador'),
#  (2017, Decimal('3.84'), Decimal('3.84'), 'Ecuador'),
#  (2018, Decimal('3.53'), Decimal('3.53'), 'Ecuador'),
#  (2019, Decimal('3.81'), Decimal('3.81'), 'Ecuador'),
#  (2020, Decimal('6.11'), Decimal('6.11'), 'Ecuador'),
#  (2015, Decimal('4.00'), Decimal('4.00'), 'El Salvador'),
#  (2016, Decimal('4.42'), Decimal('4.42'), 'El Salvador'),
#  (2017, Decimal('4.39'), Decimal('4.39'), 'El Salvador'),
#  (2018, Decimal('4.01'), Decimal('4.01'), 'El Salvador'),
#  (2019, Decimal('4.17'), Decimal('4.17'), 'El Salvador'),
#  (2020, Decimal('5.01'), Decimal('5.01'), 'El Salvador'),
#  (2015, None, Decimal('24.23'), 'Falkland Islands (Malvinas)'),
#  (2016, None, Decimal('24.23'), 'Falkland Islands (Malvinas)'),
#  (2017, None, Decimal('24.23'), 'Falkland Islands (Malvinas)'),
#  (2018, None, Decimal('24.23'), 'Falkland Islands (Malvinas)'),
#  (2019, None, Decimal('24.23'), 'Falkland Islands (Malvinas)'),
#  (2020, None, Decimal('24.23'), 'Falkland Islands (Malvinas)'),
#  (2015, None, Decimal('24.23'), 'French Guiana'),
#  (2016, None, Decimal('24.23'), 'French Guiana'),
#  (2017, None, Decimal('24.23'), 'French Guiana'),
#  (2018, None, Decimal('24.23'), 'French Guiana'),
#  (2019, None, Decimal('24.23'), 'French Guiana'),
#  (2020, None, Decimal('24.23'), 'French Guiana'),
#  (2015, Decimal('22.90'), Decimal('22.90'), 'Grenada'),
#  (2016, None, Decimal('24.23'), 'Grenada'),
#  (2017, None, Decimal('24.23'), 'Grenada'),
#  (2015, None, Decimal('24.23'), 'Guadeloupe'),
#  (2016, None, Decimal('24.23'), 'Guadeloupe'),
#  (2017, None, Decimal('24.23'), 'Guadeloupe'),
#  (2018, None, Decimal('24.23'), 'Guadeloupe'),
#  (2019, None, Decimal('24.23'), 'Guadeloupe'),
#  (2020, None, Decimal('24.23'), 'Guadeloupe'),
#  (2015, Decimal('2.51'), Decimal('2.51'), 'Guatemala'),
#  (2016, Decimal('2.58'), Decimal('2.58'), 'Guatemala'),
#  (2017, Decimal('2.46'), Decimal('2.46'), 'Guatemala'),
#  (2018, Decimal('2.28'), Decimal('2.28'), 'Guatemala'),
#  (2019, Decimal('2.19'), Decimal('2.19'), 'Guatemala'),
#  (2020, None, Decimal('24.23'), 'Guatemala'),
#  (2015, None, Decimal('24.23'), 'Guyana'),
#  (2016, None, Decimal('24.23'), 'Guyana'),
#  (2017, None, Decimal('24.23'), 'Guyana'),
#  (2018, Decimal('14.02'), Decimal('14.02'), 'Guyana'),
#  (2019, Decimal('13.52'), Decimal('13.52'), 'Guyana'),
#  (2020, None, Decimal('24.23'), 'Guyana'),
#  (2015, None, Decimal('24.23'), 'Haiti'),
#  (2016, None, Decimal('24.23'), 'Haiti'),
#  (2017, None, Decimal('24.23'), 'Haiti'),
#  (2018, None, Decimal('24.23'), 'Haiti'),
#  (2019, None, Decimal('24.23'), 'Haiti'),
#  (2020, None, Decimal('24.23'), 'Haiti'),
#  (2015, Decimal('6.15'), Decimal('6.15'), 'Honduras'),
#  (2016, Decimal('6.73'), Decimal('6.73'), 'Honduras'),
#  (2017, Decimal('5.53'), Decimal('5.53'), 'Honduras'),
#  (2018, Decimal('5.62'), Decimal('5.62'), 'Honduras'),
#  (2019, Decimal('5.55'), Decimal('5.55'), 'Honduras'),
#  (2020, Decimal('10.68'), Decimal('10.68'), 'Honduras'),
#  (2015, Decimal('13.51'), Decimal('13.51'), 'Jamaica'),
#  (2016, Decimal('8.63'), Decimal('8.63'), 'Jamaica'),
#  (2017, Decimal('7.40'), Decimal('7.40'), 'Jamaica'),
#  (2018, Decimal('5.47'), Decimal('5.47'), 'Jamaica'),
#  (2019, Decimal('4.99'), Decimal('4.99'), 'Jamaica'),
#  (2020, Decimal('6.50'), Decimal('6.50'), 'Jamaica'),
#  (2015, None, Decimal('24.23'), 'Martinique'),
#  (2016, None, Decimal('24.23'), 'Martinique'),
#  (2017, None, Decimal('24.23'), 'Martinique'),
#  (2018, None, Decimal('24.23'), 'Martinique'),
#  (2019, None, Decimal('24.23'), 'Martinique'),
#  (2020, None, Decimal('24.23'), 'Martinique'),
#  (2015, Decimal('4.31'), Decimal('4.31'), 'Mexico'),
#  (2016, Decimal('3.85'), Decimal('3.85'), 'Mexico'),
#  (2017, Decimal('3.42'), Decimal('3.42'), 'Mexico'),
#  (2018, Decimal('3.27'), Decimal('3.27'), 'Mexico'),
#  (2019, Decimal('3.48'), Decimal('3.48'), 'Mexico'),
#  (2020, Decimal('4.44'), Decimal('4.44'), 'Mexico'),
#  (2015, None, Decimal('24.23'), 'Montserrat'),
#  (2016, None, Decimal('24.23'), 'Montserrat'),
#  (2017, None, Decimal('24.23'), 'Montserrat'),
#  (2018, None, Decimal('24.23'), 'Montserrat'),
#  (2019, None, Decimal('24.23'), 'Montserrat'),
#  (2020, None, Decimal('24.23'), 'Montserrat'),
#  (2015, Decimal('4.70'), Decimal('4.70'), 'Nicaragua'),
#  (2016, Decimal('3.90'), Decimal('3.90'), 'Nicaragua'),
#  (2017, Decimal('3.30'), Decimal('3.30'), 'Nicaragua'),
#  (2018, Decimal('5.20'), Decimal('5.20'), 'Nicaragua'),
#  (2019, None, Decimal('24.23'), 'Nicaragua'),
#  (2020, None, Decimal('24.23'), 'Nicaragua'),
#  (2015, Decimal('4.40'), Decimal('4.40'), 'Panama'),
#  (2016, Decimal('4.84'), Decimal('4.84'), 'Panama'),
#  (2017, Decimal('5.46'), Decimal('5.46'), 'Panama'),
#  (2018, Decimal('5.31'), Decimal('5.31'), 'Panama'),
#  (2019, Decimal('6.41'), Decimal('6.41'), 'Panama'),
#  (2020, Decimal('18.55'), Decimal('18.55'), 'Panama'),
#  (2015, Decimal('4.56'), Decimal('4.56'), 'Paraguay'),
#  (2016, Decimal('5.25'), Decimal('5.25'), 'Paraguay'),
#  (2017, Decimal('4.61'), Decimal('4.61'), 'Paraguay'),
#  (2018, Decimal('6.22'), Decimal('6.22'), 'Paraguay'),
#  (2019, Decimal('6.59'), Decimal('6.59'), 'Paraguay'),
#  (2020, Decimal('7.55'), Decimal('7.55'), 'Paraguay'),
#  (2015, Decimal('3.27'), Decimal('3.27'), 'Peru'),
#  (2016, Decimal('3.74'), Decimal('3.74'), 'Peru'),
#  (2017, Decimal('3.69'), Decimal('3.69'), 'Peru'),
#  (2018, Decimal('3.49'), Decimal('3.49'), 'Peru'),
#  (2019, Decimal('3.38'), Decimal('3.38'), 'Peru'),
#  (2020, Decimal('7.18'), Decimal('7.18'), 'Peru'),
#  (2015, Decimal('12.00'), Decimal('12.00'), 'Puerto Rico'),
#  (2016, Decimal('11.80'), Decimal('11.80'), 'Puerto Rico'),
#  (2017, Decimal('10.80'), Decimal('10.80'), 'Puerto Rico'),
#  (2018, Decimal('9.20'), Decimal('9.20'), 'Puerto Rico'),
#  (2019, Decimal('8.30'), Decimal('8.30'), 'Puerto Rico'),
#  (2020, None, Decimal('24.23'), 'Puerto Rico'),
#  (2015, None, Decimal('24.23'), 'Saint Barthélemy'),
#  (2016, None, Decimal('24.23'), 'Saint Barthélemy'),
#  (2017, None, Decimal('24.23'), 'Saint Barthélemy'),
#  (2018, None, Decimal('24.23'), 'Saint Barthélemy'),
#  (2019, None, Decimal('24.23'), 'Saint Barthélemy'),
#  (2020, None, Decimal('24.23'), 'Saint Barthélemy'),
#  (2015, None, Decimal('24.23'), 'Saint Kitts and Nevis'),
#  (2016, None, Decimal('24.23'), 'Saint Kitts and Nevis'),
#  (2017, None, Decimal('24.23'), 'Saint Kitts and Nevis'),
#  (2015, None, Decimal('24.23'), 'Saint Lucia'),
#  (2016, None, Decimal('24.23'), 'Saint Lucia'),
#  (2017, None, Decimal('24.23'), 'Saint Lucia'),
#  (2018, None, Decimal('24.23'), 'Saint Lucia'),
#  (2019, None, Decimal('24.23'), 'Saint Lucia'),
#  (2020, None, Decimal('24.23'), 'Saint Lucia'),
#  (2015, None, Decimal('24.23'), 'Saint Martin (French Part)'),
#  (2016, None, Decimal('24.23'), 'Saint Martin (French Part)'),
#  (2017, None, Decimal('24.23'), 'Saint Martin (French Part)'),
#  (2018, None, Decimal('24.23'), 'Saint Martin (French Part)'),
#  (2019, None, Decimal('24.23'), 'Saint Martin (French Part)'),
#  (2020, None, Decimal('24.23'), 'Saint Martin (French Part)'),
#  (2015, None, Decimal('24.23'), 'Saint Vincent and the Grenadines'),
#  (2016, None, Decimal('24.23'), 'Saint Vincent and the Grenadines'),
#  (2017, None, Decimal('24.23'), 'Saint Vincent and the Grenadines'),
#  (2018, None, Decimal('24.23'), 'Saint Vincent and the Grenadines'),
#  (2015, None, Decimal('24.23'), 'Sint Maarten (Dutch part)'),
#  (2016, None, Decimal('24.23'), 'Sint Maarten (Dutch part)'),
#  (2017, None, Decimal('24.23'), 'Sint Maarten (Dutch part)'),
#  (2015, Decimal('7.22'), Decimal('7.22'), 'Suriname'),
#  (2016, Decimal('7.92'), Decimal('7.92'), 'Suriname'),
#  (2017, None, Decimal('24.23'), 'Suriname'),
#  (2018, None, Decimal('24.23'), 'Suriname'),
#  (2019, None, Decimal('24.23'), 'Suriname'),
#  (2020, None, Decimal('24.23'), 'Suriname'),
#  (2015, Decimal('2.43'), Decimal('2.43'), 'Trinidad and Tobago'),
#  (2016, Decimal('3.21'), Decimal('3.21'), 'Trinidad and Tobago'),
#  (2017, None, Decimal('24.23'), 'Trinidad and Tobago'),
#  (2018, None, Decimal('24.23'), 'Trinidad and Tobago'),
#  (2019, Decimal('3.52'), Decimal('3.52'), 'Trinidad and Tobago'),
#  (2020, Decimal('4.21'), Decimal('4.21'), 'Trinidad and Tobago'),
#  (2015, None, Decimal('24.23'), 'Turks and Caicos Islands'),
#  (2016, None, Decimal('24.23'), 'Turks and Caicos Islands'),
#  (2017, None, Decimal('24.23'), 'Turks and Caicos Islands'),
#  (2018, None, Decimal('24.23'), 'Turks and Caicos Islands'),
#  (2015, None, Decimal('24.23'), 'United States Virgin Islands'),
#  (2016, None, Decimal('24.23'), 'United States Virgin Islands'),
#  (2017, None, Decimal('24.23'), 'United States Virgin Islands'),
#  (2018, None, Decimal('24.23'), 'United States Virgin Islands'),
#  (2019, None, Decimal('24.23'), 'United States Virgin Islands'),
#  (2020, None, Decimal('24.23'), 'United States Virgin Islands'),
#  (2015, Decimal('7.49'), Decimal('7.49'), 'Uruguay'),
#  (2016, Decimal('7.84'), Decimal('7.84'), 'Uruguay'),
#  (2017, Decimal('7.89'), Decimal('7.89'), 'Uruguay'),
#  (2018, Decimal('8.34'), Decimal('8.34'), 'Uruguay'),
#  (2019, Decimal('8.73'), Decimal('8.73'), 'Uruguay'),
#  (2020, Decimal('10.33'), Decimal('10.33'), 'Uruguay'),
#  (2015, None, Decimal('24.23'), 'Venezuela (Bolivarian Republic of)'),
#  (2016, None, Decimal('24.23'), 'Venezuela (Bolivarian Republic of)'),
#  (2017, None, Decimal('24.23'), 'Venezuela (Bolivarian Republic of)'),
#  (2018, None, Decimal('24.23'), 'Venezuela (Bolivarian Republic of)'),
#  (2019, None, Decimal('24.23'), 'Venezuela (Bolivarian Republic of)'),
#  (2020, None, Decimal('24.23'), 'Venezuela (Bolivarian Republic of)'),
#  (2015, None, Decimal('24.43'), 'Bermuda'),
#  (2016, None, Decimal('24.43'), 'Bermuda'),
#  (2017, None, Decimal('24.43'), 'Bermuda'),
#  (2018, None, Decimal('24.43'), 'Bermuda'),
#  (2019, None, Decimal('24.43'), 'Bermuda'),
#  (2020, None, Decimal('24.43'), 'Bermuda'),
#  (2015, Decimal('6.91'), Decimal('6.91'), 'Canada'),
#  (2016, Decimal('7.00'), Decimal('7.00'), 'Canada'),
#  (2017, Decimal('6.34'), Decimal('6.34'), 'Canada'),
#  (2018, Decimal('5.83'), Decimal('5.83'), 'Canada'),
#  (2019, Decimal('5.66'), Decimal('5.66'), 'Canada'),
#  (2020, Decimal('9.46'), Decimal('9.46'), 'Canada'),
#  (2015, Decimal('9.10'), Decimal('9.10'), 'Greenland'),
#  (2016, None, Decimal('24.43'), 'Greenland'),
#  (2017, None, Decimal('24.43'), 'Greenland'),
#  (2018, None, Decimal('24.43'), 'Greenland'),
#  (2019, None, Decimal('24.43'), 'Greenland'),
#  (2020, None, Decimal('24.43'), 'Greenland'),
#  (2015, None, Decimal('24.43'), 'Saint Pierre and Miquelon'),
#  (2016, None, Decimal('24.43'), 'Saint Pierre and Miquelon'),
#  (2017, None, Decimal('24.43'), 'Saint Pierre and Miquelon'),
#  (2018, None, Decimal('24.43'), 'Saint Pierre and Miquelon'),
#  (2019, None, Decimal('24.43'), 'Saint Pierre and Miquelon'),
#  (2020, None, Decimal('24.43'), 'Saint Pierre and Miquelon'),
#  (2015, None, Decimal('24.43'), 'United States of America'),
#  (2016, None, Decimal('24.43'), 'United States of America'),
#  (2017, None, Decimal('24.43'), 'United States of America'),
#  (2018, None, Decimal('24.43'), 'United States of America'),
#  (2019, None, Decimal('24.43'), 'United States of America'),
#  (2020, None, Decimal('24.43'), 'United States of America'),
#  (2015, None, Decimal('22.64'), 'Brunei Darussalam'),
#  (2016, None, Decimal('22.64'), 'Brunei Darussalam'),
#  (2017, Decimal('9.32'), Decimal('9.32'), 'Brunei Darussalam'),
#  (2018, Decimal('8.70'), Decimal('8.70'), 'Brunei Darussalam'),
#  (2019, Decimal('6.60'), Decimal('6.60'), 'Brunei Darussalam'),
#  (2020, Decimal('7.41'), Decimal('7.41'), 'Brunei Darussalam'),
#  (2015, Decimal('0.39'), Decimal('0.39'), 'Cambodia'),
#  (2016, Decimal('0.72'), Decimal('0.72'), 'Cambodia'),
#  (2017, Decimal('0.14'), Decimal('0.14'), 'Cambodia'),
#  (2018, None, Decimal('22.64'), 'Cambodia'),
#  (2019, Decimal('0.50'), Decimal('0.50'), 'Cambodia'),
#  (2020, None, Decimal('22.64'), 'Cambodia'),
#  (2015, None, Decimal('22.64'), 'China'),
#  (2016, None, Decimal('22.64'), 'China'),
#  (2017, Decimal('3.90'), Decimal('3.90'), 'China'),
#  (2018, Decimal('4.93'), Decimal('4.93'), 'China'),
#  (2019, Decimal('5.15'), Decimal('5.15'), 'China'),
#  (2020, Decimal('5.61'), Decimal('5.61'), 'China'),
#  (2015, None, Decimal('22.64'), "Democratic People's Republic of Korea"),
#  (2016, None, Decimal('22.64'), "Democratic People's Republic of Korea"),
#  (2017, None, Decimal('22.64'), "Democratic People's Republic of Korea"),
#  (2018, None, Decimal('22.64'), "Democratic People's Republic of Korea"),
#  (2019, None, Decimal('22.64'), "Democratic People's Republic of Korea"),
#  (2020, None, Decimal('22.64'), "Democratic People's Republic of Korea"),
#  (2015, Decimal('4.51'), Decimal('4.51'), 'Indonesia'),
#  (2016, Decimal('4.30'), Decimal('4.30'), 'Indonesia'),
#  (2017, Decimal('3.78'), Decimal('3.78'), 'Indonesia'),
#  (2018, Decimal('4.39'), Decimal('4.39'), 'Indonesia'),
#  (2019, Decimal('3.59'), Decimal('3.59'), 'Indonesia'),
#  (2020, Decimal('4.25'), Decimal('4.25'), 'Indonesia'),
#  (2015, Decimal('3.39'), Decimal('3.39'), 'Japan'),
#  (2016, Decimal('3.13'), Decimal('3.13'), 'Japan'),
#  (2017, Decimal('2.82'), Decimal('2.82'), 'Japan'),
#  (2018, Decimal('2.47'), Decimal('2.47'), 'Japan'),
#  (2019, Decimal('2.35'), Decimal('2.35'), 'Japan'),
#  (2020, Decimal('2.81'), Decimal('2.81'), 'Japan'),
#  (2015, None, Decimal('22.64'), "Lao People's Democratic Republic"),
#  (2016, None, Decimal('22.64'), "Lao People's Democratic Republic"),
#  (2017, None, Decimal('22.64'), "Lao People's Democratic Republic"),
#  (2018, None, Decimal('22.64'), "Lao People's Democratic Republic"),
#  (2019, None, Decimal('22.64'), "Lao People's Democratic Republic"),
#  (2020, None, Decimal('22.64'), "Lao People's Democratic Republic"),
#  (2015, Decimal('3.10'), Decimal('3.10'), 'Malaysia'),
#  (2016, Decimal('3.44'), Decimal('3.44'), 'Malaysia'),
#  (2017, Decimal('3.41'), Decimal('3.41'), 'Malaysia'),
#  (2018, Decimal('3.30'), Decimal('3.30'), 'Malaysia'),
#  (2019, Decimal('3.26'), Decimal('3.26'), 'Malaysia'),
#  (2020, Decimal('4.54'), Decimal('4.54'), 'Malaysia'),
#  ...]

# %% [markdown]
# ## Solutions

# %% [markdown]
# ### 1. Join tables

# %%
# %%sql
#
# SELECT
# 	loc.Country_name,
# 	eco.Time_period,
# 	eco.Pct_unemployment
# FROM
# 	united_nations.Geographic_Location AS loc
# LEFT JOIN
# 	united_nations.Economic_Indicators AS eco
# 	ON eco.Country_name = loc.Country_name
# WHERE REGION LIKE '%Central and Southern Asia%';

# %% [markdown]
# ### 2. Impute `NULL` values

# %%
# %%sql
#
# SELECT
# 	loc.Country_name,
# 	eco.Time_period,
# 	IFNULL(eco.Pct_unemployment, 19.59) AS Pct_unemployment_imputed
# FROM
# 	united_nations.Geographic_Location AS loc
# LEFT JOIN
# 	united_nations.Economic_Indicators AS eco
# 	ON eco.Country_name = loc.Country_name
# WHERE REGION LIKE '%Central and Southern Asia%';
# Out:
#  * mysql+pymysql://root:***@localhost:3306/united_nations
# 84 rows affected.
# [('Afghanistan', 2015, Decimal('19.59')),
#  ('Afghanistan', 2016, Decimal('19.59')),
#  ('Afghanistan', 2017, Decimal('11.18')),
#  ('Afghanistan', 2018, Decimal('19.59')),
#  ('Afghanistan', 2019, Decimal('19.59')),
#  ('Afghanistan', 2020, Decimal('11.71')),
#  ('Bangladesh', 2015, Decimal('19.59')),
#  ('Bangladesh', 2016, Decimal('4.35')),
#  ('Bangladesh', 2017, Decimal('4.37')),
#  ('Bangladesh', 2018, Decimal('19.59')),
#  ('Bangladesh', 2019, Decimal('19.59')),
#  ('Bangladesh', 2020, Decimal('19.59')),
#  ('Bhutan', 2015, Decimal('2.45')),
#  ('Bhutan', 2016, Decimal('19.59')),
#  ('Bhutan', 2017, Decimal('19.59')),
#  ('Bhutan', 2018, Decimal('3.35')),
#  ('Bhutan', 2019, Decimal('2.72')),
#  ('Bhutan', 2020, Decimal('5.03')),
#  ('India', 2015, Decimal('19.59')),
#  ('India', 2016, Decimal('19.59')),
#  ('India', 2017, Decimal('19.59')),
#  ('India', 2018, Decimal('7.65')),
#  ('India', 2019, Decimal('6.51')),
#  ('India', 2020, Decimal('7.86')),
#  ('Iran (Islamic Republic of)', 2015, Decimal('19.59')),
#  ('Iran (Islamic Republic of)', 2016, Decimal('19.59')),
#  ('Iran (Islamic Republic of)', 2017, Decimal('19.59')),
#  ('Iran (Islamic Republic of)', 2018, Decimal('19.59')),
#  ('Iran (Islamic Republic of)', 2019, Decimal('19.59')),
#  ('Iran (Islamic Republic of)', 2020, Decimal('19.59')),
#  ('Kazakhstan', 2015, Decimal('4.93')),
#  ('Kazakhstan', 2016, Decimal('4.96')),
#  ('Kazakhstan', 2017, Decimal('4.90')),
#  ('Kazakhstan', 2018, Decimal('4.85')),
#  ('Kazakhstan', 2019, Decimal('4.80')),
#  ('Kazakhstan', 2020, Decimal('4.89')),
#  ('Kyrgyzstan', 2015, Decimal('19.59')),
#  ('Kyrgyzstan', 2016, Decimal('19.59')),
#  ('Kyrgyzstan', 2017, Decimal('19.59')),
#  ('Kyrgyzstan', 2018, Decimal('19.59')),
#  ('Kyrgyzstan', 2019, Decimal('19.59')),
#  ('Kyrgyzstan', 2020, Decimal('19.59')),
#  ('Maldives', 2015, Decimal('19.59')),
#  ('Maldives', 2016, Decimal('5.77')),
#  ('Maldives', 2017, Decimal('19.59')),
#  ('Maldives', 2018, Decimal('19.59')),
#  ('Maldives', 2019, Decimal('4.56')),
#  ('Maldives', 2020, Decimal('19.59')),
#  ('Nepal', 2015, Decimal('3.10')),
#  ('Nepal', 2016, Decimal('19.59')),
#  ('Nepal', 2017, Decimal('10.66')),
#  ('Nepal', 2018, Decimal('19.59')),
#  ('Nepal', 2019, Decimal('19.59')),
#  ('Nepal', 2020, Decimal('19.59')),
#  ('Pakistan', 2015, Decimal('3.57')),
#  ('Pakistan', 2016, Decimal('19.59')),
#  ('Pakistan', 2017, Decimal('19.59')),
#  ('Pakistan', 2018, Decimal('4.08')),
#  ('Pakistan', 2019, Decimal('4.83')),
#  ('Pakistan', 2020, Decimal('19.59')),
#  ('Sri Lanka', 2015, Decimal('4.52')),
#  ('Sri Lanka', 2016, Decimal('4.24')),
#  ('Sri Lanka', 2017, Decimal('4.05')),
#  ('Sri Lanka', 2018, Decimal('4.32')),
#  ('Sri Lanka', 2019, Decimal('4.67')),
#  ('Sri Lanka', 2020, Decimal('5.36')),
#  ('Tajikistan', 2015, Decimal('19.59')),
#  ('Tajikistan', 2016, Decimal('6.90')),
#  ('Tajikistan', 2017, Decimal('19.59')),
#  ('Tajikistan', 2018, Decimal('19.59')),
#  ('Tajikistan', 2019, Decimal('19.59')),
#  ('Tajikistan', 2020, Decimal('19.59')),
#  ('Turkmenistan', 2015, Decimal('19.59')),
#  ('Turkmenistan', 2016, Decimal('19.59')),
#  ('Turkmenistan', 2017, Decimal('19.59')),
#  ('Turkmenistan', 2018, Decimal('19.59')),
#  ('Turkmenistan', 2019, Decimal('19.59')),
#  ('Turkmenistan', 2020, Decimal('19.59')),
#  ('Uzbekistan', 2015, Decimal('5.15')),
#  ('Uzbekistan', 2016, Decimal('5.16')),
#  ('Uzbekistan', 2017, Decimal('5.83')),
#  ('Uzbekistan', 2018, Decimal('9.35')),
#  ('Uzbekistan', 2019, Decimal('8.98')),
#  ('Uzbekistan', 2020, Decimal('5.29'))]

# %% [markdown]
# ### 3. Repeat for other regions

# %%
# %%sql
#
# SELECT
# 	loc.Country_name,
# 	eco.Time_period,
# 	IFNULL(eco.Pct_unemployment, 19.59) as Pct_unemployment_imputed
# FROM
# 	united_nations.Geographic_Location as loc
# LEFT JOIN
# 	united_nations.Economic_Indicators as eco
# 	ON eco.Country_name = loc.Country_name
# WHERE REGION LIKE '%Central and Southern Asia%'
#
# UNION
#
# SELECT
# 	loc.Country_name,
# 	eco.Time_period,
# 	IFNULL(eco.Pct_unemployment, 22.64) as Pct_unemployment_imputed
# FROM
# 	united_nations.Geographic_Location as loc
# LEFT JOIN
# 	united_nations.Economic_Indicators as eco
# 	ON eco.Country_name = loc.Country_name
# WHERE REGION LIKE '%Eastern and South-Eastern Asia%'
#
# UNION
#
# SELECT
# 	loc.Country_name,
# 	eco.Time_period,
# 	IFNULL(eco.Pct_unemployment, 24.43) as Pct_unemployment_imputed
# FROM united_nations.Geographic_Location as loc
# LEFT JOIN
# 	united_nations.Economic_Indicators as eco
# 	ON eco.Country_name = loc.Country_name
# WHERE REGION LIKE '%Europe and Northern America%'
#
# UNION
#
# SELECT
# 	loc.Country_name,
# 	eco.Time_period,
# 	IFNULL(eco.Pct_unemployment, 24.23) as Pct_unemployment_imputed
# FROM united_nations.Geographic_Location as loc
# LEFT JOIN
# 	united_nations.Economic_Indicators as eco
# 	ON eco.Country_name = loc.Country_name
# WHERE REGION LIKE '%Latin America and the Caribbean%'
#
# UNION
#
# SELECT
# 	loc.Country_name,
# 	eco.Time_period,
# 	IFNULL(eco.Pct_unemployment, 17.84) as Pct_unemployment_imputed
# FROM
# 	united_nations.Geographic_Location as loc
# LEFT JOIN
# 	united_nations.Economic_Indicators as eco
# 	ON eco.Country_name = loc.Country_name
# WHERE REGION LIKE '%Northern Africa and Western Asia%'
#
# UNION
#
# SELECT
# 	loc.Country_name,
# 	eco.Time_period,
# 	IFNULL(eco.Pct_unemployment, 4.98) as Pct_unemployment_imputed
# FROM
# 	united_nations.Geographic_Location as loc
# LEFT JOIN
# 	united_nations.Economic_Indicators as eco
# 	ON eco.Country_name = loc.Country_name
# WHERE REGION LIKE '%Oceania%'
#
# UNION
#
# SELECT
# 	loc.Country_name,
# 	eco.Time_period,
# 	IFNULL(eco.Pct_unemployment, 33.65) as Pct_unemployment_imputed
# FROM
# 	united_nations.Geographic_Location as loc
# LEFT JOIN united_nations.Economic_Indicators as eco
# 	ON eco.Country_name = loc.Country_name
# WHERE REGION LIKE '%Sub-Saharan Africa%';

# %% [markdown]
# #
#
# <div align="center" style=" font-size: 80%; text-align: center; margin: 0 auto">
# <img src="https://raw.githubusercontent.com/Explore-AI/Pictures/master/ExploreAI_logos/EAI_Blue_Dark.png"  style="width:200px";/>
# </div>
