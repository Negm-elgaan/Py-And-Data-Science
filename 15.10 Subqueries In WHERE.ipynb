# %% [markdown]
# <div align="right" style=" font-size: 80%; text-align: center; margin: 0 auto">
# <img src="https://raw.githubusercontent.com/Explore-AI/Pictures/master/ExploreAI_logos/Logo blue_dark.png"  style="width:25px" align="right";/>
# </div>

# %% [markdown]
# # Subquery in  WHERE
# © ExploreAI Academy

# %% [markdown]
# In this notebook, we delve deeper into subqueries, specifically subqueries within a WHERE clause. One of the powerful aspects of subqueries is their ability to compare individual rows with aggregated data. This concept will be explored here.

# %% [markdown]
# > ⚠️ This notebook will not run on Google Colab because it cannot connect to a local database. Please make sure that this notebook is running on the same local machine as your MySQL Workbench installation and MySQL `united_nations` database.

# %% [markdown]
# ## Learning objectives
#
# In this train, we will learn:
# - How to use the WHERE clause in subqueries.
# - How to join tables.

# %% [markdown]
# ## Connecting to our MySQL database
#
# Using our `Access_to_Basic_Services` table in our `united_nations` database we created in MySQL Workbench, we want to answer some questions about our dataset. We can apply the same queries we used in MySQL Workbench in this notebook if we connect to our MySQL server by running the cells below.
#
# Note that before this tutorial, we will already have worked through the lessons where the `united_nations.Basic_Services` table, `united_nations.Economic_Indicators` table, and `united_nations.Geographic_Locations` table were created.

# %%
# Load and activate the SQL extension to allow us to execute SQL in a Jupyter notebook. 
# If you get an error here, make sure that mysql and pymysql are installed correctly. 

# %load_ext sql

# %%
# Establish a connection to the local database using the '%sql' magic command.
# Replace 'password' with our connection password and `db_name` with our database name. 
# If you get an error here, please make sure the database name or password is correct.

# %sql mysql+pymysql://root:Omar2003negm*@localhost:3306/united_nations
# Out:
# 'Connected: root@united_nations'

# %% [markdown]
# To make a query, we add the `%%sql` command to the start of a cell, create one open line then the query like below, and run the cell.

# %%
# %%sql
#
# SELECT
#     *
# FROM
#     Access_to_Basic_Services
# LIMIT 5;
# Out:
#  * mysql+pymysql://root:***@localhost:3306/united_nations
# 5 rows affected.
# [('Central and Southern Asia', 'Central Asia', 'Kazakhstan', 2015, Decimal('94.67'), Decimal('98.00'), Decimal('17.542806'), Decimal('184.39'), Decimal('2699700.00'), Decimal('4.93')),
#  ('Central and Southern Asia', 'Central Asia', 'Kazakhstan', 2016, Decimal('94.67'), Decimal('98.00'), Decimal('17.794055'), Decimal('137.28'), Decimal('2699700.00'), Decimal('4.96')),
#  ('Central and Southern Asia', 'Central Asia', 'Kazakhstan', 2017, Decimal('95.00'), Decimal('98.00'), Decimal('18.037776'), Decimal('166.81'), Decimal('2699700.00'), Decimal('4.90')),
#  ('Central and Southern Asia', 'Central Asia', 'Kazakhstan', 2018, Decimal('95.00'), Decimal('98.00'), Decimal('18.276452'), Decimal('179.34'), Decimal('2699700.00'), Decimal('4.85')),
#  ('Central and Southern Asia', 'Central Asia', 'Kazakhstan', 2019, Decimal('95.00'), Decimal('98.00'), Decimal('18.513673'), Decimal('181.67'), Decimal('2699700.00'), Decimal('4.80'))]

# %% [markdown]
# ## Exercise

# %% [markdown]
# We want to answer the following question:
#
# For the year 2020, which countries have a GDP above the global average, but still have less than 90% of their population with access to managed drinking water services?
#
# This question will shed light on nations that, despite having a robust economy, may still be facing challenges in providing basic amenities like water.

# %% [markdown]
# ### Task 1
#
# Start by constructing a query that displays the average GDP of a country during the year 2020.

# %%
# %%sql
# # Add your code here
# SELECT
#     AVG(Est_gdp_in_billions)
# FROM
#     Economic_Indicators
# WHERE
#     Time_period = 2020
# Out:
#  * mysql+pymysql://root:***@localhost:3306/united_nations
# 1 rows affected.
# [(Decimal('301.176825'),)]

# %% [markdown]
# ### Task 2

# %% [markdown]
# In order to answer our question, we need to pull data from both the Economic_Indicators and the Basic_Services tables; therefore, we need to join them together. Using `Country_name` and  `Time_period`, join the Basic_Services table to the Economic_Indicators table.

# %%
# %%sql
# # Add your code here
# SELECT
#     *
# FROM
#     Basic_services B
# INNER JOIN
#     Economic_Indicators E
# ON
#     B.Country_Name = E.Country_Name
#     AND
#     B.Time_period = E.Time_period
# Out:
#  * mysql+pymysql://root:***@localhost:3306/united_nations
# 1048 rows affected.
# [('Afghanistan', 2015, Decimal('67.00'), Decimal('45.67'), 'Afghanistan', 2015, Decimal('20.00'), Decimal('33.753499'), None),
#  ('Afghanistan', 2016, Decimal('69.67'), Decimal('47.00'), 'Afghanistan', 2016, Decimal('18.02'), Decimal('34.636207'), None),
#  ('Afghanistan', 2017, Decimal('72.33'), Decimal('49.33'), 'Afghanistan', 2017, Decimal('18.90'), Decimal('35.643418'), Decimal('11.18')),
#  ('Afghanistan', 2018, Decimal('75.33'), Decimal('50.67'), 'Afghanistan', 2018, Decimal('18.42'), Decimal('36.686784'), None),
#  ('Afghanistan', 2019, Decimal('78.00'), Decimal('52.33'), 'Afghanistan', 2019, Decimal('18.90'), Decimal('37.769499'), None),
#  ('Afghanistan', 2020, Decimal('80.33'), Decimal('54.00'), 'Afghanistan', 2020, Decimal('20.14'), Decimal('38.972230'), Decimal('11.71')),
#  ('Algeria', 2015, Decimal('92.00'), Decimal('85.00'), 'Algeria', 2015, Decimal('165.98'), Decimal('39.543154'), Decimal('11.21')),
#  ('Algeria', 2016, Decimal('93.00'), Decimal('85.33'), 'Algeria', 2016, Decimal('160.03'), Decimal('40.339329'), Decimal('10.20')),
#  ('Algeria', 2017, Decimal('93.00'), Decimal('84.67'), 'Algeria', 2017, Decimal('170.10'), Decimal('41.136546'), Decimal('12.00')),
#  ('Algeria', 2018, Decimal('93.00'), Decimal('84.67'), 'Algeria', 2018, Decimal('174.91'), Decimal('41.927007'), None),
#  ('Algeria', 2019, Decimal('93.33'), Decimal('84.67'), 'Algeria', 2019, Decimal('171.77'), Decimal('42.705368'), None),
#  ('Algeria', 2020, Decimal('93.33'), Decimal('84.33'), 'Algeria', 2020, Decimal('145.01'), Decimal('43.451666'), None),
#  ('American Samoa', 2015, Decimal('100.00'), Decimal('57.00'), 'American Samoa', 2015, Decimal('0.67'), Decimal('0.051368'), None),
#  ('American Samoa', 2016, Decimal('100.00'), Decimal('56.00'), 'American Samoa', 2016, Decimal('0.67'), Decimal('0.050448'), None),
#  ('American Samoa', 2017, Decimal('100.00'), Decimal('54.00'), 'American Samoa', 2017, Decimal('0.61'), Decimal('0.049463'), None),
#  ('American Samoa', 2018, Decimal('100.00'), Decimal('54.00'), 'American Samoa', 2018, Decimal('0.64'), Decimal('0.048424'), None),
#  ('American Samoa', 2019, Decimal('100.00'), Decimal('54.00'), 'American Samoa', 2019, Decimal('0.65'), Decimal('0.047321'), None),
#  ('American Samoa', 2020, Decimal('100.00'), Decimal('54.00'), 'American Samoa', 2020, Decimal('0.72'), Decimal('0.046189'), None),
#  ('Angola', 2015, Decimal('50.33'), Decimal('43.33'), 'Angola', 2015, Decimal('87.22'), Decimal('28.127721'), None),
#  ('Angola', 2016, Decimal('51.00'), Decimal('44.67'), 'Angola', 2016, Decimal('49.84'), Decimal('29.154746'), None),
#  ('Angola', 2017, Decimal('51.33'), Decimal('45.67'), 'Angola', 2017, Decimal('68.97'), Decimal('30.208628'), None),
#  ('Angola', 2018, Decimal('52.33'), Decimal('46.67'), 'Angola', 2018, Decimal('77.79'), Decimal('31.273533'), None),
#  ('Angola', 2019, Decimal('52.33'), Decimal('46.67'), 'Angola', 2019, Decimal('69.31'), Decimal('32.353588'), Decimal('16.50')),
#  ('Angola', 2020, Decimal('52.33'), Decimal('47.00'), 'Angola', 2020, Decimal('53.62'), Decimal('33.428486'), None),
#  ('Anguilla', 2015, Decimal('97.00'), Decimal('97.00'), 'Anguilla', 2015, None, None, None),
#  ('Anguilla', 2016, Decimal('97.00'), Decimal('97.00'), 'Anguilla', 2016, None, None, None),
#  ('Anguilla', 2017, Decimal('97.00'), Decimal('97.00'), 'Anguilla', 2017, None, None, None),
#  ('Antigua and Barbuda', 2015, Decimal('97.00'), Decimal('88.00'), 'Antigua and Barbuda', 2015, Decimal('1.34'), Decimal('0.089941'), None),
#  ('Antigua and Barbuda', 2016, Decimal('97.00'), Decimal('88.00'), 'Antigua and Barbuda', 2016, Decimal('1.44'), Decimal('0.090564'), None),
#  ('Antigua and Barbuda', 2017, Decimal('97.00'), Decimal('88.00'), 'Antigua and Barbuda', 2017, Decimal('1.47'), Decimal('0.091119'), None),
#  ('Argentina', 2015, Decimal('97.33'), Decimal('89.67'), 'Argentina', 2015, Decimal('594.75'), Decimal('43.131966'), None),
#  ('Argentina', 2016, Decimal('97.33'), Decimal('89.67'), 'Argentina', 2016, Decimal('557.53'), Decimal('43.590368'), None),
#  ('Argentina', 2017, Decimal('100.00'), Decimal('97.00'), 'Argentina', 2017, Decimal('643.63'), Decimal('44.044811'), Decimal('8.35')),
#  ('Argentina', 2018, Decimal('100.00'), Decimal('98.00'), 'Argentina', 2018, Decimal('524.82'), Decimal('44.494502'), Decimal('9.22')),
#  ('Argentina', 2019, Decimal('100.00'), Decimal('98.00'), 'Argentina', 2019, Decimal('447.75'), Decimal('44.938712'), Decimal('9.84')),
#  ('Argentina', 2020, Decimal('100.00'), Decimal('99.00'), 'Argentina', 2020, Decimal('385.54'), Decimal('45.376763'), Decimal('11.46')),
#  ('Armenia', 2015, Decimal('99.67'), Decimal('91.33'), 'Armenia', 2015, Decimal('10.55'), Decimal('2.878595'), Decimal('18.26')),
#  ('Armenia', 2016, Decimal('99.67'), Decimal('91.67'), 'Armenia', 2016, Decimal('10.55'), Decimal('2.865835'), Decimal('17.62')),
#  ('Armenia', 2017, Decimal('100.00'), Decimal('92.00'), 'Armenia', 2017, Decimal('11.53'), Decimal('2.851923'), Decimal('17.70')),
#  ('Armenia', 2018, Decimal('100.00'), Decimal('92.33'), 'Armenia', 2018, Decimal('12.46'), Decimal('2.836557'), Decimal('13.21')),
#  ('Armenia', 2019, Decimal('100.00'), Decimal('92.33'), 'Armenia', 2019, Decimal('13.62'), Decimal('2.820602'), Decimal('12.20')),
#  ('Armenia', 2020, Decimal('100.00'), Decimal('92.33'), 'Armenia', 2020, Decimal('12.64'), Decimal('2.805608'), Decimal('12.18')),
#  ('Aruba', 2015, Decimal('98.00'), Decimal('98.00'), 'Aruba', 2015, Decimal('2.96'), Decimal('0.104257'), None),
#  ('Aruba', 2016, Decimal('98.00'), Decimal('98.00'), 'Aruba', 2016, Decimal('2.98'), Decimal('0.104874'), None),
#  ('Australia', 2015, Decimal('100.00'), Decimal('100.00'), 'Australia', 2015, Decimal('1350.62'), Decimal('23.815995'), Decimal('6.06')),
#  ('Australia', 2016, Decimal('100.00'), Decimal('100.00'), 'Australia', 2016, Decimal('1206.54'), Decimal('24.190907'), Decimal('5.71')),
#  ('Australia', 2017, Decimal('100.00'), Decimal('100.00'), 'Australia', 2017, Decimal('1326.52'), Decimal('24.594202'), Decimal('5.59')),
#  ('Australia', 2018, Decimal('100.00'), Decimal('100.00'), 'Australia', 2018, Decimal('1428.29'), Decimal('24.966643'), Decimal('5.30')),
#  ('Australia', 2019, Decimal('100.00'), Decimal('100.00'), 'Australia', 2019, Decimal('1392.23'), Decimal('25.340217'), Decimal('5.16')),
#  ('Australia', 2020, Decimal('100.00'), Decimal('100.00'), 'Australia', 2020, Decimal('1326.90'), Decimal('25.655289'), Decimal('6.46')),
#  ('Azerbaijan', 2015, Decimal('91.67'), Decimal('96.00'), 'Azerbaijan', 2015, Decimal('53.07'), Decimal('9.649341'), Decimal('4.96')),
#  ('Azerbaijan', 2016, Decimal('92.33'), Decimal('96.00'), 'Azerbaijan', 2016, Decimal('37.87'), Decimal('9.757812'), Decimal('5.00')),
#  ('Azerbaijan', 2017, Decimal('93.67'), Decimal('96.00'), 'Azerbaijan', 2017, Decimal('40.87'), Decimal('9.854033'), Decimal('4.96')),
#  ('Azerbaijan', 2018, Decimal('94.33'), Decimal('96.00'), 'Azerbaijan', 2018, Decimal('47.11'), Decimal('9.939771'), Decimal('4.94')),
#  ('Azerbaijan', 2019, Decimal('95.00'), Decimal('96.00'), 'Azerbaijan', 2019, Decimal('48.17'), Decimal('10.024283'), Decimal('4.85')),
#  ('Azerbaijan', 2020, Decimal('95.67'), Decimal('96.00'), 'Azerbaijan', 2020, Decimal('42.69'), Decimal('10.093121'), Decimal('7.16')),
#  ('Bahamas', 2015, Decimal('99.00'), Decimal('95.00'), 'Bahamas', 2015, None, None, None),
#  ('Bahamas', 2016, Decimal('99.00'), Decimal('95.00'), 'Bahamas', 2016, None, None, None),
#  ('Bahamas', 2017, Decimal('99.00'), Decimal('95.00'), 'Bahamas', 2017, None, None, None),
#  ('Bahamas', 2018, Decimal('99.00'), Decimal('95.00'), 'Bahamas', 2018, None, None, None),
#  ('Bahamas', 2019, Decimal('99.00'), Decimal('95.00'), 'Bahamas', 2019, None, None, None),
#  ('Bahrain', 2015, Decimal('100.00'), Decimal('100.00'), 'Bahrain', 2015, Decimal('31.05'), Decimal('1.362142'), None),
#  ('Bahrain', 2016, Decimal('100.00'), Decimal('100.00'), 'Bahrain', 2016, Decimal('32.23'), Decimal('1.409661'), None),
#  ('Bahrain', 2017, Decimal('100.00'), Decimal('100.00'), 'Bahrain', 2017, Decimal('35.47'), Decimal('1.456834'), None),
#  ('Bahrain', 2018, Decimal('100.00'), Decimal('100.00'), 'Bahrain', 2018, Decimal('37.80'), Decimal('1.487340'), None),
#  ('Bahrain', 2019, Decimal('100.00'), Decimal('100.00'), 'Bahrain', 2019, Decimal('38.65'), Decimal('1.494188'), None),
#  ('Bahrain', 2020, Decimal('100.00'), Decimal('100.00'), 'Bahrain', 2020, Decimal('34.72'), Decimal('1.477469'), None),
#  ('Bangladesh', 2015, Decimal('97.33'), Decimal('47.33'), 'Bangladesh', 2015, Decimal('195.08'), Decimal('157.830000'), None),
#  ('Bangladesh', 2016, Decimal('97.33'), Decimal('48.67'), 'Bangladesh', 2016, Decimal('265.24'), Decimal('159.784568'), Decimal('4.35')),
#  ('Bangladesh', 2017, Decimal('97.33'), Decimal('50.00'), 'Bangladesh', 2017, Decimal('293.75'), Decimal('161.793964'), Decimal('4.37')),
#  ('Bangladesh', 2018, Decimal('97.33'), Decimal('51.33'), 'Bangladesh', 2018, Decimal('321.38'), Decimal('163.683958'), None),
#  ('Bangladesh', 2019, Decimal('97.67'), Decimal('52.67'), 'Bangladesh', 2019, Decimal('351.24'), Decimal('165.516222'), None),
#  ('Bangladesh', 2020, Decimal('97.67'), Decimal('54.00'), 'Bangladesh', 2020, Decimal('373.90'), Decimal('167.420951'), None),
#  ('Barbados', 2015, Decimal('98.00'), Decimal('96.00'), 'Barbados', 2015, Decimal('4.72'), Decimal('0.278083'), Decimal('9.80')),
#  ('Barbados', 2016, Decimal('98.00'), Decimal('97.00'), 'Barbados', 2016, Decimal('4.83'), Decimal('0.278649'), Decimal('8.25')),
#  ('Barbados', 2017, Decimal('98.00'), Decimal('97.00'), 'Barbados', 2017, Decimal('4.98'), Decimal('0.279187'), Decimal('8.62')),
#  ('Barbados', 2018, Decimal('99.00'), Decimal('97.00'), 'Barbados', 2018, Decimal('5.10'), Decimal('0.279688'), Decimal('8.32')),
#  ('Barbados', 2019, Decimal('99.00'), Decimal('98.00'), 'Barbados', 2019, Decimal('5.32'), Decimal('0.280180'), Decimal('8.41')),
#  ('Barbados', 2020, Decimal('99.00'), Decimal('98.00'), 'Barbados', 2020, Decimal('4.67'), Decimal('0.280693'), None),
#  ('Belize', 2015, Decimal('97.33'), Decimal('87.33'), 'Belize', 2015, Decimal('2.21'), Decimal('0.359871'), Decimal('7.58')),
#  ('Belize', 2016, Decimal('97.67'), Decimal('88.00'), 'Belize', 2016, Decimal('2.26'), Decimal('0.367313'), Decimal('7.00')),
#  ('Belize', 2017, Decimal('98.00'), Decimal('88.00'), 'Belize', 2017, Decimal('2.29'), Decimal('0.374693'), Decimal('6.60')),
#  ('Belize', 2018, Decimal('98.33'), Decimal('88.67'), 'Belize', 2018, Decimal('2.31'), Decimal('0.382066'), None),
#  ('Belize', 2019, Decimal('98.33'), Decimal('88.67'), 'Belize', 2019, Decimal('2.42'), Decimal('0.389095'), Decimal('9.05')),
#  ('Belize', 2020, Decimal('98.33'), Decimal('88.67'), 'Belize', 2020, Decimal('2.08'), Decimal('0.394921'), None),
#  ('Benin', 2015, Decimal('65.33'), Decimal('15.33'), 'Benin', 2015, Decimal('11.39'), Decimal('10.932783'), None),
#  ('Benin', 2016, Decimal('65.33'), Decimal('15.67'), 'Benin', 2016, Decimal('11.82'), Decimal('11.260085'), None),
#  ('Benin', 2017, Decimal('65.33'), Decimal('16.00'), 'Benin', 2017, Decimal('12.70'), Decimal('11.596779'), None),
#  ('Benin', 2018, Decimal('65.67'), Decimal('16.33'), 'Benin', 2018, Decimal('14.26'), Decimal('11.940683'), Decimal('1.47')),
#  ('Benin', 2019, Decimal('65.33'), Decimal('17.00'), 'Benin', 2019, Decimal('14.39'), Decimal('12.290444'), None),
#  ('Benin', 2020, Decimal('65.33'), Decimal('17.33'), 'Benin', 2020, Decimal('15.65'), Decimal('12.643123'), None),
#  ('Bermuda', 2015, Decimal('100.00'), Decimal('100.00'), 'Bermuda', 2015, Decimal('6.65'), Decimal('0.065237'), None),
#  ('Bermuda', 2016, Decimal('100.00'), Decimal('100.00'), 'Bermuda', 2016, Decimal('6.90'), Decimal('0.064554'), None),
#  ('Bermuda', 2017, Decimal('100.00'), Decimal('100.00'), 'Bermuda', 2017, Decimal('7.14'), Decimal('0.063873'), None),
#  ('Bermuda', 2018, Decimal('100.00'), Decimal('100.00'), 'Bermuda', 2018, Decimal('7.23'), Decimal('0.063918'), None),
#  ('Bermuda', 2019, Decimal('100.00'), Decimal('100.00'), 'Bermuda', 2019, Decimal('7.42'), Decimal('0.063911'), None),
#  ('Bermuda', 2020, Decimal('100.00'), Decimal('100.00'), 'Bermuda', 2020, Decimal('6.89'), Decimal('0.063893'), None),
#  ('Bhutan', 2015, Decimal('96.33'), Decimal('70.67'), 'Bhutan', 2015, Decimal('2.00'), Decimal('0.743274'), Decimal('2.45')),
#  ('Bhutan', 2016, Decimal('97.00'), Decimal('71.67'), 'Bhutan', 2016, Decimal('2.16'), Decimal('0.749761'), None),
#  ('Bhutan', 2017, Decimal('97.33'), Decimal('73.33'), 'Bhutan', 2017, Decimal('2.45'), Decimal('0.756121'), None),
#  ('Bhutan', 2018, Decimal('97.33'), Decimal('74.33'), 'Bhutan', 2018, Decimal('2.45'), Decimal('0.762096'), Decimal('3.35')),
#  ('Bhutan', 2019, Decimal('97.33'), Decimal('75.00'), 'Bhutan', 2019, Decimal('2.54'), Decimal('0.767459'), Decimal('2.72')),
#  ('Bhutan', 2020, Decimal('97.33'), Decimal('76.67'), 'Bhutan', 2020, Decimal('2.33'), Decimal('0.772506'), Decimal('5.03')),
#  ('Bolivia (Plurinational State of)', 2015, Decimal('87.33'), Decimal('53.00'), 'Bolivia (Plurinational State of)', 2015, None, None, None),
#  ('Bolivia (Plurinational State of)', 2016, Decimal('88.00'), Decimal('54.33'), 'Bolivia (Plurinational State of)', 2016, None, None, None),
#  ('Bolivia (Plurinational State of)', 2017, Decimal('89.00'), Decimal('56.33'), 'Bolivia (Plurinational State of)', 2017, None, None, None),
#  ('Bolivia (Plurinational State of)', 2018, Decimal('89.67'), Decimal('58.00'), 'Bolivia (Plurinational State of)', 2018, None, None, None),
#  ('Bolivia (Plurinational State of)', 2019, Decimal('90.33'), Decimal('59.67'), 'Bolivia (Plurinational State of)', 2019, None, None, None),
#  ('Bolivia (Plurinational State of)', 2020, Decimal('90.67'), Decimal('61.67'), 'Bolivia (Plurinational State of)', 2020, None, None, None),
#  ('Botswana', 2015, Decimal('85.67'), Decimal('70.33'), 'Botswana', 2015, Decimal('13.53'), Decimal('2.305171'), None),
#  ('Botswana', 2016, Decimal('86.67'), Decimal('71.33'), 'Botswana', 2016, Decimal('15.08'), Decimal('2.352416'), None),
#  ('Botswana', 2017, Decimal('87.67'), Decimal('72.33'), 'Botswana', 2017, Decimal('16.11'), Decimal('2.401840'), None),
#  ('Botswana', 2018, Decimal('88.33'), Decimal('73.67'), 'Botswana', 2018, Decimal('17.03'), Decimal('2.451409'), None),
#  ('Botswana', 2019, Decimal('89.67'), Decimal('74.33'), 'Botswana', 2019, Decimal('16.70'), Decimal('2.499702'), Decimal('20.09')),
#  ('Botswana', 2020, Decimal('89.67'), Decimal('74.33'), 'Botswana', 2020, Decimal('14.93'), Decimal('2.546402'), Decimal('21.02')),
#  ('Brazil', 2015, Decimal('95.33'), Decimal('77.67'), 'Brazil', 2015, Decimal('1802.21'), Decimal('205.188205'), Decimal('8.54')),
#  ('Brazil', 2016, Decimal('95.33'), Decimal('79.00'), 'Brazil', 2016, Decimal('1795.70'), Decimal('206.859578'), Decimal('11.58')),
#  ('Brazil', 2017, Decimal('96.33'), Decimal('79.67'), 'Brazil', 2017, Decimal('2063.51'), Decimal('208.504960'), Decimal('12.79')),
#  ('Brazil', 2018, Decimal('97.00'), Decimal('80.33'), 'Brazil', 2018, Decimal('1916.95'), Decimal('210.166592'), Decimal('12.33')),
#  ('Brazil', 2019, Decimal('97.33'), Decimal('81.67'), 'Brazil', 2019, Decimal('1873.27'), Decimal('211.782878'), Decimal('11.94')),
#  ('Brazil', 2020, Decimal('98.33'), Decimal('82.33'), 'Brazil', 2020, Decimal('1448.56'), Decimal('213.196304'), Decimal('13.70')),
#  ('British Virgin Islands', 2015, Decimal('100.00'), Decimal('97.00'), 'British Virgin Islands', 2015, None, Decimal('0.029366'), None),
#  ('British Virgin Islands', 2016, Decimal('100.00'), Decimal('97.00'), 'British Virgin Islands', 2016, None, Decimal('0.029739'), None),
#  ('British Virgin Islands', 2017, Decimal('100.00'), None, 'British Virgin Islands', 2017, None, Decimal('0.030060'), None),
#  ('British Virgin Islands', 2018, Decimal('100.00'), None, 'British Virgin Islands', 2018, None, Decimal('0.030335'), None),
#  ('British Virgin Islands', 2019, Decimal('100.00'), None, 'British Virgin Islands', 2019, None, Decimal('0.030610'), None),
#  ('British Virgin Islands', 2020, Decimal('100.00'), None, 'British Virgin Islands', 2020, None, Decimal('0.030910'), None),
#  ('Brunei Darussalam', 2015, Decimal('99.67'), Decimal('96.00'), 'Brunei Darussalam', 2015, Decimal('12.93'), Decimal('0.421437'), None),
#  ('Brunei Darussalam', 2016, Decimal('100.00'), None, 'Brunei Darussalam', 2016, Decimal('11.40'), Decimal('0.425994'), None),
#  ('Brunei Darussalam', 2017, Decimal('100.00'), None, 'Brunei Darussalam', 2017, Decimal('12.13'), Decimal('0.430276'), Decimal('9.32')),
#  ('Brunei Darussalam', 2018, Decimal('100.00'), None, 'Brunei Darussalam', 2018, Decimal('13.57'), Decimal('0.434274'), Decimal('8.70')),
#  ('Brunei Darussalam', 2019, Decimal('100.00'), None, 'Brunei Darussalam', 2019, Decimal('13.47'), Decimal('0.438048'), Decimal('6.60')),
#  ('Brunei Darussalam', 2020, Decimal('100.00'), None, 'Brunei Darussalam', 2020, Decimal('12.01'), Decimal('0.441725'), Decimal('7.41')),
#  ('Burkina Faso', 2015, Decimal('56.33'), Decimal('24.67'), 'Burkina Faso', 2015, Decimal('11.83'), Decimal('18.718019'), None),
#  ('Burkina Faso', 2016, Decimal('56.00'), Decimal('24.67'), 'Burkina Faso', 2016, Decimal('12.83'), Decimal('19.275498'), None),
#  ('Burkina Faso', 2017, Decimal('55.00'), Decimal('25.00'), 'Burkina Faso', 2017, Decimal('14.11'), Decimal('19.835858'), None),
#  ('Burkina Faso', 2018, Decimal('54.33'), Decimal('25.00'), 'Burkina Faso', 2018, Decimal('15.89'), Decimal('20.392723'), Decimal('4.69')),
#  ('Burkina Faso', 2019, Decimal('54.00'), Decimal('25.00'), 'Burkina Faso', 2019, Decimal('16.18'), Decimal('20.951639'), None),
#  ('Burkina Faso', 2020, Decimal('53.33'), Decimal('25.00'), 'Burkina Faso', 2020, Decimal('17.93'), Decimal('21.522626'), None),
#  ('Burundi', 2015, Decimal('68.33'), Decimal('44.67'), 'Burundi', 2015, Decimal('3.10'), Decimal('10.727148'), None),
#  ('Burundi', 2016, Decimal('68.33'), Decimal('44.67'), 'Burundi', 2016, Decimal('2.64'), Decimal('10.903327'), None),
#  ('Burundi', 2017, Decimal('69.33'), Decimal('44.67'), 'Burundi', 2017, Decimal('2.71'), Decimal('11.155593'), None),
#  ('Burundi', 2018, Decimal('69.33'), Decimal('44.33'), 'Burundi', 2018, Decimal('2.66'), Decimal('11.493472'), None),
#  ('Burundi', 2019, Decimal('70.33'), Decimal('44.33'), 'Burundi', 2019, Decimal('2.58'), Decimal('11.874838'), None),
#  ('Burundi', 2020, Decimal('70.33'), Decimal('44.33'), 'Burundi', 2020, Decimal('2.65'), Decimal('12.220227'), Decimal('1.03')),
#  ('Cabo Verde', 2015, Decimal('83.33'), Decimal('68.67'), 'Cabo Verde', 2015, Decimal('1.60'), Decimal('0.552166'), Decimal('31.31')),
#  ('Cabo Verde', 2016, Decimal('84.33'), Decimal('70.33'), 'Cabo Verde', 2016, Decimal('1.66'), Decimal('0.558394'), None),
#  ('Cabo Verde', 2017, Decimal('85.33'), Decimal('72.33'), 'Cabo Verde', 2017, Decimal('1.77'), Decimal('0.564954'), Decimal('12.24')),
#  ('Cabo Verde', 2018, Decimal('86.00'), Decimal('74.67'), 'Cabo Verde', 2018, Decimal('1.97'), Decimal('0.571202'), Decimal('12.17')),
#  ('Cabo Verde', 2019, Decimal('86.67'), Decimal('76.00'), 'Cabo Verde', 2019, Decimal('1.98'), Decimal('0.577030'), Decimal('11.29')),
#  ('Cabo Verde', 2020, Decimal('87.33'), Decimal('78.00'), 'Cabo Verde', 2020, Decimal('1.70'), Decimal('0.582640'), None),
#  ('Cambodia', 2015, Decimal('73.33'), Decimal('60.33'), 'Cambodia', 2015, Decimal('18.05'), Decimal('15.417523'), Decimal('0.39')),
#  ('Cambodia', 2016, Decimal('73.67'), Decimal('63.00'), 'Cambodia', 2016, Decimal('20.02'), Decimal('15.624584'), Decimal('0.72')),
#  ('Cambodia', 2017, Decimal('74.33'), Decimal('65.67'), 'Cambodia', 2017, Decimal('22.18'), Decimal('15.830689'), Decimal('0.14')),
#  ('Cambodia', 2018, Decimal('74.67'), Decimal('68.33'), 'Cambodia', 2018, Decimal('24.57'), Decimal('16.025238'), None),
#  ('Cambodia', 2019, Decimal('75.33'), Decimal('71.67'), 'Cambodia', 2019, Decimal('27.09'), Decimal('16.207746'), Decimal('0.50')),
#  ('Cambodia', 2020, Decimal('75.33'), Decimal('74.33'), 'Cambodia', 2020, Decimal('25.87'), Decimal('16.396860'), None),
#  ('Cameroon', 2015, Decimal('62.67'), Decimal('41.67'), 'Cameroon', 2015, Decimal('32.21'), Decimal('23.012646'), None),
#  ('Cameroon', 2016, Decimal('62.67'), Decimal('41.67'), 'Cameroon', 2016, Decimal('33.81'), Decimal('23.711630'), None),
#  ('Cameroon', 2017, Decimal('63.33'), Decimal('42.00'), 'Cameroon', 2017, Decimal('36.10'), Decimal('24.393181'), None),
#  ('Cameroon', 2018, Decimal('63.33'), Decimal('42.33'), 'Cameroon', 2018, Decimal('39.97'), Decimal('25.076747'), None),
#  ('Cameroon', 2019, Decimal('63.33'), Decimal('42.33'), 'Cameroon', 2019, Decimal('39.67'), Decimal('25.782341'), None),
#  ('Cameroon', 2020, Decimal('64.00'), Decimal('43.00'), 'Cameroon', 2020, Decimal('40.77'), Decimal('26.491087'), None),
#  ('Canada', 2015, Decimal('99.00'), Decimal('99.00'), 'Canada', 2015, Decimal('1556.51'), Decimal('35.702908'), Decimal('6.91')),
#  ('Canada', 2016, Decimal('99.00'), Decimal('99.00'), 'Canada', 2016, Decimal('1527.99'), Decimal('36.109487'), Decimal('7.00')),
#  ('Canada', 2017, Decimal('99.00'), Decimal('99.00'), 'Canada', 2017, Decimal('1649.27'), Decimal('36.545236'), Decimal('6.34')),
#  ('Canada', 2018, Decimal('99.00'), Decimal('99.00'), 'Canada', 2018, Decimal('1725.33'), Decimal('37.065084'), Decimal('5.83')),
#  ('Canada', 2019, Decimal('99.00'), Decimal('99.00'), 'Canada', 2019, Decimal('1742.02'), Decimal('37.601230'), Decimal('5.66')),
#  ('Canada', 2020, Decimal('99.00'), Decimal('99.00'), 'Canada', 2020, Decimal('1645.42'), Decimal('38.037204'), Decimal('9.46')),
#  ('Cayman Islands', 2015, Decimal('96.00'), Decimal('84.00'), 'Cayman Islands', 2015, Decimal('4.71'), Decimal('0.060911'), Decimal('4.24')),
#  ('Cayman Islands', 2016, Decimal('96.00'), Decimal('84.00'), 'Cayman Islands', 2016, Decimal('4.91'), Decimal('0.062255'), None),
#  ('Central African Republic', 2015, Decimal('44.00'), Decimal('17.33'), 'Central African Republic', 2015, Decimal('1.70'), Decimal('4.819333'), None),
#  ('Central African Republic', 2016, Decimal('42.67'), Decimal('17.00'), 'Central African Republic', 2016, Decimal('1.83'), Decimal('4.904177'), None),
#  ('Central African Republic', 2017, Decimal('41.33'), Decimal('16.67'), 'Central African Republic', 2017, Decimal('2.07'), Decimal('4.996741'), None),
#  ('Central African Republic', 2018, Decimal('40.67'), Decimal('16.00'), 'Central African Republic', 2018, Decimal('2.22'), Decimal('5.094780'), None),
#  ('Central African Republic', 2019, Decimal('39.33'), Decimal('15.33'), 'Central African Republic', 2019, Decimal('2.22'), Decimal('5.209324'), None),
#  ('Central African Republic', 2020, Decimal('38.33'), Decimal('15.00'), 'Central African Republic', 2020, Decimal('2.33'), Decimal('5.343020'), None),
#  ('Chad', 2015, Decimal('51.67'), Decimal('16.33'), 'Chad', 2015, Decimal('10.95'), Decimal('14.140274'), None),
#  ('Chad', 2016, Decimal('52.00'), Decimal('16.67'), 'Chad', 2016, Decimal('10.10'), Decimal('14.592585'), None),
#  ('Chad', 2017, Decimal('52.00'), Decimal('17.00'), 'Chad', 2017, Decimal('10.00'), Decimal('15.085884'), None),
#  ('Chad', 2018, Decimal('52.00'), Decimal('17.67'), 'Chad', 2018, Decimal('11.24'), Decimal('15.604210'), Decimal('1.13')),
#  ('Chad', 2019, Decimal('52.33'), Decimal('18.33'), 'Chad', 2019, Decimal('11.31'), Decimal('16.126866'), None),
#  ('Chad', 2020, Decimal('52.67'), Decimal('18.67'), 'Chad', 2020, Decimal('10.72'), Decimal('16.644701'), None),
#  ('Chile', 2015, Decimal('99.00'), Decimal('98.67'), 'Chile', 2015, Decimal('242.50'), Decimal('17.870124'), Decimal('6.49')),
#  ('Chile', 2016, Decimal('99.67'), Decimal('99.67'), 'Chile', 2016, Decimal('249.30'), Decimal('18.083879'), Decimal('6.73')),
#  ('Chile', 2017, Decimal('100.00'), Decimal('100.00'), 'Chile', 2017, Decimal('276.36'), Decimal('18.368577'), Decimal('6.95')),
#  ('Chile', 2018, Decimal('100.00'), Decimal('100.00'), 'Chile', 2018, Decimal('295.40'), Decimal('18.701450'), Decimal('7.21')),
#  ('Chile', 2019, Decimal('100.00'), Decimal('100.00'), 'Chile', 2019, Decimal('278.58'), Decimal('19.039485'), Decimal('7.27')),
#  ('Chile', 2020, Decimal('100.00'), Decimal('100.00'), 'Chile', 2020, Decimal('252.73'), Decimal('19.300315'), Decimal('10.94')),
#  ('China', 2015, Decimal('91.33'), Decimal('83.67'), 'China', 2015, Decimal('11061.55'), Decimal('1379.860000'), None),
#  ('China', 2016, Decimal('91.33'), Decimal('85.67'), 'China', 2016, Decimal('11233.28'), Decimal('1387.790000'), None),
#  ('China', 2017, Decimal('92.00'), Decimal('87.00'), 'China', 2017, Decimal('12310.41'), Decimal('1396.215000'), Decimal('3.90')),
#  ('China', 2018, Decimal('92.67'), Decimal('88.33'), 'China', 2018, Decimal('13894.82'), Decimal('1402.760000'), Decimal('4.93')),
#  ('China', 2019, Decimal('93.33'), Decimal('90.33'), 'China', 2019, Decimal('14279.94'), Decimal('1407.745000'), Decimal('5.15')),
#  ('China', 2020, Decimal('93.67'), Decimal('91.67'), 'China', 2020, Decimal('14687.67'), Decimal('1411.100000'), Decimal('5.61')),
#  ('Colombia', 2015, Decimal('93.00'), Decimal('86.33'), 'Colombia', 2015, Decimal('293.48'), Decimal('47.119728'), Decimal('8.57')),
#  ('Colombia', 2016, Decimal('93.67'), Decimal('87.33'), 'Colombia', 2016, Decimal('282.83'), Decimal('47.625955'), Decimal('8.92')),
#  ('Colombia', 2017, Decimal('94.00'), Decimal('88.00'), 'Colombia', 2017, Decimal('311.88'), Decimal('48.351671'), Decimal('9.09')),
#  ('Colombia', 2018, Decimal('94.00'), Decimal('89.33'), 'Colombia', 2018, Decimal('334.20'), Decimal('49.276961'), Decimal('9.36')),
#  ('Colombia', 2019, Decimal('94.33'), Decimal('90.33'), 'Colombia', 2019, Decimal('323.11'), Decimal('50.187406'), Decimal('10.28')),
#  ('Colombia', 2020, Decimal('94.67'), Decimal('91.33'), 'Colombia', 2020, Decimal('270.30'), Decimal('50.930662'), Decimal('15.98')),
#  ('Comoros', 2015, Decimal('81.67'), Decimal('37.67'), 'Comoros', 2015, Decimal('0.97'), Decimal('0.730216'), None),
#  ('Comoros', 2016, Decimal('81.67'), Decimal('37.67'), 'Comoros', 2016, Decimal('1.01'), Decimal('0.746232'), None),
#  ('Comoros', 2017, Decimal('81.67'), Decimal('37.67'), 'Comoros', 2017, Decimal('1.08'), Decimal('0.761664'), None),
#  ('Comoros', 2018, Decimal('81.67'), Decimal('37.67'), 'Comoros', 2018, Decimal('1.19'), Decimal('0.776313'), None),
#  ('Comoros', 2019, Decimal('81.67'), Decimal('37.67'), 'Comoros', 2019, Decimal('1.20'), Decimal('0.790986'), None),
#  ('Congo', 2015, Decimal('66.33'), Decimal('17.00'), 'Congo', 2015, None, None, None),
#  ('Congo', 2016, Decimal('67.67'), Decimal('17.33'), 'Congo', 2016, None, None, None),
#  ('Congo', 2017, Decimal('68.67'), Decimal('17.67'), 'Congo', 2017, None, None, None),
#  ('Congo', 2018, Decimal('68.67'), Decimal('17.67'), 'Congo', 2018, None, None, None),
#  ('Congo', 2019, Decimal('69.00'), Decimal('17.67'), 'Congo', 2019, None, None, None),
#  ('Congo', 2020, Decimal('69.00'), Decimal('17.67'), 'Congo', 2020, None, None, None),
#  ('Cook Islands', 2015, Decimal('100.00'), Decimal('98.00'), 'Cook Islands', 2015, None, None, None),
#  ('Cook Islands', 2016, Decimal('100.00'), Decimal('98.00'), 'Cook Islands', 2016, None, None, None),
#  ('Cook Islands', 2017, Decimal('100.00'), Decimal('99.00'), 'Cook Islands', 2017, None, None, None),
#  ('Cook Islands', 2018, Decimal('100.00'), Decimal('99.00'), 'Cook Islands', 2018, None, None, None),
#  ('Cook Islands', 2019, Decimal('100.00'), Decimal('99.00'), 'Cook Islands', 2019, None, None, None),
#  ('Cook Islands', 2020, Decimal('100.00'), Decimal('99.00'), 'Cook Islands', 2020, None, None, None),
#  ('Costa Rica', 2015, Decimal('99.00'), Decimal('96.33'), 'Costa Rica', 2015, Decimal('56.44'), Decimal('4.895242'), Decimal('8.42')),
#  ('Costa Rica', 2016, Decimal('99.67'), Decimal('96.67'), 'Costa Rica', 2016, Decimal('58.85'), Decimal('4.945205'), Decimal('8.09')),
#  ('Costa Rica', 2017, Decimal('100.00'), Decimal('96.67'), 'Costa Rica', 2017, Decimal('60.52'), Decimal('4.993842'), Decimal('7.73')),
#  ('Costa Rica', 2018, Decimal('100.00'), Decimal('97.33'), 'Costa Rica', 2018, Decimal('62.42'), Decimal('5.040734'), Decimal('9.01')),
#  ('Costa Rica', 2019, Decimal('100.00'), Decimal('97.33'), 'Costa Rica', 2019, Decimal('64.42'), Decimal('5.084532'), Decimal('10.81')),
#  ('Costa Rica', 2020, Decimal('100.00'), Decimal('97.67'), 'Costa Rica', 2020, Decimal('62.16'), Decimal('5.123105'), Decimal('16.43')),
#  ("Côte d'Ivoire", 2015, Decimal('71.33'), Decimal('30.67'), "Côte d'Ivoire", 2015, None, None, None),
#  ("Côte d'Ivoire", 2016, Decimal('71.00'), Decimal('31.33'), "Côte d'Ivoire", 2016, None, None, None),
#  ("Côte d'Ivoire", 2017, Decimal('71.00'), Decimal('32.00'), "Côte d'Ivoire", 2017, None, None, None),
#  ("Côte d'Ivoire", 2018, Decimal('71.00'), Decimal('33.00'), "Côte d'Ivoire", 2018, None, None, None),
#  ("Côte d'Ivoire", 2019, Decimal('70.67'), Decimal('33.67'), "Côte d'Ivoire", 2019, None, None, None),
#  ("Côte d'Ivoire", 2020, Decimal('70.67'), Decimal('34.67'), "Côte d'Ivoire", 2020, None, None, None),
#  ('Cuba', 2015, Decimal('94.67'), Decimal('88.67'), 'Cuba', 2015, Decimal('87.13'), Decimal('11.339894'), Decimal('2.40')),
#  ('Cuba', 2016, Decimal('95.00'), Decimal('89.00'), 'Cuba', 2016, Decimal('91.37'), Decimal('11.342012'), Decimal('2.00')),
#  ('Cuba', 2017, Decimal('95.33'), Decimal('89.33'), 'Cuba', 2017, Decimal('96.85'), Decimal('11.336405'), Decimal('1.70')),
#  ('Cuba', 2018, Decimal('96.00'), Decimal('89.67'), 'Cuba', 2018, Decimal('100.05'), Decimal('11.328244'), Decimal('1.70')),
#  ('Cuba', 2019, Decimal('96.33'), Decimal('90.00'), 'Cuba', 2019, Decimal('103.43'), Decimal('11.316697'), None),
#  ('Cuba', 2020, Decimal('96.33'), Decimal('90.00'), 'Cuba', 2020, Decimal('107.35'), Decimal('11.300698'), None),
#  ('Curaçao', 2015, Decimal('99.00'), Decimal('99.00'), 'Curaçao', 2015, None, None, None),
#  ('Curaçao', 2016, Decimal('99.00'), Decimal('99.00'), 'Curaçao', 2016, None, None, None),
#  ('Curaçao', 2017, Decimal('99.00'), Decimal('99.00'), 'Curaçao', 2017, None, None, None),
#  ('Cyprus', 2015, Decimal('100.00'), Decimal('99.33'), 'Cyprus', 2015, Decimal('19.91'), Decimal('1.187280'), Decimal('15.03')),
#  ('Cyprus', 2016, Decimal('100.00'), Decimal('99.33'), 'Cyprus', 2016, Decimal('21.05'), Decimal('1.197881'), Decimal('13.01')),
#  ('Cyprus', 2017, Decimal('100.00'), Decimal('99.33'), 'Cyprus', 2017, Decimal('22.95'), Decimal('1.208523'), Decimal('11.16')),
#  ('Cyprus', 2018, Decimal('100.00'), Decimal('99.33'), 'Cyprus', 2018, Decimal('25.60'), Decimal('1.218831'), Decimal('8.50')),
#  ('Cyprus', 2019, Decimal('100.00'), Decimal('99.33'), 'Cyprus', 2019, Decimal('25.94'), Decimal('1.228836'), Decimal('7.15')),
#  ('Cyprus', 2020, Decimal('100.00'), Decimal('99.33'), 'Cyprus', 2020, Decimal('25.01'), Decimal('1.237537'), Decimal('7.76')),
#  ("Democratic People's Republic of Korea", 2015, Decimal('94.67'), Decimal('80.33'), "Democratic People's Republic of Korea", 2015, None, None, None),
#  ("Democratic People's Republic of Korea", 2016, Decimal('94.33'), Decimal('81.00'), "Democratic People's Republic of Korea", 2016, None, None, None),
#  ("Democratic People's Republic of Korea", 2017, Decimal('94.00'), Decimal('81.67'), "Democratic People's Republic of Korea", 2017, None, None, None),
#  ("Democratic People's Republic of Korea", 2018, Decimal('93.33'), Decimal('82.67'), "Democratic People's Republic of Korea", 2018, None, None, None),
#  ("Democratic People's Republic of Korea", 2019, Decimal('93.33'), Decimal('83.33'), "Democratic People's Republic of Korea", 2019, None, None, None),
#  ("Democratic People's Republic of Korea", 2020, Decimal('93.33'), Decimal('83.33'), "Democratic People's Republic of Korea", 2020, None, None, None),
#  ('Democratic Republic of the Congo', 2015, Decimal('45.33'), Decimal('17.67'), 'Democratic Republic of the Congo', 2015, None, None, None),
#  ('Democratic Republic of the Congo', 2016, Decimal('45.67'), Decimal('17.33'), 'Democratic Republic of the Congo', 2016, None, None, None),
#  ('Democratic Republic of the Congo', 2017, Decimal('46.00'), Decimal('17.00'), 'Democratic Republic of the Congo', 2017, None, None, None),
#  ('Democratic Republic of the Congo', 2018, Decimal('46.67'), Decimal('16.33'), 'Democratic Republic of the Congo', 2018, None, None, None),
#  ('Democratic Republic of the Congo', 2019, Decimal('47.00'), Decimal('16.33'), 'Democratic Republic of the Congo', 2019, None, None, None),
#  ('Democratic Republic of the Congo', 2020, Decimal('47.67'), Decimal('15.33'), 'Democratic Republic of the Congo', 2020, None, None, None),
#  ('Djibouti', 2015, Decimal('69.67'), Decimal('51.33'), 'Djibouti', 2015, Decimal('2.42'), Decimal('1.006259'), None),
#  ('Djibouti', 2016, Decimal('69.33'), Decimal('52.67'), 'Djibouti', 2016, Decimal('2.60'), Decimal('1.023261'), None),
#  ('Djibouti', 2017, Decimal('69.33'), Decimal('53.67'), 'Djibouti', 2017, Decimal('2.76'), Decimal('1.040233'), Decimal('26.06')),
#  ('Djibouti', 2018, Decimal('69.33'), Decimal('54.67'), 'Djibouti', 2018, Decimal('2.91'), Decimal('1.057198'), None),
#  ('Djibouti', 2019, Decimal('69.00'), Decimal('56.00'), 'Djibouti', 2019, Decimal('3.09'), Decimal('1.073994'), None),
#  ('Djibouti', 2020, Decimal('69.00'), Decimal('56.00'), 'Djibouti', 2020, Decimal('3.18'), Decimal('1.090156'), None),
#  ('Dominica', 2015, Decimal('95.00'), Decimal('80.00'), 'Dominica', 2015, Decimal('0.54'), Decimal('0.070007'), None),
#  ('Dominica', 2016, Decimal('95.00'), Decimal('80.00'), 'Dominica', 2016, Decimal('0.58'), Decimal('0.070075'), None),
#  ('Dominica', 2017, Decimal('95.00'), Decimal('80.00'), 'Dominica', 2017, Decimal('0.52'), Decimal('0.070403'), None),
#  ('Dominican Republic', 2015, Decimal('94.33'), Decimal('82.33'), 'Dominican Republic', 2015, Decimal('71.16'), Decimal('10.405832'), Decimal('7.61')),
#  ('Dominican Republic', 2016, Decimal('94.67'), Decimal('83.00'), 'Dominican Republic', 2016, Decimal('75.70'), Decimal('10.527592'), Decimal('7.28')),
#  ('Dominican Republic', 2017, Decimal('94.67'), Decimal('83.33'), 'Dominican Republic', 2017, Decimal('80.00'), Decimal('10.647244'), Decimal('5.83')),
#  ('Dominican Republic', 2018, Decimal('95.00'), Decimal('83.67'), 'Dominican Republic', 2018, Decimal('85.56'), Decimal('10.765531'), Decimal('5.86')),
#  ('Dominican Republic', 2019, Decimal('95.00'), Decimal('84.33'), 'Dominican Republic', 2019, Decimal('88.94'), Decimal('10.881882'), Decimal('6.18')),
#  ('Dominican Republic', 2020, Decimal('95.00'), Decimal('84.33'), 'Dominican Republic', 2020, Decimal('78.84'), Decimal('10.999664'), Decimal('6.13')),
#  ('Ecuador', 2015, Decimal('91.67'), Decimal('85.33'), 'Ecuador', 2015, Decimal('99.29'), Decimal('16.195902'), Decimal('3.62')),
#  ('Ecuador', 2016, Decimal('92.33'), Decimal('87.00'), 'Ecuador', 2016, Decimal('99.94'), Decimal('16.439585'), Decimal('4.60')),
#  ('Ecuador', 2017, Decimal('92.67'), Decimal('88.33'), 'Ecuador', 2017, Decimal('104.30'), Decimal('16.696944'), Decimal('3.84')),
#  ('Ecuador', 2018, Decimal('93.33'), Decimal('89.33'), 'Ecuador', 2018, Decimal('107.56'), Decimal('17.015672'), Decimal('3.53')),
#  ('Ecuador', 2019, Decimal('93.67'), Decimal('90.00'), 'Ecuador', 2019, Decimal('108.11'), Decimal('17.343740'), Decimal('3.81')),
#  ('Ecuador', 2020, Decimal('94.00'), Decimal('91.33'), 'Ecuador', 2020, Decimal('99.29'), Decimal('17.588595'), Decimal('6.11')),
#  ('Egypt', 2015, Decimal('99.33'), Decimal('96.33'), 'Egypt', 2015, None, None, None),
#  ('Egypt', 2016, Decimal('99.33'), Decimal('96.33'), 'Egypt', 2016, None, None, None),
#  ('Egypt', 2017, Decimal('99.33'), Decimal('96.33'), 'Egypt', 2017, None, None, None),
#  ('Egypt', 2018, Decimal('99.33'), Decimal('97.00'), 'Egypt', 2018, None, None, None),
#  ('Egypt', 2019, Decimal('99.33'), Decimal('97.00'), 'Egypt', 2019, None, None, None),
#  ('Egypt', 2020, Decimal('99.33'), Decimal('97.67'), 'Egypt', 2020, None, None, None),
#  ('El Salvador', 2015, Decimal('94.33'), Decimal('81.00'), 'El Salvador', 2015, Decimal('23.44'), Decimal('6.231066'), Decimal('4.00')),
#  ('El Salvador', 2016, Decimal('95.33'), Decimal('81.00'), 'El Salvador', 2016, Decimal('24.19'), Decimal('6.250510'), Decimal('4.42')),
#  ('El Salvador', 2017, Decimal('96.00'), Decimal('80.67'), 'El Salvador', 2017, Decimal('24.98'), Decimal('6.266654'), Decimal('4.39')),
#  ('El Salvador', 2018, Decimal('97.00'), Decimal('80.33'), 'El Salvador', 2018, Decimal('26.02'), Decimal('6.276342'), Decimal('4.01')),
#  ('El Salvador', 2019, Decimal('97.00'), Decimal('80.33'), 'El Salvador', 2019, Decimal('26.88'), Decimal('6.280217'), Decimal('4.17')),
#  ('El Salvador', 2020, Decimal('97.00'), Decimal('79.67'), 'El Salvador', 2020, Decimal('24.56'), Decimal('6.292731'), Decimal('5.01')),
#  ('Equatorial Guinea', 2015, Decimal('57.67'), Decimal('64.33'), 'Equatorial Guinea', 2015, Decimal('13.19'), Decimal('1.346973'), None),
#  ('Equatorial Guinea', 2016, Decimal('57.67'), Decimal('64.33'), 'Equatorial Guinea', 2016, Decimal('11.24'), Decimal('1.398927'), None),
#  ('Equatorial Guinea', 2017, Decimal('58.00'), Decimal('64.33'), 'Equatorial Guinea', 2017, Decimal('12.20'), Decimal('1.450694'), None),
#  ('Eritrea', 2015, Decimal('56.33'), Decimal('13.33'), 'Eritrea', 2015, None, Decimal('3.340006'), None),
#  ('Eritrea', 2016, Decimal('56.67'), Decimal('13.33'), 'Eritrea', 2016, None, Decimal('3.365287'), None),
#  ('Eswatini', 2015, Decimal('73.33'), Decimal('59.33'), 'Eswatini', 2015, Decimal('4.06'), Decimal('1.133936'), None),
#  ('Eswatini', 2016, Decimal('74.00'), Decimal('60.00'), 'Eswatini', 2016, Decimal('3.82'), Decimal('1.142524'), Decimal('22.72')),
#  ('Eswatini', 2017, Decimal('75.00'), Decimal('60.00'), 'Eswatini', 2017, Decimal('4.40'), Decimal('1.151390'), None),
#  ('Eswatini', 2018, Decimal('75.67'), Decimal('60.67'), 'Eswatini', 2018, Decimal('4.67'), Decimal('1.160428'), None),
#  ('Eswatini', 2019, Decimal('76.67'), Decimal('61.33'), 'Eswatini', 2019, Decimal('4.50'), Decimal('1.169613'), None),
#  ('Eswatini', 2020, Decimal('76.67'), Decimal('61.33'), 'Eswatini', 2020, Decimal('3.98'), Decimal('1.180655'), None),
#  ('Ethiopia', 2015, Decimal('52.00'), Decimal('10.67'), 'Ethiopia', 2015, Decimal('64.59'), Decimal('102.471895'), None),
#  ('Ethiopia', 2016, Decimal('53.33'), Decimal('11.00'), 'Ethiopia', 2016, Decimal('74.30'), Decimal('105.293228'), None),
#  ('Ethiopia', 2017, Decimal('54.67'), Decimal('11.00'), 'Ethiopia', 2017, Decimal('81.77'), Decimal('108.197950'), None),
#  ('Ethiopia', 2018, Decimal('55.67'), Decimal('11.33'), 'Ethiopia', 2018, Decimal('84.27'), Decimal('111.129438'), None),
#  ('Ethiopia', 2019, Decimal('57.00'), Decimal('11.67'), 'Ethiopia', 2019, Decimal('95.91'), Decimal('114.120594'), None),
#  ('Ethiopia', 2020, Decimal('58.00'), Decimal('11.67'), 'Ethiopia', 2020, Decimal('107.66'), Decimal('117.190911'), None),
#  ('Falkland Islands (Malvinas)', 2015, Decimal('91.00'), Decimal('100.00'), 'Falkland Islands (Malvinas)', 2015, None, None, None),
#  ('Falkland Islands (Malvinas)', 2016, Decimal('91.00'), Decimal('100.00'), 'Falkland Islands (Malvinas)', 2016, None, None, None),
#  ('Falkland Islands (Malvinas)', 2017, Decimal('91.00'), Decimal('100.00'), 'Falkland Islands (Malvinas)', 2017, None, None, None),
#  ('Falkland Islands (Malvinas)', 2018, Decimal('91.00'), Decimal('100.00'), 'Falkland Islands (Malvinas)', 2018, None, None, None),
#  ('Falkland Islands (Malvinas)', 2019, Decimal('91.00'), Decimal('100.00'), 'Falkland Islands (Malvinas)', 2019, None, None, None),
#  ('Falkland Islands (Malvinas)', 2020, Decimal('91.00'), Decimal('100.00'), 'Falkland Islands (Malvinas)', 2020, None, None, None),
#  ('Fiji', 2015, Decimal('93.67'), Decimal('96.00'), 'Fiji', 2015, Decimal('4.68'), Decimal('0.917200'), None),
#  ('Fiji', 2016, Decimal('93.67'), Decimal('97.33'), 'Fiji', 2016, Decimal('4.93'), Decimal('0.918371'), Decimal('4.32')),
#  ('Fiji', 2017, Decimal('93.67'), Decimal('98.33'), 'Fiji', 2017, Decimal('5.35'), Decimal('0.919019'), None),
#  ('Fiji', 2018, Decimal('93.67'), Decimal('99.00'), 'Fiji', 2018, Decimal('5.58'), Decimal('0.918996'), None),
#  ('Fiji', 2019, Decimal('93.67'), Decimal('99.00'), 'Fiji', 2019, Decimal('5.48'), Decimal('0.918465'), None),
#  ('Fiji', 2020, Decimal('93.67'), Decimal('99.00'), 'Fiji', 2020, Decimal('4.48'), Decimal('0.920422'), None),
#  ('French Guiana', 2015, Decimal('94.00'), Decimal('92.00'), 'French Guiana', 2015, None, None, None),
#  ('French Guiana', 2016, Decimal('94.00'), Decimal('92.00'), 'French Guiana', 2016, None, None, None),
#  ('French Guiana', 2017, Decimal('94.00'), Decimal('92.00'), 'French Guiana', 2017, None, None, None),
#  ('French Guiana', 2018, Decimal('94.00'), Decimal('92.00'), 'French Guiana', 2018, None, None, None),
#  ('French Guiana', 2019, Decimal('94.00'), Decimal('92.00'), 'French Guiana', 2019, None, None, None),
#  ('French Guiana', 2020, Decimal('94.00'), Decimal('92.00'), 'French Guiana', 2020, None, None, None),
#  ('French Polynesia', 2015, Decimal('100.00'), Decimal('97.00'), 'French Polynesia', 2015, Decimal('5.33'), Decimal('0.291787'), None),
#  ('French Polynesia', 2016, Decimal('100.00'), Decimal('97.00'), 'French Polynesia', 2016, Decimal('5.50'), Decimal('0.293541'), None),
#  ('French Polynesia', 2017, Decimal('100.00'), Decimal('97.00'), 'French Polynesia', 2017, Decimal('5.83'), Decimal('0.295450'), None),
#  ('French Polynesia', 2018, Decimal('100.00'), Decimal('97.00'), 'French Polynesia', 2018, Decimal('6.14'), Decimal('0.297606'), None),
#  ('French Polynesia', 2019, Decimal('100.00'), Decimal('97.00'), 'French Polynesia', 2019, Decimal('6.00'), Decimal('0.299717'), None),
#  ('French Polynesia', 2020, Decimal('100.00'), Decimal('97.00'), 'French Polynesia', 2020, Decimal('5.71'), Decimal('0.301920'), None),
#  ('Gabon', 2015, Decimal('72.00'), Decimal('46.33'), 'Gabon', 2015, Decimal('14.38'), Decimal('2.028517'), None),
#  ('Gabon', 2016, Decimal('72.33'), Decimal('46.33'), 'Gabon', 2016, Decimal('14.02'), Decimal('2.086206'), None),
#  ('Gabon', 2017, Decimal('73.00'), Decimal('46.33'), 'Gabon', 2017, Decimal('14.93'), Decimal('2.140215'), None),
#  ('Gabon', 2018, Decimal('73.00'), Decimal('46.67'), 'Gabon', 2018, Decimal('16.87'), Decimal('2.192012'), None),
#  ('Gabon', 2019, Decimal('73.33'), Decimal('47.00'), 'Gabon', 2019, Decimal('16.87'), Decimal('2.242785'), None),
#  ('Gabon', 2020, Decimal('73.33'), Decimal('47.00'), 'Gabon', 2020, Decimal('15.31'), Decimal('2.292573'), None),
#  ('Gambia', 2015, Decimal('78.00'), Decimal('45.00'), 'Gambia', 2015, None, None, None),
#  ('Gambia', 2016, Decimal('78.33'), Decimal('45.00'), 'Gambia', 2016, None, None, None),
#  ('Gambia', 2017, Decimal('78.67'), Decimal('44.67'), 'Gambia', 2017, None, None, None),
#  ('Gambia', 2018, Decimal('78.67'), Decimal('44.67'), 'Gambia', 2018, None, None, None),
#  ('Gambia', 2019, Decimal('79.33'), Decimal('44.33'), 'Gambia', 2019, None, None, None),
#  ('Gambia', 2020, Decimal('79.33'), Decimal('44.33'), 'Gambia', 2020, None, None, None),
#  ('Georgia', 2015, Decimal('95.33'), Decimal('85.67'), 'Georgia', 2015, Decimal('14.95'), Decimal('3.725276'), Decimal('16.51')),
#  ('Georgia', 2016, Decimal('96.00'), Decimal('85.00'), 'Georgia', 2016, Decimal('15.14'), Decimal('3.727505'), Decimal('16.60')),
#  ('Georgia', 2017, Decimal('96.67'), Decimal('85.33'), 'Georgia', 2017, Decimal('16.24'), Decimal('3.728004'), Decimal('13.94')),
#  ('Georgia', 2018, Decimal('96.67'), Decimal('85.00'), 'Georgia', 2018, Decimal('17.60'), Decimal('3.726549'), Decimal('12.67')),
#  ('Georgia', 2019, Decimal('96.67'), Decimal('84.67'), 'Georgia', 2019, Decimal('17.47'), Decimal('3.720161'), Decimal('11.57')),
#  ('Georgia', 2020, Decimal('96.67'), Decimal('84.33'), 'Georgia', 2020, Decimal('15.84'), Decimal('3.722716'), Decimal('11.73')),
#  ('Ghana', 2015, Decimal('79.33'), Decimal('18.67'), 'Ghana', 2015, Decimal('49.41'), Decimal('28.870939'), Decimal('6.81')),
#  ('Ghana', 2016, Decimal('80.33'), Decimal('19.67'), 'Ghana', 2016, Decimal('56.17'), Decimal('29.554303'), None),
#  ('Ghana', 2017, Decimal('81.33'), Decimal('20.67'), 'Ghana', 2017, Decimal('60.41'), Decimal('30.222262'), Decimal('3.37')),
#  ('Ghana', 2018, Decimal('82.67'), Decimal('21.67'), 'Ghana', 2018, Decimal('67.30'), Decimal('30.870641'), None),
#  ('Ghana', 2019, Decimal('83.67'), Decimal('22.67'), 'Ghana', 2019, Decimal('68.34'), Decimal('31.522290'), None),
#  ('Ghana', 2020, Decimal('84.67'), Decimal('23.00'), 'Ghana', 2020, Decimal('70.04'), Decimal('32.180401'), None),
#  ('Greenland', 2015, Decimal('100.00'), Decimal('100.00'), 'Greenland', 2015, Decimal('2.50'), Decimal('0.056114'), Decimal('9.10')),
#  ('Greenland', 2016, Decimal('100.00'), Decimal('100.00'), 'Greenland', 2016, Decimal('2.71'), Decimal('0.056186'), None),
#  ('Greenland', 2017, Decimal('100.00'), Decimal('100.00'), 'Greenland', 2017, Decimal('2.85'), Decimal('0.056171'), None),
#  ('Greenland', 2018, Decimal('100.00'), Decimal('100.00'), 'Greenland', 2018, Decimal('3.06'), Decimal('0.056023'), None),
#  ('Greenland', 2019, Decimal('100.00'), Decimal('100.00'), 'Greenland', 2019, Decimal('2.99'), Decimal('0.056225'), None),
#  ('Greenland', 2020, Decimal('100.00'), Decimal('100.00'), 'Greenland', 2020, Decimal('3.08'), Decimal('0.056367'), None),
#  ('Grenada', 2015, Decimal('96.00'), Decimal('91.00'), 'Grenada', 2015, Decimal('1.00'), Decimal('0.118980'), Decimal('22.90')),
#  ('Grenada', 2016, Decimal('96.00'), Decimal('91.00'), 'Grenada', 2016, Decimal('1.06'), Decimal('0.119966'), None),
#  ('Grenada', 2017, Decimal('96.00'), Decimal('91.00'), 'Grenada', 2017, Decimal('1.13'), Decimal('0.120921'), None),
#  ('Guadeloupe', 2015, Decimal('100.00'), Decimal('99.00'), 'Guadeloupe', 2015, None, None, None),
#  ('Guadeloupe', 2016, Decimal('100.00'), Decimal('99.00'), 'Guadeloupe', 2016, None, None, None),
#  ('Guadeloupe', 2017, Decimal('100.00'), Decimal('99.00'), 'Guadeloupe', 2017, None, None, None),
#  ('Guadeloupe', 2018, Decimal('100.00'), Decimal('99.00'), 'Guadeloupe', 2018, None, None, None),
#  ('Guadeloupe', 2019, Decimal('100.00'), Decimal('100.00'), 'Guadeloupe', 2019, None, None, None),
#  ('Guadeloupe', 2020, Decimal('100.00'), Decimal('100.00'), 'Guadeloupe', 2020, None, None, None),
#  ('Guam', 2015, Decimal('100.00'), Decimal('90.00'), 'Guam', 2015, Decimal('5.80'), Decimal('0.167978'), Decimal('6.90')),
#  ('Guam', 2016, Decimal('100.00'), Decimal('90.00'), 'Guam', 2016, Decimal('5.90'), Decimal('0.168346'), Decimal('5.40')),
#  ('Guam', 2017, Decimal('100.00'), None, 'Guam', 2017, Decimal('6.01'), Decimal('0.168606'), None),
#  ('Guam', 2018, Decimal('100.00'), None, 'Guam', 2018, Decimal('6.06'), Decimal('0.168678'), None),
#  ('Guam', 2019, Decimal('100.00'), None, 'Guam', 2019, Decimal('6.37'), Decimal('0.168624'), None),
#  ('Guam', 2020, Decimal('100.00'), None, 'Guam', 2020, Decimal('5.89'), Decimal('0.169231'), None),
#  ('Guatemala', 2015, Decimal('92.00'), Decimal('67.00'), 'Guatemala', 2015, Decimal('62.19'), Decimal('15.567419'), Decimal('2.51')),
#  ('Guatemala', 2016, Decimal('92.33'), Decimal('67.00'), 'Guatemala', 2016, Decimal('66.05'), Decimal('15.827690'), Decimal('2.58')),
#  ('Guatemala', 2017, Decimal('92.67'), Decimal('67.00'), 'Guatemala', 2017, Decimal('71.65'), Decimal('16.087418'), Decimal('2.46')),
#  ('Guatemala', 2018, Decimal('93.00'), Decimal('67.33'), 'Guatemala', 2018, Decimal('73.33'), Decimal('16.346950'), Decimal('2.28')),
#  ('Guatemala', 2019, Decimal('94.00'), Decimal('67.67'), 'Guatemala', 2019, Decimal('77.17'), Decimal('16.604026'), Decimal('2.19')),
#  ('Guatemala', 2020, Decimal('94.00'), Decimal('67.67'), 'Guatemala', 2020, Decimal('77.63'), Decimal('16.858333'), None),
#  ('Guinea', 2015, Decimal('67.00'), Decimal('26.00'), 'Guinea', 2015, Decimal('8.79'), Decimal('11.625998'), None),
#  ('Guinea', 2016, Decimal('67.00'), Decimal('27.33'), 'Guinea', 2016, Decimal('8.60'), Decimal('11.930985'), None),
#  ('Guinea', 2017, Decimal('67.33'), Decimal('28.33'), 'Guinea', 2017, Decimal('10.32'), Decimal('12.240789'), None),
#  ('Guinea', 2018, Decimal('67.00'), Decimal('29.67'), 'Guinea', 2018, Decimal('11.86'), Decimal('12.554864'), None),
#  ('Guinea', 2019, Decimal('67.00'), Decimal('30.67'), 'Guinea', 2019, Decimal('13.44'), Decimal('12.877539'), Decimal('5.02')),
#  ('Guinea', 2020, Decimal('67.33'), Decimal('32.33'), 'Guinea', 2020, Decimal('14.18'), Decimal('13.205153'), None),
# ...
#  ('State of Palestine', 2018, Decimal('97.00'), Decimal('97.67'), 'State of Palestine', 2018, None, None, None),
#  ('State of Palestine', 2019, Decimal('97.67'), Decimal('97.67'), 'State of Palestine', 2019, None, None, None),
#  ('State of Palestine', 2020, Decimal('98.33'), Decimal('98.67'), 'State of Palestine', 2020, None, None, None),
#  ('Sudan', 2015, Decimal('61.33'), Decimal('38.67'), 'Sudan', 2015, Decimal('84.99'), Decimal('38.171178'), None),
#  ('Sudan', 2016, Decimal('62.33'), Decimal('40.00'), 'Sudan', 2016, Decimal('102.94'), Decimal('39.377169'), None),
#  ('Sudan', 2017, Decimal('62.33'), Decimal('40.33'), 'Sudan', 2017, Decimal('129.72'), Decimal('40.679828'), None),
#  ('Sudan', 2018, Decimal('62.33'), Decimal('40.33'), 'Sudan', 2018, Decimal('32.33'), Decimal('41.999059'), None),
#  ('Sudan', 2019, Decimal('62.33'), Decimal('40.33'), 'Sudan', 2019, Decimal('32.34'), Decimal('43.232093'), None),
#  ('Sudan', 2020, Decimal('62.33'), Decimal('40.33'), 'Sudan', 2020, Decimal('27.03'), Decimal('44.440486'), None),
#  ('Suriname', 2015, Decimal('95.00'), Decimal('84.67'), 'Suriname', 2015, Decimal('5.13'), Decimal('0.575475'), Decimal('7.22')),
#  ('Suriname', 2016, Decimal('95.33'), Decimal('85.33'), 'Suriname', 2016, Decimal('3.32'), Decimal('0.581453'), Decimal('7.92')),
#  ('Suriname', 2017, Decimal('96.33'), Decimal('86.33'), 'Suriname', 2017, Decimal('3.59'), Decimal('0.587559'), None),
#  ('Suriname', 2018, Decimal('96.67'), Decimal('87.33'), 'Suriname', 2018, Decimal('4.00'), Decimal('0.593715'), None),
#  ('Suriname', 2019, Decimal('97.33'), Decimal('87.67'), 'Suriname', 2019, Decimal('4.02'), Decimal('0.600301'), None),
#  ('Suriname', 2020, Decimal('98.00'), Decimal('88.67'), 'Suriname', 2020, Decimal('2.91'), Decimal('0.607065'), None),
#  ('Syrian Arab Republic', 2015, Decimal('93.33'), Decimal('90.00'), 'Syrian Arab Republic', 2015, Decimal('16.47'), Decimal('19.205178'), None),
#  ('Syrian Arab Republic', 2016, Decimal('93.67'), Decimal('90.00'), 'Syrian Arab Republic', 2016, Decimal('12.60'), Decimal('18.964252'), None),
#  ('Syrian Arab Republic', 2017, Decimal('93.67'), Decimal('90.00'), 'Syrian Arab Republic', 2017, Decimal('16.37'), Decimal('18.983373'), None),
#  ('Syrian Arab Republic', 2018, Decimal('93.67'), Decimal('89.67'), 'Syrian Arab Republic', 2018, Decimal('21.35'), Decimal('19.333463'), None),
#  ('Syrian Arab Republic', 2019, Decimal('93.67'), Decimal('90.00'), 'Syrian Arab Republic', 2019, Decimal('22.44'), Decimal('20.098251'), None),
#  ('Syrian Arab Republic', 2020, Decimal('93.67'), Decimal('90.00'), 'Syrian Arab Republic', 2020, Decimal('11.08'), Decimal('20.772595'), None),
#  ('Tajikistan', 2015, Decimal('80.33'), Decimal('95.00'), 'Tajikistan', 2015, Decimal('8.27'), Decimal('8.524063'), None),
#  ('Tajikistan', 2016, Decimal('81.33'), Decimal('95.33'), 'Tajikistan', 2016, Decimal('6.99'), Decimal('8.725318'), Decimal('6.90')),
#  ('Tajikistan', 2017, Decimal('82.33'), Decimal('95.67'), 'Tajikistan', 2017, Decimal('7.54'), Decimal('8.925525'), None),
#  ('Tajikistan', 2018, Decimal('83.33'), Decimal('95.67'), 'Tajikistan', 2018, Decimal('7.77'), Decimal('9.128132'), None),
#  ('Tajikistan', 2019, Decimal('85.00'), Decimal('96.33'), 'Tajikistan', 2019, Decimal('8.30'), Decimal('9.337003'), None),
#  ('Tajikistan', 2020, Decimal('85.00'), Decimal('96.33'), 'Tajikistan', 2020, Decimal('8.13'), Decimal('9.543207'), None),
#  ('Thailand', 2015, Decimal('99.33'), Decimal('97.00'), 'Thailand', 2015, Decimal('401.30'), Decimal('70.294397'), Decimal('0.60')),
#  ('Thailand', 2016, Decimal('99.33'), Decimal('97.33'), 'Thailand', 2016, Decimal('413.37'), Decimal('70.607037'), Decimal('0.69')),
#  ('Thailand', 2017, Decimal('100.00'), Decimal('98.00'), 'Thailand', 2017, Decimal('456.36'), Decimal('70.898202'), Decimal('0.83')),
#  ('Thailand', 2018, Decimal('100.00'), Decimal('98.00'), 'Thailand', 2018, Decimal('506.75'), Decimal('71.127802'), Decimal('0.77')),
#  ('Thailand', 2019, Decimal('100.00'), Decimal('98.33'), 'Thailand', 2019, Decimal('544.08'), Decimal('71.307763'), Decimal('0.72')),
#  ('Thailand', 2020, Decimal('100.00'), Decimal('98.67'), 'Thailand', 2020, Decimal('499.68'), Decimal('71.475664'), Decimal('1.10')),
#  ('Timor-Leste', 2015, Decimal('78.00'), Decimal('55.00'), 'Timor-Leste', 2015, Decimal('1.59'), Decimal('1.205813'), None),
#  ('Timor-Leste', 2016, Decimal('80.67'), Decimal('55.67'), 'Timor-Leste', 2016, Decimal('1.65'), Decimal('1.224562'), Decimal('4.66')),
#  ('Timor-Leste', 2017, Decimal('82.33'), Decimal('57.33'), 'Timor-Leste', 2017, Decimal('1.60'), Decimal('1.243235'), None),
#  ('Timor-Leste', 2018, Decimal('84.33'), Decimal('58.00'), 'Timor-Leste', 2018, Decimal('1.56'), Decimal('1.261845'), None),
#  ('Timor-Leste', 2019, Decimal('86.00'), Decimal('59.00'), 'Timor-Leste', 2019, Decimal('2.03'), Decimal('1.280438'), None),
#  ('Timor-Leste', 2020, Decimal('87.00'), Decimal('60.00'), 'Timor-Leste', 2020, Decimal('2.16'), Decimal('1.299995'), None),
#  ('Togo', 2015, Decimal('66.33'), Decimal('17.67'), 'Togo', 2015, Decimal('4.18'), Decimal('7.473229'), Decimal('2.20')),
#  ('Togo', 2016, Decimal('67.33'), Decimal('18.33'), 'Togo', 2016, Decimal('6.03'), Decimal('7.661354'), None),
#  ('Togo', 2017, Decimal('68.33'), Decimal('18.33'), 'Togo', 2017, Decimal('6.40'), Decimal('7.852795'), Decimal('3.74')),
#  ('Togo', 2018, Decimal('69.33'), Decimal('19.33'), 'Togo', 2018, Decimal('7.11'), Decimal('8.046679'), None),
#  ('Togo', 2019, Decimal('70.33'), Decimal('19.67'), 'Togo', 2019, Decimal('7.22'), Decimal('8.243094'), None),
#  ('Togo', 2020, Decimal('70.67'), Decimal('20.00'), 'Togo', 2020, Decimal('7.57'), Decimal('8.442580'), None),
#  ('Tokelau', 2015, Decimal('99.00'), Decimal('94.00'), 'Tokelau', 2015, None, None, None),
#  ('Tokelau', 2016, Decimal('100.00'), Decimal('96.00'), 'Tokelau', 2016, None, None, None),
#  ('Tokelau', 2017, Decimal('100.00'), Decimal('97.00'), 'Tokelau', 2017, None, None, None),
#  ('Tokelau', 2018, Decimal('100.00'), Decimal('97.00'), 'Tokelau', 2018, None, None, None),
#  ('Tokelau', 2019, Decimal('100.00'), Decimal('97.00'), 'Tokelau', 2019, None, None, None),
#  ('Tokelau', 2020, Decimal('100.00'), Decimal('97.00'), 'Tokelau', 2020, None, None, None),
#  ('Tonga', 2015, Decimal('98.67'), Decimal('94.00'), 'Tonga', 2015, Decimal('0.44'), Decimal('0.106122'), None),
#  ('Tonga', 2016, Decimal('98.67'), Decimal('94.00'), 'Tonga', 2016, Decimal('0.42'), Decimal('0.105707'), None),
#  ('Tonga', 2017, Decimal('98.67'), Decimal('93.67'), 'Tonga', 2017, Decimal('0.46'), Decimal('0.105415'), None),
#  ('Tonga', 2018, Decimal('98.67'), Decimal('93.67'), 'Tonga', 2018, Decimal('0.49'), Decimal('0.105150'), Decimal('2.25')),
#  ('Tonga', 2019, Decimal('98.67'), Decimal('93.67'), 'Tonga', 2019, Decimal('0.51'), Decimal('0.104951'), None),
#  ('Tonga', 2020, Decimal('99.00'), Decimal('93.33'), 'Tonga', 2020, Decimal('0.48'), Decimal('0.105254'), None),
#  ('Trinidad and Tobago', 2015, Decimal('98.00'), Decimal('94.00'), 'Trinidad and Tobago', 2015, Decimal('26.85'), Decimal('1.460177'), Decimal('2.43')),
#  ('Trinidad and Tobago', 2016, Decimal('99.00'), Decimal('94.00'), 'Trinidad and Tobago', 2016, Decimal('23.50'), Decimal('1.469330'), Decimal('3.21')),
#  ('Trinidad and Tobago', 2017, Decimal('99.00'), Decimal('94.00'), 'Trinidad and Tobago', 2017, Decimal('23.80'), Decimal('1.478607'), None),
#  ('Trinidad and Tobago', 2018, Decimal('99.00'), Decimal('94.00'), 'Trinidad and Tobago', 2018, Decimal('24.32'), Decimal('1.504709'), None),
#  ('Trinidad and Tobago', 2019, Decimal('99.00'), Decimal('94.00'), 'Trinidad and Tobago', 2019, Decimal('23.85'), Decimal('1.519955'), Decimal('3.52')),
#  ('Trinidad and Tobago', 2020, Decimal('99.00'), Decimal('94.00'), 'Trinidad and Tobago', 2020, Decimal('21.06'), Decimal('1.518147'), Decimal('4.21')),
#  ('Tunisia', 2015, Decimal('93.33'), Decimal('90.33'), 'Tunisia', 2015, Decimal('45.78'), Decimal('11.557779'), Decimal('15.16')),
#  ('Tunisia', 2016, Decimal('93.67'), Decimal('92.00'), 'Tunisia', 2016, Decimal('44.36'), Decimal('11.685667'), Decimal('15.56')),
#  ('Tunisia', 2017, Decimal('94.67'), Decimal('93.00'), 'Tunisia', 2017, Decimal('42.16'), Decimal('11.811443'), Decimal('15.33')),
#  ('Tunisia', 2018, Decimal('95.67'), Decimal('94.33'), 'Tunisia', 2018, Decimal('42.69'), Decimal('11.933041'), Decimal('15.46')),
#  ('Tunisia', 2019, Decimal('96.00'), Decimal('95.67'), 'Tunisia', 2019, Decimal('41.91'), Decimal('12.049314'), Decimal('15.13')),
#  ('Tunisia', 2020, Decimal('97.00'), Decimal('97.33'), 'Tunisia', 2020, Decimal('42.54'), Decimal('12.161723'), None),
#  ('Türkiye', 2015, Decimal('95.67'), Decimal('95.00'), 'Türkiye', 2015, None, None, None),
#  ('Türkiye', 2016, Decimal('96.00'), Decimal('95.67'), 'Türkiye', 2016, None, None, None),
#  ('Türkiye', 2017, Decimal('96.33'), Decimal('96.67'), 'Türkiye', 2017, None, None, None),
#  ('Türkiye', 2018, Decimal('96.33'), Decimal('97.00'), 'Türkiye', 2018, None, None, None),
#  ('Türkiye', 2019, Decimal('96.67'), Decimal('98.33'), 'Türkiye', 2019, None, None, None),
#  ('Türkiye', 2020, Decimal('96.67'), Decimal('98.67'), 'Türkiye', 2020, None, None, None),
#  ('Turkmenistan', 2015, Decimal('97.67'), Decimal('97.33'), 'Turkmenistan', 2015, Decimal('35.80'), Decimal('5.766431'), None),
#  ('Turkmenistan', 2016, Decimal('98.00'), Decimal('98.00'), 'Turkmenistan', 2016, Decimal('36.17'), Decimal('5.868561'), None),
#  ('Turkmenistan', 2017, Decimal('98.67'), Decimal('98.00'), 'Turkmenistan', 2017, Decimal('37.93'), Decimal('5.968383'), None),
#  ('Turkmenistan', 2018, Decimal('99.33'), Decimal('98.67'), 'Turkmenistan', 2018, Decimal('40.77'), Decimal('6.065066'), None),
#  ('Turkmenistan', 2019, Decimal('100.00'), Decimal('99.33'), 'Turkmenistan', 2019, Decimal('45.23'), Decimal('6.158420'), None),
#  ('Turkmenistan', 2020, Decimal('100.00'), Decimal('99.33'), 'Turkmenistan', 2020, None, Decimal('6.250438'), None),
#  ('Turks and Caicos Islands', 2015, Decimal('94.00'), Decimal('88.00'), 'Turks and Caicos Islands', 2015, Decimal('0.94'), Decimal('0.036538'), None),
#  ('Turks and Caicos Islands', 2016, Decimal('94.00'), Decimal('88.00'), 'Turks and Caicos Islands', 2016, Decimal('1.03'), Decimal('0.038246'), None),
#  ('Turks and Caicos Islands', 2017, Decimal('94.00'), Decimal('88.00'), 'Turks and Caicos Islands', 2017, Decimal('1.02'), Decimal('0.039844'), None),
#  ('Turks and Caicos Islands', 2018, Decimal('94.00'), Decimal('88.00'), 'Turks and Caicos Islands', 2018, Decimal('1.11'), Decimal('0.041487'), None),
#  ('Tuvalu', 2015, Decimal('100.00'), Decimal('83.67'), 'Tuvalu', 2015, Decimal('0.04'), Decimal('0.010877'), None),
#  ('Tuvalu', 2016, Decimal('100.00'), Decimal('83.67'), 'Tuvalu', 2016, Decimal('0.04'), Decimal('0.010852'), Decimal('8.49')),
#  ('Tuvalu', 2017, Decimal('100.00'), Decimal('83.67'), 'Tuvalu', 2017, Decimal('0.05'), Decimal('0.010828'), Decimal('26.55')),
#  ('Tuvalu', 2018, Decimal('100.00'), Decimal('83.67'), 'Tuvalu', 2018, Decimal('0.05'), Decimal('0.010865'), None),
#  ('Tuvalu', 2019, Decimal('100.00'), None, 'Tuvalu', 2019, Decimal('0.05'), Decimal('0.010956'), None),
#  ('Tuvalu', 2020, Decimal('100.00'), None, 'Tuvalu', 2020, Decimal('0.06'), Decimal('0.011069'), None),
#  ('Uganda', 2015, Decimal('55.00'), Decimal('21.33'), 'Uganda', 2015, Decimal('32.39'), Decimal('37.477356'), None),
#  ('Uganda', 2016, Decimal('55.67'), Decimal('21.33'), 'Uganda', 2016, Decimal('29.20'), Decimal('38.748299'), None),
#  ('Uganda', 2017, Decimal('57.00'), Decimal('21.33'), 'Uganda', 2017, Decimal('30.74'), Decimal('40.127085'), Decimal('3.64')),
#  ('Uganda', 2018, Decimal('58.67'), Decimal('21.67'), 'Uganda', 2018, Decimal('32.93'), Decimal('41.515395'), None),
#  ('Uganda', 2019, Decimal('59.33'), Decimal('21.67'), 'Uganda', 2019, Decimal('35.35'), Decimal('42.949080'), None),
#  ('Uganda', 2020, Decimal('61.00'), Decimal('21.67'), 'Uganda', 2020, Decimal('37.60'), Decimal('44.404611'), None),
#  ('United Arab Emirates', 2015, Decimal('100.00'), Decimal('99.00'), 'United Arab Emirates', 2015, Decimal('370.28'), Decimal('8.916899'), None),
#  ('United Arab Emirates', 2016, Decimal('100.00'), Decimal('99.00'), 'United Arab Emirates', 2016, Decimal('369.26'), Decimal('8.994263'), Decimal('1.64')),
#  ('United Arab Emirates', 2017, Decimal('100.00'), Decimal('99.00'), 'United Arab Emirates', 2017, Decimal('390.52'), Decimal('9.068296'), Decimal('2.46')),
#  ('United Arab Emirates', 2018, Decimal('100.00'), Decimal('99.00'), 'United Arab Emirates', 2018, Decimal('427.05'), Decimal('9.140169'), Decimal('2.24')),
#  ('United Arab Emirates', 2019, Decimal('100.00'), Decimal('99.00'), 'United Arab Emirates', 2019, Decimal('417.99'), Decimal('9.211657'), Decimal('2.33')),
#  ('United Arab Emirates', 2020, Decimal('100.00'), Decimal('99.00'), 'United Arab Emirates', 2020, Decimal('349.47'), Decimal('9.287289'), Decimal('4.29')),
#  ('United Republic of Tanzania', 2015, Decimal('58.33'), Decimal('28.33'), 'United Republic of Tanzania', 2015, None, None, None),
#  ('United Republic of Tanzania', 2016, Decimal('60.00'), Decimal('29.33'), 'United Republic of Tanzania', 2016, None, None, None),
#  ('United Republic of Tanzania', 2017, Decimal('61.67'), Decimal('31.00'), 'United Republic of Tanzania', 2017, None, None, None),
#  ('United Republic of Tanzania', 2018, Decimal('63.33'), Decimal('32.33'), 'United Republic of Tanzania', 2018, None, None, None),
#  ('United Republic of Tanzania', 2019, Decimal('64.67'), Decimal('34.00'), 'United Republic of Tanzania', 2019, None, None, None),
#  ('United Republic of Tanzania', 2020, Decimal('65.00'), Decimal('34.00'), 'United Republic of Tanzania', 2020, None, None, None),
#  ('United States of America', 2015, Decimal('99.00'), Decimal('99.67'), 'United States of America', 2015, None, None, None),
#  ('United States of America', 2016, Decimal('99.33'), Decimal('99.67'), 'United States of America', 2016, None, None, None),
#  ('United States of America', 2017, Decimal('99.67'), Decimal('99.67'), 'United States of America', 2017, None, None, None),
#  ('United States of America', 2018, Decimal('99.67'), Decimal('99.67'), 'United States of America', 2018, None, None, None),
#  ('United States of America', 2019, Decimal('99.67'), Decimal('99.67'), 'United States of America', 2019, None, None, None),
#  ('United States of America', 2020, Decimal('100.00'), Decimal('99.67'), 'United States of America', 2020, None, None, None),
#  ('United States Virgin Islands', 2015, Decimal('99.00'), Decimal('99.00'), 'United States Virgin Islands', 2015, None, None, None),
#  ('United States Virgin Islands', 2016, Decimal('99.00'), Decimal('99.00'), 'United States Virgin Islands', 2016, None, None, None),
#  ('United States Virgin Islands', 2017, Decimal('99.00'), Decimal('99.00'), 'United States Virgin Islands', 2017, None, None, None),
#  ('United States Virgin Islands', 2018, Decimal('99.00'), Decimal('99.00'), 'United States Virgin Islands', 2018, None, None, None),
#  ('United States Virgin Islands', 2019, Decimal('99.00'), Decimal('99.00'), 'United States Virgin Islands', 2019, None, None, None),
#  ('United States Virgin Islands', 2020, Decimal('99.00'), Decimal('99.00'), 'United States Virgin Islands', 2020, None, None, None),
#  ('Uruguay', 2015, Decimal('96.67'), Decimal('96.33'), 'Uruguay', 2015, Decimal('53.27'), Decimal('3.402818'), Decimal('7.49')),
#  ('Uruguay', 2016, Decimal('97.33'), Decimal('96.33'), 'Uruguay', 2016, Decimal('57.24'), Decimal('3.413766'), Decimal('7.84')),
#  ('Uruguay', 2017, Decimal('98.00'), Decimal('96.67'), 'Uruguay', 2017, Decimal('64.23'), Decimal('3.422200'), Decimal('7.89')),
#  ('Uruguay', 2018, Decimal('98.00'), Decimal('97.00'), 'Uruguay', 2018, Decimal('64.52'), Decimal('3.427042'), Decimal('8.34')),
#  ('Uruguay', 2019, Decimal('98.00'), Decimal('98.00'), 'Uruguay', 2019, Decimal('61.23'), Decimal('3.428409'), Decimal('8.73')),
#  ('Uruguay', 2020, Decimal('98.00'), Decimal('98.33'), 'Uruguay', 2020, Decimal('53.56'), Decimal('3.429086'), Decimal('10.33')),
#  ...]

# %% [markdown]
# ### Task 3
#
# Using the query created in Task 2, filter the results to display records where:
#
# 1. The year = 2020.
# 2. The GDP is above the global average.
# 3. Less than 90% of the country's population have access to managed drinking water services.
#
# Hint: Keep in mind that we determined the GDP above the global average in Task 1.

# %%
# %%sql
# # Add your code here
# SELECT
#     *
# FROM
#     Basic_services B
# INNER JOIN
#     Economic_Indicators E
# ON
#     B.Country_Name = E.Country_Name
#     AND
#     B.Time_period = E.Time_period
# WHERE
#     E.Time_period = 2020
#     AND
#     B.Pct_managed_drinking_water_services < 90
#     AND
#     E.Est_gdp_in_billions >
#     (
#         SELECT
#             AVG(Est_gdp_in_billions)
#         FROM
#             Economic_Indicators
#         WHERE
#             Time_period = 2020
#     );
# Out:
#  * mysql+pymysql://root:***@localhost:3306/united_nations
# 1 rows affected.
# [('Nigeria', 2020, Decimal('77.33'), Decimal('42.67'), 'Nigeria', 2020, Decimal('432.20'), Decimal('208.327405'), None)]

# %% [markdown]
# ## Solutions

# %% [markdown]
# ### Task 1

# %%
# %%sql
#
# SELECT
#     AVG(Est_gdp_in_billions)
# FROM
#     Economic_Indicators
# WHERE
#     Time_period = 2020;
# Out:
#  * mysql+pymysql://root:***@localhost:3306/united_nations
# 1 rows affected.
# [(Decimal('301.176825'),)]

# %% [markdown]
# ### Task 2

# %%
# %%sql
#
# SELECT
#     econ.Country_name,
#     econ.Time_period,
#     econ.Est_gdp_in_billions,
#     service.Pct_managed_drinking_water_services
# FROM
#     Economic_Indicators AS econ
# INNER JOIN
#     Basic_Services AS service
# ON
#     econ.Country_name = service.Country_name
#     AND econ.Time_period = service.Time_period
# LIMIT 10;
# Out:
#  * mysql+pymysql://root:***@localhost:3306/united_nations
# 10 rows affected.
# [('Afghanistan', 2015, Decimal('20.00'), Decimal('67.00')),
#  ('Afghanistan', 2016, Decimal('18.02'), Decimal('69.67')),
#  ('Afghanistan', 2017, Decimal('18.90'), Decimal('72.33')),
#  ('Afghanistan', 2018, Decimal('18.42'), Decimal('75.33')),
#  ('Afghanistan', 2019, Decimal('18.90'), Decimal('78.00')),
#  ('Afghanistan', 2020, Decimal('20.14'), Decimal('80.33')),
#  ('Algeria', 2015, Decimal('165.98'), Decimal('92.00')),
#  ('Algeria', 2016, Decimal('160.03'), Decimal('93.00')),
#  ('Algeria', 2017, Decimal('170.10'), Decimal('93.00')),
#  ('Algeria', 2018, Decimal('174.91'), Decimal('93.00'))]

# %% [markdown]
# ### Task 3

# %%
# %%sql
#
# SELECT
#     econ.Country_name,
#     econ.Time_period,
#     econ.Est_gdp_in_billions,
#     service.Pct_managed_drinking_water_services
# FROM
#     Economic_Indicators AS econ
# INNER JOIN
#     Basic_Services AS service
# ON
#     econ.Country_name = service.Country_name
#     AND econ.Time_period = service.Time_period
# WHERE
#     econ.time_period = 2020
#     AND service.Pct_managed_drinking_water_services < 90
#     AND econ.Est_gdp_in_billions > (SELECT
#                                         AVG(Est_gdp_in_billions)
#                                     FROM
#                                         Economic_Indicators
#                                     WHERE
#                                         Time_period = 2020);
# Out:
#  * mysql+pymysql://root:***@localhost:3306/united_nations
# 1 rows affected.
# [('Nigeria', 2020, Decimal('432.20'), Decimal('77.33'))]

# %% [markdown]
# ## Summary

# %% [markdown]
# This layered query first calculates the average GDP and then uses that value to filter out countries, along with all of the other criteria.
# Nigeria is the only country that satisfies this criteria. While its GDP might be above average, the low access to water is linked to policies that are not aligned with SDG 6, bad governance, infrastructure, quality, and supply, according to the World Bank.
# Finally, note that these queries quickly become complex when we use JOINs, subqueries, filters, and calculations together. The code is hard to read now and will be even harder to read for someone else who might work on this later. So we need to be mindful of this as we create these complex queries.

# %% [markdown]
# #
#
# <div align="center" style=" font-size: 80%; text-align: center; margin: 0 auto">
# <img src="https://raw.githubusercontent.com/Explore-AI/Pictures/master/ExploreAI_logos/EAI_Blue_Dark.png"  style="width:200px";/>
# </div>
