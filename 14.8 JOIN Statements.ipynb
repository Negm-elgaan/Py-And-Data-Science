# %% [markdown]
# <div align="right" style=" font-size: 80%; text-align: center; margin: 0 auto">
# <img src="https://raw.githubusercontent.com/Explore-AI/Pictures/master/ExploreAI_logos/Logo blue_dark.png"  style="width:25px" align="right";/>
# </div>

# %% [markdown]
# # Join statements
# © ExploreAI Academy

# %% [markdown]
# In this exercise,  we will explore different SQL `JOIN` statements in order to cross-examine data contained in multiple tables in a dataset.

# %% [markdown]
# > ⚠️ In this exercise, we will query a sample SQLite database file called Chinook to gain some insight into the data. Ensure that you have downloaded the database file, `chinook.db`.

# %% [markdown]
# ## Learning objectives
#
# In this train, we will learn how to:
# - Join multiple tables.
# - Find common information between tables.
# - Use a `LEFT JOIN` to check for missing information.
# - Use `CROSS JOIN` to find all the possible combinations of required table rows.

# %% [markdown]
# First, let's load our sample database:

# %%
# load and activate the SQL extension to allow us to execute SQL in a Jupyter notebook
# %load_ext sql

# Load the Chinook database stored in your local machine. 
# Make sure the file is saved in the same folder as this notebook.
# %sql sqlite:///chinook.db
# Out:
# 'Connected: @chinook.db'

# %% [markdown]
# <div align="center" style=" font-size: 80%; text-align: center; margin: 0 auto">
# <img src="https://raw.githubusercontent.com/Explore-AI/Pictures/master/The%20chinook%20database%20ERD.jpeg"/>
# <br>
# <br>
#     <em>Figure 1: The Chinook database ERD</em>
# </div>

# %% [markdown]
# ## Overview
# Run the necessary queries that will provide us with the following information. Compare your queries with the solutions at the end of this notebook.

# %% [markdown]
# ### Exercise 1
#
# Sometimes artists add a title track to their albums. This is a track that has the same title as the album. Write a query that returns albums that have a title track.
# Return rows in the AlbumId column from the albums table, Title from the albums table, and the Name from the tracks table, where the album table Title column matches the tracks table Name column.

# %%
# %%sql
#
# SELECT
#     Title,albums.AlbumId,Tracks.Name
# FROM
#     albums
# INNER JOIN
#     Tracks
# on
#     albums.Title = Tracks.Name;
# Out:
#  * sqlite:///chinook.db
# Done.
# [('Balls to the Wall', 2, 'Balls to the Wall'),
#  ('Restless and Wild', 3, 'Restless and Wild'),
#  ('Let There Be Rock', 4, 'Let There Be Rock'),
#  ('Master Of Puppets', 152, 'Master Of Puppets'),
#  ('Out Of Exile', 11, 'Out Of Exile'),
#  ('Black Sabbath', 16, 'Black Sabbath'),
#  ('Body Count', 18, 'Body Count'),
#  ('Chemical Wedding', 19, 'Chemical Wedding'),
#  ('Prenda Minha', 21, 'Prenda Minha'),
#  ('Minha Historia', 23, 'Minha Historia'),
#  ('Da Lama Ao Caos', 25, 'Da Lama Ao Caos'),
#  ('Heart of the Night', 38, 'Heart of the Night'),
#  ('Into The Light', 40, 'Into The Light'),
#  ('Stormbringer', 65, 'Stormbringer'),
#  ('Houses Of The Holy', 129, 'Houses Of The Holy'),
#  ("Up An' Atom", 51, "Up An' Atom"),
#  ('Fireball', 60, 'Fireball'),
#  ('Stormbringer', 65, 'Stormbringer'),
#  ('The Battle Rages On', 66, 'The Battle Rages On'),
#  ('Outbreak', 68, 'Outbreak'),
#  ('The Real Thing', 77, 'The Real Thing'),
#  ('Deixa Entrar', 78, 'Deixa Entrar'),
#  ('Faceless', 88, 'Faceless'),
#  ('American Idiot', 89, 'American Idiot'),
#  ('Iron Maiden', 100, 'Iron Maiden'),
#  ('Fear Of The Dark', 99, 'Fear Of The Dark'),
#  ('Brave New World', 97, 'Brave New World'),
#  ('Dance Of Death', 98, 'Dance Of Death'),
#  ('Fear Of The Dark', 99, 'Fear Of The Dark'),
#  ('Killers', 101, 'Killers'),
#  ('Revelations', 271, 'Revelations'),
#  ('Powerslave', 107, 'Powerslave'),
#  ('Iron Maiden', 100, 'Iron Maiden'),
#  ('Fear Of The Dark', 99, 'Fear Of The Dark'),
#  ('Iron Maiden', 100, 'Iron Maiden'),
#  ('No Prayer For The Dying', 105, 'No Prayer For The Dying'),
#  ('Revelations', 271, 'Revelations'),
#  ('Powerslave', 107, 'Powerslave'),
#  ('Brave New World', 97, 'Brave New World'),
#  ('Fear Of The Dark', 99, 'Fear Of The Dark'),
#  ('Iron Maiden', 100, 'Iron Maiden'),
#  ('Seventh Son of a Seventh Son', 110, 'Seventh Son of a Seventh Son'),
#  ('Emergency On Planet Earth', 116, 'Emergency On Planet Earth'),
#  ('Are You Experienced?', 120, 'Are You Experienced?'),
#  ('Cafezinho', 124, 'Cafezinho'),
#  ('Living After Midnight', 125, 'Living After Midnight'),
#  ('Master Of Puppets', 152, 'Master Of Puppets'),
#  ('Ride The Lightning', 154, 'Ride The Lightning'),
#  ('St. Anger', 155, 'St. Anger'),
#  ('...And Justice For All', 156, '...And Justice For All'),
#  ('Miles Ahead', 157, 'Miles Ahead'),
#  ('Minas', 159, 'Minas'),
#  ('Ace Of Spades', 160, 'Ace Of Spades'),
#  ('Walking Into Clarksdale', 175, 'Walking Into Clarksdale'),
#  ('Killers', 101, 'Killers'),
#  ('Iron Maiden', 100, 'Iron Maiden'),
#  ('Blood Sugar Sex Magik', 193, 'Blood Sugar Sex Magik'),
#  ('By The Way', 194, 'By The Way'),
#  ('Californication', 195, 'Californication'),
#  ('Maquinarama', 199, 'Maquinarama'),
#  ('Morning Dance', 204, 'Morning Dance'),
#  ('Transmission', 220, 'Transmission'),
#  ('Battlestar Galactica: The Story So Far', 226, 'Battlestar Galactica: The Story So Far'),
#  ('Zooropa', 240, 'Zooropa'),
#  ('Greatest Hits', 141, 'Greatest Hits'),
#  ('Black Sabbath', 16, 'Black Sabbath'),
#  ('Revelations', 271, 'Revelations'),
#  ('Back to Black', 321, 'Back to Black')]

# %% [markdown]
# ### Exercise 2
#
# Suppose that in the previous exercise, we were additionally interested in knowing who the artists of the listed albums are. Write a query that can achieve this.

# %%
# %%sql
#
# SELECT
#     Title,albums.AlbumId,Tracks.Name,artists.name
# FROM
#     albums
# INNER JOIN
#     Tracks,artists
# on
#     albums.Title = Tracks.Name
#     AND
#     artists.ArtistId = albums.ArtistId
# Out:
#  * sqlite:///chinook.db
# Done.
# [('Balls to the Wall', 2, 'Balls to the Wall', 'Accept'),
#  ('Restless and Wild', 3, 'Restless and Wild', 'Accept'),
#  ('Let There Be Rock', 4, 'Let There Be Rock', 'AC/DC'),
#  ('Out Of Exile', 11, 'Out Of Exile', 'Audioslave'),
#  ('Black Sabbath', 16, 'Black Sabbath', 'Black Sabbath'),
#  ('Black Sabbath', 16, 'Black Sabbath', 'Black Sabbath'),
#  ('Body Count', 18, 'Body Count', 'Body Count'),
#  ('Chemical Wedding', 19, 'Chemical Wedding', 'Bruce Dickinson'),
#  ('Prenda Minha', 21, 'Prenda Minha', 'Caetano Veloso'),
#  ('Minha Historia', 23, 'Minha Historia', 'Chico Buarque'),
#  ('Da Lama Ao Caos', 25, 'Da Lama Ao Caos', 'Chico Science & Nação Zumbi'),
#  ('Heart of the Night', 38, 'Heart of the Night', 'Spyro Gyra'),
#  ('Into The Light', 40, 'Into The Light', 'David Coverdale'),
#  ("Up An' Atom", 51, "Up An' Atom", 'Gene Krupa'),
#  ('Fireball', 60, 'Fireball', 'Deep Purple'),
#  ('Stormbringer', 65, 'Stormbringer', 'Deep Purple'),
#  ('Stormbringer', 65, 'Stormbringer', 'Deep Purple'),
#  ('The Battle Rages On', 66, 'The Battle Rages On', 'Deep Purple'),
#  ('Outbreak', 68, 'Outbreak', 'Dennis Chambers'),
#  ('The Real Thing', 77, 'The Real Thing', 'Faith No More'),
#  ('Deixa Entrar', 78, 'Deixa Entrar', 'Falamansa'),
#  ('Faceless', 88, 'Faceless', 'Godsmack'),
#  ('American Idiot', 89, 'American Idiot', 'Green Day'),
#  ('Brave New World', 97, 'Brave New World', 'Iron Maiden'),
#  ('Brave New World', 97, 'Brave New World', 'Iron Maiden'),
#  ('Dance Of Death', 98, 'Dance Of Death', 'Iron Maiden'),
#  ('Fear Of The Dark', 99, 'Fear Of The Dark', 'Iron Maiden'),
#  ('Fear Of The Dark', 99, 'Fear Of The Dark', 'Iron Maiden'),
#  ('Fear Of The Dark', 99, 'Fear Of The Dark', 'Iron Maiden'),
#  ('Fear Of The Dark', 99, 'Fear Of The Dark', 'Iron Maiden'),
#  ('Iron Maiden', 100, 'Iron Maiden', 'Iron Maiden'),
#  ('Iron Maiden', 100, 'Iron Maiden', 'Iron Maiden'),
#  ('Iron Maiden', 100, 'Iron Maiden', 'Iron Maiden'),
#  ('Iron Maiden', 100, 'Iron Maiden', 'Iron Maiden'),
#  ('Iron Maiden', 100, 'Iron Maiden', 'Iron Maiden'),
#  ('Killers', 101, 'Killers', 'Iron Maiden'),
#  ('Killers', 101, 'Killers', 'Iron Maiden'),
#  ('No Prayer For The Dying', 105, 'No Prayer For The Dying', 'Iron Maiden'),
#  ('Powerslave', 107, 'Powerslave', 'Iron Maiden'),
#  ('Powerslave', 107, 'Powerslave', 'Iron Maiden'),
#  ('Seventh Son of a Seventh Son', 110, 'Seventh Son of a Seventh Son', 'Iron Maiden'),
#  ('Emergency On Planet Earth', 116, 'Emergency On Planet Earth', 'Jamiroquai'),
#  ('Are You Experienced?', 120, 'Are You Experienced?', 'Jimi Hendrix'),
#  ('Cafezinho', 124, 'Cafezinho', 'João Suplicy'),
#  ('Living After Midnight', 125, 'Living After Midnight', 'Judas Priest'),
#  ('Houses Of The Holy', 129, 'Houses Of The Holy', 'Led Zeppelin'),
#  ('Greatest Hits', 141, 'Greatest Hits', 'Lenny Kravitz'),
#  ('Master Of Puppets', 152, 'Master Of Puppets', 'Metallica'),
#  ('Master Of Puppets', 152, 'Master Of Puppets', 'Metallica'),
#  ('Ride The Lightning', 154, 'Ride The Lightning', 'Metallica'),
#  ('St. Anger', 155, 'St. Anger', 'Metallica'),
#  ('...And Justice For All', 156, '...And Justice For All', 'Metallica'),
#  ('Miles Ahead', 157, 'Miles Ahead', 'Miles Davis'),
#  ('Minas', 159, 'Minas', 'Milton Nascimento'),
#  ('Ace Of Spades', 160, 'Ace Of Spades', 'Motörhead'),
#  ('Walking Into Clarksdale', 175, 'Walking Into Clarksdale', 'Page & Plant'),
#  ('Blood Sugar Sex Magik', 193, 'Blood Sugar Sex Magik', 'Red Hot Chili Peppers'),
#  ('By The Way', 194, 'By The Way', 'Red Hot Chili Peppers'),
#  ('Californication', 195, 'Californication', 'Red Hot Chili Peppers'),
#  ('Maquinarama', 199, 'Maquinarama', 'Skank'),
#  ('Morning Dance', 204, 'Morning Dance', 'Spyro Gyra'),
#  ('Transmission', 220, 'Transmission', 'The Tea Party'),
#  ('Battlestar Galactica: The Story So Far', 226, 'Battlestar Galactica: The Story So Far', 'Battlestar Galactica'),
#  ('Zooropa', 240, 'Zooropa', 'U2'),
#  ('Revelations', 271, 'Revelations', 'Audioslave'),
#  ('Revelations', 271, 'Revelations', 'Audioslave'),
#  ('Revelations', 271, 'Revelations', 'Audioslave'),
#  ('Back to Black', 321, 'Back to Black', 'Amy Winehouse')]

# %%
# %%sql
#
# SELECT
#     Name,Tracks.TrackId,invoice_items.TrackId
# FROM
#     Tracks
# LEFT JOIN
#     invoice_items
# ON
#    Tracks.TrackId != invoice_items.TrackId
# LIMIT
#     3;
# Out:
#  * sqlite:///chinook.db
# Done.
# [('For Those About To Rock (We Salute You)', 1, 2),
#  ('For Those About To Rock (We Salute You)', 1, 2),
#  ('For Those About To Rock (We Salute You)', 1, 3)]

# %% [markdown]
# ### Exercise 3
#
# One use case for a `LEFT JOIN` is that it can be used to check for missing information. In this case, try to find out what media items have not been bought yet (i.e. are not an item in any invoice).

# %%
# %%sql
#
# SELECT
#    Tracks.TrackId,invoice_items.InvoiceId
# FROM
#     Tracks
# LEFT JOIN
#     invoice_items
# ON
#    Tracks.TrackId = invoice_items.TrackId
# LIMIT
#     10;
# Out:
#  * sqlite:///chinook.db
# Done.
# [(1, 108),
#  (6, 2),
#  (7, None),
#  (8, 2),
#  (8, 214),
#  (9, 108),
#  (9, 319),
#  (10, 2),
#  (11, None),
#  (12, 2)]

# %%
# %%sql
#
# SELECT
#     *
# FROM
#     Tracks
# LIMIT 5;
# Out:
#  * sqlite:///chinook.db
# Done.
# [(1, 'For Those About To Rock (We Salute You)', 1, 1, 1, 'Angus Young, Malcolm Young, Brian Johnson', 343719, 11170334, 0.99),
#  (2, 'Balls to the Wall', 2, 2, 1, None, 342562, 5510424, 0.99),
#  (3, 'Fast As a Shark', 3, 2, 1, 'F. Baltes, S. Kaufman, U. Dirkscneider & W. Hoffman', 230619, 3990994, 0.99),
#  (4, 'Restless and Wild', 3, 2, 1, 'F. Baltes, R.A. Smith-Diesel, S. Kaufman, U. Dirkscneider & W. Hoffman', 252051, 4331779, 0.99),
#  (5, 'Princess of the Dawn', 3, 2, 1, 'Deaffy & R.A. Smith-Diesel', 375418, 6290521, 0.99)]

# %% [markdown]
# ### Exercise 4
#
# In the results, the tracks that have a value of `None` (i.e. `NULL`) for `InvoiceId` are the ones that have not been purchased yet. Add a `WHERE` clause to only focus on these 'unpopular' tracks.

# %%
# %%sql
#
# SELECT
#    Tracks.TrackId,invoice_items.InvoiceId
# FROM
#     Tracks
# LEFT JOIN
#     invoice_items
# ON
#    Tracks.TrackId = invoice_items.TrackId
# WHERE
#     invoice_items.InvoiceId IS NULL
# Out:
#  * sqlite:///chinook.db
# Done.
# [(7, None),
#  (11, None),
#  (17, None),
#  (18, None),
#  (22, None),
#  (23, None),
#  (27, None),
#  (29, None),
#  (33, None),
#  (34, None),
#  (35, None),
#  (40, None),
#  (41, None),
#  (45, None),
#  (46, None),
#  (47, None),
#  (50, None),
#  (51, None),
#  (52, None),
#  (56, None),
#  (58, None),
#  (59, None),
#  (63, None),
#  (64, None),
#  (65, None),
#  (68, None),
#  (69, None),
#  (70, None),
#  (73, None),
#  (74, None),
#  (77, None),
#  (79, None),
#  (81, None),
#  (82, None),
#  (83, None),
#  (86, None),
#  (87, None),
#  (88, None),
#  (91, None),
#  (92, None),
#  (95, None),
#  (96, None),
#  (97, None),
#  (100, None),
#  (101, None),
#  (104, None),
#  (105, None),
#  (106, None),
#  (109, None),
#  (110, None),
#  (113, None),
#  (114, None),
#  (115, None),
#  (118, None),
#  (119, None),
#  (122, None),
#  (123, None),
#  (124, None),
#  (127, None),
#  (128, None),
#  (131, None),
#  (132, None),
#  (133, None),
#  (136, None),
#  (137, None),
#  (140, None),
#  (141, None),
#  (142, None),
#  (145, None),
#  (146, None),
#  (149, None),
#  (150, None),
#  (151, None),
#  (154, None),
#  (155, None),
#  (156, None),
#  (158, None),
#  (159, None),
#  (160, None),
#  (164, None),
#  (168, None),
#  (172, None),
#  (174, None),
#  (176, None),
#  (177, None),
#  (178, None),
#  (181, None),
#  (182, None),
#  (197, None),
#  (200, None),
#  (201, None),
#  (203, None),
#  (204, None),
#  (212, None),
#  (220, None),
#  (224, None),
#  (226, None),
#  (227, None),
#  (239, None),
#  (243, None),
#  (249, None),
#  (250, None),
#  (254, None),
#  (255, None),
#  (259, None),
#  (261, None),
#  (265, None),
#  (266, None),
#  (267, None),
#  (272, None),
#  (273, None),
#  (277, None),
#  (278, None),
#  (279, None),
#  (282, None),
#  (283, None),
#  (284, None),
#  (288, None),
#  (290, None),
#  (291, None),
#  (295, None),
#  (296, None),
#  (297, None),
#  (300, None),
#  (301, None),
#  (302, None),
#  (305, None),
#  (306, None),
#  (309, None),
#  (311, None),
#  (313, None),
#  (314, None),
#  (315, None),
#  (318, None),
#  (319, None),
#  (320, None),
#  (323, None),
#  (324, None),
#  (327, None),
#  (328, None),
#  (329, None),
#  (332, None),
#  (333, None),
#  (336, None),
#  (337, None),
#  (338, None),
#  (341, None),
#  (342, None),
#  (345, None),
#  (346, None),
#  (347, None),
#  (350, None),
#  (351, None),
#  (354, None),
#  (355, None),
#  (356, None),
#  (359, None),
# %%
# %%sql
#
# SELECT
#     *
# FROM
#     media_types
# UNION
# SELECT
#     *
# FROM
#     genres
# Out:
#  * sqlite:///chinook.db
# Done.
# [(1, 'MPEG audio file'),
#  (1, 'Rock'),
#  (2, 'Jazz'),
#  (2, 'Protected AAC audio file'),
#  (3, 'Metal'),
#  (3, 'Protected MPEG-4 video file'),
#  (4, 'Alternative & Punk'),
#  (4, 'Purchased AAC audio file'),
#  (5, 'AAC audio file'),
#  (5, 'Rock And Roll'),
#  (6, 'Blues'),
#  (7, 'Latin'),
#  (8, 'Reggae'),
#  (9, 'Pop'),
#  (10, 'Soundtrack'),
#  (11, 'Bossa Nova'),
#  (12, 'Easy Listening'),
#  (13, 'Heavy Metal'),
#  (14, 'R&B/Soul'),
#  (15, 'Electronica/Dance'),
#  (16, 'World'),
#  (17, 'Hip Hop/Rap'),
#  (18, 'Science Fiction'),
#  (19, 'TV Shows'),
#  (20, 'Sci Fi & Fantasy'),
#  (21, 'Drama'),
#  (22, 'Comedy'),
#  (23, 'Alternative'),
#  (24, 'Classical'),
#  (25, 'Opera')]

# %%
# %%sql
#
# SELECT
#     *
# FROM
#     media_types
# CROSS JOIN
#     genres
# Out:
#  * sqlite:///chinook.db
# Done.
# [(1, 'MPEG audio file', 1, 'Rock'),
#  (1, 'MPEG audio file', 2, 'Jazz'),
#  (1, 'MPEG audio file', 3, 'Metal'),
#  (1, 'MPEG audio file', 4, 'Alternative & Punk'),
#  (1, 'MPEG audio file', 5, 'Rock And Roll'),
#  (1, 'MPEG audio file', 6, 'Blues'),
#  (1, 'MPEG audio file', 7, 'Latin'),
#  (1, 'MPEG audio file', 8, 'Reggae'),
#  (1, 'MPEG audio file', 9, 'Pop'),
#  (1, 'MPEG audio file', 10, 'Soundtrack'),
#  (1, 'MPEG audio file', 11, 'Bossa Nova'),
#  (1, 'MPEG audio file', 12, 'Easy Listening'),
#  (1, 'MPEG audio file', 13, 'Heavy Metal'),
#  (1, 'MPEG audio file', 14, 'R&B/Soul'),
#  (1, 'MPEG audio file', 15, 'Electronica/Dance'),
#  (1, 'MPEG audio file', 16, 'World'),
#  (1, 'MPEG audio file', 17, 'Hip Hop/Rap'),
#  (1, 'MPEG audio file', 18, 'Science Fiction'),
#  (1, 'MPEG audio file', 19, 'TV Shows'),
#  (1, 'MPEG audio file', 20, 'Sci Fi & Fantasy'),
#  (1, 'MPEG audio file', 21, 'Drama'),
#  (1, 'MPEG audio file', 22, 'Comedy'),
#  (1, 'MPEG audio file', 23, 'Alternative'),
#  (1, 'MPEG audio file', 24, 'Classical'),
#  (1, 'MPEG audio file', 25, 'Opera'),
#  (2, 'Protected AAC audio file', 1, 'Rock'),
#  (2, 'Protected AAC audio file', 2, 'Jazz'),
#  (2, 'Protected AAC audio file', 3, 'Metal'),
#  (2, 'Protected AAC audio file', 4, 'Alternative & Punk'),
#  (2, 'Protected AAC audio file', 5, 'Rock And Roll'),
#  (2, 'Protected AAC audio file', 6, 'Blues'),
#  (2, 'Protected AAC audio file', 7, 'Latin'),
#  (2, 'Protected AAC audio file', 8, 'Reggae'),
#  (2, 'Protected AAC audio file', 9, 'Pop'),
#  (2, 'Protected AAC audio file', 10, 'Soundtrack'),
#  (2, 'Protected AAC audio file', 11, 'Bossa Nova'),
#  (2, 'Protected AAC audio file', 12, 'Easy Listening'),
#  (2, 'Protected AAC audio file', 13, 'Heavy Metal'),
#  (2, 'Protected AAC audio file', 14, 'R&B/Soul'),
#  (2, 'Protected AAC audio file', 15, 'Electronica/Dance'),
#  (2, 'Protected AAC audio file', 16, 'World'),
#  (2, 'Protected AAC audio file', 17, 'Hip Hop/Rap'),
#  (2, 'Protected AAC audio file', 18, 'Science Fiction'),
#  (2, 'Protected AAC audio file', 19, 'TV Shows'),
#  (2, 'Protected AAC audio file', 20, 'Sci Fi & Fantasy'),
#  (2, 'Protected AAC audio file', 21, 'Drama'),
#  (2, 'Protected AAC audio file', 22, 'Comedy'),
#  (2, 'Protected AAC audio file', 23, 'Alternative'),
#  (2, 'Protected AAC audio file', 24, 'Classical'),
#  (2, 'Protected AAC audio file', 25, 'Opera'),
#  (3, 'Protected MPEG-4 video file', 1, 'Rock'),
#  (3, 'Protected MPEG-4 video file', 2, 'Jazz'),
#  (3, 'Protected MPEG-4 video file', 3, 'Metal'),
#  (3, 'Protected MPEG-4 video file', 4, 'Alternative & Punk'),
#  (3, 'Protected MPEG-4 video file', 5, 'Rock And Roll'),
#  (3, 'Protected MPEG-4 video file', 6, 'Blues'),
#  (3, 'Protected MPEG-4 video file', 7, 'Latin'),
#  (3, 'Protected MPEG-4 video file', 8, 'Reggae'),
#  (3, 'Protected MPEG-4 video file', 9, 'Pop'),
#  (3, 'Protected MPEG-4 video file', 10, 'Soundtrack'),
#  (3, 'Protected MPEG-4 video file', 11, 'Bossa Nova'),
#  (3, 'Protected MPEG-4 video file', 12, 'Easy Listening'),
#  (3, 'Protected MPEG-4 video file', 13, 'Heavy Metal'),
#  (3, 'Protected MPEG-4 video file', 14, 'R&B/Soul'),
#  (3, 'Protected MPEG-4 video file', 15, 'Electronica/Dance'),
#  (3, 'Protected MPEG-4 video file', 16, 'World'),
#  (3, 'Protected MPEG-4 video file', 17, 'Hip Hop/Rap'),
#  (3, 'Protected MPEG-4 video file', 18, 'Science Fiction'),
#  (3, 'Protected MPEG-4 video file', 19, 'TV Shows'),
#  (3, 'Protected MPEG-4 video file', 20, 'Sci Fi & Fantasy'),
#  (3, 'Protected MPEG-4 video file', 21, 'Drama'),
#  (3, 'Protected MPEG-4 video file', 22, 'Comedy'),
#  (3, 'Protected MPEG-4 video file', 23, 'Alternative'),
#  (3, 'Protected MPEG-4 video file', 24, 'Classical'),
#  (3, 'Protected MPEG-4 video file', 25, 'Opera'),
#  (4, 'Purchased AAC audio file', 1, 'Rock'),
#  (4, 'Purchased AAC audio file', 2, 'Jazz'),
#  (4, 'Purchased AAC audio file', 3, 'Metal'),
#  (4, 'Purchased AAC audio file', 4, 'Alternative & Punk'),
#  (4, 'Purchased AAC audio file', 5, 'Rock And Roll'),
#  (4, 'Purchased AAC audio file', 6, 'Blues'),
#  (4, 'Purchased AAC audio file', 7, 'Latin'),
#  (4, 'Purchased AAC audio file', 8, 'Reggae'),
#  (4, 'Purchased AAC audio file', 9, 'Pop'),
#  (4, 'Purchased AAC audio file', 10, 'Soundtrack'),
#  (4, 'Purchased AAC audio file', 11, 'Bossa Nova'),
#  (4, 'Purchased AAC audio file', 12, 'Easy Listening'),
#  (4, 'Purchased AAC audio file', 13, 'Heavy Metal'),
#  (4, 'Purchased AAC audio file', 14, 'R&B/Soul'),
#  (4, 'Purchased AAC audio file', 15, 'Electronica/Dance'),
#  (4, 'Purchased AAC audio file', 16, 'World'),
#  (4, 'Purchased AAC audio file', 17, 'Hip Hop/Rap'),
#  (4, 'Purchased AAC audio file', 18, 'Science Fiction'),
#  (4, 'Purchased AAC audio file', 19, 'TV Shows'),
#  (4, 'Purchased AAC audio file', 20, 'Sci Fi & Fantasy'),
#  (4, 'Purchased AAC audio file', 21, 'Drama'),
#  (4, 'Purchased AAC audio file', 22, 'Comedy'),
#  (4, 'Purchased AAC audio file', 23, 'Alternative'),
#  (4, 'Purchased AAC audio file', 24, 'Classical'),
#  (4, 'Purchased AAC audio file', 25, 'Opera'),
#  (5, 'AAC audio file', 1, 'Rock'),
#  (5, 'AAC audio file', 2, 'Jazz'),
#  (5, 'AAC audio file', 3, 'Metal'),
#  (5, 'AAC audio file', 4, 'Alternative & Punk'),
#  (5, 'AAC audio file', 5, 'Rock And Roll'),
#  (5, 'AAC audio file', 6, 'Blues'),
#  (5, 'AAC audio file', 7, 'Latin'),
#  (5, 'AAC audio file', 8, 'Reggae'),
#  (5, 'AAC audio file', 9, 'Pop'),
#  (5, 'AAC audio file', 10, 'Soundtrack'),
#  (5, 'AAC audio file', 11, 'Bossa Nova'),
#  (5, 'AAC audio file', 12, 'Easy Listening'),
#  (5, 'AAC audio file', 13, 'Heavy Metal'),
#  (5, 'AAC audio file', 14, 'R&B/Soul'),
#  (5, 'AAC audio file', 15, 'Electronica/Dance'),
#  (5, 'AAC audio file', 16, 'World'),
#  (5, 'AAC audio file', 17, 'Hip Hop/Rap'),
#  (5, 'AAC audio file', 18, 'Science Fiction'),
#  (5, 'AAC audio file', 19, 'TV Shows'),
#  (5, 'AAC audio file', 20, 'Sci Fi & Fantasy'),
#  (5, 'AAC audio file', 21, 'Drama'),
#  (5, 'AAC audio file', 22, 'Comedy'),
#  (5, 'AAC audio file', 23, 'Alternative'),
#  (5, 'AAC audio file', 24, 'Classical'),
#  (5, 'AAC audio file', 25, 'Opera')]

# %% [markdown]
# ## Solutions

# %% [markdown]
# ### Exercise 1

# %%
# %%sql
#
# SELECT
#     a.AlbumId,
#     a.Title AS "Album Title",
#     t.Name AS "Track Name"
# FROM
#     albums a
# INNER JOIN
#     tracks AS t
#     ON a.Title = t.Name
# LIMIT 10;  -- Remove this line to see the full query output

# %% [markdown]
# ### Exercise 2

# %%
# %%sql
#
# SELECT
#     a.AlbumId,
#     a.Title AS "Album Title",
#     t.Name AS "Track Name",
#     ar.Name AS "Artist Name"
# FROM
#     albums AS a
# INNER JOIN
#     tracks AS t
#     ON a.Title = t.Name
# INNER JOIN
#     artists AS ar
#     ON ar.ArtistId = a.ArtistId
#   -- Remove this line to see the full query output
# Out:
#  * sqlite:///chinook.db
# Done.
# [(2, 'Balls to the Wall', 'Balls to the Wall', 'Accept'),
#  (3, 'Restless and Wild', 'Restless and Wild', 'Accept'),
#  (4, 'Let There Be Rock', 'Let There Be Rock', 'AC/DC'),
#  (11, 'Out Of Exile', 'Out Of Exile', 'Audioslave'),
#  (16, 'Black Sabbath', 'Black Sabbath', 'Black Sabbath'),
#  (16, 'Black Sabbath', 'Black Sabbath', 'Black Sabbath'),
#  (18, 'Body Count', 'Body Count', 'Body Count'),
#  (19, 'Chemical Wedding', 'Chemical Wedding', 'Bruce Dickinson'),
#  (21, 'Prenda Minha', 'Prenda Minha', 'Caetano Veloso'),
#  (23, 'Minha Historia', 'Minha Historia', 'Chico Buarque'),
#  (25, 'Da Lama Ao Caos', 'Da Lama Ao Caos', 'Chico Science & Nação Zumbi'),
#  (38, 'Heart of the Night', 'Heart of the Night', 'Spyro Gyra'),
#  (40, 'Into The Light', 'Into The Light', 'David Coverdale'),
#  (51, "Up An' Atom", "Up An' Atom", 'Gene Krupa'),
#  (60, 'Fireball', 'Fireball', 'Deep Purple'),
#  (65, 'Stormbringer', 'Stormbringer', 'Deep Purple'),
#  (65, 'Stormbringer', 'Stormbringer', 'Deep Purple'),
#  (66, 'The Battle Rages On', 'The Battle Rages On', 'Deep Purple'),
#  (68, 'Outbreak', 'Outbreak', 'Dennis Chambers'),
#  (77, 'The Real Thing', 'The Real Thing', 'Faith No More'),
#  (78, 'Deixa Entrar', 'Deixa Entrar', 'Falamansa'),
#  (88, 'Faceless', 'Faceless', 'Godsmack'),
#  (89, 'American Idiot', 'American Idiot', 'Green Day'),
#  (97, 'Brave New World', 'Brave New World', 'Iron Maiden'),
#  (97, 'Brave New World', 'Brave New World', 'Iron Maiden'),
#  (98, 'Dance Of Death', 'Dance Of Death', 'Iron Maiden'),
#  (99, 'Fear Of The Dark', 'Fear Of The Dark', 'Iron Maiden'),
#  (99, 'Fear Of The Dark', 'Fear Of The Dark', 'Iron Maiden'),
#  (99, 'Fear Of The Dark', 'Fear Of The Dark', 'Iron Maiden'),
#  (99, 'Fear Of The Dark', 'Fear Of The Dark', 'Iron Maiden'),
#  (100, 'Iron Maiden', 'Iron Maiden', 'Iron Maiden'),
#  (100, 'Iron Maiden', 'Iron Maiden', 'Iron Maiden'),
#  (100, 'Iron Maiden', 'Iron Maiden', 'Iron Maiden'),
#  (100, 'Iron Maiden', 'Iron Maiden', 'Iron Maiden'),
#  (100, 'Iron Maiden', 'Iron Maiden', 'Iron Maiden'),
#  (101, 'Killers', 'Killers', 'Iron Maiden'),
#  (101, 'Killers', 'Killers', 'Iron Maiden'),
#  (105, 'No Prayer For The Dying', 'No Prayer For The Dying', 'Iron Maiden'),
#  (107, 'Powerslave', 'Powerslave', 'Iron Maiden'),
#  (107, 'Powerslave', 'Powerslave', 'Iron Maiden'),
#  (110, 'Seventh Son of a Seventh Son', 'Seventh Son of a Seventh Son', 'Iron Maiden'),
#  (116, 'Emergency On Planet Earth', 'Emergency On Planet Earth', 'Jamiroquai'),
#  (120, 'Are You Experienced?', 'Are You Experienced?', 'Jimi Hendrix'),
#  (124, 'Cafezinho', 'Cafezinho', 'João Suplicy'),
#  (125, 'Living After Midnight', 'Living After Midnight', 'Judas Priest'),
#  (129, 'Houses Of The Holy', 'Houses Of The Holy', 'Led Zeppelin'),
#  (141, 'Greatest Hits', 'Greatest Hits', 'Lenny Kravitz'),
#  (152, 'Master Of Puppets', 'Master Of Puppets', 'Metallica'),
#  (152, 'Master Of Puppets', 'Master Of Puppets', 'Metallica'),
#  (154, 'Ride The Lightning', 'Ride The Lightning', 'Metallica'),
#  (155, 'St. Anger', 'St. Anger', 'Metallica'),
#  (156, '...And Justice For All', '...And Justice For All', 'Metallica'),
#  (157, 'Miles Ahead', 'Miles Ahead', 'Miles Davis'),
#  (159, 'Minas', 'Minas', 'Milton Nascimento'),
#  (160, 'Ace Of Spades', 'Ace Of Spades', 'Motörhead'),
#  (175, 'Walking Into Clarksdale', 'Walking Into Clarksdale', 'Page & Plant'),
#  (193, 'Blood Sugar Sex Magik', 'Blood Sugar Sex Magik', 'Red Hot Chili Peppers'),
#  (194, 'By The Way', 'By The Way', 'Red Hot Chili Peppers'),
#  (195, 'Californication', 'Californication', 'Red Hot Chili Peppers'),
#  (199, 'Maquinarama', 'Maquinarama', 'Skank'),
#  (204, 'Morning Dance', 'Morning Dance', 'Spyro Gyra'),
#  (220, 'Transmission', 'Transmission', 'The Tea Party'),
#  (226, 'Battlestar Galactica: The Story So Far', 'Battlestar Galactica: The Story So Far', 'Battlestar Galactica'),
#  (240, 'Zooropa', 'Zooropa', 'U2'),
#  (271, 'Revelations', 'Revelations', 'Audioslave'),
#  (271, 'Revelations', 'Revelations', 'Audioslave'),
#  (271, 'Revelations', 'Revelations', 'Audioslave'),
#  (321, 'Back to Black', 'Back to Black', 'Amy Winehouse')]

# %% [markdown]
# Return rows in the `AlbumId` from the `albums` table, `Title` from the `albums` table, the `Name` from the `tracks` table, and the `Name` from the `artists` table, where the `albums` table `Title` column matches the `tracks` table `Name` column, and the `artists` table `Name` column where the `artists` table `ArtistId` is equal to the `albums` table `ArtistId`.

# %% [markdown]
# ### Exercise 3

# %%
# %%sql
#
# SELECT
#     t.TrackId,
#     ii.InvoiceId
# FROM
#     tracks t
# LEFT JOIN
#     invoice_items ii
#     ON t.TrackId = ii.TrackId
# LIMIT 10;  -- Remove this line to see the full query output
# Out:
#  * sqlite:///chinook.db
# Done.
# [(1, 108),
#  (6, 2),
#  (7, None),
#  (8, 2),
#  (8, 214),
#  (9, 108),
#  (9, 319),
#  (10, 2),
#  (11, None),
#  (12, 2)]

# %% [markdown]
# ### Exercise 4

# %%
# %%sql
#
# SELECT
#     t.TrackId,
#     ii.InvoiceId
# FROM
#     tracks AS t
# LEFT JOIN
#     invoice_items AS ii
#     ON t.TrackId = ii.TrackId
# WHERE ii.InvoiceId IS NULL
# LIMIT 10;  -- Remove this line to see the full query output

# %% [markdown]
# ### Exercise 5

# %%
# %%sql
#
# SELECT
#     g.Name AS "Genre",
#     m.Name AS "Media Type"
# FROM
#     genres AS g
# CROSS JOIN
#     media_types AS m
#   -- Remove this line to see the full query output
# Out:
#  * sqlite:///chinook.db
# Done.
# [('Rock', 'MPEG audio file'),
#  ('Rock', 'Protected AAC audio file'),
#  ('Rock', 'Protected MPEG-4 video file'),
#  ('Rock', 'Purchased AAC audio file'),
#  ('Rock', 'AAC audio file'),
#  ('Jazz', 'MPEG audio file'),
#  ('Jazz', 'Protected AAC audio file'),
#  ('Jazz', 'Protected MPEG-4 video file'),
#  ('Jazz', 'Purchased AAC audio file'),
#  ('Jazz', 'AAC audio file'),
#  ('Metal', 'MPEG audio file'),
#  ('Metal', 'Protected AAC audio file'),
#  ('Metal', 'Protected MPEG-4 video file'),
#  ('Metal', 'Purchased AAC audio file'),
#  ('Metal', 'AAC audio file'),
#  ('Alternative & Punk', 'MPEG audio file'),
#  ('Alternative & Punk', 'Protected AAC audio file'),
#  ('Alternative & Punk', 'Protected MPEG-4 video file'),
#  ('Alternative & Punk', 'Purchased AAC audio file'),
#  ('Alternative & Punk', 'AAC audio file'),
#  ('Rock And Roll', 'MPEG audio file'),
#  ('Rock And Roll', 'Protected AAC audio file'),
#  ('Rock And Roll', 'Protected MPEG-4 video file'),
#  ('Rock And Roll', 'Purchased AAC audio file'),
#  ('Rock And Roll', 'AAC audio file'),
#  ('Blues', 'MPEG audio file'),
#  ('Blues', 'Protected AAC audio file'),
#  ('Blues', 'Protected MPEG-4 video file'),
#  ('Blues', 'Purchased AAC audio file'),
#  ('Blues', 'AAC audio file'),
#  ('Latin', 'MPEG audio file'),
#  ('Latin', 'Protected AAC audio file'),
#  ('Latin', 'Protected MPEG-4 video file'),
#  ('Latin', 'Purchased AAC audio file'),
#  ('Latin', 'AAC audio file'),
#  ('Reggae', 'MPEG audio file'),
#  ('Reggae', 'Protected AAC audio file'),
#  ('Reggae', 'Protected MPEG-4 video file'),
#  ('Reggae', 'Purchased AAC audio file'),
#  ('Reggae', 'AAC audio file'),
#  ('Pop', 'MPEG audio file'),
#  ('Pop', 'Protected AAC audio file'),
#  ('Pop', 'Protected MPEG-4 video file'),
#  ('Pop', 'Purchased AAC audio file'),
#  ('Pop', 'AAC audio file'),
#  ('Soundtrack', 'MPEG audio file'),
#  ('Soundtrack', 'Protected AAC audio file'),
#  ('Soundtrack', 'Protected MPEG-4 video file'),
#  ('Soundtrack', 'Purchased AAC audio file'),
#  ('Soundtrack', 'AAC audio file'),
#  ('Bossa Nova', 'MPEG audio file'),
#  ('Bossa Nova', 'Protected AAC audio file'),
#  ('Bossa Nova', 'Protected MPEG-4 video file'),
#  ('Bossa Nova', 'Purchased AAC audio file'),
#  ('Bossa Nova', 'AAC audio file'),
#  ('Easy Listening', 'MPEG audio file'),
#  ('Easy Listening', 'Protected AAC audio file'),
#  ('Easy Listening', 'Protected MPEG-4 video file'),
#  ('Easy Listening', 'Purchased AAC audio file'),
#  ('Easy Listening', 'AAC audio file'),
#  ('Heavy Metal', 'MPEG audio file'),
#  ('Heavy Metal', 'Protected AAC audio file'),
#  ('Heavy Metal', 'Protected MPEG-4 video file'),
#  ('Heavy Metal', 'Purchased AAC audio file'),
#  ('Heavy Metal', 'AAC audio file'),
#  ('R&B/Soul', 'MPEG audio file'),
#  ('R&B/Soul', 'Protected AAC audio file'),
#  ('R&B/Soul', 'Protected MPEG-4 video file'),
#  ('R&B/Soul', 'Purchased AAC audio file'),
#  ('R&B/Soul', 'AAC audio file'),
#  ('Electronica/Dance', 'MPEG audio file'),
#  ('Electronica/Dance', 'Protected AAC audio file'),
#  ('Electronica/Dance', 'Protected MPEG-4 video file'),
#  ('Electronica/Dance', 'Purchased AAC audio file'),
#  ('Electronica/Dance', 'AAC audio file'),
#  ('World', 'MPEG audio file'),
#  ('World', 'Protected AAC audio file'),
#  ('World', 'Protected MPEG-4 video file'),
#  ('World', 'Purchased AAC audio file'),
#  ('World', 'AAC audio file'),
#  ('Hip Hop/Rap', 'MPEG audio file'),
#  ('Hip Hop/Rap', 'Protected AAC audio file'),
#  ('Hip Hop/Rap', 'Protected MPEG-4 video file'),
#  ('Hip Hop/Rap', 'Purchased AAC audio file'),
#  ('Hip Hop/Rap', 'AAC audio file'),
#  ('Science Fiction', 'MPEG audio file'),
#  ('Science Fiction', 'Protected AAC audio file'),
#  ('Science Fiction', 'Protected MPEG-4 video file'),
#  ('Science Fiction', 'Purchased AAC audio file'),
#  ('Science Fiction', 'AAC audio file'),
#  ('TV Shows', 'MPEG audio file'),
#  ('TV Shows', 'Protected AAC audio file'),
#  ('TV Shows', 'Protected MPEG-4 video file'),
#  ('TV Shows', 'Purchased AAC audio file'),
#  ('TV Shows', 'AAC audio file'),
#  ('Sci Fi & Fantasy', 'MPEG audio file'),
#  ('Sci Fi & Fantasy', 'Protected AAC audio file'),
#  ('Sci Fi & Fantasy', 'Protected MPEG-4 video file'),
#  ('Sci Fi & Fantasy', 'Purchased AAC audio file'),
#  ('Sci Fi & Fantasy', 'AAC audio file'),
#  ('Drama', 'MPEG audio file'),
#  ('Drama', 'Protected AAC audio file'),
#  ('Drama', 'Protected MPEG-4 video file'),
#  ('Drama', 'Purchased AAC audio file'),
#  ('Drama', 'AAC audio file'),
#  ('Comedy', 'MPEG audio file'),
#  ('Comedy', 'Protected AAC audio file'),
#  ('Comedy', 'Protected MPEG-4 video file'),
#  ('Comedy', 'Purchased AAC audio file'),
#  ('Comedy', 'AAC audio file'),
#  ('Alternative', 'MPEG audio file'),
#  ('Alternative', 'Protected AAC audio file'),
#  ('Alternative', 'Protected MPEG-4 video file'),
#  ('Alternative', 'Purchased AAC audio file'),
#  ('Alternative', 'AAC audio file'),
#  ('Classical', 'MPEG audio file'),
#  ('Classical', 'Protected AAC audio file'),
#  ('Classical', 'Protected MPEG-4 video file'),
#  ('Classical', 'Purchased AAC audio file'),
#  ('Classical', 'AAC audio file'),
#  ('Opera', 'MPEG audio file'),
#  ('Opera', 'Protected AAC audio file'),
#  ('Opera', 'Protected MPEG-4 video file'),
#  ('Opera', 'Purchased AAC audio file'),
#  ('Opera', 'AAC audio file')]
