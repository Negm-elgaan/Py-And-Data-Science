# %% [markdown]
# <div align="right" style=" font-size: 80%; text-align: center; margin: 0 auto">
# <img src="https://raw.githubusercontent.com/Explore-AI/Pictures/master/ExploreAI_logos/Logo blue_dark.png"  style="width:25px" align="right";/>
# </div>

# %% [markdown]
# # Data anomalies – 2NF [Exercise]
# © ExploreAI Academy
#
# Database normalisation is a design technique for decoupling table structures to **reduce data redundancies and anomalies**.
#
# In this train, we will go through a practical example of normalising a database up to the **Second Normal Form**. At the end of the train, we will reflect on the data anomalies that can occur in practice and how **2NF** attempts to remedy their  state.
#
# ## Learning objectives
# In this train, we will:
# * Learn how to normalise a database up to the Second Normal Form.
# * Learn how to decompose a 1NF database into multiple tables to eliminate partial dependencies.
# * Understand data anomalies and how database normalisation reduces the likelihood of their occurrence.

# %% [markdown]
# ## Imports and DB connections
#
# > ⚠️ ⚠️ This exercise extends the concepts introduced in the previous one, `Data anomalies – 1NF`. Therefore, it's important to ensure that you continue using the modified SoftDevEmployees.db database after successfully completing the previous exercise.
#
# > ⚠️ Since the queries here will modify the database, you will have to get a fresh copy of the modified database to redo the code cells.

# %%
# Load and activate the SQL extension to allow us to execute SQL in a Jupyter notebook.
# %load_ext sql

# %%
## Load the SoftDevEmployees database stored in your local machine. 
# Make sure the file is saved in the same folder as this notebook.
# %sql sqlite:///SoftDevEmployees.db
# Out:
# 'Connected: @SoftDevEmployees.db'

# %% [markdown]
# ## Data anomalies
#
# Data anomalies are issues that present themselves in poorly structured or denormalised databases. The following are examples of commonly occurring anomalies which you may find:
#
#  - **Deletion anomaly**: The deletion of a record that leads to the unintentional removal of another required attribute from the database.
#  - **Insertion anomaly**: The inability to insert a record as it requires additional data which may presently not be available.
#  - **Update anomaly**: This occurs when we have duplicated data; if we were to update the affected rows and a single row gets missed, this will lead to a data inconsistency.

# %% [markdown]
# ## First Normal Form database
#
# Below is the ERD for the **`SoftDevEmployees.db`** database which contains a single table called **`Employees_1NF`**. Currently, our database is in the **First Normal Form (1NF)**. Our goal within this train is to transform this database to conform to the **Second Normal Form**.
#
#
# <img src ="https://raw.githubusercontent.com/Explore-AI/Pictures/master/SQL4DS/Practical_Normalization/1NF.png" alt="first Normal Form" >

# %% [markdown]
# ## Second Normal Form – 2NF
#
# To convert to the Second Normal Form, we need to make sure that we meet the following conditions:
#
# 1. The table needs to already be in the First Normal Form.
# 2. The table should not contain any **partial dependencies.**
#
# **No partial dependency** simply means that **every non-key attribute should be fully dependent on the primary key**. This translates to each table serving a single purpose.

# %% [markdown]
# ## Converting to 2NF
#
# The strategy to "employ" here is to create new tables that each serve a single purpose. Have a look at the desired ERD sketch given below:
#
# <img src="https://raw.githubusercontent.com/Explore-AI/Pictures/master/SQL4DS/Practical_Normalization/2NF.png" alt="Second Normal Form">
#
# Note that most of the heavy lifting was performed when setting up the First Normal Form. So we will use this table to create the required fields for the Second Normal Form.
# We want to achieve the following:
#
# 1. Create the required tables.
# 2. For each table, pay attention to relationships that exist between the tables and create the appropriate foreign keys to maintain the referential integrity of the tables.

# %% [markdown]
# ### Exercise 1 – Create the required tables
#
# Let's start by creating the required 2NF tables based on the above structure. They include:
# - **`Titles_2NF`**
# - **`Roles_2NF`**
# - **`Departments_2NF`**
# - **`Employees_2NF`**
# - **`Employee_Department_2NF`**
# - **`Employee_Role_2NF`**
#
# Remember to `AUTOINCREMENT` the **ID** `PRIMARY KEY` columns for each table.

# %%
# %%sql
#
# DROP TABLE IF EXISTS Titles_2NF;
#
# CREATE TABLE Titles_2NF
# (
#     TitleID INTEGER PRIMARY KEY AUTOINCREMENT ,
#     Title VARCHAR
# );
#
# DROP TABLE IF EXISTS Roles_2NF;
#
# CREATE TABLE Roles_2NF
# (
#     RoleID INTEGER PRIMARY KEY AUTOINCREMENT ,
#     Role VARCHAR
# );
#
# DROP TABLE IF EXISTS Departments_2NF;
#
# CREATE TABLE Departments_2NF
# (
#     DepartmentID INTEGER PRIMARY KEY AUTOINCREMENT ,
#     Department VARCHAR
# );
#
# DROP TABLE IF EXISTS Employees_2NF;
#
# CREATE TABLE Employees_2NF
# (
#     EmployeeID INTEGER PRIMARY KEY AUTOINCREMENT ,
#     Name VARCHAR ,
#     Surname VARCHAR ,
#     Salary REAL ,
#     OccupationBand VARCHAR ,
#     TitleID INTEGER NOT NULL ,
#     FOREIGN KEY (TitleID) REFERENCES Titles_2NF(TitleID)
# );
#
# DROP TABLE IF EXISTS Employee_Department_2NF;
#
# CREATE TABLE Employee_Department_2NF
# (
#     EmployeeID INTEGER NOT NULL,
#     DepartmentID INTEGER NOT NULL,
#     FOREIGN KEY (EmployeeID) REFERENCES Employees_2NF (EmployeeID),
#     FOREIGN KEY (DepartmentID) REFERENCES Departments_2NF (DepartmentID),
#     PRIMARY KEY (EmployeeID, DepartmentID)
# );
#
# DROP TABLE IF EXISTS Employee_Role_2NF;
#
# CREATE TABLE Employee_Role_2NF
# (
#     EmployeeID INTEGER NOT NULL ,
#     RoleID INTEGER NOT NULL ,
#     FOREIGN KEY (EmployeeID) REFERENCES Employees_2NF(EmployeeID),
#     FOREIGN KEY (RoleID) REFERENCES Roles_2NF(RoleID),
#     PRIMARY KEY (EmployeeID , RoleID)
# );
# Out:
#  * sqlite:///SoftDevEmployees.db
# Done.
# Done.
# Done.
# Done.
# Done.
# Done.
# Done.
# Done.
# Done.
# Done.
# Done.
# Done.
# []

# %% [markdown]
# ### Exercise 2
#
# Let us proceed to populate the 2NF tables we have created in Exercise 1 using the relevant data from the **`Employees_1NF`** table.

# %% [markdown]
# ### 2.1 – Populate the `Titles_2NF`, `Roles_2NF`, and `Departments_2NF` tables
#
# We start with the **`Titles_2NF`, `Roles_2NF`**, and **`Departments_2NF`** tables as the queries for these insertions are fairly trivial.
#
# Write a query to populate these tables by selecting **distinct** values in the relevant columns from the **`Employees_1NF`** table.
#
# Remember to only select rows where the **row value is not blank**.

# %%
# %%sql
#
# INSERT INTO Titles_2NF(Title)
# SELECT
#     Title
# FROM
#     Employees_1NF;
#
# INSERT INTO Roles_2NF(Role)
# SELECT
#     Role
# FROM
#     Employees_1NF;
#
# INSERT INTO Departments_2NF(Department)
# SELECT
#     Department
# FROM
#     Employees_1NF;
# Out:
#  * sqlite:///SoftDevEmployees.db
# 61 rows affected.
# 61 rows affected.
# 61 rows affected.
# []

# %% [markdown]
# ###  2.2 – Populate the `Employees_2NF` table
#
# Now we move on to the **`Employees_2NF`** table. Things become a bit more complex here since we start to take the foreign keys into account. This is because, in the **`Employees_2NF`** table, we have the **`TitleID`** column which references the **`TitleID`** column in the **`Titles_2NF`** table.
#
# Write a query to populate the **`Employees_2NF`** table by selecting the relevant data from the **`Employees_1NF`** table.
#
# **`Hint:`** We need to join with the appropriate table in order to populate the **`TitleID`** such that we maintain referential integrity.

# %%
# %%sql
#
# DELETE FROM Employees_2NF;
#
# INSERT INTO Employees_2NF(Name , Surname , Salary , OccupationBand , TitleID)
# SELECT DISTINCT
#     Name ,
#     Surname ,
#     Salary ,
#     OccupationBand ,
#     T.TitleID
# FROM
#     Employees_1NF E
# INNER JOIN
#     Titles_2NF T
# ON
#     T.Title = E.Title
# Out:
#  * sqlite:///SoftDevEmployees.db
# 860 rows affected.
# 688 rows affected.
# []

# %% [markdown]
# ###  2.3 – Populate the `Employee_Department_2NF` and `Employee_Role_2NF` tables.
#
# Finally, we insert data into our **mapping tables**: **`Employee_Department_2NF`** and **`Employee_Role_2NF`**. These are tables that will be used to establish links between the different tables we have already created.
#
# Write a query to populate these tables using foreign keys that reference the primary keys in the 2NF tables being connected.
#
# **`Hint:`** Again, we need to join with the appropriate tables based on the foreign key references that exist in the database structure.

# %%
# %%sql
#
# SELECT
#     *
# FROM
#     Employees_1NF
# Out:
#  * sqlite:///SoftDevEmployees.db
# Done.
# [('André', 'gerber', 'Front-End Developer', 'Web Applications', 'Mrs', 'Junior', 52357.0),
#  ('Antoinette', 'Van Der Berg', 'UI/UX Developer', 'Mobile Applications', 'Dr', 'Junior', 118731.0),
#  ('Bronwyn', 'Swartz', 'UI/UX Developer', 'Mobile Applications', 'Miss', 'Graduate', 34350.0),
#  ('Christopher', 'Walker', 'Back-End Developer', 'Mobile Applications', 'Mr', 'Junior', 122894.0),
#  ('Christopher', 'Walker', 'Back-End Developer', 'Web Applications', 'Mr', 'Junior', 122894.0),
#  ('Claire', 'Morris', 'Full-Stack Developer', 'Mobile Applications', 'Ms', 'Intern', 36000.0),
#  ('Contact', 'Xaba', 'UI/UX Developer', 'Mobile Applications', 'Dr', 'Mid-Level', 85836.0),
#  ('Danie', 'Campbell', 'Business Analyst', 'Mobile Applications', 'Mrs', 'Mid-Level', 205621.0),
#  ('Danie', 'Campbell', 'Business Analyst', 'Web Applications', 'Mrs', 'Mid-Level', 205621.0),
#  ('Danie', 'davies', 'Database Analyst', 'Web Applications', 'Dr', 'Senior', 313491.0),
#  ('Dirk', 'Banda', 'Business Analyst', 'Mobile Applications', 'Mr', 'Intern', 37601.0),
#  ('Dirk', 'Banda', 'Business Analyst', 'Web Applications', 'Mr', 'Intern', 37601.0),
#  ('Douglas', 'Sibanda', 'UI/UX Developer', 'Web Applications', 'Mr', 'Mid-Level', 57353.0),
#  ('Dumisani', 'Thwala', 'Back-End Developer', 'Mobile Applications', 'Mr', 'Graduate', 52171.0),
#  ('Dumisani', 'Thwala', 'Back-End Developer', 'Web Applications', 'Mr', 'Graduate', 52171.0),
#  ('Ernest', 'maritz', 'Full-Stack Developer', 'Web Applications', 'Mr', 'Graduate', 88569.0),
#  ('Ivan', 'Schoeman', 'Systems Analyst', 'Web Applications', 'Dr', 'Junior', 167439.0),
#  ('Jabulani', 'Horn', 'Front-End Developer', 'Mobile Applications', 'Mr', 'Intern', 55725.0),
#  ('Jacqueline', 'fredericks', 'Front-End Developer', 'Web Applications', 'Ms', 'Graduate', 51104.0),
#  ('Jan', 'Ngwenya', 'Back-End Developer', 'Web Applications', 'Mr', 'Intern', 38959.0),
#  ('Janet', 'Patel', 'Systems Analyst', 'Mobile Applications', 'Ms', 'Intern', 39081.0),
#  ('Janet', 'Patel', 'Systems Analyst', 'Web Applications', 'Ms', 'Intern', 39081.0),
#  ('Janine', 'De Villiers', 'Database Analyst', 'Mobile Applications', 'Mrs', 'Intern', 32886.0),
#  ('Jessica', 'Mchunu', 'Full-Stack Developer', 'Web Applications', 'Miss', 'Mid-Level', 70741.0),
#  ('Jessica', 'Mchunu', 'Scrum Master', 'Web Applications', 'Miss', 'Mid-Level', 70741.0),
#  ('Johan', 'du Plessis', 'Database Analyst', 'Mobile Applications', 'Mr', 'Mid-Level', 235178.0),
#  ('Juan', 'Smit', 'UI/UX Developer', 'Web Applications', 'Mr', 'Senior', 308542.0),
#  ('Kevin', 'Motloung', 'Systems Analyst', 'Mobile Applications', 'Mr', 'Graduate', 99370.0),
#  ('Laura', 'Makhanya', 'Full-Stack Developer', 'Mobile Applications', 'Ms', 'Senior', 293352.0),
#  ('Laura', 'Makhanya', 'Team Lead', 'Mobile Applications', 'Ms', 'Senior', 293352.0),
#  ('Lesego', 'Bennett', 'Business Analyst', 'Web Applications', 'Ms', 'Junior', 41083.0),
#  ('Lizelle', 'Dhlamini', 'Database Analyst', 'Mobile Applications', 'Miss', 'Junior', 64179.0),
#  ('Louise', 'Lourens', 'Front-End Developer', 'Mobile Applications', 'Mrs', 'Mid-Level', 158634.0),
#  ('Lynn', 'Mashaba', 'Full-Stack Developer', 'Web Applications', 'Dr', 'Junior', 115478.0),
#  ('Marco', 'Morris', 'Back-End Developer', 'Mobile Applications', 'Prof', 'Mid-Level', 110506.0),
#  ('Marco', 'Morris', 'Back-End Developer', 'Web Applications', 'Prof', 'Mid-Level', 110506.0),
#  ('Marthinus', 'Gordon', 'Front-End Developer', 'Web Applications', 'Mrs', 'Mid-Level', 106178.0),
#  ('Nadine', 'Morris', 'Full-Stack Developer', 'Web Applications', 'Mrs', 'Senior', 326767.0),
#  ('Nico', 'Mthembu', 'Project Manager', 'Mobile Applications', 'Mr', 'Senior', 97673.0),
#  ('Nico', 'Mthembu', 'Systems Analyst', 'Mobile Applications', 'Mr', 'Senior', 97673.0),
#  ('Patience', 'Khoza', 'Front-End Developer', 'Mobile Applications', None, 'Junior', 104062.0),
#  ('Patience', 'Willemse', 'Back-End Developer', 'Mobile Applications', 'Mrs', 'Intern', 52053.0),
#  ('Pearl', 'Stewart', 'UI/UX Developer', 'Mobile Applications', 'Miss', 'Intern', 24289.0),
#  ('Precious', 'zungu', 'UI/UX Developer', 'Mobile Applications', 'Miss', 'Senior', 264376.0),
#  ('Priscilla', 'Anderson', 'Business Analyst', 'Mobile Applications', 'Ms', 'Senior', 262686.0),
#  ('Siyabonga', 'Hanekom', 'Front-End Developer', 'Web Applications', 'Ms', 'Senior', 213477.0),
#  ('Tony', 'Horn', 'Back-End Developer', 'Mobile Applications', 'Mr', 'Graduate', 103397.0),
#  ('Tumelo', 'Rikhotso', 'Business Analyst', 'Mobile Applications', 'Mr', 'Mid-Level', 144372.0),
#  ('Vuyokazi', 'barnes', 'Business Analyst', 'Web Applications', 'Mr', 'Graduate', 69220.0),
#  ('Walter', 'Jansen', 'Front-End Developer', 'Mobile Applications', 'Mr', 'Graduate', 35454.0),
#  ('barend', 'Edwards', 'Database Analyst', 'Mobile Applications', 'Mr', 'Intern', 13163.0),
#  ('barend', 'Edwards', 'Database Analyst', 'Web Applications', 'Mr', 'Intern', 13163.0),
#  ('gugulethu', 'Maluleka', 'Business Analyst', 'Mobile Applications', 'Mrs', 'Junior', 181609.0),
#  ('kelly', 'Manuel', 'Full-Stack Developer', 'Mobile Applications', 'Ms', 'Intern', 47442.0),
#  ('kelly', 'Manuel', 'Full-Stack Developer', 'Web Applications', 'Ms', 'Intern', 47442.0),
#  ('liezel', 'moyo', 'Systems Analyst', 'Mobile Applications', 'Ms', 'Mid-Level', 106276.0),
#  ('marthinus', 'ngobeni', 'Back-End Developer', 'Web Applications', 'Ms', 'Senior', 354298.0),
#  ('nicole', 'Ebrahim', 'Database Analyst', 'Mobile Applications', 'Dr', 'Senior', 180919.0),
#  ('phumzile', 'motsepe', 'Systems Analyst', 'Mobile Applications', 'Prof', 'Junior', 129627.0),
#  ('sello', 'Details', 'Database Analyst', 'Mobile Applications', 'Mr', 'Graduate', 54945.0),
#  ('takalani', 'Richards', 'Systems Analyst', 'Web Applications', 'Mr', 'Graduate', 57906.0)]

# %%
# %%sql
#
# SELECT
#     *
# FROM
#     Employees_2NF
# Out:
#  * sqlite:///SoftDevEmployees.db
# Done.
# [(861, 'André', 'gerber', 52357.0, 'Junior', 1),
#  (862, 'André', 'gerber', 52357.0, 'Junior', 8),
#  (863, 'André', 'gerber', 52357.0, 'Junior', 9),
#  (864, 'André', 'gerber', 52357.0, 'Junior', 23),
#  (865, 'André', 'gerber', 52357.0, 'Junior', 33),
#  (866, 'André', 'gerber', 52357.0, 'Junior', 37),
#  (867, 'André', 'gerber', 52357.0, 'Junior', 38),
#  (868, 'André', 'gerber', 52357.0, 'Junior', 42),
#  (869, 'André', 'gerber', 52357.0, 'Junior', 53),
#  (870, 'Antoinette', 'Van Der Berg', 118731.0, 'Junior', 2),
#  (871, 'Antoinette', 'Van Der Berg', 118731.0, 'Junior', 7),
#  (872, 'Antoinette', 'Van Der Berg', 118731.0, 'Junior', 10),
#  (873, 'Antoinette', 'Van Der Berg', 118731.0, 'Junior', 17),
#  (874, 'Antoinette', 'Van Der Berg', 118731.0, 'Junior', 34),
#  (875, 'Antoinette', 'Van Der Berg', 118731.0, 'Junior', 58),
#  (876, 'Bronwyn', 'Swartz', 34350.0, 'Graduate', 3),
#  (877, 'Bronwyn', 'Swartz', 34350.0, 'Graduate', 24),
#  (878, 'Bronwyn', 'Swartz', 34350.0, 'Graduate', 25),
#  (879, 'Bronwyn', 'Swartz', 34350.0, 'Graduate', 32),
#  (880, 'Bronwyn', 'Swartz', 34350.0, 'Graduate', 43),
#  (881, 'Bronwyn', 'Swartz', 34350.0, 'Graduate', 44),
#  (882, 'Christopher', 'Walker', 122894.0, 'Junior', 4),
#  (883, 'Christopher', 'Walker', 122894.0, 'Junior', 5),
#  (884, 'Christopher', 'Walker', 122894.0, 'Junior', 11),
#  (885, 'Christopher', 'Walker', 122894.0, 'Junior', 12),
#  (886, 'Christopher', 'Walker', 122894.0, 'Junior', 13),
#  (887, 'Christopher', 'Walker', 122894.0, 'Junior', 14),
#  (888, 'Christopher', 'Walker', 122894.0, 'Junior', 15),
#  (889, 'Christopher', 'Walker', 122894.0, 'Junior', 16),
#  (890, 'Christopher', 'Walker', 122894.0, 'Junior', 18),
#  (891, 'Christopher', 'Walker', 122894.0, 'Junior', 20),
#  (892, 'Christopher', 'Walker', 122894.0, 'Junior', 26),
#  (893, 'Christopher', 'Walker', 122894.0, 'Junior', 27),
#  (894, 'Christopher', 'Walker', 122894.0, 'Junior', 28),
#  (895, 'Christopher', 'Walker', 122894.0, 'Junior', 39),
#  (896, 'Christopher', 'Walker', 122894.0, 'Junior', 40),
#  (897, 'Christopher', 'Walker', 122894.0, 'Junior', 47),
#  (898, 'Christopher', 'Walker', 122894.0, 'Junior', 48),
#  (899, 'Christopher', 'Walker', 122894.0, 'Junior', 49),
#  (900, 'Christopher', 'Walker', 122894.0, 'Junior', 50),
#  (901, 'Christopher', 'Walker', 122894.0, 'Junior', 51),
#  (902, 'Christopher', 'Walker', 122894.0, 'Junior', 52),
#  (903, 'Christopher', 'Walker', 122894.0, 'Junior', 60),
#  (904, 'Christopher', 'Walker', 122894.0, 'Junior', 61),
#  (905, 'Claire', 'Morris', 36000.0, 'Intern', 6),
#  (906, 'Claire', 'Morris', 36000.0, 'Intern', 19),
#  (907, 'Claire', 'Morris', 36000.0, 'Intern', 21),
#  (908, 'Claire', 'Morris', 36000.0, 'Intern', 22),
#  (909, 'Claire', 'Morris', 36000.0, 'Intern', 29),
#  (910, 'Claire', 'Morris', 36000.0, 'Intern', 30),
#  (911, 'Claire', 'Morris', 36000.0, 'Intern', 31),
#  (912, 'Claire', 'Morris', 36000.0, 'Intern', 45),
#  (913, 'Claire', 'Morris', 36000.0, 'Intern', 46),
#  (914, 'Claire', 'Morris', 36000.0, 'Intern', 54),
#  (915, 'Claire', 'Morris', 36000.0, 'Intern', 55),
#  (916, 'Claire', 'Morris', 36000.0, 'Intern', 56),
#  (917, 'Claire', 'Morris', 36000.0, 'Intern', 57),
#  (918, 'Contact', 'Xaba', 85836.0, 'Mid-Level', 2),
#  (919, 'Contact', 'Xaba', 85836.0, 'Mid-Level', 7),
#  (920, 'Contact', 'Xaba', 85836.0, 'Mid-Level', 10),
#  (921, 'Contact', 'Xaba', 85836.0, 'Mid-Level', 17),
#  (922, 'Contact', 'Xaba', 85836.0, 'Mid-Level', 34),
#  (923, 'Contact', 'Xaba', 85836.0, 'Mid-Level', 58),
#  (924, 'Danie', 'Campbell', 205621.0, 'Mid-Level', 1),
#  (925, 'Danie', 'Campbell', 205621.0, 'Mid-Level', 8),
#  (926, 'Danie', 'Campbell', 205621.0, 'Mid-Level', 9),
#  (927, 'Danie', 'Campbell', 205621.0, 'Mid-Level', 23),
#  (928, 'Danie', 'Campbell', 205621.0, 'Mid-Level', 33),
#  (929, 'Danie', 'Campbell', 205621.0, 'Mid-Level', 37),
#  (930, 'Danie', 'Campbell', 205621.0, 'Mid-Level', 38),
#  (931, 'Danie', 'Campbell', 205621.0, 'Mid-Level', 42),
#  (932, 'Danie', 'Campbell', 205621.0, 'Mid-Level', 53),
#  (933, 'Danie', 'davies', 313491.0, 'Senior', 2),
#  (934, 'Danie', 'davies', 313491.0, 'Senior', 7),
#  (935, 'Danie', 'davies', 313491.0, 'Senior', 10),
#  (936, 'Danie', 'davies', 313491.0, 'Senior', 17),
#  (937, 'Danie', 'davies', 313491.0, 'Senior', 34),
#  (938, 'Danie', 'davies', 313491.0, 'Senior', 58),
#  (939, 'Dirk', 'Banda', 37601.0, 'Intern', 4),
#  (940, 'Dirk', 'Banda', 37601.0, 'Intern', 5),
#  (941, 'Dirk', 'Banda', 37601.0, 'Intern', 11),
#  (942, 'Dirk', 'Banda', 37601.0, 'Intern', 12),
#  (943, 'Dirk', 'Banda', 37601.0, 'Intern', 13),
#  (944, 'Dirk', 'Banda', 37601.0, 'Intern', 14),
#  (945, 'Dirk', 'Banda', 37601.0, 'Intern', 15),
#  (946, 'Dirk', 'Banda', 37601.0, 'Intern', 16),
#  (947, 'Dirk', 'Banda', 37601.0, 'Intern', 18),
#  (948, 'Dirk', 'Banda', 37601.0, 'Intern', 20),
#  (949, 'Dirk', 'Banda', 37601.0, 'Intern', 26),
#  (950, 'Dirk', 'Banda', 37601.0, 'Intern', 27),
#  (951, 'Dirk', 'Banda', 37601.0, 'Intern', 28),
#  (952, 'Dirk', 'Banda', 37601.0, 'Intern', 39),
#  (953, 'Dirk', 'Banda', 37601.0, 'Intern', 40),
#  (954, 'Dirk', 'Banda', 37601.0, 'Intern', 47),
#  (955, 'Dirk', 'Banda', 37601.0, 'Intern', 48),
#  (956, 'Dirk', 'Banda', 37601.0, 'Intern', 49),
#  (957, 'Dirk', 'Banda', 37601.0, 'Intern', 50),
#  (958, 'Dirk', 'Banda', 37601.0, 'Intern', 51),
#  (959, 'Dirk', 'Banda', 37601.0, 'Intern', 52),
#  (960, 'Dirk', 'Banda', 37601.0, 'Intern', 60),
#  (961, 'Dirk', 'Banda', 37601.0, 'Intern', 61),
#  (962, 'Douglas', 'Sibanda', 57353.0, 'Mid-Level', 4),
#  (963, 'Douglas', 'Sibanda', 57353.0, 'Mid-Level', 5),
#  (964, 'Douglas', 'Sibanda', 57353.0, 'Mid-Level', 11),
#  (965, 'Douglas', 'Sibanda', 57353.0, 'Mid-Level', 12),
#  (966, 'Douglas', 'Sibanda', 57353.0, 'Mid-Level', 13),
#  (967, 'Douglas', 'Sibanda', 57353.0, 'Mid-Level', 14),
#  (968, 'Douglas', 'Sibanda', 57353.0, 'Mid-Level', 15),
#  (969, 'Douglas', 'Sibanda', 57353.0, 'Mid-Level', 16),
#  (970, 'Douglas', 'Sibanda', 57353.0, 'Mid-Level', 18),
#  (971, 'Douglas', 'Sibanda', 57353.0, 'Mid-Level', 20),
#  (972, 'Douglas', 'Sibanda', 57353.0, 'Mid-Level', 26),
#  (973, 'Douglas', 'Sibanda', 57353.0, 'Mid-Level', 27),
#  (974, 'Douglas', 'Sibanda', 57353.0, 'Mid-Level', 28),
#  (975, 'Douglas', 'Sibanda', 57353.0, 'Mid-Level', 39),
#  (976, 'Douglas', 'Sibanda', 57353.0, 'Mid-Level', 40),
#  (977, 'Douglas', 'Sibanda', 57353.0, 'Mid-Level', 47),
#  (978, 'Douglas', 'Sibanda', 57353.0, 'Mid-Level', 48),
#  (979, 'Douglas', 'Sibanda', 57353.0, 'Mid-Level', 49),
#  (980, 'Douglas', 'Sibanda', 57353.0, 'Mid-Level', 50),
#  (981, 'Douglas', 'Sibanda', 57353.0, 'Mid-Level', 51),
#  (982, 'Douglas', 'Sibanda', 57353.0, 'Mid-Level', 52),
#  (983, 'Douglas', 'Sibanda', 57353.0, 'Mid-Level', 60),
#  (984, 'Douglas', 'Sibanda', 57353.0, 'Mid-Level', 61),
#  (985, 'Dumisani', 'Thwala', 52171.0, 'Graduate', 4),
#  (986, 'Dumisani', 'Thwala', 52171.0, 'Graduate', 5),
#  (987, 'Dumisani', 'Thwala', 52171.0, 'Graduate', 11),
#  (988, 'Dumisani', 'Thwala', 52171.0, 'Graduate', 12),
#  (989, 'Dumisani', 'Thwala', 52171.0, 'Graduate', 13),
#  (990, 'Dumisani', 'Thwala', 52171.0, 'Graduate', 14),
#  (991, 'Dumisani', 'Thwala', 52171.0, 'Graduate', 15),
#  (992, 'Dumisani', 'Thwala', 52171.0, 'Graduate', 16),
#  (993, 'Dumisani', 'Thwala', 52171.0, 'Graduate', 18),
#  (994, 'Dumisani', 'Thwala', 52171.0, 'Graduate', 20),
#  (995, 'Dumisani', 'Thwala', 52171.0, 'Graduate', 26),
#  (996, 'Dumisani', 'Thwala', 52171.0, 'Graduate', 27),
#  (997, 'Dumisani', 'Thwala', 52171.0, 'Graduate', 28),
#  (998, 'Dumisani', 'Thwala', 52171.0, 'Graduate', 39),
#  (999, 'Dumisani', 'Thwala', 52171.0, 'Graduate', 40),
#  (1000, 'Dumisani', 'Thwala', 52171.0, 'Graduate', 47),
#  (1001, 'Dumisani', 'Thwala', 52171.0, 'Graduate', 48),
#  (1002, 'Dumisani', 'Thwala', 52171.0, 'Graduate', 49),
#  (1003, 'Dumisani', 'Thwala', 52171.0, 'Graduate', 50),
#  (1004, 'Dumisani', 'Thwala', 52171.0, 'Graduate', 51),
#  (1005, 'Dumisani', 'Thwala', 52171.0, 'Graduate', 52),
#  (1006, 'Dumisani', 'Thwala', 52171.0, 'Graduate', 60),
#  (1007, 'Dumisani', 'Thwala', 52171.0, 'Graduate', 61),
#  (1008, 'Ernest', 'maritz', 88569.0, 'Graduate', 4),
#  (1009, 'Ernest', 'maritz', 88569.0, 'Graduate', 5),
#  (1010, 'Ernest', 'maritz', 88569.0, 'Graduate', 11),
#  (1011, 'Ernest', 'maritz', 88569.0, 'Graduate', 12),
#  (1012, 'Ernest', 'maritz', 88569.0, 'Graduate', 13),
#  (1013, 'Ernest', 'maritz', 88569.0, 'Graduate', 14),
#  (1014, 'Ernest', 'maritz', 88569.0, 'Graduate', 15),
#  (1015, 'Ernest', 'maritz', 88569.0, 'Graduate', 16),
#  (1016, 'Ernest', 'maritz', 88569.0, 'Graduate', 18),
#  (1017, 'Ernest', 'maritz', 88569.0, 'Graduate', 20),
#  (1018, 'Ernest', 'maritz', 88569.0, 'Graduate', 26),
#  (1019, 'Ernest', 'maritz', 88569.0, 'Graduate', 27),
#  (1020, 'Ernest', 'maritz', 88569.0, 'Graduate', 28),
#  (1021, 'Ernest', 'maritz', 88569.0, 'Graduate', 39),
#  (1022, 'Ernest', 'maritz', 88569.0, 'Graduate', 40),
#  (1023, 'Ernest', 'maritz', 88569.0, 'Graduate', 47),
#  (1024, 'Ernest', 'maritz', 88569.0, 'Graduate', 48),
#  (1025, 'Ernest', 'maritz', 88569.0, 'Graduate', 49),
#  (1026, 'Ernest', 'maritz', 88569.0, 'Graduate', 50),
#  (1027, 'Ernest', 'maritz', 88569.0, 'Graduate', 51),
#  (1028, 'Ernest', 'maritz', 88569.0, 'Graduate', 52),
#  (1029, 'Ernest', 'maritz', 88569.0, 'Graduate', 60),
#  (1030, 'Ernest', 'maritz', 88569.0, 'Graduate', 61),
#  (1031, 'Ivan', 'Schoeman', 167439.0, 'Junior', 2),
#  (1032, 'Ivan', 'Schoeman', 167439.0, 'Junior', 7),
#  (1033, 'Ivan', 'Schoeman', 167439.0, 'Junior', 10),
#  (1034, 'Ivan', 'Schoeman', 167439.0, 'Junior', 17),
#  (1035, 'Ivan', 'Schoeman', 167439.0, 'Junior', 34),
#  (1036, 'Ivan', 'Schoeman', 167439.0, 'Junior', 58),
#  (1037, 'Jabulani', 'Horn', 55725.0, 'Intern', 4),
#  (1038, 'Jabulani', 'Horn', 55725.0, 'Intern', 5),
#  (1039, 'Jabulani', 'Horn', 55725.0, 'Intern', 11),
#  (1040, 'Jabulani', 'Horn', 55725.0, 'Intern', 12),
#  (1041, 'Jabulani', 'Horn', 55725.0, 'Intern', 13),
#  (1042, 'Jabulani', 'Horn', 55725.0, 'Intern', 14),
#  (1043, 'Jabulani', 'Horn', 55725.0, 'Intern', 15),
#  (1044, 'Jabulani', 'Horn', 55725.0, 'Intern', 16),
#  (1045, 'Jabulani', 'Horn', 55725.0, 'Intern', 18),
#  (1046, 'Jabulani', 'Horn', 55725.0, 'Intern', 20),
#  (1047, 'Jabulani', 'Horn', 55725.0, 'Intern', 26),
#  (1048, 'Jabulani', 'Horn', 55725.0, 'Intern', 27),
#  (1049, 'Jabulani', 'Horn', 55725.0, 'Intern', 28),
#  (1050, 'Jabulani', 'Horn', 55725.0, 'Intern', 39),
#  (1051, 'Jabulani', 'Horn', 55725.0, 'Intern', 40),
#  (1052, 'Jabulani', 'Horn', 55725.0, 'Intern', 47),
#  (1053, 'Jabulani', 'Horn', 55725.0, 'Intern', 48),
#  (1054, 'Jabulani', 'Horn', 55725.0, 'Intern', 49),
#  (1055, 'Jabulani', 'Horn', 55725.0, 'Intern', 50),
#  (1056, 'Jabulani', 'Horn', 55725.0, 'Intern', 51),
#  (1057, 'Jabulani', 'Horn', 55725.0, 'Intern', 52),
#  (1058, 'Jabulani', 'Horn', 55725.0, 'Intern', 60),
#  (1059, 'Jabulani', 'Horn', 55725.0, 'Intern', 61),
#  (1060, 'Jacqueline', 'fredericks', 51104.0, 'Graduate', 6),
#  (1061, 'Jacqueline', 'fredericks', 51104.0, 'Graduate', 19),
#  (1062, 'Jacqueline', 'fredericks', 51104.0, 'Graduate', 21),
#  (1063, 'Jacqueline', 'fredericks', 51104.0, 'Graduate', 22),
#  (1064, 'Jacqueline', 'fredericks', 51104.0, 'Graduate', 29),
#  (1065, 'Jacqueline', 'fredericks', 51104.0, 'Graduate', 30),
#  (1066, 'Jacqueline', 'fredericks', 51104.0, 'Graduate', 31),
#  (1067, 'Jacqueline', 'fredericks', 51104.0, 'Graduate', 45),
#  (1068, 'Jacqueline', 'fredericks', 51104.0, 'Graduate', 46),
#  (1069, 'Jacqueline', 'fredericks', 51104.0, 'Graduate', 54),
#  (1070, 'Jacqueline', 'fredericks', 51104.0, 'Graduate', 55),
#  (1071, 'Jacqueline', 'fredericks', 51104.0, 'Graduate', 56),
#  (1072, 'Jacqueline', 'fredericks', 51104.0, 'Graduate', 57),
#  (1073, 'Jan', 'Ngwenya', 38959.0, 'Intern', 4),
#  (1074, 'Jan', 'Ngwenya', 38959.0, 'Intern', 5),
#  (1075, 'Jan', 'Ngwenya', 38959.0, 'Intern', 11),
#  (1076, 'Jan', 'Ngwenya', 38959.0, 'Intern', 12),
#  (1077, 'Jan', 'Ngwenya', 38959.0, 'Intern', 13),
#  (1078, 'Jan', 'Ngwenya', 38959.0, 'Intern', 14),
#  (1079, 'Jan', 'Ngwenya', 38959.0, 'Intern', 15),
#  (1080, 'Jan', 'Ngwenya', 38959.0, 'Intern', 16),
#  (1081, 'Jan', 'Ngwenya', 38959.0, 'Intern', 18),
#  (1082, 'Jan', 'Ngwenya', 38959.0, 'Intern', 20),
#  (1083, 'Jan', 'Ngwenya', 38959.0, 'Intern', 26),
#  (1084, 'Jan', 'Ngwenya', 38959.0, 'Intern', 27),
#  (1085, 'Jan', 'Ngwenya', 38959.0, 'Intern', 28),
#  (1086, 'Jan', 'Ngwenya', 38959.0, 'Intern', 39),
#  (1087, 'Jan', 'Ngwenya', 38959.0, 'Intern', 40),
#  (1088, 'Jan', 'Ngwenya', 38959.0, 'Intern', 47),
#  (1089, 'Jan', 'Ngwenya', 38959.0, 'Intern', 48),
#  (1090, 'Jan', 'Ngwenya', 38959.0, 'Intern', 49),
#  (1091, 'Jan', 'Ngwenya', 38959.0, 'Intern', 50),
#  (1092, 'Jan', 'Ngwenya', 38959.0, 'Intern', 51),
#  (1093, 'Jan', 'Ngwenya', 38959.0, 'Intern', 52),
#  (1094, 'Jan', 'Ngwenya', 38959.0, 'Intern', 60),
#  (1095, 'Jan', 'Ngwenya', 38959.0, 'Intern', 61),
#  (1096, 'Janet', 'Patel', 39081.0, 'Intern', 6),
#  (1097, 'Janet', 'Patel', 39081.0, 'Intern', 19),
#  (1098, 'Janet', 'Patel', 39081.0, 'Intern', 21),
#  (1099, 'Janet', 'Patel', 39081.0, 'Intern', 22),
#  (1100, 'Janet', 'Patel', 39081.0, 'Intern', 29),
#  (1101, 'Janet', 'Patel', 39081.0, 'Intern', 30),
#  (1102, 'Janet', 'Patel', 39081.0, 'Intern', 31),
#  (1103, 'Janet', 'Patel', 39081.0, 'Intern', 45),
#  (1104, 'Janet', 'Patel', 39081.0, 'Intern', 46),
#  (1105, 'Janet', 'Patel', 39081.0, 'Intern', 54),
#  (1106, 'Janet', 'Patel', 39081.0, 'Intern', 55),
#  (1107, 'Janet', 'Patel', 39081.0, 'Intern', 56),
#  (1108, 'Janet', 'Patel', 39081.0, 'Intern', 57),
#  (1109, 'Janine', 'De Villiers', 32886.0, 'Intern', 1),
#  (1110, 'Janine', 'De Villiers', 32886.0, 'Intern', 8),
#  (1111, 'Janine', 'De Villiers', 32886.0, 'Intern', 9),
#  (1112, 'Janine', 'De Villiers', 32886.0, 'Intern', 23),
#  (1113, 'Janine', 'De Villiers', 32886.0, 'Intern', 33),
#  (1114, 'Janine', 'De Villiers', 32886.0, 'Intern', 37),
#  (1115, 'Janine', 'De Villiers', 32886.0, 'Intern', 38),
#  (1116, 'Janine', 'De Villiers', 32886.0, 'Intern', 42),
#  (1117, 'Janine', 'De Villiers', 32886.0, 'Intern', 53),
#  (1118, 'Jessica', 'Mchunu', 70741.0, 'Mid-Level', 3),
#  (1119, 'Jessica', 'Mchunu', 70741.0, 'Mid-Level', 24),
#  (1120, 'Jessica', 'Mchunu', 70741.0, 'Mid-Level', 25),
#  (1121, 'Jessica', 'Mchunu', 70741.0, 'Mid-Level', 32),
#  (1122, 'Jessica', 'Mchunu', 70741.0, 'Mid-Level', 43),
#  (1123, 'Jessica', 'Mchunu', 70741.0, 'Mid-Level', 44),
#  (1124, 'Johan', 'du Plessis', 235178.0, 'Mid-Level', 4),
#  (1125, 'Johan', 'du Plessis', 235178.0, 'Mid-Level', 5),
#  (1126, 'Johan', 'du Plessis', 235178.0, 'Mid-Level', 11),
#  (1127, 'Johan', 'du Plessis', 235178.0, 'Mid-Level', 12),
#  (1128, 'Johan', 'du Plessis', 235178.0, 'Mid-Level', 13),
#  (1129, 'Johan', 'du Plessis', 235178.0, 'Mid-Level', 14),
#  (1130, 'Johan', 'du Plessis', 235178.0, 'Mid-Level', 15),
#  (1131, 'Johan', 'du Plessis', 235178.0, 'Mid-Level', 16),
#  (1132, 'Johan', 'du Plessis', 235178.0, 'Mid-Level', 18),
#  (1133, 'Johan', 'du Plessis', 235178.0, 'Mid-Level', 20),
#  (1134, 'Johan', 'du Plessis', 235178.0, 'Mid-Level', 26),
#  (1135, 'Johan', 'du Plessis', 235178.0, 'Mid-Level', 27),
#  (1136, 'Johan', 'du Plessis', 235178.0, 'Mid-Level', 28),
#  (1137, 'Johan', 'du Plessis', 235178.0, 'Mid-Level', 39),
#  (1138, 'Johan', 'du Plessis', 235178.0, 'Mid-Level', 40),
#  (1139, 'Johan', 'du Plessis', 235178.0, 'Mid-Level', 47),
#  (1140, 'Johan', 'du Plessis', 235178.0, 'Mid-Level', 48),
#  (1141, 'Johan', 'du Plessis', 235178.0, 'Mid-Level', 49),
#  (1142, 'Johan', 'du Plessis', 235178.0, 'Mid-Level', 50),
#  (1143, 'Johan', 'du Plessis', 235178.0, 'Mid-Level', 51),
#  (1144, 'Johan', 'du Plessis', 235178.0, 'Mid-Level', 52),
#  (1145, 'Johan', 'du Plessis', 235178.0, 'Mid-Level', 60),
#  (1146, 'Johan', 'du Plessis', 235178.0, 'Mid-Level', 61),
#  (1147, 'Juan', 'Smit', 308542.0, 'Senior', 4),
#  (1148, 'Juan', 'Smit', 308542.0, 'Senior', 5),
#  (1149, 'Juan', 'Smit', 308542.0, 'Senior', 11),
#  (1150, 'Juan', 'Smit', 308542.0, 'Senior', 12),
#  (1151, 'Juan', 'Smit', 308542.0, 'Senior', 13),
#  (1152, 'Juan', 'Smit', 308542.0, 'Senior', 14),
#  (1153, 'Juan', 'Smit', 308542.0, 'Senior', 15),
#  (1154, 'Juan', 'Smit', 308542.0, 'Senior', 16),
#  (1155, 'Juan', 'Smit', 308542.0, 'Senior', 18),
#  (1156, 'Juan', 'Smit', 308542.0, 'Senior', 20),
#  (1157, 'Juan', 'Smit', 308542.0, 'Senior', 26),
#  (1158, 'Juan', 'Smit', 308542.0, 'Senior', 27),
#  (1159, 'Juan', 'Smit', 308542.0, 'Senior', 28),
#  (1160, 'Juan', 'Smit', 308542.0, 'Senior', 39),
#  (1161, 'Juan', 'Smit', 308542.0, 'Senior', 40),
#  (1162, 'Juan', 'Smit', 308542.0, 'Senior', 47),
#  (1163, 'Juan', 'Smit', 308542.0, 'Senior', 48),
#  (1164, 'Juan', 'Smit', 308542.0, 'Senior', 49),
#  (1165, 'Juan', 'Smit', 308542.0, 'Senior', 50),
#  (1166, 'Juan', 'Smit', 308542.0, 'Senior', 51),
#  (1167, 'Juan', 'Smit', 308542.0, 'Senior', 52),
#  (1168, 'Juan', 'Smit', 308542.0, 'Senior', 60),
#  (1169, 'Juan', 'Smit', 308542.0, 'Senior', 61),
#  (1170, 'Kevin', 'Motloung', 99370.0, 'Graduate', 4),
#  (1171, 'Kevin', 'Motloung', 99370.0, 'Graduate', 5),
#  (1172, 'Kevin', 'Motloung', 99370.0, 'Graduate', 11),
#  (1173, 'Kevin', 'Motloung', 99370.0, 'Graduate', 12),
#  (1174, 'Kevin', 'Motloung', 99370.0, 'Graduate', 13),
#  (1175, 'Kevin', 'Motloung', 99370.0, 'Graduate', 14),
#  (1176, 'Kevin', 'Motloung', 99370.0, 'Graduate', 15),
#  (1177, 'Kevin', 'Motloung', 99370.0, 'Graduate', 16),
#  (1178, 'Kevin', 'Motloung', 99370.0, 'Graduate', 18),
#  (1179, 'Kevin', 'Motloung', 99370.0, 'Graduate', 20),
#  (1180, 'Kevin', 'Motloung', 99370.0, 'Graduate', 26),
#  (1181, 'Kevin', 'Motloung', 99370.0, 'Graduate', 27),
#  (1182, 'Kevin', 'Motloung', 99370.0, 'Graduate', 28),
#  (1183, 'Kevin', 'Motloung', 99370.0, 'Graduate', 39),
#  (1184, 'Kevin', 'Motloung', 99370.0, 'Graduate', 40),
#  (1185, 'Kevin', 'Motloung', 99370.0, 'Graduate', 47),
#  (1186, 'Kevin', 'Motloung', 99370.0, 'Graduate', 48),
#  (1187, 'Kevin', 'Motloung', 99370.0, 'Graduate', 49),
#  (1188, 'Kevin', 'Motloung', 99370.0, 'Graduate', 50),
#  (1189, 'Kevin', 'Motloung', 99370.0, 'Graduate', 51),
#  (1190, 'Kevin', 'Motloung', 99370.0, 'Graduate', 52),
#  (1191, 'Kevin', 'Motloung', 99370.0, 'Graduate', 60),
#  (1192, 'Kevin', 'Motloung', 99370.0, 'Graduate', 61),
#  (1193, 'Laura', 'Makhanya', 293352.0, 'Senior', 6),
#  (1194, 'Laura', 'Makhanya', 293352.0, 'Senior', 19),
#  (1195, 'Laura', 'Makhanya', 293352.0, 'Senior', 21),
#  (1196, 'Laura', 'Makhanya', 293352.0, 'Senior', 22),
#  (1197, 'Laura', 'Makhanya', 293352.0, 'Senior', 29),
#  (1198, 'Laura', 'Makhanya', 293352.0, 'Senior', 30),
#  (1199, 'Laura', 'Makhanya', 293352.0, 'Senior', 31),
#  (1200, 'Laura', 'Makhanya', 293352.0, 'Senior', 45),
#  (1201, 'Laura', 'Makhanya', 293352.0, 'Senior', 46),
#  (1202, 'Laura', 'Makhanya', 293352.0, 'Senior', 54),
#  (1203, 'Laura', 'Makhanya', 293352.0, 'Senior', 55),
#  (1204, 'Laura', 'Makhanya', 293352.0, 'Senior', 56),
#  (1205, 'Laura', 'Makhanya', 293352.0, 'Senior', 57),
#  (1206, 'Lesego', 'Bennett', 41083.0, 'Junior', 6),
#  (1207, 'Lesego', 'Bennett', 41083.0, 'Junior', 19),
#  (1208, 'Lesego', 'Bennett', 41083.0, 'Junior', 21),
#  (1209, 'Lesego', 'Bennett', 41083.0, 'Junior', 22),
#  (1210, 'Lesego', 'Bennett', 41083.0, 'Junior', 29),
#  (1211, 'Lesego', 'Bennett', 41083.0, 'Junior', 30),
#  (1212, 'Lesego', 'Bennett', 41083.0, 'Junior', 31),
#  (1213, 'Lesego', 'Bennett', 41083.0, 'Junior', 45),
#  (1214, 'Lesego', 'Bennett', 41083.0, 'Junior', 46),
#  (1215, 'Lesego', 'Bennett', 41083.0, 'Junior', 54),
#  (1216, 'Lesego', 'Bennett', 41083.0, 'Junior', 55),
#  (1217, 'Lesego', 'Bennett', 41083.0, 'Junior', 56),
#  (1218, 'Lesego', 'Bennett', 41083.0, 'Junior', 57),
#  (1219, 'Lizelle', 'Dhlamini', 64179.0, 'Junior', 3),
#  (1220, 'Lizelle', 'Dhlamini', 64179.0, 'Junior', 24),
#  (1221, 'Lizelle', 'Dhlamini', 64179.0, 'Junior', 25),
#  (1222, 'Lizelle', 'Dhlamini', 64179.0, 'Junior', 32),
#  (1223, 'Lizelle', 'Dhlamini', 64179.0, 'Junior', 43),
#  (1224, 'Lizelle', 'Dhlamini', 64179.0, 'Junior', 44),
#  (1225, 'Louise', 'Lourens', 158634.0, 'Mid-Level', 1),
#  (1226, 'Louise', 'Lourens', 158634.0, 'Mid-Level', 8),
#  (1227, 'Louise', 'Lourens', 158634.0, 'Mid-Level', 9),
#  (1228, 'Louise', 'Lourens', 158634.0, 'Mid-Level', 23),
#  (1229, 'Louise', 'Lourens', 158634.0, 'Mid-Level', 33),
#  (1230, 'Louise', 'Lourens', 158634.0, 'Mid-Level', 37),
#  (1231, 'Louise', 'Lourens', 158634.0, 'Mid-Level', 38),
#  (1232, 'Louise', 'Lourens', 158634.0, 'Mid-Level', 42),
#  (1233, 'Louise', 'Lourens', 158634.0, 'Mid-Level', 53),
#  (1234, 'Lynn', 'Mashaba', 115478.0, 'Junior', 2),
#  (1235, 'Lynn', 'Mashaba', 115478.0, 'Junior', 7),
#  (1236, 'Lynn', 'Mashaba', 115478.0, 'Junior', 10),
#  (1237, 'Lynn', 'Mashaba', 115478.0, 'Junior', 17),
#  (1238, 'Lynn', 'Mashaba', 115478.0, 'Junior', 34),
#  (1239, 'Lynn', 'Mashaba', 115478.0, 'Junior', 58),
#  (1240, 'Marco', 'Morris', 110506.0, 'Mid-Level', 35),
#  (1241, 'Marco', 'Morris', 110506.0, 'Mid-Level', 36),
#  (1242, 'Marco', 'Morris', 110506.0, 'Mid-Level', 59),
#  (1243, 'Marthinus', 'Gordon', 106178.0, 'Mid-Level', 1),
#  (1244, 'Marthinus', 'Gordon', 106178.0, 'Mid-Level', 8),
#  (1245, 'Marthinus', 'Gordon', 106178.0, 'Mid-Level', 9),
#  (1246, 'Marthinus', 'Gordon', 106178.0, 'Mid-Level', 23),
#  (1247, 'Marthinus', 'Gordon', 106178.0, 'Mid-Level', 33),
#  (1248, 'Marthinus', 'Gordon', 106178.0, 'Mid-Level', 37),
#  (1249, 'Marthinus', 'Gordon', 106178.0, 'Mid-Level', 38),
#  (1250, 'Marthinus', 'Gordon', 106178.0, 'Mid-Level', 42),
#  (1251, 'Marthinus', 'Gordon', 106178.0, 'Mid-Level', 53),
#  (1252, 'Nadine', 'Morris', 326767.0, 'Senior', 1),
#  (1253, 'Nadine', 'Morris', 326767.0, 'Senior', 8),
#  (1254, 'Nadine', 'Morris', 326767.0, 'Senior', 9),
#  (1255, 'Nadine', 'Morris', 326767.0, 'Senior', 23),
#  (1256, 'Nadine', 'Morris', 326767.0, 'Senior', 33),
#  (1257, 'Nadine', 'Morris', 326767.0, 'Senior', 37),
#  (1258, 'Nadine', 'Morris', 326767.0, 'Senior', 38),
#  (1259, 'Nadine', 'Morris', 326767.0, 'Senior', 42),
#  (1260, 'Nadine', 'Morris', 326767.0, 'Senior', 53),
#  (1261, 'Nico', 'Mthembu', 97673.0, 'Senior', 4),
#  (1262, 'Nico', 'Mthembu', 97673.0, 'Senior', 5),
#  (1263, 'Nico', 'Mthembu', 97673.0, 'Senior', 11),
#  (1264, 'Nico', 'Mthembu', 97673.0, 'Senior', 12),
#  (1265, 'Nico', 'Mthembu', 97673.0, 'Senior', 13),
#  (1266, 'Nico', 'Mthembu', 97673.0, 'Senior', 14),
#  (1267, 'Nico', 'Mthembu', 97673.0, 'Senior', 15),
#  (1268, 'Nico', 'Mthembu', 97673.0, 'Senior', 16),
#  (1269, 'Nico', 'Mthembu', 97673.0, 'Senior', 18),
#  (1270, 'Nico', 'Mthembu', 97673.0, 'Senior', 20),
#  (1271, 'Nico', 'Mthembu', 97673.0, 'Senior', 26),
#  (1272, 'Nico', 'Mthembu', 97673.0, 'Senior', 27),
#  (1273, 'Nico', 'Mthembu', 97673.0, 'Senior', 28),
#  (1274, 'Nico', 'Mthembu', 97673.0, 'Senior', 39),
#  (1275, 'Nico', 'Mthembu', 97673.0, 'Senior', 40),
#  (1276, 'Nico', 'Mthembu', 97673.0, 'Senior', 47),
#  (1277, 'Nico', 'Mthembu', 97673.0, 'Senior', 48),
#  (1278, 'Nico', 'Mthembu', 97673.0, 'Senior', 49),
#  (1279, 'Nico', 'Mthembu', 97673.0, 'Senior', 50),
#  (1280, 'Nico', 'Mthembu', 97673.0, 'Senior', 51),
#  (1281, 'Nico', 'Mthembu', 97673.0, 'Senior', 52),
#  (1282, 'Nico', 'Mthembu', 97673.0, 'Senior', 60),
#  (1283, 'Nico', 'Mthembu', 97673.0, 'Senior', 61),
#  (1284, 'Patience', 'Willemse', 52053.0, 'Intern', 1),
#  (1285, 'Patience', 'Willemse', 52053.0, 'Intern', 8),
#  (1286, 'Patience', 'Willemse', 52053.0, 'Intern', 9),
#  (1287, 'Patience', 'Willemse', 52053.0, 'Intern', 23),
#  (1288, 'Patience', 'Willemse', 52053.0, 'Intern', 33),
#  (1289, 'Patience', 'Willemse', 52053.0, 'Intern', 37),
#  (1290, 'Patience', 'Willemse', 52053.0, 'Intern', 38),
#  (1291, 'Patience', 'Willemse', 52053.0, 'Intern', 42),
#  (1292, 'Patience', 'Willemse', 52053.0, 'Intern', 53),
#  (1293, 'Pearl', 'Stewart', 24289.0, 'Intern', 3),
#  (1294, 'Pearl', 'Stewart', 24289.0, 'Intern', 24),
#  (1295, 'Pearl', 'Stewart', 24289.0, 'Intern', 25),
#  (1296, 'Pearl', 'Stewart', 24289.0, 'Intern', 32),
#  (1297, 'Pearl', 'Stewart', 24289.0, 'Intern', 43),
#  (1298, 'Pearl', 'Stewart', 24289.0, 'Intern', 44),
#  (1299, 'Precious', 'zungu', 264376.0, 'Senior', 3),
#  (1300, 'Precious', 'zungu', 264376.0, 'Senior', 24),
#  (1301, 'Precious', 'zungu', 264376.0, 'Senior', 25),
#  (1302, 'Precious', 'zungu', 264376.0, 'Senior', 32),
#  (1303, 'Precious', 'zungu', 264376.0, 'Senior', 43),
#  (1304, 'Precious', 'zungu', 264376.0, 'Senior', 44),
#  (1305, 'Priscilla', 'Anderson', 262686.0, 'Senior', 6),
#  (1306, 'Priscilla', 'Anderson', 262686.0, 'Senior', 19),
#  (1307, 'Priscilla', 'Anderson', 262686.0, 'Senior', 21),
#  (1308, 'Priscilla', 'Anderson', 262686.0, 'Senior', 22),
#  (1309, 'Priscilla', 'Anderson', 262686.0, 'Senior', 29),
#  (1310, 'Priscilla', 'Anderson', 262686.0, 'Senior', 30),
#  (1311, 'Priscilla', 'Anderson', 262686.0, 'Senior', 31),
#  (1312, 'Priscilla', 'Anderson', 262686.0, 'Senior', 45),
#  (1313, 'Priscilla', 'Anderson', 262686.0, 'Senior', 46),
#  (1314, 'Priscilla', 'Anderson', 262686.0, 'Senior', 54),
#  (1315, 'Priscilla', 'Anderson', 262686.0, 'Senior', 55),
#  (1316, 'Priscilla', 'Anderson', 262686.0, 'Senior', 56),
#  (1317, 'Priscilla', 'Anderson', 262686.0, 'Senior', 57),
#  (1318, 'Siyabonga', 'Hanekom', 213477.0, 'Senior', 6),
#  (1319, 'Siyabonga', 'Hanekom', 213477.0, 'Senior', 19),
#  (1320, 'Siyabonga', 'Hanekom', 213477.0, 'Senior', 21),
#  (1321, 'Siyabonga', 'Hanekom', 213477.0, 'Senior', 22),
#  (1322, 'Siyabonga', 'Hanekom', 213477.0, 'Senior', 29),
#  (1323, 'Siyabonga', 'Hanekom', 213477.0, 'Senior', 30),
#  (1324, 'Siyabonga', 'Hanekom', 213477.0, 'Senior', 31),
#  (1325, 'Siyabonga', 'Hanekom', 213477.0, 'Senior', 45),
#  (1326, 'Siyabonga', 'Hanekom', 213477.0, 'Senior', 46),
#  (1327, 'Siyabonga', 'Hanekom', 213477.0, 'Senior', 54),
#  (1328, 'Siyabonga', 'Hanekom', 213477.0, 'Senior', 55),
#  (1329, 'Siyabonga', 'Hanekom', 213477.0, 'Senior', 56),
#  (1330, 'Siyabonga', 'Hanekom', 213477.0, 'Senior', 57),
#  (1331, 'Tony', 'Horn', 103397.0, 'Graduate', 4),
#  (1332, 'Tony', 'Horn', 103397.0, 'Graduate', 5),
#  (1333, 'Tony', 'Horn', 103397.0, 'Graduate', 11),
#  (1334, 'Tony', 'Horn', 103397.0, 'Graduate', 12),
#  (1335, 'Tony', 'Horn', 103397.0, 'Graduate', 13),
#  (1336, 'Tony', 'Horn', 103397.0, 'Graduate', 14),
#  (1337, 'Tony', 'Horn', 103397.0, 'Graduate', 15),
#  (1338, 'Tony', 'Horn', 103397.0, 'Graduate', 16),
#  (1339, 'Tony', 'Horn', 103397.0, 'Graduate', 18),
#  (1340, 'Tony', 'Horn', 103397.0, 'Graduate', 20),
#  (1341, 'Tony', 'Horn', 103397.0, 'Graduate', 26),
#  (1342, 'Tony', 'Horn', 103397.0, 'Graduate', 27),
#  (1343, 'Tony', 'Horn', 103397.0, 'Graduate', 28),
#  (1344, 'Tony', 'Horn', 103397.0, 'Graduate', 39),
#  (1345, 'Tony', 'Horn', 103397.0, 'Graduate', 40),
#  (1346, 'Tony', 'Horn', 103397.0, 'Graduate', 47),
#  (1347, 'Tony', 'Horn', 103397.0, 'Graduate', 48),
#  (1348, 'Tony', 'Horn', 103397.0, 'Graduate', 49),
#  (1349, 'Tony', 'Horn', 103397.0, 'Graduate', 50),
#  (1350, 'Tony', 'Horn', 103397.0, 'Graduate', 51),
#  (1351, 'Tony', 'Horn', 103397.0, 'Graduate', 52),
#  (1352, 'Tony', 'Horn', 103397.0, 'Graduate', 60),
#  (1353, 'Tony', 'Horn', 103397.0, 'Graduate', 61),
#  (1354, 'Tumelo', 'Rikhotso', 144372.0, 'Mid-Level', 4),
#  (1355, 'Tumelo', 'Rikhotso', 144372.0, 'Mid-Level', 5),
#  (1356, 'Tumelo', 'Rikhotso', 144372.0, 'Mid-Level', 11),
#  (1357, 'Tumelo', 'Rikhotso', 144372.0, 'Mid-Level', 12),
#  (1358, 'Tumelo', 'Rikhotso', 144372.0, 'Mid-Level', 13),
#  (1359, 'Tumelo', 'Rikhotso', 144372.0, 'Mid-Level', 14),
#  (1360, 'Tumelo', 'Rikhotso', 144372.0, 'Mid-Level', 15),
#  (1361, 'Tumelo', 'Rikhotso', 144372.0, 'Mid-Level', 16),
#  (1362, 'Tumelo', 'Rikhotso', 144372.0, 'Mid-Level', 18),
#  (1363, 'Tumelo', 'Rikhotso', 144372.0, 'Mid-Level', 20),
#  (1364, 'Tumelo', 'Rikhotso', 144372.0, 'Mid-Level', 26),
#  (1365, 'Tumelo', 'Rikhotso', 144372.0, 'Mid-Level', 27),
#  (1366, 'Tumelo', 'Rikhotso', 144372.0, 'Mid-Level', 28),
#  (1367, 'Tumelo', 'Rikhotso', 144372.0, 'Mid-Level', 39),
#  (1368, 'Tumelo', 'Rikhotso', 144372.0, 'Mid-Level', 40),
#  (1369, 'Tumelo', 'Rikhotso', 144372.0, 'Mid-Level', 47),
#  (1370, 'Tumelo', 'Rikhotso', 144372.0, 'Mid-Level', 48),
#  (1371, 'Tumelo', 'Rikhotso', 144372.0, 'Mid-Level', 49),
#  (1372, 'Tumelo', 'Rikhotso', 144372.0, 'Mid-Level', 50),
#  (1373, 'Tumelo', 'Rikhotso', 144372.0, 'Mid-Level', 51),
#  (1374, 'Tumelo', 'Rikhotso', 144372.0, 'Mid-Level', 52),
#  (1375, 'Tumelo', 'Rikhotso', 144372.0, 'Mid-Level', 60),
#  (1376, 'Tumelo', 'Rikhotso', 144372.0, 'Mid-Level', 61),
#  (1377, 'Vuyokazi', 'barnes', 69220.0, 'Graduate', 4),
#  (1378, 'Vuyokazi', 'barnes', 69220.0, 'Graduate', 5),
#  (1379, 'Vuyokazi', 'barnes', 69220.0, 'Graduate', 11),
#  (1380, 'Vuyokazi', 'barnes', 69220.0, 'Graduate', 12),
#  (1381, 'Vuyokazi', 'barnes', 69220.0, 'Graduate', 13),
#  (1382, 'Vuyokazi', 'barnes', 69220.0, 'Graduate', 14),
#  (1383, 'Vuyokazi', 'barnes', 69220.0, 'Graduate', 15),
#  (1384, 'Vuyokazi', 'barnes', 69220.0, 'Graduate', 16),
#  (1385, 'Vuyokazi', 'barnes', 69220.0, 'Graduate', 18),
#  (1386, 'Vuyokazi', 'barnes', 69220.0, 'Graduate', 20),
#  (1387, 'Vuyokazi', 'barnes', 69220.0, 'Graduate', 26),
#  (1388, 'Vuyokazi', 'barnes', 69220.0, 'Graduate', 27),
#  (1389, 'Vuyokazi', 'barnes', 69220.0, 'Graduate', 28),
#  (1390, 'Vuyokazi', 'barnes', 69220.0, 'Graduate', 39),
#  (1391, 'Vuyokazi', 'barnes', 69220.0, 'Graduate', 40),
#  (1392, 'Vuyokazi', 'barnes', 69220.0, 'Graduate', 47),
#  (1393, 'Vuyokazi', 'barnes', 69220.0, 'Graduate', 48),
#  (1394, 'Vuyokazi', 'barnes', 69220.0, 'Graduate', 49),
#  (1395, 'Vuyokazi', 'barnes', 69220.0, 'Graduate', 50),
#  (1396, 'Vuyokazi', 'barnes', 69220.0, 'Graduate', 51),
#  (1397, 'Vuyokazi', 'barnes', 69220.0, 'Graduate', 52),
#  (1398, 'Vuyokazi', 'barnes', 69220.0, 'Graduate', 60),
#  (1399, 'Vuyokazi', 'barnes', 69220.0, 'Graduate', 61),
#  (1400, 'Walter', 'Jansen', 35454.0, 'Graduate', 4),
#  (1401, 'Walter', 'Jansen', 35454.0, 'Graduate', 5),
#  (1402, 'Walter', 'Jansen', 35454.0, 'Graduate', 11),
#  (1403, 'Walter', 'Jansen', 35454.0, 'Graduate', 12),
#  (1404, 'Walter', 'Jansen', 35454.0, 'Graduate', 13),
#  (1405, 'Walter', 'Jansen', 35454.0, 'Graduate', 14),
#  (1406, 'Walter', 'Jansen', 35454.0, 'Graduate', 15),
#  (1407, 'Walter', 'Jansen', 35454.0, 'Graduate', 16),
#  (1408, 'Walter', 'Jansen', 35454.0, 'Graduate', 18),
#  (1409, 'Walter', 'Jansen', 35454.0, 'Graduate', 20),
#  (1410, 'Walter', 'Jansen', 35454.0, 'Graduate', 26),
#  (1411, 'Walter', 'Jansen', 35454.0, 'Graduate', 27),
#  (1412, 'Walter', 'Jansen', 35454.0, 'Graduate', 28),
#  (1413, 'Walter', 'Jansen', 35454.0, 'Graduate', 39),
#  (1414, 'Walter', 'Jansen', 35454.0, 'Graduate', 40),
#  (1415, 'Walter', 'Jansen', 35454.0, 'Graduate', 47),
#  (1416, 'Walter', 'Jansen', 35454.0, 'Graduate', 48),
#  (1417, 'Walter', 'Jansen', 35454.0, 'Graduate', 49),
#  (1418, 'Walter', 'Jansen', 35454.0, 'Graduate', 50),
#  (1419, 'Walter', 'Jansen', 35454.0, 'Graduate', 51),
#  (1420, 'Walter', 'Jansen', 35454.0, 'Graduate', 52),
#  (1421, 'Walter', 'Jansen', 35454.0, 'Graduate', 60),
#  (1422, 'Walter', 'Jansen', 35454.0, 'Graduate', 61),
#  (1423, 'barend', 'Edwards', 13163.0, 'Intern', 4),
#  (1424, 'barend', 'Edwards', 13163.0, 'Intern', 5),
#  (1425, 'barend', 'Edwards', 13163.0, 'Intern', 11),
#  (1426, 'barend', 'Edwards', 13163.0, 'Intern', 12),
#  (1427, 'barend', 'Edwards', 13163.0, 'Intern', 13),
#  (1428, 'barend', 'Edwards', 13163.0, 'Intern', 14),
#  (1429, 'barend', 'Edwards', 13163.0, 'Intern', 15),
#  (1430, 'barend', 'Edwards', 13163.0, 'Intern', 16),
#  (1431, 'barend', 'Edwards', 13163.0, 'Intern', 18),
#  (1432, 'barend', 'Edwards', 13163.0, 'Intern', 20),
#  (1433, 'barend', 'Edwards', 13163.0, 'Intern', 26),
#  (1434, 'barend', 'Edwards', 13163.0, 'Intern', 27),
#  (1435, 'barend', 'Edwards', 13163.0, 'Intern', 28),
#  (1436, 'barend', 'Edwards', 13163.0, 'Intern', 39),
#  (1437, 'barend', 'Edwards', 13163.0, 'Intern', 40),
#  (1438, 'barend', 'Edwards', 13163.0, 'Intern', 47),
#  (1439, 'barend', 'Edwards', 13163.0, 'Intern', 48),
#  (1440, 'barend', 'Edwards', 13163.0, 'Intern', 49),
#  (1441, 'barend', 'Edwards', 13163.0, 'Intern', 50),
#  (1442, 'barend', 'Edwards', 13163.0, 'Intern', 51),
#  (1443, 'barend', 'Edwards', 13163.0, 'Intern', 52),
#  (1444, 'barend', 'Edwards', 13163.0, 'Intern', 60),
#  (1445, 'barend', 'Edwards', 13163.0, 'Intern', 61),
#  (1446, 'gugulethu', 'Maluleka', 181609.0, 'Junior', 1),
#  (1447, 'gugulethu', 'Maluleka', 181609.0, 'Junior', 8),
#  (1448, 'gugulethu', 'Maluleka', 181609.0, 'Junior', 9),
#  (1449, 'gugulethu', 'Maluleka', 181609.0, 'Junior', 23),
#  (1450, 'gugulethu', 'Maluleka', 181609.0, 'Junior', 33),
#  (1451, 'gugulethu', 'Maluleka', 181609.0, 'Junior', 37),
#  (1452, 'gugulethu', 'Maluleka', 181609.0, 'Junior', 38),
#  (1453, 'gugulethu', 'Maluleka', 181609.0, 'Junior', 42),
#  (1454, 'gugulethu', 'Maluleka', 181609.0, 'Junior', 53),
#  (1455, 'kelly', 'Manuel', 47442.0, 'Intern', 6),
#  (1456, 'kelly', 'Manuel', 47442.0, 'Intern', 19),
#  (1457, 'kelly', 'Manuel', 47442.0, 'Intern', 21),
#  (1458, 'kelly', 'Manuel', 47442.0, 'Intern', 22),
#  (1459, 'kelly', 'Manuel', 47442.0, 'Intern', 29),
#  (1460, 'kelly', 'Manuel', 47442.0, 'Intern', 30),
#  (1461, 'kelly', 'Manuel', 47442.0, 'Intern', 31),
#  (1462, 'kelly', 'Manuel', 47442.0, 'Intern', 45),
#  (1463, 'kelly', 'Manuel', 47442.0, 'Intern', 46),
#  (1464, 'kelly', 'Manuel', 47442.0, 'Intern', 54),
#  (1465, 'kelly', 'Manuel', 47442.0, 'Intern', 55),
#  (1466, 'kelly', 'Manuel', 47442.0, 'Intern', 56),
#  (1467, 'kelly', 'Manuel', 47442.0, 'Intern', 57),
#  (1468, 'liezel', 'moyo', 106276.0, 'Mid-Level', 6),
#  (1469, 'liezel', 'moyo', 106276.0, 'Mid-Level', 19),
#  (1470, 'liezel', 'moyo', 106276.0, 'Mid-Level', 21),
#  (1471, 'liezel', 'moyo', 106276.0, 'Mid-Level', 22),
#  (1472, 'liezel', 'moyo', 106276.0, 'Mid-Level', 29),
#  (1473, 'liezel', 'moyo', 106276.0, 'Mid-Level', 30),
#  (1474, 'liezel', 'moyo', 106276.0, 'Mid-Level', 31),
#  (1475, 'liezel', 'moyo', 106276.0, 'Mid-Level', 45),
#  (1476, 'liezel', 'moyo', 106276.0, 'Mid-Level', 46),
#  (1477, 'liezel', 'moyo', 106276.0, 'Mid-Level', 54),
#  (1478, 'liezel', 'moyo', 106276.0, 'Mid-Level', 55),
#  (1479, 'liezel', 'moyo', 106276.0, 'Mid-Level', 56),
#  (1480, 'liezel', 'moyo', 106276.0, 'Mid-Level', 57),
#  (1481, 'marthinus', 'ngobeni', 354298.0, 'Senior', 6),
#  (1482, 'marthinus', 'ngobeni', 354298.0, 'Senior', 19),
#  (1483, 'marthinus', 'ngobeni', 354298.0, 'Senior', 21),
#  (1484, 'marthinus', 'ngobeni', 354298.0, 'Senior', 22),
#  (1485, 'marthinus', 'ngobeni', 354298.0, 'Senior', 29),
#  (1486, 'marthinus', 'ngobeni', 354298.0, 'Senior', 30),
#  (1487, 'marthinus', 'ngobeni', 354298.0, 'Senior', 31),
#  (1488, 'marthinus', 'ngobeni', 354298.0, 'Senior', 45),
#  (1489, 'marthinus', 'ngobeni', 354298.0, 'Senior', 46),
#  (1490, 'marthinus', 'ngobeni', 354298.0, 'Senior', 54),
#  (1491, 'marthinus', 'ngobeni', 354298.0, 'Senior', 55),
#  (1492, 'marthinus', 'ngobeni', 354298.0, 'Senior', 56),
#  (1493, 'marthinus', 'ngobeni', 354298.0, 'Senior', 57),
#  (1494, 'nicole', 'Ebrahim', 180919.0, 'Senior', 2),
#  (1495, 'nicole', 'Ebrahim', 180919.0, 'Senior', 7),
#  (1496, 'nicole', 'Ebrahim', 180919.0, 'Senior', 10),
#  (1497, 'nicole', 'Ebrahim', 180919.0, 'Senior', 17),
#  (1498, 'nicole', 'Ebrahim', 180919.0, 'Senior', 34),
#  (1499, 'nicole', 'Ebrahim', 180919.0, 'Senior', 58),
#  (1500, 'phumzile', 'motsepe', 129627.0, 'Junior', 35),
#  (1501, 'phumzile', 'motsepe', 129627.0, 'Junior', 36),
#  (1502, 'phumzile', 'motsepe', 129627.0, 'Junior', 59),
#  (1503, 'sello', 'Details', 54945.0, 'Graduate', 4),
#  (1504, 'sello', 'Details', 54945.0, 'Graduate', 5),
#  (1505, 'sello', 'Details', 54945.0, 'Graduate', 11),
#  (1506, 'sello', 'Details', 54945.0, 'Graduate', 12),
#  (1507, 'sello', 'Details', 54945.0, 'Graduate', 13),
#  (1508, 'sello', 'Details', 54945.0, 'Graduate', 14),
#  (1509, 'sello', 'Details', 54945.0, 'Graduate', 15),
#  (1510, 'sello', 'Details', 54945.0, 'Graduate', 16),
#  (1511, 'sello', 'Details', 54945.0, 'Graduate', 18),
#  (1512, 'sello', 'Details', 54945.0, 'Graduate', 20),
#  (1513, 'sello', 'Details', 54945.0, 'Graduate', 26),
#  (1514, 'sello', 'Details', 54945.0, 'Graduate', 27),
#  (1515, 'sello', 'Details', 54945.0, 'Graduate', 28),
#  (1516, 'sello', 'Details', 54945.0, 'Graduate', 39),
#  (1517, 'sello', 'Details', 54945.0, 'Graduate', 40),
#  (1518, 'sello', 'Details', 54945.0, 'Graduate', 47),
#  (1519, 'sello', 'Details', 54945.0, 'Graduate', 48),
#  (1520, 'sello', 'Details', 54945.0, 'Graduate', 49),
#  (1521, 'sello', 'Details', 54945.0, 'Graduate', 50),
#  (1522, 'sello', 'Details', 54945.0, 'Graduate', 51),
#  (1523, 'sello', 'Details', 54945.0, 'Graduate', 52),
#  (1524, 'sello', 'Details', 54945.0, 'Graduate', 60),
#  (1525, 'sello', 'Details', 54945.0, 'Graduate', 61),
#  (1526, 'takalani', 'Richards', 57906.0, 'Graduate', 4),
#  (1527, 'takalani', 'Richards', 57906.0, 'Graduate', 5),
#  (1528, 'takalani', 'Richards', 57906.0, 'Graduate', 11),
#  (1529, 'takalani', 'Richards', 57906.0, 'Graduate', 12),
#  (1530, 'takalani', 'Richards', 57906.0, 'Graduate', 13),
#  (1531, 'takalani', 'Richards', 57906.0, 'Graduate', 14),
#  (1532, 'takalani', 'Richards', 57906.0, 'Graduate', 15),
#  (1533, 'takalani', 'Richards', 57906.0, 'Graduate', 16),
#  (1534, 'takalani', 'Richards', 57906.0, 'Graduate', 18),
#  (1535, 'takalani', 'Richards', 57906.0, 'Graduate', 20),
#  (1536, 'takalani', 'Richards', 57906.0, 'Graduate', 26),
#  (1537, 'takalani', 'Richards', 57906.0, 'Graduate', 27),
#  (1538, 'takalani', 'Richards', 57906.0, 'Graduate', 28),
#  (1539, 'takalani', 'Richards', 57906.0, 'Graduate', 39),
#  (1540, 'takalani', 'Richards', 57906.0, 'Graduate', 40),
#  (1541, 'takalani', 'Richards', 57906.0, 'Graduate', 47),
#  (1542, 'takalani', 'Richards', 57906.0, 'Graduate', 48),
#  (1543, 'takalani', 'Richards', 57906.0, 'Graduate', 49),
#  (1544, 'takalani', 'Richards', 57906.0, 'Graduate', 50),
#  (1545, 'takalani', 'Richards', 57906.0, 'Graduate', 51),
#  (1546, 'takalani', 'Richards', 57906.0, 'Graduate', 52),
#  (1547, 'takalani', 'Richards', 57906.0, 'Graduate', 60),
#  (1548, 'takalani', 'Richards', 57906.0, 'Graduate', 61)]

# %%
# %%sql
#
# DELETE FROM Employee_Department_2NF;
# DELETE FROM Employee_Role_2NF;
#
# INSERT INTO Employee_Department_2NF(EmployeeID , DepartmentID)
# SELECT DISTINCT
#     EE.EmployeeID,
#     D.DepartmentID
# FROM
#     Employees_1NF E
# INNER JOIN
#     Departments_2NF D
# ON
#     E.Department = D.Department
# INNER JOIN
#     Employees_2NF EE
# ON
#     E.Name = EE.Name
#     AND
#     E.Surname = EE.Surname;
#
# INSERT INTO Employee_Role_2NF(EmployeeID , RoleID)
# SELECT DISTINCT
#     EE.EmployeeID,
#     R.RoleID
# FROM
#     Employees_1NF E
# INNER JOIN
#     Employees_2NF EE
# ON
#     E.Name = EE.Name
#     AND
#     E.Surname = EE.Surname
# INNER JOIN
#     Roles_2NF R
# ON
#     R.Role = E.Role
# Out:
#  * sqlite:///SoftDevEmployees.db
# 25291 rows affected.
# 0 rows affected.
# 25291 rows affected.
# 5817 rows affected.
# []

# %% [markdown]
# ## Solutions

# %% [markdown]
# ### Exercise 1 – Create the required tables

# %%
# %%sql
#
# DROP TABLE IF EXISTS Employees_2NF;
# DROP TABLE IF EXISTS Titles_2NF;
# DROP TABLE IF EXISTS Roles_2NF;
# DROP TABLE IF EXISTS Departments_2NF;
# DROP TABLE IF EXISTS Employee_Department_2NF;
# DROP TABLE IF EXISTS Employee_Role_2NF;
#
# CREATE TABLE Titles_2NF (
#     TitleID INTEGER NOT NULL,
#     Title VARCHAR,
#     PRIMARY KEY(TitleID AUTOINCREMENT)
# );
#
# CREATE TABLE Roles_2NF (
#     RoleID INTEGER NOT NULL,
#     Role VARCHAR,
#     PRIMARY KEY(RoleID AUTOINCREMENT)
# );
#
# CREATE TABLE  Departments_2NF (
#     DepartmentID INTEGER NOT NULL,
#     Department VARCHAR,
#     PRIMARY KEY(DepartmentID AUTOINCREMENT)
# );
#
# CREATE TABLE Employees_2NF (
#     EmployeeID INTEGER NOT NULL,
#     Name VARCHAR,
#     Surname VARCHAR,
#     Salary REAL,
#     OccupationBand VARCHAR,
#     TitleID INTEGER,
#     FOREIGN KEY(TitleID) REFERENCES Titles_2NF (TitleID),
#     PRIMARY KEY(EmployeeID AUTOINCREMENT)
# );
#
#
# CREATE TABLE Employee_Role_2NF(
#     EmployeeID INTEGER NOT NULL,
#     RoleID INTEGER NOT NULL,
#     FOREIGN KEY (EmployeeID) REFERENCES Employees_2NF (EmployeeID),
#     FOREIGN KEY (RoleID) REFERENCES Roles_2NF (RoleID),
#     PRIMARY KEY(EmployeeID, RoleID)
# );
#
# CREATE TABLE Employee_Department_2NF(
#     EmployeeID INTEGER NOT NULL,
#     DepartmentID INTEGER NOT NULL,
#     FOREIGN KEY (EmployeeID) REFERENCES Employees_2NF (EmployeeID),
#     FOREIGN KEY (DepartmentID) REFERENCES Departments_2NF (DepartmentID),
#     PRIMARY KEY(EmployeeID, DepartmentID)
# );

# %% [markdown]
# ### Exercise 2

# %% [markdown]
# #### 2.1 – Populate the `Titles_2NF, Roles_2NF`, and `Departments_2NF` tables

# %%
# %%sql
# DELETE FROM Titles_2NF;
# DELETE FROM Roles_2NF;
# DELETE FROM Departments_2NF;
#
# INSERT INTO Titles_2NF (Title)
# SELECT
#     DISTINCT Title
# FROM Employees_1NF
# WHERE Title <> '';
#
# INSERT INTO Roles_2NF (Role)
# SELECT
#     DISTINCT Role
# FROM Employees_1NF
# WHERE Role <>'';
#
# INSERT INTO Departments_2NF (Department)
# SELECT
#     DISTINCT Department
# FROM Employees_1NF
# WHERE Department <>'';

# %% [markdown]
# ####  2.2 – Populate the `Employees_2NF` table

# %%
# %%sql
# DELETE FROM Employees_2NF;
#
# INSERT INTO Employees_2NF (Name, Surname, Salary, OccupationBand, TitleID)
# SELECT DISTINCT
#     EMP.Name,
#     EMP.Surname,
#     EMP.Salary,
#     EMP.OccupationBand,
#     T.TitleID
# FROM
#     Employees_1NF AS EMP
# JOIN
#     Titles_2NF AS T
#     ON T.Title = EMP.Title;

# %% [markdown]
# ####  2.3 – Populate the `Employee_Department_2NF` and `Employee_Role_2NF` tables

# %%
# %%sql
# DELETE FROM Employee_Department_2NF;
# DELETE FROM Employee_Role_2NF;
#
# INSERT INTO Employee_Department_2NF (EmployeeID,DepartmentID)
# SELECT DISTINCT
#     EMP2.EmployeeID,
#     DPT.DepartmentID
# FROM
#     Employees_1NF AS EMP1
# JOIN
#     Employees_2NF AS EMP2
#     ON EMP1.Name = EMP2.Name AND EMP1.Surname = EMP2.Surname
# JOIN
#     Departments_2NF AS DPT
#     ON EMP1.Department = DPT.Department;
#
#
# INSERT INTO Employee_Role_2NF (EmployeeID,RoleID)
# SELECT DISTINCT
#     EMP2.EmployeeID,
#     R.RoleID
# FROM
#     Employees_1NF AS EMP1
# JOIN
#     Employees_2NF AS EMP2
#     ON EMP1.Name = EMP2.Name AND EMP1.Surname = EMP2.Surname
# JOIN
#     Roles_2NF AS R
#     ON EMP1.Role = R.Role

# %% [markdown]
# ## Conclusion
#
# By normalising our database up to the **Second Normal Form (2NF)**, we have ensured that all the data in the database are entirely dependent to the primary key which has, in turn, helped us address various anomalies:
#
#  - **Deletion anomaly**: We have eliminated the deletion anomalies that could occur on the **`Roles`**, **`Departments`**, and **`Titles`** columns by creating separate tables for them. For example, if Jessica Mchunu gets deleted from the **Employees_2NF** table, the **Scrum Master** role will continue to persist in the **Roles_2NF** table.
#
#  - **Update anomaly**: Christoper only appears once in the **Employees_2NF**, so should he get a raise we only need to change his salary information in one place. This reduces the chances of having any data inconsistencies.
#
#  - **Insertion anomaly**: Now we can insert new graduates into the database without having to define a role or place them in a specific department.
#
# Also, as we organise our data into separate tables, we have seen the need for foreign keys to establish relationships between tables and enforcing referential integrity.
#
# Referential integrity plays a key role in understanding the relationships between tables – which are usually underpinned by business rules. Take time to understand these business rules when creating your database. This effort will serve you well for organising your data as a future data professional.

# %% [markdown]
# <div align="center" style=" font-size: 80%; text-align: center; margin: 0 auto">
# <img src="https://raw.githubusercontent.com/Explore-AI/Pictures/master/ExploreAI_logos/EAI_Blue_Dark.png"  style="width:200px";/>
# </div>
