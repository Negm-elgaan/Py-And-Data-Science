# %% [markdown]
# <div align="right" style=" font-size: 80%; text-align: center; margin: 0 auto">
# <img src="https://raw.githubusercontent.com/Explore-AI/Pictures/master/ExploreAI_logos/Logo blue_dark.png"  style="width:25px" align="right";/>
# </div>

# %% [markdown]
# # Database views
# © ExploreAI Academy

# %% [markdown]
# A view is a virtual table that represents data derived from one or more base tables. It does not store data. It is basically a saved query that can be used as a table. Views allow you to simplify complex queries, abstract the underlying data structure, and provide some security by allowing access to specific columns or rows of data.
#
# In this lesson, we will construct a complex query and then create a view of that query.

# %% [markdown]
# > ⚠️ This notebook will not run on Google Colab because it cannot connect to a local database. Please make sure that this notebook is running on the same local machine as your MySQL Workbench installation and MySQL `united_nations` database.

# %% [markdown]
# ## Learning objectives
#
# By the end of this lesson, you should know:
# - What a view is and why it's needed.
# - How to create a view.
# - How to join tables using views.
# - How to impute Null values using views.

# %% [markdown]
# ## Connecting to our MySQL database
#
# Using our `Access_to_Basic_Services` table in the `united_nations` database that we created in MySQL Workbench, we want to answer some questions about our dataset. We can apply the same queries we used in MySQL Workbench in this notebook if we connect to our MySQL server by running the cells below.

# %%
# Load and activate the SQL extension to allow us to execute SQL in a Jupyter notebook. 
# If you get an error here, make sure that mysql and pymysql are installed correctly. 

# %load_ext sql

# %%
# Establish a connection to the local database using the '%sql' magic command.
# Replace `password` with our connection password and `db_name` with our database name. 
# If you get an error here, please make sure the database name or password is correct.

# %sql mysql+pymysql://root:Omar2003negm*@localhost:3306/united_nations
# Out:
# 'Connected: root@united_nations'

# %% [markdown]
# To make a query, we add the `%%sql` command to the start of a cell, create one open line then add the query like below, and run the cell.

# %%
# %%sql
#
# SELECT
#     *
# FROM
#     Access_to_Basic_Services
# LIMIT 5;
# Out:
#  * mysql+pymysql://root:***@localhost:3306/united_nations
# 5 rows affected.
# [('Central and Southern Asia', 'Central Asia', 'Kazakhstan', 2015, Decimal('94.67'), Decimal('98.00'), Decimal('17.542806'), Decimal('184.39'), Decimal('2699700.00'), Decimal('4.93')),
#  ('Central and Southern Asia', 'Central Asia', 'Kazakhstan', 2016, Decimal('94.67'), Decimal('98.00'), Decimal('17.794055'), Decimal('137.28'), Decimal('2699700.00'), Decimal('4.96')),
#  ('Central and Southern Asia', 'Central Asia', 'Kazakhstan', 2017, Decimal('95.00'), Decimal('98.00'), Decimal('18.037776'), Decimal('166.81'), Decimal('2699700.00'), Decimal('4.90')),
#  ('Central and Southern Asia', 'Central Asia', 'Kazakhstan', 2018, Decimal('95.00'), Decimal('98.00'), Decimal('18.276452'), Decimal('179.34'), Decimal('2699700.00'), Decimal('4.85')),
#  ('Central and Southern Asia', 'Central Asia', 'Kazakhstan', 2019, Decimal('95.00'), Decimal('98.00'), Decimal('18.513673'), Decimal('181.67'), Decimal('2699700.00'), Decimal('4.80'))]

# %% [markdown]
# ## Exercise

# %% [markdown]
# We have decomposed the `united_nations.Access_to_Basic_Services` table into three tables. The `united_nations.Basic_Services` table, `united_nations.Economic_Indicators` table, and the `united_nations.Geographic_Locations` table. In this tutorial, we will be constructing a complex query to view the unemployment rate in Sub-Saharan Africa. We will then save that query as a VIEW.

# %%
# %%sql
# # Add your code here
# SELECT
#     *
# FROM
#     Economic_Indicators
# LIMIT
#     10;
# Out:
#  * mysql+pymysql://root:***@localhost:3306/united_nations
# 10 rows affected.
# [('Afghanistan', 2015, Decimal('20.00'), Decimal('33.753499'), None),
#  ('Afghanistan', 2016, Decimal('18.02'), Decimal('34.636207'), None),
#  ('Afghanistan', 2017, Decimal('18.90'), Decimal('35.643418'), Decimal('11.18')),
#  ('Afghanistan', 2018, Decimal('18.42'), Decimal('36.686784'), None),
#  ('Afghanistan', 2019, Decimal('18.90'), Decimal('37.769499'), None),
#  ('Afghanistan', 2020, Decimal('20.14'), Decimal('38.972230'), Decimal('11.71')),
#  ('Algeria', 2015, Decimal('165.98'), Decimal('39.543154'), Decimal('11.21')),
#  ('Algeria', 2016, Decimal('160.03'), Decimal('40.339329'), Decimal('10.20')),
#  ('Algeria', 2017, Decimal('170.10'), Decimal('41.136546'), Decimal('12.00')),
#  ('Algeria', 2018, Decimal('174.91'), Decimal('41.927007'), None)]

# %%
# %%sql
# # Add your code here
# SELECT
#     *
# FROM
#     Geographic_Location
# LIMIT
#     10;
# Out:
#  * mysql+pymysql://root:***@localhost:3306/united_nations
# 10 rows affected.
# [('Afghanistan', 'Southern Asia', 'Central and Southern Asia', Decimal('652230.00')),
#  ('Algeria', 'Northern Africa', 'Northern Africa and Western Asia', Decimal('2381741.00')),
#  ('American Samoa', 'Polynesia', 'Oceania', Decimal('200.00')),
#  ('Angola', 'Middle Africa', 'Sub-Saharan Africa', Decimal('1246700.00')),
#  ('Anguilla', 'Caribbean', 'Latin America and the Caribbean', None),
#  ('Antigua and Barbuda', 'Caribbean', 'Latin America and the Caribbean', Decimal('440.00')),
#  ('Argentina', 'South America', 'Latin America and the Caribbean', Decimal('2736690.00')),
#  ('Armenia', 'Western Asia', 'Northern Africa and Western Asia', Decimal('28470.00')),
#  ('Aruba', 'Caribbean', 'Latin America and the Caribbean', Decimal('180.00')),
#  ('Australia', 'Australia and New Zealand', 'Oceania', Decimal('7690400.00'))]

# %% [markdown]
# ### Task 1
# To view the unemployment rate per region we will have to first join the `Economic_Indicators` table to the `Geographic_Locations` table.

# %%
# %%sql
# # Add your code here
# SELECT
#     E.Country_name,
#     region,
#     Pct_unemployment,
#     time_period
# FROM
#     Economic_Indicators E
# INNER JOIN
#     Geographic_Location G
# ON
#     E.Country_name = G.Country_name
# Out:
#  * mysql+pymysql://root:***@localhost:3306/united_nations
# 1048 rows affected.
# [('Afghanistan', 'Central and Southern Asia', None, 2015),
#  ('Afghanistan', 'Central and Southern Asia', None, 2016),
#  ('Afghanistan', 'Central and Southern Asia', Decimal('11.18'), 2017),
#  ('Afghanistan', 'Central and Southern Asia', None, 2018),
#  ('Afghanistan', 'Central and Southern Asia', None, 2019),
#  ('Afghanistan', 'Central and Southern Asia', Decimal('11.71'), 2020),
#  ('Algeria', 'Northern Africa and Western Asia', Decimal('11.21'), 2015),
#  ('Algeria', 'Northern Africa and Western Asia', Decimal('10.20'), 2016),
#  ('Algeria', 'Northern Africa and Western Asia', Decimal('12.00'), 2017),
#  ('Algeria', 'Northern Africa and Western Asia', None, 2018),
#  ('Algeria', 'Northern Africa and Western Asia', None, 2019),
#  ('Algeria', 'Northern Africa and Western Asia', None, 2020),
#  ('American Samoa', 'Oceania', None, 2015),
#  ('American Samoa', 'Oceania', None, 2016),
#  ('American Samoa', 'Oceania', None, 2017),
#  ('American Samoa', 'Oceania', None, 2018),
#  ('American Samoa', 'Oceania', None, 2019),
#  ('American Samoa', 'Oceania', None, 2020),
#  ('Angola', 'Sub-Saharan Africa', None, 2015),
#  ('Angola', 'Sub-Saharan Africa', None, 2016),
#  ('Angola', 'Sub-Saharan Africa', None, 2017),
#  ('Angola', 'Sub-Saharan Africa', None, 2018),
#  ('Angola', 'Sub-Saharan Africa', Decimal('16.50'), 2019),
#  ('Angola', 'Sub-Saharan Africa', None, 2020),
#  ('Anguilla', 'Latin America and the Caribbean', None, 2015),
#  ('Anguilla', 'Latin America and the Caribbean', None, 2016),
#  ('Anguilla', 'Latin America and the Caribbean', None, 2017),
#  ('Antigua and Barbuda', 'Latin America and the Caribbean', None, 2015),
#  ('Antigua and Barbuda', 'Latin America and the Caribbean', None, 2016),
#  ('Antigua and Barbuda', 'Latin America and the Caribbean', None, 2017),
#  ('Argentina', 'Latin America and the Caribbean', None, 2015),
#  ('Argentina', 'Latin America and the Caribbean', None, 2016),
#  ('Argentina', 'Latin America and the Caribbean', Decimal('8.35'), 2017),
#  ('Argentina', 'Latin America and the Caribbean', Decimal('9.22'), 2018),
#  ('Argentina', 'Latin America and the Caribbean', Decimal('9.84'), 2019),
#  ('Argentina', 'Latin America and the Caribbean', Decimal('11.46'), 2020),
#  ('Armenia', 'Northern Africa and Western Asia', Decimal('18.26'), 2015),
#  ('Armenia', 'Northern Africa and Western Asia', Decimal('17.62'), 2016),
#  ('Armenia', 'Northern Africa and Western Asia', Decimal('17.70'), 2017),
#  ('Armenia', 'Northern Africa and Western Asia', Decimal('13.21'), 2018),
#  ('Armenia', 'Northern Africa and Western Asia', Decimal('12.20'), 2019),
#  ('Armenia', 'Northern Africa and Western Asia', Decimal('12.18'), 2020),
#  ('Aruba', 'Latin America and the Caribbean', None, 2015),
#  ('Aruba', 'Latin America and the Caribbean', None, 2016),
#  ('Australia', 'Oceania', Decimal('6.06'), 2015),
#  ('Australia', 'Oceania', Decimal('5.71'), 2016),
#  ('Australia', 'Oceania', Decimal('5.59'), 2017),
#  ('Australia', 'Oceania', Decimal('5.30'), 2018),
#  ('Australia', 'Oceania', Decimal('5.16'), 2019),
#  ('Australia', 'Oceania', Decimal('6.46'), 2020),
#  ('Azerbaijan', 'Northern Africa and Western Asia', Decimal('4.96'), 2015),
#  ('Azerbaijan', 'Northern Africa and Western Asia', Decimal('5.00'), 2016),
#  ('Azerbaijan', 'Northern Africa and Western Asia', Decimal('4.96'), 2017),
#  ('Azerbaijan', 'Northern Africa and Western Asia', Decimal('4.94'), 2018),
#  ('Azerbaijan', 'Northern Africa and Western Asia', Decimal('4.85'), 2019),
#  ('Azerbaijan', 'Northern Africa and Western Asia', Decimal('7.16'), 2020),
#  ('Bahamas', 'Latin America and the Caribbean', None, 2015),
#  ('Bahamas', 'Latin America and the Caribbean', None, 2016),
#  ('Bahamas', 'Latin America and the Caribbean', None, 2017),
#  ('Bahamas', 'Latin America and the Caribbean', None, 2018),
#  ('Bahamas', 'Latin America and the Caribbean', None, 2019),
#  ('Bahrain', 'Northern Africa and Western Asia', None, 2015),
#  ('Bahrain', 'Northern Africa and Western Asia', None, 2016),
#  ('Bahrain', 'Northern Africa and Western Asia', None, 2017),
#  ('Bahrain', 'Northern Africa and Western Asia', None, 2018),
#  ('Bahrain', 'Northern Africa and Western Asia', None, 2019),
#  ('Bahrain', 'Northern Africa and Western Asia', None, 2020),
#  ('Bangladesh', 'Central and Southern Asia', None, 2015),
#  ('Bangladesh', 'Central and Southern Asia', Decimal('4.35'), 2016),
#  ('Bangladesh', 'Central and Southern Asia', Decimal('4.37'), 2017),
#  ('Bangladesh', 'Central and Southern Asia', None, 2018),
#  ('Bangladesh', 'Central and Southern Asia', None, 2019),
#  ('Bangladesh', 'Central and Southern Asia', None, 2020),
#  ('Barbados', 'Latin America and the Caribbean', Decimal('9.80'), 2015),
#  ('Barbados', 'Latin America and the Caribbean', Decimal('8.25'), 2016),
#  ('Barbados', 'Latin America and the Caribbean', Decimal('8.62'), 2017),
#  ('Barbados', 'Latin America and the Caribbean', Decimal('8.32'), 2018),
#  ('Barbados', 'Latin America and the Caribbean', Decimal('8.41'), 2019),
#  ('Barbados', 'Latin America and the Caribbean', None, 2020),
#  ('Belize', 'Latin America and the Caribbean', Decimal('7.58'), 2015),
#  ('Belize', 'Latin America and the Caribbean', Decimal('7.00'), 2016),
#  ('Belize', 'Latin America and the Caribbean', Decimal('6.60'), 2017),
#  ('Belize', 'Latin America and the Caribbean', None, 2018),
#  ('Belize', 'Latin America and the Caribbean', Decimal('9.05'), 2019),
#  ('Belize', 'Latin America and the Caribbean', None, 2020),
#  ('Benin', 'Sub-Saharan Africa', None, 2015),
#  ('Benin', 'Sub-Saharan Africa', None, 2016),
#  ('Benin', 'Sub-Saharan Africa', None, 2017),
#  ('Benin', 'Sub-Saharan Africa', Decimal('1.47'), 2018),
#  ('Benin', 'Sub-Saharan Africa', None, 2019),
#  ('Benin', 'Sub-Saharan Africa', None, 2020),
#  ('Bermuda', 'Europe and Northern America', None, 2015),
#  ('Bermuda', 'Europe and Northern America', None, 2016),
#  ('Bermuda', 'Europe and Northern America', None, 2017),
#  ('Bermuda', 'Europe and Northern America', None, 2018),
#  ('Bermuda', 'Europe and Northern America', None, 2019),
#  ('Bermuda', 'Europe and Northern America', None, 2020),
#  ('Bhutan', 'Central and Southern Asia', Decimal('2.45'), 2015),
#  ('Bhutan', 'Central and Southern Asia', None, 2016),
#  ('Bhutan', 'Central and Southern Asia', None, 2017),
#  ('Bhutan', 'Central and Southern Asia', Decimal('3.35'), 2018),
#  ('Bhutan', 'Central and Southern Asia', Decimal('2.72'), 2019),
#  ('Bhutan', 'Central and Southern Asia', Decimal('5.03'), 2020),
#  ('Bolivia (Plurinational State of)', 'Latin America and the Caribbean', None, 2015),
#  ('Bolivia (Plurinational State of)', 'Latin America and the Caribbean', None, 2016),
#  ('Bolivia (Plurinational State of)', 'Latin America and the Caribbean', None, 2017),
#  ('Bolivia (Plurinational State of)', 'Latin America and the Caribbean', None, 2018),
#  ('Bolivia (Plurinational State of)', 'Latin America and the Caribbean', None, 2019),
#  ('Bolivia (Plurinational State of)', 'Latin America and the Caribbean', None, 2020),
#  ('Botswana', 'Sub-Saharan Africa', None, 2015),
#  ('Botswana', 'Sub-Saharan Africa', None, 2016),
#  ('Botswana', 'Sub-Saharan Africa', None, 2017),
#  ('Botswana', 'Sub-Saharan Africa', None, 2018),
#  ('Botswana', 'Sub-Saharan Africa', Decimal('20.09'), 2019),
#  ('Botswana', 'Sub-Saharan Africa', Decimal('21.02'), 2020),
#  ('Brazil', 'Latin America and the Caribbean', Decimal('8.54'), 2015),
#  ('Brazil', 'Latin America and the Caribbean', Decimal('11.58'), 2016),
#  ('Brazil', 'Latin America and the Caribbean', Decimal('12.79'), 2017),
#  ('Brazil', 'Latin America and the Caribbean', Decimal('12.33'), 2018),
#  ('Brazil', 'Latin America and the Caribbean', Decimal('11.94'), 2019),
#  ('Brazil', 'Latin America and the Caribbean', Decimal('13.70'), 2020),
#  ('British Virgin Islands', 'Latin America and the Caribbean', None, 2015),
#  ('British Virgin Islands', 'Latin America and the Caribbean', None, 2016),
#  ('British Virgin Islands', 'Latin America and the Caribbean', None, 2017),
#  ('British Virgin Islands', 'Latin America and the Caribbean', None, 2018),
#  ('British Virgin Islands', 'Latin America and the Caribbean', None, 2019),
#  ('British Virgin Islands', 'Latin America and the Caribbean', None, 2020),
#  ('Brunei Darussalam', 'Eastern and South-Eastern Asia', None, 2015),
#  ('Brunei Darussalam', 'Eastern and South-Eastern Asia', None, 2016),
#  ('Brunei Darussalam', 'Eastern and South-Eastern Asia', Decimal('9.32'), 2017),
#  ('Brunei Darussalam', 'Eastern and South-Eastern Asia', Decimal('8.70'), 2018),
#  ('Brunei Darussalam', 'Eastern and South-Eastern Asia', Decimal('6.60'), 2019),
#  ('Brunei Darussalam', 'Eastern and South-Eastern Asia', Decimal('7.41'), 2020),
#  ('Burkina Faso', 'Sub-Saharan Africa', None, 2015),
#  ('Burkina Faso', 'Sub-Saharan Africa', None, 2016),
#  ('Burkina Faso', 'Sub-Saharan Africa', None, 2017),
#  ('Burkina Faso', 'Sub-Saharan Africa', Decimal('4.69'), 2018),
#  ('Burkina Faso', 'Sub-Saharan Africa', None, 2019),
#  ('Burkina Faso', 'Sub-Saharan Africa', None, 2020),
#  ('Burundi', 'Sub-Saharan Africa', None, 2015),
#  ('Burundi', 'Sub-Saharan Africa', None, 2016),
#  ('Burundi', 'Sub-Saharan Africa', None, 2017),
#  ('Burundi', 'Sub-Saharan Africa', None, 2018),
#  ('Burundi', 'Sub-Saharan Africa', None, 2019),
#  ('Burundi', 'Sub-Saharan Africa', Decimal('1.03'), 2020),
#  ('Cabo Verde', 'Sub-Saharan Africa', Decimal('31.31'), 2015),
#  ('Cabo Verde', 'Sub-Saharan Africa', None, 2016),
#  ('Cabo Verde', 'Sub-Saharan Africa', Decimal('12.24'), 2017),
#  ('Cabo Verde', 'Sub-Saharan Africa', Decimal('12.17'), 2018),
#  ('Cabo Verde', 'Sub-Saharan Africa', Decimal('11.29'), 2019),
#  ('Cabo Verde', 'Sub-Saharan Africa', None, 2020),
#  ('Cambodia', 'Eastern and South-Eastern Asia', Decimal('0.39'), 2015),
#  ('Cambodia', 'Eastern and South-Eastern Asia', Decimal('0.72'), 2016),
#  ('Cambodia', 'Eastern and South-Eastern Asia', Decimal('0.14'), 2017),
#  ('Cambodia', 'Eastern and South-Eastern Asia', None, 2018),
#  ('Cambodia', 'Eastern and South-Eastern Asia', Decimal('0.50'), 2019),
#  ('Cambodia', 'Eastern and South-Eastern Asia', None, 2020),
#  ('Cameroon', 'Sub-Saharan Africa', None, 2015),
#  ('Cameroon', 'Sub-Saharan Africa', None, 2016),
#  ('Cameroon', 'Sub-Saharan Africa', None, 2017),
#  ('Cameroon', 'Sub-Saharan Africa', None, 2018),
#  ('Cameroon', 'Sub-Saharan Africa', None, 2019),
#  ('Cameroon', 'Sub-Saharan Africa', None, 2020),
#  ('Canada', 'Europe and Northern America', Decimal('6.91'), 2015),
#  ('Canada', 'Europe and Northern America', Decimal('7.00'), 2016),
#  ('Canada', 'Europe and Northern America', Decimal('6.34'), 2017),
#  ('Canada', 'Europe and Northern America', Decimal('5.83'), 2018),
#  ('Canada', 'Europe and Northern America', Decimal('5.66'), 2019),
#  ('Canada', 'Europe and Northern America', Decimal('9.46'), 2020),
#  ('Cayman Islands', 'Latin America and the Caribbean', Decimal('4.24'), 2015),
#  ('Cayman Islands', 'Latin America and the Caribbean', None, 2016),
#  ('Central African Republic', 'Sub-Saharan Africa', None, 2015),
#  ('Central African Republic', 'Sub-Saharan Africa', None, 2016),
#  ('Central African Republic', 'Sub-Saharan Africa', None, 2017),
#  ('Central African Republic', 'Sub-Saharan Africa', None, 2018),
#  ('Central African Republic', 'Sub-Saharan Africa', None, 2019),
#  ('Central African Republic', 'Sub-Saharan Africa', None, 2020),
#  ('Chad', 'Sub-Saharan Africa', None, 2015),
#  ('Chad', 'Sub-Saharan Africa', None, 2016),
#  ('Chad', 'Sub-Saharan Africa', None, 2017),
#  ('Chad', 'Sub-Saharan Africa', Decimal('1.13'), 2018),
#  ('Chad', 'Sub-Saharan Africa', None, 2019),
#  ('Chad', 'Sub-Saharan Africa', None, 2020),
#  ('Chile', 'Latin America and the Caribbean', Decimal('6.49'), 2015),
#  ('Chile', 'Latin America and the Caribbean', Decimal('6.73'), 2016),
#  ('Chile', 'Latin America and the Caribbean', Decimal('6.95'), 2017),
#  ('Chile', 'Latin America and the Caribbean', Decimal('7.21'), 2018),
#  ('Chile', 'Latin America and the Caribbean', Decimal('7.27'), 2019),
#  ('Chile', 'Latin America and the Caribbean', Decimal('10.94'), 2020),
#  ('China', 'Eastern and South-Eastern Asia', None, 2015),
#  ('China', 'Eastern and South-Eastern Asia', None, 2016),
#  ('China', 'Eastern and South-Eastern Asia', Decimal('3.90'), 2017),
#  ('China', 'Eastern and South-Eastern Asia', Decimal('4.93'), 2018),
#  ('China', 'Eastern and South-Eastern Asia', Decimal('5.15'), 2019),
#  ('China', 'Eastern and South-Eastern Asia', Decimal('5.61'), 2020),
#  ('Colombia', 'Latin America and the Caribbean', Decimal('8.57'), 2015),
#  ('Colombia', 'Latin America and the Caribbean', Decimal('8.92'), 2016),
#  ('Colombia', 'Latin America and the Caribbean', Decimal('9.09'), 2017),
#  ('Colombia', 'Latin America and the Caribbean', Decimal('9.36'), 2018),
#  ('Colombia', 'Latin America and the Caribbean', Decimal('10.28'), 2019),
#  ('Colombia', 'Latin America and the Caribbean', Decimal('15.98'), 2020),
#  ('Comoros', 'Sub-Saharan Africa', None, 2015),
#  ('Comoros', 'Sub-Saharan Africa', None, 2016),
#  ('Comoros', 'Sub-Saharan Africa', None, 2017),
#  ('Comoros', 'Sub-Saharan Africa', None, 2018),
#  ('Comoros', 'Sub-Saharan Africa', None, 2019),
#  ('Congo', 'Sub-Saharan Africa', None, 2015),
#  ('Congo', 'Sub-Saharan Africa', None, 2016),
#  ('Congo', 'Sub-Saharan Africa', None, 2017),
#  ('Congo', 'Sub-Saharan Africa', None, 2018),
#  ('Congo', 'Sub-Saharan Africa', None, 2019),
#  ('Congo', 'Sub-Saharan Africa', None, 2020),
#  ('Cook Islands', 'Oceania', None, 2015),
#  ('Cook Islands', 'Oceania', None, 2016),
#  ('Cook Islands', 'Oceania', None, 2017),
#  ('Cook Islands', 'Oceania', None, 2018),
#  ('Cook Islands', 'Oceania', None, 2019),
#  ('Cook Islands', 'Oceania', None, 2020),
#  ('Costa Rica', 'Latin America and the Caribbean', Decimal('8.42'), 2015),
#  ('Costa Rica', 'Latin America and the Caribbean', Decimal('8.09'), 2016),
#  ('Costa Rica', 'Latin America and the Caribbean', Decimal('7.73'), 2017),
#  ('Costa Rica', 'Latin America and the Caribbean', Decimal('9.01'), 2018),
#  ('Costa Rica', 'Latin America and the Caribbean', Decimal('10.81'), 2019),
#  ('Costa Rica', 'Latin America and the Caribbean', Decimal('16.43'), 2020),
#  ("Côte d'Ivoire", 'Sub-Saharan Africa', None, 2015),
#  ("Côte d'Ivoire", 'Sub-Saharan Africa', None, 2016),
#  ("Côte d'Ivoire", 'Sub-Saharan Africa', None, 2017),
#  ("Côte d'Ivoire", 'Sub-Saharan Africa', None, 2018),
#  ("Côte d'Ivoire", 'Sub-Saharan Africa', None, 2019),
#  ("Côte d'Ivoire", 'Sub-Saharan Africa', None, 2020),
#  ('Cuba', 'Latin America and the Caribbean', Decimal('2.40'), 2015),
#  ('Cuba', 'Latin America and the Caribbean', Decimal('2.00'), 2016),
#  ('Cuba', 'Latin America and the Caribbean', Decimal('1.70'), 2017),
#  ('Cuba', 'Latin America and the Caribbean', Decimal('1.70'), 2018),
#  ('Cuba', 'Latin America and the Caribbean', None, 2019),
#  ('Cuba', 'Latin America and the Caribbean', None, 2020),
#  ('Curaçao', 'Latin America and the Caribbean', None, 2015),
#  ('Curaçao', 'Latin America and the Caribbean', None, 2016),
#  ('Curaçao', 'Latin America and the Caribbean', None, 2017),
#  ('Cyprus', 'Northern Africa and Western Asia', Decimal('15.03'), 2015),
#  ('Cyprus', 'Northern Africa and Western Asia', Decimal('13.01'), 2016),
#  ('Cyprus', 'Northern Africa and Western Asia', Decimal('11.16'), 2017),
#  ('Cyprus', 'Northern Africa and Western Asia', Decimal('8.50'), 2018),
#  ('Cyprus', 'Northern Africa and Western Asia', Decimal('7.15'), 2019),
#  ('Cyprus', 'Northern Africa and Western Asia', Decimal('7.76'), 2020),
#  ("Democratic People's Republic of Korea", 'Eastern and South-Eastern Asia', None, 2015),
#  ("Democratic People's Republic of Korea", 'Eastern and South-Eastern Asia', None, 2016),
#  ("Democratic People's Republic of Korea", 'Eastern and South-Eastern Asia', None, 2017),
#  ("Democratic People's Republic of Korea", 'Eastern and South-Eastern Asia', None, 2018),
#  ("Democratic People's Republic of Korea", 'Eastern and South-Eastern Asia', None, 2019),
#  ("Democratic People's Republic of Korea", 'Eastern and South-Eastern Asia', None, 2020),
#  ('Democratic Republic of the Congo', 'Sub-Saharan Africa', None, 2015),
#  ('Democratic Republic of the Congo', 'Sub-Saharan Africa', None, 2016),
#  ('Democratic Republic of the Congo', 'Sub-Saharan Africa', None, 2017),
#  ('Democratic Republic of the Congo', 'Sub-Saharan Africa', None, 2018),
#  ('Democratic Republic of the Congo', 'Sub-Saharan Africa', None, 2019),
#  ('Democratic Republic of the Congo', 'Sub-Saharan Africa', None, 2020),
#  ('Djibouti', 'Sub-Saharan Africa', None, 2015),
#  ('Djibouti', 'Sub-Saharan Africa', None, 2016),
#  ('Djibouti', 'Sub-Saharan Africa', Decimal('26.06'), 2017),
#  ('Djibouti', 'Sub-Saharan Africa', None, 2018),
#  ('Djibouti', 'Sub-Saharan Africa', None, 2019),
#  ('Djibouti', 'Sub-Saharan Africa', None, 2020),
#  ('Dominica', 'Latin America and the Caribbean', None, 2015),
#  ('Dominica', 'Latin America and the Caribbean', None, 2016),
#  ('Dominica', 'Latin America and the Caribbean', None, 2017),
#  ('Dominican Republic', 'Latin America and the Caribbean', Decimal('7.61'), 2015),
#  ('Dominican Republic', 'Latin America and the Caribbean', Decimal('7.28'), 2016),
#  ('Dominican Republic', 'Latin America and the Caribbean', Decimal('5.83'), 2017),
#  ('Dominican Republic', 'Latin America and the Caribbean', Decimal('5.86'), 2018),
#  ('Dominican Republic', 'Latin America and the Caribbean', Decimal('6.18'), 2019),
#  ('Dominican Republic', 'Latin America and the Caribbean', Decimal('6.13'), 2020),
#  ('Ecuador', 'Latin America and the Caribbean', Decimal('3.62'), 2015),
#  ('Ecuador', 'Latin America and the Caribbean', Decimal('4.60'), 2016),
#  ('Ecuador', 'Latin America and the Caribbean', Decimal('3.84'), 2017),
#  ('Ecuador', 'Latin America and the Caribbean', Decimal('3.53'), 2018),
#  ('Ecuador', 'Latin America and the Caribbean', Decimal('3.81'), 2019),
#  ('Ecuador', 'Latin America and the Caribbean', Decimal('6.11'), 2020),
#  ('Egypt', 'Northern Africa and Western Asia', None, 2015),
#  ('Egypt', 'Northern Africa and Western Asia', None, 2016),
#  ('Egypt', 'Northern Africa and Western Asia', None, 2017),
#  ('Egypt', 'Northern Africa and Western Asia', None, 2018),
#  ('Egypt', 'Northern Africa and Western Asia', None, 2019),
#  ('Egypt', 'Northern Africa and Western Asia', None, 2020),
#  ('El Salvador', 'Latin America and the Caribbean', Decimal('4.00'), 2015),
#  ('El Salvador', 'Latin America and the Caribbean', Decimal('4.42'), 2016),
#  ('El Salvador', 'Latin America and the Caribbean', Decimal('4.39'), 2017),
#  ('El Salvador', 'Latin America and the Caribbean', Decimal('4.01'), 2018),
#  ('El Salvador', 'Latin America and the Caribbean', Decimal('4.17'), 2019),
#  ('El Salvador', 'Latin America and the Caribbean', Decimal('5.01'), 2020),
#  ('Equatorial Guinea', 'Sub-Saharan Africa', None, 2015),
#  ('Equatorial Guinea', 'Sub-Saharan Africa', None, 2016),
#  ('Equatorial Guinea', 'Sub-Saharan Africa', None, 2017),
#  ('Eritrea', 'Sub-Saharan Africa', None, 2015),
#  ('Eritrea', 'Sub-Saharan Africa', None, 2016),
#  ('Eswatini', 'Sub-Saharan Africa', None, 2015),
#  ('Eswatini', 'Sub-Saharan Africa', Decimal('22.72'), 2016),
#  ('Eswatini', 'Sub-Saharan Africa', None, 2017),
#  ('Eswatini', 'Sub-Saharan Africa', None, 2018),
#  ('Eswatini', 'Sub-Saharan Africa', None, 2019),
#  ('Eswatini', 'Sub-Saharan Africa', None, 2020),
#  ('Ethiopia', 'Sub-Saharan Africa', None, 2015),
#  ('Ethiopia', 'Sub-Saharan Africa', None, 2016),
#  ('Ethiopia', 'Sub-Saharan Africa', None, 2017),
#  ('Ethiopia', 'Sub-Saharan Africa', None, 2018),
#  ('Ethiopia', 'Sub-Saharan Africa', None, 2019),
#  ('Ethiopia', 'Sub-Saharan Africa', None, 2020),
#  ('Falkland Islands (Malvinas)', 'Latin America and the Caribbean', None, 2015),
#  ('Falkland Islands (Malvinas)', 'Latin America and the Caribbean', None, 2016),
#  ('Falkland Islands (Malvinas)', 'Latin America and the Caribbean', None, 2017),
#  ('Falkland Islands (Malvinas)', 'Latin America and the Caribbean', None, 2018),
#  ('Falkland Islands (Malvinas)', 'Latin America and the Caribbean', None, 2019),
#  ('Falkland Islands (Malvinas)', 'Latin America and the Caribbean', None, 2020),
#  ('Fiji', 'Oceania', None, 2015),
#  ('Fiji', 'Oceania', Decimal('4.32'), 2016),
#  ('Fiji', 'Oceania', None, 2017),
#  ('Fiji', 'Oceania', None, 2018),
#  ('Fiji', 'Oceania', None, 2019),
#  ('Fiji', 'Oceania', None, 2020),
#  ('French Guiana', 'Latin America and the Caribbean', None, 2015),
#  ('French Guiana', 'Latin America and the Caribbean', None, 2016),
#  ('French Guiana', 'Latin America and the Caribbean', None, 2017),
#  ('French Guiana', 'Latin America and the Caribbean', None, 2018),
#  ('French Guiana', 'Latin America and the Caribbean', None, 2019),
#  ('French Guiana', 'Latin America and the Caribbean', None, 2020),
#  ('French Polynesia', 'Oceania', None, 2015),
#  ('French Polynesia', 'Oceania', None, 2016),
#  ('French Polynesia', 'Oceania', None, 2017),
#  ('French Polynesia', 'Oceania', None, 2018),
#  ('French Polynesia', 'Oceania', None, 2019),
#  ('French Polynesia', 'Oceania', None, 2020),
#  ('Gabon', 'Sub-Saharan Africa', None, 2015),
#  ('Gabon', 'Sub-Saharan Africa', None, 2016),
#  ('Gabon', 'Sub-Saharan Africa', None, 2017),
#  ('Gabon', 'Sub-Saharan Africa', None, 2018),
#  ('Gabon', 'Sub-Saharan Africa', None, 2019),
#  ('Gabon', 'Sub-Saharan Africa', None, 2020),
#  ('Gambia', 'Sub-Saharan Africa', None, 2015),
#  ('Gambia', 'Sub-Saharan Africa', None, 2016),
#  ('Gambia', 'Sub-Saharan Africa', None, 2017),
#  ('Gambia', 'Sub-Saharan Africa', None, 2018),
#  ('Gambia', 'Sub-Saharan Africa', None, 2019),
#  ('Gambia', 'Sub-Saharan Africa', None, 2020),
#  ('Georgia', 'Northern Africa and Western Asia', Decimal('16.51'), 2015),
#  ('Georgia', 'Northern Africa and Western Asia', Decimal('16.60'), 2016),
#  ('Georgia', 'Northern Africa and Western Asia', Decimal('13.94'), 2017),
#  ('Georgia', 'Northern Africa and Western Asia', Decimal('12.67'), 2018),
#  ('Georgia', 'Northern Africa and Western Asia', Decimal('11.57'), 2019),
#  ('Georgia', 'Northern Africa and Western Asia', Decimal('11.73'), 2020),
#  ('Ghana', 'Sub-Saharan Africa', Decimal('6.81'), 2015),
#  ('Ghana', 'Sub-Saharan Africa', None, 2016),
#  ('Ghana', 'Sub-Saharan Africa', Decimal('3.37'), 2017),
#  ('Ghana', 'Sub-Saharan Africa', None, 2018),
#  ('Ghana', 'Sub-Saharan Africa', None, 2019),
#  ('Ghana', 'Sub-Saharan Africa', None, 2020),
#  ('Greenland', 'Europe and Northern America', Decimal('9.10'), 2015),
#  ('Greenland', 'Europe and Northern America', None, 2016),
#  ('Greenland', 'Europe and Northern America', None, 2017),
#  ('Greenland', 'Europe and Northern America', None, 2018),
#  ('Greenland', 'Europe and Northern America', None, 2019),
#  ('Greenland', 'Europe and Northern America', None, 2020),
#  ('Grenada', 'Latin America and the Caribbean', Decimal('22.90'), 2015),
#  ('Grenada', 'Latin America and the Caribbean', None, 2016),
#  ('Grenada', 'Latin America and the Caribbean', None, 2017),
#  ('Guadeloupe', 'Latin America and the Caribbean', None, 2015),
#  ('Guadeloupe', 'Latin America and the Caribbean', None, 2016),
#  ('Guadeloupe', 'Latin America and the Caribbean', None, 2017),
#  ('Guadeloupe', 'Latin America and the Caribbean', None, 2018),
#  ('Guadeloupe', 'Latin America and the Caribbean', None, 2019),
#  ('Guadeloupe', 'Latin America and the Caribbean', None, 2020),
#  ('Guam', 'Oceania', Decimal('6.90'), 2015),
#  ('Guam', 'Oceania', Decimal('5.40'), 2016),
#  ('Guam', 'Oceania', None, 2017),
#  ('Guam', 'Oceania', None, 2018),
#  ('Guam', 'Oceania', None, 2019),
#  ('Guam', 'Oceania', None, 2020),
#  ('Guatemala', 'Latin America and the Caribbean', Decimal('2.51'), 2015),
#  ('Guatemala', 'Latin America and the Caribbean', Decimal('2.58'), 2016),
#  ('Guatemala', 'Latin America and the Caribbean', Decimal('2.46'), 2017),
#  ('Guatemala', 'Latin America and the Caribbean', Decimal('2.28'), 2018),
#  ('Guatemala', 'Latin America and the Caribbean', Decimal('2.19'), 2019),
#  ('Guatemala', 'Latin America and the Caribbean', None, 2020),
#  ('Guinea', 'Sub-Saharan Africa', None, 2015),
#  ('Guinea', 'Sub-Saharan Africa', None, 2016),
#  ('Guinea', 'Sub-Saharan Africa', None, 2017),
#  ('Guinea', 'Sub-Saharan Africa', None, 2018),
#  ('Guinea', 'Sub-Saharan Africa', Decimal('5.02'), 2019),
#  ('Guinea', 'Sub-Saharan Africa', None, 2020),
#  ('Guinea-Bissau', 'Sub-Saharan Africa', None, 2015),
#  ('Guinea-Bissau', 'Sub-Saharan Africa', None, 2016),
#  ('Guinea-Bissau', 'Sub-Saharan Africa', None, 2017),
#  ('Guinea-Bissau', 'Sub-Saharan Africa', Decimal('3.20'), 2018),
#  ('Guinea-Bissau', 'Sub-Saharan Africa', None, 2019),
#  ('Guinea-Bissau', 'Sub-Saharan Africa', None, 2020),
#  ('Guyana', 'Latin America and the Caribbean', None, 2015),
#  ('Guyana', 'Latin America and the Caribbean', None, 2016),
#  ('Guyana', 'Latin America and the Caribbean', None, 2017),
#  ('Guyana', 'Latin America and the Caribbean', Decimal('14.02'), 2018),
#  ('Guyana', 'Latin America and the Caribbean', Decimal('13.52'), 2019),
#  ('Guyana', 'Latin America and the Caribbean', None, 2020),
#  ('Haiti', 'Latin America and the Caribbean', None, 2015),
#  ('Haiti', 'Latin America and the Caribbean', None, 2016),
#  ('Haiti', 'Latin America and the Caribbean', None, 2017),
#  ('Haiti', 'Latin America and the Caribbean', None, 2018),
#  ('Haiti', 'Latin America and the Caribbean', None, 2019),
#  ('Haiti', 'Latin America and the Caribbean', None, 2020),
#  ('Honduras', 'Latin America and the Caribbean', Decimal('6.15'), 2015),
#  ('Honduras', 'Latin America and the Caribbean', Decimal('6.73'), 2016),
#  ('Honduras', 'Latin America and the Caribbean', Decimal('5.53'), 2017),
#  ('Honduras', 'Latin America and the Caribbean', Decimal('5.62'), 2018),
#  ('Honduras', 'Latin America and the Caribbean', Decimal('5.55'), 2019),
#  ('Honduras', 'Latin America and the Caribbean', Decimal('10.68'), 2020),
#  ('India', 'Central and Southern Asia', None, 2015),
#  ('India', 'Central and Southern Asia', None, 2016),
#  ('India', 'Central and Southern Asia', None, 2017),
#  ('India', 'Central and Southern Asia', Decimal('7.65'), 2018),
#  ('India', 'Central and Southern Asia', Decimal('6.51'), 2019),
#  ('India', 'Central and Southern Asia', Decimal('7.86'), 2020),
#  ('Indonesia', 'Eastern and South-Eastern Asia', Decimal('4.51'), 2015),
#  ('Indonesia', 'Eastern and South-Eastern Asia', Decimal('4.30'), 2016),
#  ('Indonesia', 'Eastern and South-Eastern Asia', Decimal('3.78'), 2017),
#  ('Indonesia', 'Eastern and South-Eastern Asia', Decimal('4.39'), 2018),
#  ('Indonesia', 'Eastern and South-Eastern Asia', Decimal('3.59'), 2019),
#  ('Indonesia', 'Eastern and South-Eastern Asia', Decimal('4.25'), 2020),
#  ('Iran (Islamic Republic of)', 'Central and Southern Asia', None, 2015),
#  ('Iran (Islamic Republic of)', 'Central and Southern Asia', None, 2016),
#  ('Iran (Islamic Republic of)', 'Central and Southern Asia', None, 2017),
#  ('Iran (Islamic Republic of)', 'Central and Southern Asia', None, 2018),
#  ('Iran (Islamic Republic of)', 'Central and Southern Asia', None, 2019),
#  ('Iran (Islamic Republic of)', 'Central and Southern Asia', None, 2020),
#  ('Iraq', 'Northern Africa and Western Asia', None, 2015),
#  ('Iraq', 'Northern Africa and Western Asia', Decimal('10.82'), 2016),
#  ('Iraq', 'Northern Africa and Western Asia', Decimal('13.02'), 2017),
#  ('Iraq', 'Northern Africa and Western Asia', None, 2018),
#  ('Iraq', 'Northern Africa and Western Asia', None, 2019),
#  ('Iraq', 'Northern Africa and Western Asia', None, 2020),
#  ('Israel', 'Northern Africa and Western Asia', Decimal('5.18'), 2015),
#  ('Israel', 'Northern Africa and Western Asia', Decimal('4.72'), 2016),
#  ('Israel', 'Northern Africa and Western Asia', Decimal('4.14'), 2017),
#  ('Israel', 'Northern Africa and Western Asia', Decimal('3.92'), 2018),
#  ('Israel', 'Northern Africa and Western Asia', Decimal('3.73'), 2019),
#  ('Israel', 'Northern Africa and Western Asia', Decimal('4.17'), 2020),
#  ('Jamaica', 'Latin America and the Caribbean', Decimal('13.51'), 2015),
#  ('Jamaica', 'Latin America and the Caribbean', Decimal('8.63'), 2016),
#  ('Jamaica', 'Latin America and the Caribbean', Decimal('7.40'), 2017),
#  ('Jamaica', 'Latin America and the Caribbean', Decimal('5.47'), 2018),
#  ('Jamaica', 'Latin America and the Caribbean', Decimal('4.99'), 2019),
#  ('Jamaica', 'Latin America and the Caribbean', Decimal('6.50'), 2020),
#  ('Japan', 'Eastern and South-Eastern Asia', Decimal('3.39'), 2015),
#  ('Japan', 'Eastern and South-Eastern Asia', Decimal('3.13'), 2016),
#  ('Japan', 'Eastern and South-Eastern Asia', Decimal('2.82'), 2017),
#  ('Japan', 'Eastern and South-Eastern Asia', Decimal('2.47'), 2018),
#  ('Japan', 'Eastern and South-Eastern Asia', Decimal('2.35'), 2019),
#  ('Japan', 'Eastern and South-Eastern Asia', Decimal('2.81'), 2020),
#  ('Jordan', 'Northern Africa and Western Asia', Decimal('13.08'), 2015),
#  ('Jordan', 'Northern Africa and Western Asia', Decimal('15.28'), 2016),
#  ('Jordan', 'Northern Africa and Western Asia', Decimal('18.12'), 2017),
#  ('Jordan', 'Northern Africa and Western Asia', Decimal('18.26'), 2018),
#  ('Jordan', 'Northern Africa and Western Asia', Decimal('16.80'), 2019),
#  ('Jordan', 'Northern Africa and Western Asia', Decimal('19.21'), 2020),
#  ('Kazakhstan', 'Central and Southern Asia', Decimal('4.93'), 2015),
#  ('Kazakhstan', 'Central and Southern Asia', Decimal('4.96'), 2016),
#  ('Kazakhstan', 'Central and Southern Asia', Decimal('4.90'), 2017),
#  ('Kazakhstan', 'Central and Southern Asia', Decimal('4.85'), 2018),
#  ('Kazakhstan', 'Central and Southern Asia', Decimal('4.80'), 2019),
#  ('Kazakhstan', 'Central and Southern Asia', Decimal('4.89'), 2020),
#  ('Kenya', 'Sub-Saharan Africa', None, 2015),
#  ('Kenya', 'Sub-Saharan Africa', Decimal('2.76'), 2016),
#  ('Kenya', 'Sub-Saharan Africa', None, 2017),
#  ('Kenya', 'Sub-Saharan Africa', None, 2018),
#  ('Kenya', 'Sub-Saharan Africa', Decimal('5.01'), 2019),
#  ('Kenya', 'Sub-Saharan Africa', None, 2020),
#  ('Kiribati', 'Oceania', Decimal('9.33'), 2015),
#  ('Kiribati', 'Oceania', None, 2016),
#  ('Kiribati', 'Oceania', None, 2017),
#  ('Kiribati', 'Oceania', None, 2018),
#  ('Kiribati', 'Oceania', Decimal('8.56'), 2019),
#  ('Kiribati', 'Oceania', Decimal('10.97'), 2020),
#  ('Kuwait', 'Northern Africa and Western Asia', Decimal('2.20'), 2015),
#  ('Kuwait', 'Northern Africa and Western Asia', Decimal('2.16'), 2016),
#  ('Kuwait', 'Northern Africa and Western Asia', None, 2017),
#  ('Kuwait', 'Northern Africa and Western Asia', None, 2018),
#  ('Kuwait', 'Northern Africa and Western Asia', None, 2019),
#  ('Kuwait', 'Northern Africa and Western Asia', None, 2020),
#  ('Kyrgyzstan', 'Central and Southern Asia', None, 2015),
#  ('Kyrgyzstan', 'Central and Southern Asia', None, 2016),
#  ('Kyrgyzstan', 'Central and Southern Asia', None, 2017),
#  ('Kyrgyzstan', 'Central and Southern Asia', None, 2018),
#  ('Kyrgyzstan', 'Central and Southern Asia', None, 2019),
#  ('Kyrgyzstan', 'Central and Southern Asia', None, 2020),
#  ("Lao People's Democratic Republic", 'Eastern and South-Eastern Asia', None, 2015),
#  ("Lao People's Democratic Republic", 'Eastern and South-Eastern Asia', None, 2016),
#  ("Lao People's Democratic Republic", 'Eastern and South-Eastern Asia', None, 2017),
#  ("Lao People's Democratic Republic", 'Eastern and South-Eastern Asia', None, 2018),
#  ("Lao People's Democratic Republic", 'Eastern and South-Eastern Asia', None, 2019),
#  ("Lao People's Democratic Republic", 'Eastern and South-Eastern Asia', None, 2020),
#  ('Lebanon', 'Northern Africa and Western Asia', None, 2015),
#  ('Lebanon', 'Northern Africa and Western Asia', None, 2016),
#  ('Lebanon', 'Northern Africa and Western Asia', None, 2017),
#  ('Lebanon', 'Northern Africa and Western Asia', None, 2018),
#  ('Lebanon', 'Northern Africa and Western Asia', Decimal('11.30'), 2019),
#  ('Lebanon', 'Northern Africa and Western Asia', None, 2020),
#  ('Lesotho', 'Sub-Saharan Africa', None, 2015),
#  ('Lesotho', 'Sub-Saharan Africa', None, 2016),
#  ('Lesotho', 'Sub-Saharan Africa', None, 2017),
#  ('Lesotho', 'Sub-Saharan Africa', None, 2018),
#  ('Lesotho', 'Sub-Saharan Africa', Decimal('16.88'), 2019),
#  ('Lesotho', 'Sub-Saharan Africa', None, 2020),
#  ('Liberia', 'Sub-Saharan Africa', None, 2015),
#  ('Liberia', 'Sub-Saharan Africa', Decimal('3.08'), 2016),
#  ('Liberia', 'Sub-Saharan Africa', Decimal('5.95'), 2017),
#  ('Liberia', 'Sub-Saharan Africa', None, 2018),
#  ('Liberia', 'Sub-Saharan Africa', None, 2019),
#  ('Liberia', 'Sub-Saharan Africa', None, 2020),
#  ('Libya', 'Northern Africa and Western Asia', None, 2015),
#  ('Libya', 'Northern Africa and Western Asia', None, 2016),
#  ('Libya', 'Northern Africa and Western Asia', None, 2017),
#  ('Libya', 'Northern Africa and Western Asia', None, 2018),
#  ('Libya', 'Northern Africa and Western Asia', None, 2019),
#  ('Libya', 'Northern Africa and Western Asia', None, 2020),
#  ('Madagascar', 'Sub-Saharan Africa', Decimal('1.79'), 2015),
#  ('Madagascar', 'Sub-Saharan Africa', None, 2016),
#  ('Madagascar', 'Sub-Saharan Africa', None, 2017),
#  ('Madagascar', 'Sub-Saharan Africa', None, 2018),
#  ('Madagascar', 'Sub-Saharan Africa', None, 2019),
#  ('Madagascar', 'Sub-Saharan Africa', None, 2020),
#  ('Malawi', 'Sub-Saharan Africa', None, 2015),
#  ('Malawi', 'Sub-Saharan Africa', None, 2016),
#  ('Malawi', 'Sub-Saharan Africa', Decimal('3.54'), 2017),
#  ('Malawi', 'Sub-Saharan Africa', None, 2018),
#  ('Malawi', 'Sub-Saharan Africa', None, 2019),
#  ('Malawi', 'Sub-Saharan Africa', Decimal('0.91'), 2020),
#  ('Malaysia', 'Eastern and South-Eastern Asia', Decimal('3.10'), 2015),
#  ('Malaysia', 'Eastern and South-Eastern Asia', Decimal('3.44'), 2016),
#  ('Malaysia', 'Eastern and South-Eastern Asia', Decimal('3.41'), 2017),
#  ('Malaysia', 'Eastern and South-Eastern Asia', Decimal('3.30'), 2018),
#  ('Malaysia', 'Eastern and South-Eastern Asia', Decimal('3.26'), 2019),
#  ('Malaysia', 'Eastern and South-Eastern Asia', Decimal('4.54'), 2020),
#  ('Maldives', 'Central and Southern Asia', None, 2015),
#  ('Maldives', 'Central and Southern Asia', Decimal('5.77'), 2016),
#  ('Maldives', 'Central and Southern Asia', None, 2017),
#  ('Maldives', 'Central and Southern Asia', None, 2018),
#  ('Maldives', 'Central and Southern Asia', Decimal('4.56'), 2019),
#  ('Maldives', 'Central and Southern Asia', None, 2020),
#  ('Mali', 'Sub-Saharan Africa', Decimal('7.73'), 2015),
#  ('Mali', 'Sub-Saharan Africa', Decimal('1.37'), 2016),
#  ('Mali', 'Sub-Saharan Africa', Decimal('7.41'), 2017),
#  ('Mali', 'Sub-Saharan Africa', Decimal('1.62'), 2018),
#  ('Mali', 'Sub-Saharan Africa', None, 2019),
#  ('Mali', 'Sub-Saharan Africa', Decimal('3.53'), 2020),
#  ('Marshall Islands', 'Oceania', None, 2015),
#  ('Marshall Islands', 'Oceania', None, 2016),
#  ('Marshall Islands', 'Oceania', None, 2017),
#  ('Marshall Islands', 'Oceania', None, 2018),
#  ('Marshall Islands', 'Oceania', Decimal('6.34'), 2019),
#  ('Marshall Islands', 'Oceania', None, 2020),
#  ('Martinique', 'Latin America and the Caribbean', None, 2015),
#  ('Martinique', 'Latin America and the Caribbean', None, 2016),
#  ('Martinique', 'Latin America and the Caribbean', None, 2017),
#  ('Martinique', 'Latin America and the Caribbean', None, 2018),
#  ('Martinique', 'Latin America and the Caribbean', None, 2019),
#  ('Martinique', 'Latin America and the Caribbean', None, 2020),
#  ('Mauritania', 'Sub-Saharan Africa', None, 2015),
#  ('Mauritania', 'Sub-Saharan Africa', None, 2016),
#  ('Mauritania', 'Sub-Saharan Africa', Decimal('10.34'), 2017),
#  ('Mauritania', 'Sub-Saharan Africa', None, 2018),
#  ('Mauritania', 'Sub-Saharan Africa', Decimal('10.42'), 2019),
#  ('Mauritania', 'Sub-Saharan Africa', None, 2020),
#  ('Mauritius', 'Sub-Saharan Africa', Decimal('7.41'), 2015),
#  ('Mauritius', 'Sub-Saharan Africa', Decimal('6.81'), 2016),
#  ('Mauritius', 'Sub-Saharan Africa', Decimal('6.75'), 2017),
#  ('Mauritius', 'Sub-Saharan Africa', Decimal('6.43'), 2018),
#  ('Mauritius', 'Sub-Saharan Africa', Decimal('6.33'), 2019),
#  ('Mauritius', 'Sub-Saharan Africa', Decimal('8.63'), 2020),
#  ('Mayotte', 'Sub-Saharan Africa', None, 2015),
#  ('Mayotte', 'Sub-Saharan Africa', None, 2016),
#  ('Mayotte', 'Sub-Saharan Africa', None, 2017),
#  ('Mayotte', 'Sub-Saharan Africa', None, 2018),
#  ('Mayotte', 'Sub-Saharan Africa', None, 2019),
#  ('Mayotte', 'Sub-Saharan Africa', None, 2020),
#  ('Mexico', 'Latin America and the Caribbean', Decimal('4.31'), 2015),
#  ('Mexico', 'Latin America and the Caribbean', Decimal('3.85'), 2016),
#  ('Mexico', 'Latin America and the Caribbean', Decimal('3.42'), 2017),
#  ('Mexico', 'Latin America and the Caribbean', Decimal('3.27'), 2018),
#  ('Mexico', 'Latin America and the Caribbean', Decimal('3.48'), 2019),
#  ('Mexico', 'Latin America and the Caribbean', Decimal('4.44'), 2020),
#  ('Micronesia (Federated States of)', 'Oceania', None, 2015),
#  ('Micronesia (Federated States of)', 'Oceania', None, 2016),
#  ('Micronesia (Federated States of)', 'Oceania', None, 2017),
#  ('Micronesia (Federated States of)', 'Oceania', None, 2018),
#  ('Micronesia (Federated States of)', 'Oceania', None, 2019),
#  ('Mongolia', 'Eastern and South-Eastern Asia', Decimal('4.86'), 2015),
#  ('Mongolia', 'Eastern and South-Eastern Asia', Decimal('7.24'), 2016),
#  ('Mongolia', 'Eastern and South-Eastern Asia', Decimal('6.36'), 2017),
#  ('Mongolia', 'Eastern and South-Eastern Asia', Decimal('5.38'), 2018),
#  ('Mongolia', 'Eastern and South-Eastern Asia', Decimal('9.27'), 2019),
#  ('Mongolia', 'Eastern and South-Eastern Asia', Decimal('6.59'), 2020),
#  ('Montserrat', 'Latin America and the Caribbean', None, 2015),
#  ('Montserrat', 'Latin America and the Caribbean', None, 2016),
#  ('Montserrat', 'Latin America and the Caribbean', None, 2017),
#  ('Montserrat', 'Latin America and the Caribbean', None, 2018),
#  ('Montserrat', 'Latin America and the Caribbean', None, 2019),
#  ('Montserrat', 'Latin America and the Caribbean', None, 2020),
#  ('Morocco', 'Northern Africa and Western Asia', Decimal('9.46'), 2015),
#  ('Morocco', 'Northern Africa and Western Asia', Decimal('9.30'), 2016),
#  ('Morocco', 'Northern Africa and Western Asia', None, 2017),
#  ('Morocco', 'Northern Africa and Western Asia', None, 2018),
#  ('Morocco', 'Northern Africa and Western Asia', None, 2019),
#  ('Morocco', 'Northern Africa and Western Asia', None, 2020),
#  ('Mozambique', 'Sub-Saharan Africa', Decimal('3.43'), 2015),
#  ('Mozambique', 'Sub-Saharan Africa', None, 2016),
#  ('Mozambique', 'Sub-Saharan Africa', None, 2017),
#  ('Mozambique', 'Sub-Saharan Africa', None, 2018),
#  ('Mozambique', 'Sub-Saharan Africa', None, 2019),
#  ('Mozambique', 'Sub-Saharan Africa', None, 2020),
#  ('Myanmar', 'Eastern and South-Eastern Asia', Decimal('0.77'), 2015),
#  ('Myanmar', 'Eastern and South-Eastern Asia', None, 2016),
#  ('Myanmar', 'Eastern and South-Eastern Asia', Decimal('1.36'), 2017),
#  ('Myanmar', 'Eastern and South-Eastern Asia', Decimal('0.77'), 2018),
#  ('Myanmar', 'Eastern and South-Eastern Asia', Decimal('0.41'), 2019),
#  ('Myanmar', 'Eastern and South-Eastern Asia', Decimal('1.48'), 2020),
#  ('Namibia', 'Sub-Saharan Africa', None, 2015),
#  ('Namibia', 'Sub-Saharan Africa', Decimal('23.35'), 2016),
#  ('Namibia', 'Sub-Saharan Africa', None, 2017),
#  ('Namibia', 'Sub-Saharan Africa', Decimal('19.88'), 2018),
#  ('Namibia', 'Sub-Saharan Africa', None, 2019),
#  ('Namibia', 'Sub-Saharan Africa', None, 2020),
#  ('Nauru', 'Oceania', None, 2015),
#  ('Nauru', 'Oceania', None, 2016),
#  ('Nauru', 'Oceania', None, 2017),
#  ('Nauru', 'Oceania', None, 2018),
#  ('Nauru', 'Oceania', None, 2019),
#  ('Nauru', 'Oceania', None, 2020),
#  ('Nepal', 'Central and Southern Asia', Decimal('3.10'), 2015),
#  ('Nepal', 'Central and Southern Asia', None, 2016),
#  ('Nepal', 'Central and Southern Asia', Decimal('10.66'), 2017),
#  ('Nepal', 'Central and Southern Asia', None, 2018),
#  ('Nepal', 'Central and Southern Asia', None, 2019),
#  ('Nepal', 'Central and Southern Asia', None, 2020),
#  ('New Caledonia', 'Oceania', None, 2015),
#  ('New Caledonia', 'Oceania', None, 2016),
#  ('New Caledonia', 'Oceania', Decimal('11.68'), 2017),
#  ('New Caledonia', 'Oceania', Decimal('11.70'), 2018),
#  ('New Caledonia', 'Oceania', Decimal('10.88'), 2019),
#  ('New Caledonia', 'Oceania', Decimal('13.56'), 2020),
#  ('New Zealand', 'Oceania', Decimal('5.42'), 2015),
#  ('New Zealand', 'Oceania', Decimal('5.15'), 2016),
#  ('New Zealand', 'Oceania', Decimal('4.74'), 2017),
#  ('New Zealand', 'Oceania', Decimal('4.34'), 2018),
#  ('New Zealand', 'Oceania', Decimal('4.11'), 2019),
#  ('New Zealand', 'Oceania', Decimal('4.60'), 2020),
#  ('Nicaragua', 'Latin America and the Caribbean', Decimal('4.70'), 2015),
#  ('Nicaragua', 'Latin America and the Caribbean', Decimal('3.90'), 2016),
#  ('Nicaragua', 'Latin America and the Caribbean', Decimal('3.30'), 2017),
#  ('Nicaragua', 'Latin America and the Caribbean', Decimal('5.20'), 2018),
#  ('Nicaragua', 'Latin America and the Caribbean', None, 2019),
#  ('Nicaragua', 'Latin America and the Caribbean', None, 2020),
#  ('Niger', 'Sub-Saharan Africa', None, 2015),
#  ('Niger', 'Sub-Saharan Africa', None, 2016),
#  ('Niger', 'Sub-Saharan Africa', Decimal('7.77'), 2017),
#  ('Niger', 'Sub-Saharan Africa', None, 2018),
#  ('Niger', 'Sub-Saharan Africa', None, 2019),
#  ('Niger', 'Sub-Saharan Africa', None, 2020),
#  ('Nigeria', 'Sub-Saharan Africa', Decimal('4.31'), 2015),
#  ('Nigeria', 'Sub-Saharan Africa', Decimal('7.06'), 2016),
#  ('Nigeria', 'Sub-Saharan Africa', Decimal('8.39'), 2017),
#  ('Nigeria', 'Sub-Saharan Africa', None, 2018),
#  ('Nigeria', 'Sub-Saharan Africa', Decimal('10.70'), 2019),
#  ('Nigeria', 'Sub-Saharan Africa', None, 2020),
#  ('Niue', 'Oceania', None, 2015),
#  ('Niue', 'Oceania', None, 2016),
#  ('Niue', 'Oceania', None, 2017),
#  ('Niue', 'Oceania', None, 2018),
#  ('Niue', 'Oceania', None, 2019),
#  ('Niue', 'Oceania', None, 2020),
#  ('Northern Mariana Islands', 'Oceania', None, 2015),
#  ('Northern Mariana Islands', 'Oceania', None, 2016),
#  ('Northern Mariana Islands', 'Oceania', None, 2017),
#  ('Northern Mariana Islands', 'Oceania', None, 2018),
#  ('Northern Mariana Islands', 'Oceania', None, 2019),
#  ('Northern Mariana Islands', 'Oceania', None, 2020),
#  ('Oman', 'Northern Africa and Western Asia', None, 2015),
#  ('Oman', 'Northern Africa and Western Asia', Decimal('3.27'), 2016),
#  ('Oman', 'Northern Africa and Western Asia', None, 2017),
#  ('Oman', 'Northern Africa and Western Asia', Decimal('1.80'), 2018),
#  ('Oman', 'Northern Africa and Western Asia', None, 2019),
#  ('Oman', 'Northern Africa and Western Asia', Decimal('2.94'), 2020),
#  ('Pakistan', 'Central and Southern Asia', Decimal('3.57'), 2015),
#  ('Pakistan', 'Central and Southern Asia', None, 2016),
#  ('Pakistan', 'Central and Southern Asia', None, 2017),
#  ('Pakistan', 'Central and Southern Asia', Decimal('4.08'), 2018),
#  ('Pakistan', 'Central and Southern Asia', Decimal('4.83'), 2019),
#  ('Pakistan', 'Central and Southern Asia', None, 2020),
#  ('Palau', 'Oceania', None, 2015),
#  ('Palau', 'Oceania', None, 2016),
#  ('Palau', 'Oceania', None, 2017),
#  ('Palau', 'Oceania', None, 2018),
#  ('Palau', 'Oceania', None, 2019),
#  ('Palau', 'Oceania', Decimal('0.77'), 2020),
#  ('Panama', 'Latin America and the Caribbean', Decimal('4.40'), 2015),
#  ('Panama', 'Latin America and the Caribbean', Decimal('4.84'), 2016),
#  ('Panama', 'Latin America and the Caribbean', Decimal('5.46'), 2017),
#  ('Panama', 'Latin America and the Caribbean', Decimal('5.31'), 2018),
#  ('Panama', 'Latin America and the Caribbean', Decimal('6.41'), 2019),
#  ('Panama', 'Latin America and the Caribbean', Decimal('18.55'), 2020),
#  ('Papua New Guinea', 'Oceania', None, 2015),
#  ('Papua New Guinea', 'Oceania', None, 2016),
#  ('Papua New Guinea', 'Oceania', None, 2017),
#  ('Papua New Guinea', 'Oceania', None, 2018),
#  ('Papua New Guinea', 'Oceania', None, 2019),
#  ('Papua New Guinea', 'Oceania', None, 2020),
#  ('Paraguay', 'Latin America and the Caribbean', Decimal('4.56'), 2015),
#  ('Paraguay', 'Latin America and the Caribbean', Decimal('5.25'), 2016),
#  ('Paraguay', 'Latin America and the Caribbean', Decimal('4.61'), 2017),
#  ('Paraguay', 'Latin America and the Caribbean', Decimal('6.22'), 2018),
#  ('Paraguay', 'Latin America and the Caribbean', Decimal('6.59'), 2019),
#  ('Paraguay', 'Latin America and the Caribbean', Decimal('7.55'), 2020),
#  ('Peru', 'Latin America and the Caribbean', Decimal('3.27'), 2015),
#  ('Peru', 'Latin America and the Caribbean', Decimal('3.74'), 2016),
#  ('Peru', 'Latin America and the Caribbean', Decimal('3.69'), 2017),
#  ('Peru', 'Latin America and the Caribbean', Decimal('3.49'), 2018),
#  ('Peru', 'Latin America and the Caribbean', Decimal('3.38'), 2019),
#  ('Peru', 'Latin America and the Caribbean', Decimal('7.18'), 2020),
#  ('Philippines', 'Eastern and South-Eastern Asia', Decimal('3.07'), 2015),
#  ('Philippines', 'Eastern and South-Eastern Asia', Decimal('2.70'), 2016),
#  ('Philippines', 'Eastern and South-Eastern Asia', Decimal('2.55'), 2017),
#  ('Philippines', 'Eastern and South-Eastern Asia', Decimal('2.34'), 2018),
#  ('Philippines', 'Eastern and South-Eastern Asia', Decimal('2.24'), 2019),
#  ('Philippines', 'Eastern and South-Eastern Asia', Decimal('2.52'), 2020),
#  ('Puerto Rico', 'Latin America and the Caribbean', Decimal('12.00'), 2015),
#  ('Puerto Rico', 'Latin America and the Caribbean', Decimal('11.80'), 2016),
#  ('Puerto Rico', 'Latin America and the Caribbean', Decimal('10.80'), 2017),
#  ('Puerto Rico', 'Latin America and the Caribbean', Decimal('9.20'), 2018),
#  ('Puerto Rico', 'Latin America and the Caribbean', Decimal('8.30'), 2019),
#  ('Puerto Rico', 'Latin America and the Caribbean', None, 2020),
#  ('Qatar', 'Northern Africa and Western Asia', Decimal('0.17'), 2015),
#  ('Qatar', 'Northern Africa and Western Asia', Decimal('0.15'), 2016),
#  ('Qatar', 'Northern Africa and Western Asia', Decimal('0.14'), 2017),
#  ('Qatar', 'Northern Africa and Western Asia', Decimal('0.11'), 2018),
#  ('Qatar', 'Northern Africa and Western Asia', Decimal('0.10'), 2019),
#  ('Qatar', 'Northern Africa and Western Asia', Decimal('0.14'), 2020),
#  ('Republic of Korea', 'Eastern and South-Eastern Asia', None, 2015),
#  ('Republic of Korea', 'Eastern and South-Eastern Asia', None, 2016),
#  ('Republic of Korea', 'Eastern and South-Eastern Asia', None, 2017),
#  ('Republic of Korea', 'Eastern and South-Eastern Asia', None, 2018),
#  ('Republic of Korea', 'Eastern and South-Eastern Asia', None, 2019),
#  ('Republic of Korea', 'Eastern and South-Eastern Asia', None, 2020),
#  ('Réunion', 'Sub-Saharan Africa', None, 2015),
#  ('Réunion', 'Sub-Saharan Africa', None, 2016),
#  ('Réunion', 'Sub-Saharan Africa', None, 2017),
#  ('Réunion', 'Sub-Saharan Africa', None, 2018),
#  ('Réunion', 'Sub-Saharan Africa', None, 2019),
#  ('Réunion', 'Sub-Saharan Africa', None, 2020),
#  ('Rwanda', 'Sub-Saharan Africa', None, 2015),
#  ('Rwanda', 'Sub-Saharan Africa', None, 2016),
#  ('Rwanda', 'Sub-Saharan Africa', Decimal('11.88'), 2017),
#  ('Rwanda', 'Sub-Saharan Africa', Decimal('10.76'), 2018),
#  ('Rwanda', 'Sub-Saharan Africa', Decimal('11.24'), 2019),
#  ('Rwanda', 'Sub-Saharan Africa', Decimal('11.83'), 2020),
#  ('Saint Barthélemy', 'Latin America and the Caribbean', None, 2015),
#  ('Saint Barthélemy', 'Latin America and the Caribbean', None, 2016),
#  ('Saint Barthélemy', 'Latin America and the Caribbean', None, 2017),
#  ('Saint Barthélemy', 'Latin America and the Caribbean', None, 2018),
#  ('Saint Barthélemy', 'Latin America and the Caribbean', None, 2019),
#  ('Saint Barthélemy', 'Latin America and the Caribbean', None, 2020),
#  ('Saint Helena', 'Sub-Saharan Africa', None, 2015),
#  ('Saint Helena', 'Sub-Saharan Africa', None, 2016),
#  ('Saint Helena', 'Sub-Saharan Africa', None, 2017),
#  ('Saint Helena', 'Sub-Saharan Africa', None, 2018),
#  ('Saint Helena', 'Sub-Saharan Africa', None, 2019),
#  ('Saint Helena', 'Sub-Saharan Africa', None, 2020),
#  ('Saint Kitts and Nevis', 'Latin America and the Caribbean', None, 2015),
#  ('Saint Kitts and Nevis', 'Latin America and the Caribbean', None, 2016),
#  ('Saint Kitts and Nevis', 'Latin America and the Caribbean', None, 2017),
#  ('Saint Lucia', 'Latin America and the Caribbean', None, 2015),
#  ('Saint Lucia', 'Latin America and the Caribbean', None, 2016),
#  ('Saint Lucia', 'Latin America and the Caribbean', None, 2017),
#  ('Saint Lucia', 'Latin America and the Caribbean', None, 2018),
#  ('Saint Lucia', 'Latin America and the Caribbean', None, 2019),
#  ('Saint Lucia', 'Latin America and the Caribbean', None, 2020),
#  ('Saint Martin (French Part)', 'Latin America and the Caribbean', None, 2015),
#  ('Saint Martin (French Part)', 'Latin America and the Caribbean', None, 2016),
#  ('Saint Martin (French Part)', 'Latin America and the Caribbean', None, 2017),
#  ('Saint Martin (French Part)', 'Latin America and the Caribbean', None, 2018),
#  ('Saint Martin (French Part)', 'Latin America and the Caribbean', None, 2019),
#  ('Saint Martin (French Part)', 'Latin America and the Caribbean', None, 2020),
#  ('Saint Pierre and Miquelon', 'Europe and Northern America', None, 2015),
#  ('Saint Pierre and Miquelon', 'Europe and Northern America', None, 2016),
#  ('Saint Pierre and Miquelon', 'Europe and Northern America', None, 2017),
#  ('Saint Pierre and Miquelon', 'Europe and Northern America', None, 2018),
#  ('Saint Pierre and Miquelon', 'Europe and Northern America', None, 2019),
#  ('Saint Pierre and Miquelon', 'Europe and Northern America', None, 2020),
#  ('Saint Vincent and the Grenadines', 'Latin America and the Caribbean', None, 2015),
#  ('Saint Vincent and the Grenadines', 'Latin America and the Caribbean', None, 2016),
#  ('Saint Vincent and the Grenadines', 'Latin America and the Caribbean', None, 2017),
#  ('Saint Vincent and the Grenadines', 'Latin America and the Caribbean', None, 2018),
#  ('Samoa', 'Oceania', None, 2015),
#  ('Samoa', 'Oceania', None, 2016),
#  ('Samoa', 'Oceania', Decimal('9.40'), 2017),
#  ('Samoa', 'Oceania', None, 2018),
#  ('Samoa', 'Oceania', None, 2019),
#  ('Samoa', 'Oceania', None, 2020),
#  ('Sao Tome and Principe', 'Sub-Saharan Africa', None, 2015),
#  ('Sao Tome and Principe', 'Sub-Saharan Africa', None, 2016),
#  ('Sao Tome and Principe', 'Sub-Saharan Africa', None, 2017),
#  ('Sao Tome and Principe', 'Sub-Saharan Africa', None, 2018),
#  ('Sao Tome and Principe', 'Sub-Saharan Africa', None, 2019),
#  ('Sao Tome and Principe', 'Sub-Saharan Africa', None, 2020),
#  ('Saudi Arabia', 'Northern Africa and Western Asia', Decimal('5.60'), 2015),
#  ('Saudi Arabia', 'Northern Africa and Western Asia', Decimal('5.60'), 2016),
#  ('Saudi Arabia', 'Northern Africa and Western Asia', Decimal('5.89'), 2017),
#  ('Saudi Arabia', 'Northern Africa and Western Asia', Decimal('6.03'), 2018),
#  ('Saudi Arabia', 'Northern Africa and Western Asia', Decimal('5.64'), 2019),
#  ('Saudi Arabia', 'Northern Africa and Western Asia', Decimal('7.66'), 2020),
#  ('Senegal', 'Sub-Saharan Africa', Decimal('6.76'), 2015),
#  ('Senegal', 'Sub-Saharan Africa', Decimal('4.46'), 2016),
#  ('Senegal', 'Sub-Saharan Africa', Decimal('4.08'), 2017),
#  ('Senegal', 'Sub-Saharan Africa', Decimal('3.57'), 2018),
#  ('Senegal', 'Sub-Saharan Africa', Decimal('2.86'), 2019),
#  ('Senegal', 'Sub-Saharan Africa', None, 2020),
#  ('Seychelles', 'Sub-Saharan Africa', Decimal('4.15'), 2015),
#  ('Seychelles', 'Sub-Saharan Africa', Decimal('3.96'), 2016),
#  ('Seychelles', 'Sub-Saharan Africa', Decimal('3.71'), 2017),
#  ('Seychelles', 'Sub-Saharan Africa', Decimal('3.53'), 2018),
#  ('Seychelles', 'Sub-Saharan Africa', Decimal('2.97'), 2019),
#  ('Sierra Leone', 'Sub-Saharan Africa', None, 2015),
#  ('Sierra Leone', 'Sub-Saharan Africa', None, 2016),
#  ('Sierra Leone', 'Sub-Saharan Africa', None, 2017),
#  ('Sierra Leone', 'Sub-Saharan Africa', Decimal('3.19'), 2018),
#  ('Sierra Leone', 'Sub-Saharan Africa', None, 2019),
#  ('Sierra Leone', 'Sub-Saharan Africa', None, 2020),
#  ('Singapore', 'Eastern and South-Eastern Asia', Decimal('3.79'), 2015),
#  ('Singapore', 'Eastern and South-Eastern Asia', Decimal('4.08'), 2016),
#  ('Singapore', 'Eastern and South-Eastern Asia', Decimal('4.20'), 2017),
#  ('Singapore', 'Eastern and South-Eastern Asia', None, 2018),
#  ('Singapore', 'Eastern and South-Eastern Asia', Decimal('3.10'), 2019),
#  ('Singapore', 'Eastern and South-Eastern Asia', Decimal('4.10'), 2020),
#  ('Sint Maarten (Dutch part)', 'Latin America and the Caribbean', None, 2015),
#  ('Sint Maarten (Dutch part)', 'Latin America and the Caribbean', None, 2016),
#  ('Sint Maarten (Dutch part)', 'Latin America and the Caribbean', None, 2017),
#  ('Solomon Islands', 'Oceania', None, 2015),
#  ('Solomon Islands', 'Oceania', None, 2016),
#  ('Solomon Islands', 'Oceania', None, 2017),
#  ('Solomon Islands', 'Oceania', None, 2018),
#  ('Solomon Islands', 'Oceania', None, 2019),
#  ('Solomon Islands', 'Oceania', None, 2020),
#  ('Somalia', 'Sub-Saharan Africa', None, 2015),
#  ('Somalia', 'Sub-Saharan Africa', None, 2016),
#  ('Somalia', 'Sub-Saharan Africa', None, 2017),
#  ('Somalia', 'Sub-Saharan Africa', None, 2018),
#  ('Somalia', 'Sub-Saharan Africa', Decimal('18.83'), 2019),
#  ('Somalia', 'Sub-Saharan Africa', None, 2020),
#  ('South Africa', 'Sub-Saharan Africa', Decimal('22.87'), 2015),
#  ('South Africa', 'Sub-Saharan Africa', Decimal('24.02'), 2016),
#  ('South Africa', 'Sub-Saharan Africa', Decimal('23.99'), 2017),
#  ('South Africa', 'Sub-Saharan Africa', Decimal('24.22'), 2018),
#  ('South Africa', 'Sub-Saharan Africa', Decimal('25.54'), 2019),
#  ('South Africa', 'Sub-Saharan Africa', Decimal('24.34'), 2020),
#  ('South Sudan', 'Sub-Saharan Africa', None, 2015),
#  ('South Sudan', 'Sub-Saharan Africa', None, 2016),
#  ('South Sudan', 'Sub-Saharan Africa', None, 2017),
#  ('South Sudan', 'Sub-Saharan Africa', None, 2018),
#  ('South Sudan', 'Sub-Saharan Africa', None, 2019),
#  ('South Sudan', 'Sub-Saharan Africa', None, 2020),
#  ('Sri Lanka', 'Central and Southern Asia', Decimal('4.52'), 2015),
#  ('Sri Lanka', 'Central and Southern Asia', Decimal('4.24'), 2016),
#  ('Sri Lanka', 'Central and Southern Asia', Decimal('4.05'), 2017),
#  ('Sri Lanka', 'Central and Southern Asia', Decimal('4.32'), 2018),
#  ('Sri Lanka', 'Central and Southern Asia', Decimal('4.67'), 2019),
#  ('Sri Lanka', 'Central and Southern Asia', Decimal('5.36'), 2020),
#  ('State of Palestine', 'Northern Africa and Western Asia', None, 2015),
#  ('State of Palestine', 'Northern Africa and Western Asia', None, 2016),
#  ('State of Palestine', 'Northern Africa and Western Asia', None, 2017),
#  ('State of Palestine', 'Northern Africa and Western Asia', None, 2018),
#  ('State of Palestine', 'Northern Africa and Western Asia', None, 2019),
#  ('State of Palestine', 'Northern Africa and Western Asia', None, 2020),
#  ('Sudan', 'Northern Africa and Western Asia', None, 2015),
#  ('Sudan', 'Northern Africa and Western Asia', None, 2016),
#  ('Sudan', 'Northern Africa and Western Asia', None, 2017),
#  ('Sudan', 'Northern Africa and Western Asia', None, 2018),
#  ('Sudan', 'Northern Africa and Western Asia', None, 2019),
#  ('Sudan', 'Northern Africa and Western Asia', None, 2020),
#  ('Suriname', 'Latin America and the Caribbean', Decimal('7.22'), 2015),
#  ('Suriname', 'Latin America and the Caribbean', Decimal('7.92'), 2016),
#  ('Suriname', 'Latin America and the Caribbean', None, 2017),
#  ('Suriname', 'Latin America and the Caribbean', None, 2018),
#  ('Suriname', 'Latin America and the Caribbean', None, 2019),
#  ('Suriname', 'Latin America and the Caribbean', None, 2020),
#  ('Syrian Arab Republic', 'Northern Africa and Western Asia', None, 2015),
#  ('Syrian Arab Republic', 'Northern Africa and Western Asia', None, 2016),
#  ('Syrian Arab Republic', 'Northern Africa and Western Asia', None, 2017),
#  ('Syrian Arab Republic', 'Northern Africa and Western Asia', None, 2018),
#  ('Syrian Arab Republic', 'Northern Africa and Western Asia', None, 2019),
#  ('Syrian Arab Republic', 'Northern Africa and Western Asia', None, 2020),
#  ('Tajikistan', 'Central and Southern Asia', None, 2015),
#  ('Tajikistan', 'Central and Southern Asia', Decimal('6.90'), 2016),
#  ('Tajikistan', 'Central and Southern Asia', None, 2017),
#  ('Tajikistan', 'Central and Southern Asia', None, 2018),
#  ('Tajikistan', 'Central and Southern Asia', None, 2019),
#  ('Tajikistan', 'Central and Southern Asia', None, 2020),
#  ('Thailand', 'Eastern and South-Eastern Asia', Decimal('0.60'), 2015),
#  ('Thailand', 'Eastern and South-Eastern Asia', Decimal('0.69'), 2016),
#  ('Thailand', 'Eastern and South-Eastern Asia', Decimal('0.83'), 2017),
#  ('Thailand', 'Eastern and South-Eastern Asia', Decimal('0.77'), 2018),
#  ('Thailand', 'Eastern and South-Eastern Asia', Decimal('0.72'), 2019),
#  ('Thailand', 'Eastern and South-Eastern Asia', Decimal('1.10'), 2020),
#  ('Timor-Leste', 'Eastern and South-Eastern Asia', None, 2015),
#  ('Timor-Leste', 'Eastern and South-Eastern Asia', Decimal('4.66'), 2016),
#  ('Timor-Leste', 'Eastern and South-Eastern Asia', None, 2017),
#  ('Timor-Leste', 'Eastern and South-Eastern Asia', None, 2018),
#  ('Timor-Leste', 'Eastern and South-Eastern Asia', None, 2019),
#  ('Timor-Leste', 'Eastern and South-Eastern Asia', None, 2020),
#  ('Togo', 'Sub-Saharan Africa', Decimal('2.20'), 2015),
#  ('Togo', 'Sub-Saharan Africa', None, 2016),
#  ('Togo', 'Sub-Saharan Africa', Decimal('3.74'), 2017),
#  ('Togo', 'Sub-Saharan Africa', None, 2018),
#  ('Togo', 'Sub-Saharan Africa', None, 2019),
#  ('Togo', 'Sub-Saharan Africa', None, 2020),
#  ('Tokelau', 'Oceania', None, 2015),
#  ('Tokelau', 'Oceania', None, 2016),
#  ('Tokelau', 'Oceania', None, 2017),
#  ('Tokelau', 'Oceania', None, 2018),
#  ('Tokelau', 'Oceania', None, 2019),
#  ('Tokelau', 'Oceania', None, 2020),
#  ('Tonga', 'Oceania', None, 2015),
#  ('Tonga', 'Oceania', None, 2016),
#  ('Tonga', 'Oceania', None, 2017),
#  ('Tonga', 'Oceania', Decimal('2.25'), 2018),
#  ('Tonga', 'Oceania', None, 2019),
#  ('Tonga', 'Oceania', None, 2020),
#  ('Trinidad and Tobago', 'Latin America and the Caribbean', Decimal('2.43'), 2015),
#  ('Trinidad and Tobago', 'Latin America and the Caribbean', Decimal('3.21'), 2016),
#  ('Trinidad and Tobago', 'Latin America and the Caribbean', None, 2017),
#  ('Trinidad and Tobago', 'Latin America and the Caribbean', None, 2018),
#  ('Trinidad and Tobago', 'Latin America and the Caribbean', Decimal('3.52'), 2019),
#  ('Trinidad and Tobago', 'Latin America and the Caribbean', Decimal('4.21'), 2020),
#  ('Tunisia', 'Northern Africa and Western Asia', Decimal('15.16'), 2015),
#  ('Tunisia', 'Northern Africa and Western Asia', Decimal('15.56'), 2016),
#  ('Tunisia', 'Northern Africa and Western Asia', Decimal('15.33'), 2017),
#  ('Tunisia', 'Northern Africa and Western Asia', Decimal('15.46'), 2018),
#  ('Tunisia', 'Northern Africa and Western Asia', Decimal('15.13'), 2019),
#  ('Tunisia', 'Northern Africa and Western Asia', None, 2020),
#  ('Türkiye', 'Northern Africa and Western Asia', None, 2015),
#  ('Türkiye', 'Northern Africa and Western Asia', None, 2016),
#  ('Türkiye', 'Northern Africa and Western Asia', None, 2017),
#  ('Türkiye', 'Northern Africa and Western Asia', None, 2018),
#  ('Türkiye', 'Northern Africa and Western Asia', None, 2019),
#  ('Türkiye', 'Northern Africa and Western Asia', None, 2020),
#  ('Turkmenistan', 'Central and Southern Asia', None, 2015),
#  ('Turkmenistan', 'Central and Southern Asia', None, 2016),
#  ('Turkmenistan', 'Central and Southern Asia', None, 2017),
#  ('Turkmenistan', 'Central and Southern Asia', None, 2018),
#  ('Turkmenistan', 'Central and Southern Asia', None, 2019),
#  ('Turkmenistan', 'Central and Southern Asia', None, 2020),
#  ('Turks and Caicos Islands', 'Latin America and the Caribbean', None, 2015),
#  ('Turks and Caicos Islands', 'Latin America and the Caribbean', None, 2016),
#  ('Turks and Caicos Islands', 'Latin America and the Caribbean', None, 2017),
#  ('Turks and Caicos Islands', 'Latin America and the Caribbean', None, 2018),
#  ('Tuvalu', 'Oceania', None, 2015),
#  ('Tuvalu', 'Oceania', Decimal('8.49'), 2016),
#  ('Tuvalu', 'Oceania', Decimal('26.55'), 2017),
#  ('Tuvalu', 'Oceania', None, 2018),
#  ('Tuvalu', 'Oceania', None, 2019),
#  ('Tuvalu', 'Oceania', None, 2020),
#  ('Uganda', 'Sub-Saharan Africa', None, 2015),
#  ('Uganda', 'Sub-Saharan Africa', None, 2016),
#  ('Uganda', 'Sub-Saharan Africa', Decimal('3.64'), 2017),
#  ('Uganda', 'Sub-Saharan Africa', None, 2018),
#  ('Uganda', 'Sub-Saharan Africa', None, 2019),
#  ('Uganda', 'Sub-Saharan Africa', None, 2020),
#  ('United Arab Emirates', 'Northern Africa and Western Asia', None, 2015),
#  ('United Arab Emirates', 'Northern Africa and Western Asia', Decimal('1.64'), 2016),
#  ('United Arab Emirates', 'Northern Africa and Western Asia', Decimal('2.46'), 2017),
#  ('United Arab Emirates', 'Northern Africa and Western Asia', Decimal('2.24'), 2018),
#  ('United Arab Emirates', 'Northern Africa and Western Asia', Decimal('2.33'), 2019),
#  ('United Arab Emirates', 'Northern Africa and Western Asia', Decimal('4.29'), 2020),
#  ('United Republic of Tanzania', 'Sub-Saharan Africa', None, 2015),
#  ('United Republic of Tanzania', 'Sub-Saharan Africa', None, 2016),
#  ('United Republic of Tanzania', 'Sub-Saharan Africa', None, 2017),
#  ('United Republic of Tanzania', 'Sub-Saharan Africa', None, 2018),
#  ('United Republic of Tanzania', 'Sub-Saharan Africa', None, 2019),
#  ('United Republic of Tanzania', 'Sub-Saharan Africa', None, 2020),
#  ('United States of America', 'Europe and Northern America', None, 2015),
#  ('United States of America', 'Europe and Northern America', None, 2016),
#  ('United States of America', 'Europe and Northern America', None, 2017),
#  ('United States of America', 'Europe and Northern America', None, 2018),
#  ('United States of America', 'Europe and Northern America', None, 2019),
#  ('United States of America', 'Europe and Northern America', None, 2020),
#  ('United States Virgin Islands', 'Latin America and the Caribbean', None, 2015),
#  ('United States Virgin Islands', 'Latin America and the Caribbean', None, 2016),
#  ('United States Virgin Islands', 'Latin America and the Caribbean', None, 2017),
#  ('United States Virgin Islands', 'Latin America and the Caribbean', None, 2018),
#  ('United States Virgin Islands', 'Latin America and the Caribbean', None, 2019),
#  ('United States Virgin Islands', 'Latin America and the Caribbean', None, 2020),
#  ('Uruguay', 'Latin America and the Caribbean', Decimal('7.49'), 2015),
#  ('Uruguay', 'Latin America and the Caribbean', Decimal('7.84'), 2016),
#  ('Uruguay', 'Latin America and the Caribbean', Decimal('7.89'), 2017),
#  ('Uruguay', 'Latin America and the Caribbean', Decimal('8.34'), 2018),
#  ('Uruguay', 'Latin America and the Caribbean', Decimal('8.73'), 2019),
#  ('Uruguay', 'Latin America and the Caribbean', Decimal('10.33'), 2020),
#  ...]

# %% [markdown]
# ### Task 2
#
# After joining our tables, the query  now returns a table with the unemployment rate, country, and region. This allows us to filter for countries in Sub-Saharan Africa. So let's filter this table ensuring that we include Sub Sub-Saharan Africa only. Use the `WHERE` clause to filter our results for `Sub-Saharan Africa`. The table should include the following columns: `Country_name`, `Time_period`, and `Pct_unemployment`.

# %%
# %%sql
# # Add your code here
# SELECT
#     E.Country_name,
#     Pct_unemployment,
#     time_period
# FROM
#     Economic_Indicators E
# INNER JOIN
#     Geographic_Location G
# ON
#     E.Country_name = G.Country_name
# WHERE
#     region = 'Sub-Saharan Africa'
# Out:
#  * mysql+pymysql://root:***@localhost:3306/united_nations
# 297 rows affected.
# [('Angola', None, 2015),
#  ('Angola', None, 2016),
#  ('Angola', None, 2017),
#  ('Angola', None, 2018),
#  ('Angola', Decimal('16.50'), 2019),
#  ('Angola', None, 2020),
#  ('Benin', None, 2015),
#  ('Benin', None, 2016),
#  ('Benin', None, 2017),
#  ('Benin', Decimal('1.47'), 2018),
#  ('Benin', None, 2019),
#  ('Benin', None, 2020),
#  ('Botswana', None, 2015),
#  ('Botswana', None, 2016),
#  ('Botswana', None, 2017),
#  ('Botswana', None, 2018),
#  ('Botswana', Decimal('20.09'), 2019),
#  ('Botswana', Decimal('21.02'), 2020),
#  ('Burkina Faso', None, 2015),
#  ('Burkina Faso', None, 2016),
#  ('Burkina Faso', None, 2017),
#  ('Burkina Faso', Decimal('4.69'), 2018),
#  ('Burkina Faso', None, 2019),
#  ('Burkina Faso', None, 2020),
#  ('Burundi', None, 2015),
#  ('Burundi', None, 2016),
#  ('Burundi', None, 2017),
#  ('Burundi', None, 2018),
#  ('Burundi', None, 2019),
#  ('Burundi', Decimal('1.03'), 2020),
#  ('Cabo Verde', Decimal('31.31'), 2015),
#  ('Cabo Verde', None, 2016),
#  ('Cabo Verde', Decimal('12.24'), 2017),
#  ('Cabo Verde', Decimal('12.17'), 2018),
#  ('Cabo Verde', Decimal('11.29'), 2019),
#  ('Cabo Verde', None, 2020),
#  ('Cameroon', None, 2015),
#  ('Cameroon', None, 2016),
#  ('Cameroon', None, 2017),
#  ('Cameroon', None, 2018),
#  ('Cameroon', None, 2019),
#  ('Cameroon', None, 2020),
#  ('Central African Republic', None, 2015),
#  ('Central African Republic', None, 2016),
#  ('Central African Republic', None, 2017),
#  ('Central African Republic', None, 2018),
#  ('Central African Republic', None, 2019),
#  ('Central African Republic', None, 2020),
#  ('Chad', None, 2015),
#  ('Chad', None, 2016),
#  ('Chad', None, 2017),
#  ('Chad', Decimal('1.13'), 2018),
#  ('Chad', None, 2019),
#  ('Chad', None, 2020),
#  ('Comoros', None, 2015),
#  ('Comoros', None, 2016),
#  ('Comoros', None, 2017),
#  ('Comoros', None, 2018),
#  ('Comoros', None, 2019),
#  ('Congo', None, 2015),
#  ('Congo', None, 2016),
#  ('Congo', None, 2017),
#  ('Congo', None, 2018),
#  ('Congo', None, 2019),
#  ('Congo', None, 2020),
#  ("Côte d'Ivoire", None, 2015),
#  ("Côte d'Ivoire", None, 2016),
#  ("Côte d'Ivoire", None, 2017),
#  ("Côte d'Ivoire", None, 2018),
#  ("Côte d'Ivoire", None, 2019),
#  ("Côte d'Ivoire", None, 2020),
#  ('Democratic Republic of the Congo', None, 2015),
#  ('Democratic Republic of the Congo', None, 2016),
#  ('Democratic Republic of the Congo', None, 2017),
#  ('Democratic Republic of the Congo', None, 2018),
#  ('Democratic Republic of the Congo', None, 2019),
#  ('Democratic Republic of the Congo', None, 2020),
#  ('Djibouti', None, 2015),
#  ('Djibouti', None, 2016),
#  ('Djibouti', Decimal('26.06'), 2017),
#  ('Djibouti', None, 2018),
#  ('Djibouti', None, 2019),
#  ('Djibouti', None, 2020),
#  ('Equatorial Guinea', None, 2015),
#  ('Equatorial Guinea', None, 2016),
#  ('Equatorial Guinea', None, 2017),
#  ('Eritrea', None, 2015),
#  ('Eritrea', None, 2016),
#  ('Eswatini', None, 2015),
#  ('Eswatini', Decimal('22.72'), 2016),
#  ('Eswatini', None, 2017),
#  ('Eswatini', None, 2018),
#  ('Eswatini', None, 2019),
#  ('Eswatini', None, 2020),
#  ('Ethiopia', None, 2015),
#  ('Ethiopia', None, 2016),
#  ('Ethiopia', None, 2017),
#  ('Ethiopia', None, 2018),
#  ('Ethiopia', None, 2019),
#  ('Ethiopia', None, 2020),
#  ('Gabon', None, 2015),
#  ('Gabon', None, 2016),
#  ('Gabon', None, 2017),
#  ('Gabon', None, 2018),
#  ('Gabon', None, 2019),
#  ('Gabon', None, 2020),
#  ('Gambia', None, 2015),
#  ('Gambia', None, 2016),
#  ('Gambia', None, 2017),
#  ('Gambia', None, 2018),
#  ('Gambia', None, 2019),
#  ('Gambia', None, 2020),
#  ('Ghana', Decimal('6.81'), 2015),
#  ('Ghana', None, 2016),
#  ('Ghana', Decimal('3.37'), 2017),
#  ('Ghana', None, 2018),
#  ('Ghana', None, 2019),
#  ('Ghana', None, 2020),
#  ('Guinea', None, 2015),
#  ('Guinea', None, 2016),
#  ('Guinea', None, 2017),
#  ('Guinea', None, 2018),
#  ('Guinea', Decimal('5.02'), 2019),
#  ('Guinea', None, 2020),
#  ('Guinea-Bissau', None, 2015),
#  ('Guinea-Bissau', None, 2016),
#  ('Guinea-Bissau', None, 2017),
#  ('Guinea-Bissau', Decimal('3.20'), 2018),
#  ('Guinea-Bissau', None, 2019),
#  ('Guinea-Bissau', None, 2020),
#  ('Kenya', None, 2015),
#  ('Kenya', Decimal('2.76'), 2016),
#  ('Kenya', None, 2017),
#  ('Kenya', None, 2018),
#  ('Kenya', Decimal('5.01'), 2019),
#  ('Kenya', None, 2020),
#  ('Lesotho', None, 2015),
#  ('Lesotho', None, 2016),
#  ('Lesotho', None, 2017),
#  ('Lesotho', None, 2018),
#  ('Lesotho', Decimal('16.88'), 2019),
#  ('Lesotho', None, 2020),
#  ('Liberia', None, 2015),
#  ('Liberia', Decimal('3.08'), 2016),
#  ('Liberia', Decimal('5.95'), 2017),
#  ('Liberia', None, 2018),
#  ('Liberia', None, 2019),
#  ('Liberia', None, 2020),
#  ('Madagascar', Decimal('1.79'), 2015),
#  ('Madagascar', None, 2016),
#  ('Madagascar', None, 2017),
#  ('Madagascar', None, 2018),
#  ('Madagascar', None, 2019),
#  ('Madagascar', None, 2020),
#  ('Malawi', None, 2015),
#  ('Malawi', None, 2016),
#  ('Malawi', Decimal('3.54'), 2017),
#  ('Malawi', None, 2018),
#  ('Malawi', None, 2019),
#  ('Malawi', Decimal('0.91'), 2020),
#  ('Mali', Decimal('7.73'), 2015),
#  ('Mali', Decimal('1.37'), 2016),
#  ('Mali', Decimal('7.41'), 2017),
#  ('Mali', Decimal('1.62'), 2018),
#  ('Mali', None, 2019),
#  ('Mali', Decimal('3.53'), 2020),
#  ('Mauritania', None, 2015),
#  ('Mauritania', None, 2016),
#  ('Mauritania', Decimal('10.34'), 2017),
#  ('Mauritania', None, 2018),
#  ('Mauritania', Decimal('10.42'), 2019),
#  ('Mauritania', None, 2020),
#  ('Mauritius', Decimal('7.41'), 2015),
#  ('Mauritius', Decimal('6.81'), 2016),
#  ('Mauritius', Decimal('6.75'), 2017),
#  ('Mauritius', Decimal('6.43'), 2018),
#  ('Mauritius', Decimal('6.33'), 2019),
#  ('Mauritius', Decimal('8.63'), 2020),
#  ('Mayotte', None, 2015),
#  ('Mayotte', None, 2016),
#  ('Mayotte', None, 2017),
#  ('Mayotte', None, 2018),
#  ('Mayotte', None, 2019),
#  ('Mayotte', None, 2020),
#  ('Mozambique', Decimal('3.43'), 2015),
#  ('Mozambique', None, 2016),
#  ('Mozambique', None, 2017),
#  ('Mozambique', None, 2018),
#  ('Mozambique', None, 2019),
#  ('Mozambique', None, 2020),
#  ('Namibia', None, 2015),
#  ('Namibia', Decimal('23.35'), 2016),
#  ('Namibia', None, 2017),
#  ('Namibia', Decimal('19.88'), 2018),
#  ('Namibia', None, 2019),
#  ('Namibia', None, 2020),
#  ('Niger', None, 2015),
#  ('Niger', None, 2016),
#  ('Niger', Decimal('7.77'), 2017),
#  ('Niger', None, 2018),
#  ('Niger', None, 2019),
#  ('Niger', None, 2020),
#  ('Nigeria', Decimal('4.31'), 2015),
#  ('Nigeria', Decimal('7.06'), 2016),
#  ('Nigeria', Decimal('8.39'), 2017),
#  ('Nigeria', None, 2018),
#  ('Nigeria', Decimal('10.70'), 2019),
#  ('Nigeria', None, 2020),
#  ('Réunion', None, 2015),
#  ('Réunion', None, 2016),
#  ('Réunion', None, 2017),
#  ('Réunion', None, 2018),
#  ('Réunion', None, 2019),
#  ('Réunion', None, 2020),
#  ('Rwanda', None, 2015),
#  ('Rwanda', None, 2016),
#  ('Rwanda', Decimal('11.88'), 2017),
#  ('Rwanda', Decimal('10.76'), 2018),
#  ('Rwanda', Decimal('11.24'), 2019),
#  ('Rwanda', Decimal('11.83'), 2020),
#  ('Saint Helena', None, 2015),
#  ('Saint Helena', None, 2016),
#  ('Saint Helena', None, 2017),
#  ('Saint Helena', None, 2018),
#  ('Saint Helena', None, 2019),
#  ('Saint Helena', None, 2020),
#  ('Sao Tome and Principe', None, 2015),
#  ('Sao Tome and Principe', None, 2016),
#  ('Sao Tome and Principe', None, 2017),
#  ('Sao Tome and Principe', None, 2018),
#  ('Sao Tome and Principe', None, 2019),
#  ('Sao Tome and Principe', None, 2020),
#  ('Senegal', Decimal('6.76'), 2015),
#  ('Senegal', Decimal('4.46'), 2016),
#  ('Senegal', Decimal('4.08'), 2017),
#  ('Senegal', Decimal('3.57'), 2018),
#  ('Senegal', Decimal('2.86'), 2019),
#  ('Senegal', None, 2020),
#  ('Seychelles', Decimal('4.15'), 2015),
#  ('Seychelles', Decimal('3.96'), 2016),
#  ('Seychelles', Decimal('3.71'), 2017),
#  ('Seychelles', Decimal('3.53'), 2018),
#  ('Seychelles', Decimal('2.97'), 2019),
#  ('Sierra Leone', None, 2015),
#  ('Sierra Leone', None, 2016),
#  ('Sierra Leone', None, 2017),
#  ('Sierra Leone', Decimal('3.19'), 2018),
#  ('Sierra Leone', None, 2019),
#  ('Sierra Leone', None, 2020),
#  ('Somalia', None, 2015),
#  ('Somalia', None, 2016),
#  ('Somalia', None, 2017),
#  ('Somalia', None, 2018),
#  ('Somalia', Decimal('18.83'), 2019),
#  ('Somalia', None, 2020),
#  ('South Africa', Decimal('22.87'), 2015),
#  ('South Africa', Decimal('24.02'), 2016),
#  ('South Africa', Decimal('23.99'), 2017),
#  ('South Africa', Decimal('24.22'), 2018),
#  ('South Africa', Decimal('25.54'), 2019),
#  ('South Africa', Decimal('24.34'), 2020),
#  ('South Sudan', None, 2015),
#  ('South Sudan', None, 2016),
#  ('South Sudan', None, 2017),
#  ('South Sudan', None, 2018),
#  ('South Sudan', None, 2019),
#  ('South Sudan', None, 2020),
#  ('Togo', Decimal('2.20'), 2015),
#  ('Togo', None, 2016),
#  ('Togo', Decimal('3.74'), 2017),
#  ('Togo', None, 2018),
#  ('Togo', None, 2019),
#  ('Togo', None, 2020),
#  ('Uganda', None, 2015),
#  ('Uganda', None, 2016),
#  ('Uganda', Decimal('3.64'), 2017),
#  ('Uganda', None, 2018),
#  ('Uganda', None, 2019),
#  ('Uganda', None, 2020),
#  ('United Republic of Tanzania', None, 2015),
#  ('United Republic of Tanzania', None, 2016),
#  ('United Republic of Tanzania', None, 2017),
#  ('United Republic of Tanzania', None, 2018),
#  ('United Republic of Tanzania', None, 2019),
#  ('United Republic of Tanzania', None, 2020),
#  ('Zambia', None, 2015),
#  ('Zambia', None, 2016),
#  ('Zambia', Decimal('8.52'), 2017),
#  ('Zambia', Decimal('5.03'), 2018),
#  ('Zambia', Decimal('5.54'), 2019),
#  ('Zambia', Decimal('6.03'), 2020),
#  ('Zimbabwe', None, 2015),
#  ('Zimbabwe', None, 2016),
#  ('Zimbabwe', None, 2017),
#  ('Zimbabwe', None, 2018),
#  ('Zimbabwe', Decimal('7.37'), 2019),
#  ('Zimbabwe', None, 2020)]

# %% [markdown]
# ### Task 3
#
# After filtering, we will notice that there are Null values in the `Pct_unemployment` column. Fill in the Null values with 33.65. Rename the imputed column, `Pct_unemployment_imputed`.

# %%
# %%sql
# # Add your code here
# SELECT
#     E.Country_name,
#     IFNULL(Pct_unemployment,33.65) AS Pct_unemployment_imputed,
#     time_period
# FROM
#     Economic_Indicators E
# INNER JOIN
#     Geographic_Location G
# ON
#     E.Country_name = G.Country_name
# WHERE
#     region = 'Sub-Saharan Africa'
# Out:
#  * mysql+pymysql://root:***@localhost:3306/united_nations
# 297 rows affected.
# [('Angola', Decimal('33.65'), 2015),
#  ('Angola', Decimal('33.65'), 2016),
#  ('Angola', Decimal('33.65'), 2017),
#  ('Angola', Decimal('33.65'), 2018),
#  ('Angola', Decimal('16.50'), 2019),
#  ('Angola', Decimal('33.65'), 2020),
#  ('Benin', Decimal('33.65'), 2015),
#  ('Benin', Decimal('33.65'), 2016),
#  ('Benin', Decimal('33.65'), 2017),
#  ('Benin', Decimal('1.47'), 2018),
#  ('Benin', Decimal('33.65'), 2019),
#  ('Benin', Decimal('33.65'), 2020),
#  ('Botswana', Decimal('33.65'), 2015),
#  ('Botswana', Decimal('33.65'), 2016),
#  ('Botswana', Decimal('33.65'), 2017),
#  ('Botswana', Decimal('33.65'), 2018),
#  ('Botswana', Decimal('20.09'), 2019),
#  ('Botswana', Decimal('21.02'), 2020),
#  ('Burkina Faso', Decimal('33.65'), 2015),
#  ('Burkina Faso', Decimal('33.65'), 2016),
#  ('Burkina Faso', Decimal('33.65'), 2017),
#  ('Burkina Faso', Decimal('4.69'), 2018),
#  ('Burkina Faso', Decimal('33.65'), 2019),
#  ('Burkina Faso', Decimal('33.65'), 2020),
#  ('Burundi', Decimal('33.65'), 2015),
#  ('Burundi', Decimal('33.65'), 2016),
#  ('Burundi', Decimal('33.65'), 2017),
#  ('Burundi', Decimal('33.65'), 2018),
#  ('Burundi', Decimal('33.65'), 2019),
#  ('Burundi', Decimal('1.03'), 2020),
#  ('Cabo Verde', Decimal('31.31'), 2015),
#  ('Cabo Verde', Decimal('33.65'), 2016),
#  ('Cabo Verde', Decimal('12.24'), 2017),
#  ('Cabo Verde', Decimal('12.17'), 2018),
#  ('Cabo Verde', Decimal('11.29'), 2019),
#  ('Cabo Verde', Decimal('33.65'), 2020),
#  ('Cameroon', Decimal('33.65'), 2015),
#  ('Cameroon', Decimal('33.65'), 2016),
#  ('Cameroon', Decimal('33.65'), 2017),
#  ('Cameroon', Decimal('33.65'), 2018),
#  ('Cameroon', Decimal('33.65'), 2019),
#  ('Cameroon', Decimal('33.65'), 2020),
#  ('Central African Republic', Decimal('33.65'), 2015),
#  ('Central African Republic', Decimal('33.65'), 2016),
#  ('Central African Republic', Decimal('33.65'), 2017),
#  ('Central African Republic', Decimal('33.65'), 2018),
#  ('Central African Republic', Decimal('33.65'), 2019),
#  ('Central African Republic', Decimal('33.65'), 2020),
#  ('Chad', Decimal('33.65'), 2015),
#  ('Chad', Decimal('33.65'), 2016),
#  ('Chad', Decimal('33.65'), 2017),
#  ('Chad', Decimal('1.13'), 2018),
#  ('Chad', Decimal('33.65'), 2019),
#  ('Chad', Decimal('33.65'), 2020),
#  ('Comoros', Decimal('33.65'), 2015),
#  ('Comoros', Decimal('33.65'), 2016),
#  ('Comoros', Decimal('33.65'), 2017),
#  ('Comoros', Decimal('33.65'), 2018),
#  ('Comoros', Decimal('33.65'), 2019),
#  ('Congo', Decimal('33.65'), 2015),
#  ('Congo', Decimal('33.65'), 2016),
#  ('Congo', Decimal('33.65'), 2017),
#  ('Congo', Decimal('33.65'), 2018),
#  ('Congo', Decimal('33.65'), 2019),
#  ('Congo', Decimal('33.65'), 2020),
#  ("Côte d'Ivoire", Decimal('33.65'), 2015),
#  ("Côte d'Ivoire", Decimal('33.65'), 2016),
#  ("Côte d'Ivoire", Decimal('33.65'), 2017),
#  ("Côte d'Ivoire", Decimal('33.65'), 2018),
#  ("Côte d'Ivoire", Decimal('33.65'), 2019),
#  ("Côte d'Ivoire", Decimal('33.65'), 2020),
#  ('Democratic Republic of the Congo', Decimal('33.65'), 2015),
#  ('Democratic Republic of the Congo', Decimal('33.65'), 2016),
#  ('Democratic Republic of the Congo', Decimal('33.65'), 2017),
#  ('Democratic Republic of the Congo', Decimal('33.65'), 2018),
#  ('Democratic Republic of the Congo', Decimal('33.65'), 2019),
#  ('Democratic Republic of the Congo', Decimal('33.65'), 2020),
#  ('Djibouti', Decimal('33.65'), 2015),
#  ('Djibouti', Decimal('33.65'), 2016),
#  ('Djibouti', Decimal('26.06'), 2017),
#  ('Djibouti', Decimal('33.65'), 2018),
#  ('Djibouti', Decimal('33.65'), 2019),
#  ('Djibouti', Decimal('33.65'), 2020),
#  ('Equatorial Guinea', Decimal('33.65'), 2015),
#  ('Equatorial Guinea', Decimal('33.65'), 2016),
#  ('Equatorial Guinea', Decimal('33.65'), 2017),
#  ('Eritrea', Decimal('33.65'), 2015),
#  ('Eritrea', Decimal('33.65'), 2016),
#  ('Eswatini', Decimal('33.65'), 2015),
#  ('Eswatini', Decimal('22.72'), 2016),
#  ('Eswatini', Decimal('33.65'), 2017),
#  ('Eswatini', Decimal('33.65'), 2018),
#  ('Eswatini', Decimal('33.65'), 2019),
#  ('Eswatini', Decimal('33.65'), 2020),
#  ('Ethiopia', Decimal('33.65'), 2015),
#  ('Ethiopia', Decimal('33.65'), 2016),
#  ('Ethiopia', Decimal('33.65'), 2017),
#  ('Ethiopia', Decimal('33.65'), 2018),
#  ('Ethiopia', Decimal('33.65'), 2019),
#  ('Ethiopia', Decimal('33.65'), 2020),
#  ('Gabon', Decimal('33.65'), 2015),
#  ('Gabon', Decimal('33.65'), 2016),
#  ('Gabon', Decimal('33.65'), 2017),
#  ('Gabon', Decimal('33.65'), 2018),
#  ('Gabon', Decimal('33.65'), 2019),
#  ('Gabon', Decimal('33.65'), 2020),
#  ('Gambia', Decimal('33.65'), 2015),
#  ('Gambia', Decimal('33.65'), 2016),
#  ('Gambia', Decimal('33.65'), 2017),
#  ('Gambia', Decimal('33.65'), 2018),
#  ('Gambia', Decimal('33.65'), 2019),
#  ('Gambia', Decimal('33.65'), 2020),
#  ('Ghana', Decimal('6.81'), 2015),
#  ('Ghana', Decimal('33.65'), 2016),
#  ('Ghana', Decimal('3.37'), 2017),
#  ('Ghana', Decimal('33.65'), 2018),
#  ('Ghana', Decimal('33.65'), 2019),
#  ('Ghana', Decimal('33.65'), 2020),
#  ('Guinea', Decimal('33.65'), 2015),
#  ('Guinea', Decimal('33.65'), 2016),
#  ('Guinea', Decimal('33.65'), 2017),
#  ('Guinea', Decimal('33.65'), 2018),
#  ('Guinea', Decimal('5.02'), 2019),
#  ('Guinea', Decimal('33.65'), 2020),
#  ('Guinea-Bissau', Decimal('33.65'), 2015),
#  ('Guinea-Bissau', Decimal('33.65'), 2016),
#  ('Guinea-Bissau', Decimal('33.65'), 2017),
#  ('Guinea-Bissau', Decimal('3.20'), 2018),
#  ('Guinea-Bissau', Decimal('33.65'), 2019),
#  ('Guinea-Bissau', Decimal('33.65'), 2020),
#  ('Kenya', Decimal('33.65'), 2015),
#  ('Kenya', Decimal('2.76'), 2016),
#  ('Kenya', Decimal('33.65'), 2017),
#  ('Kenya', Decimal('33.65'), 2018),
#  ('Kenya', Decimal('5.01'), 2019),
#  ('Kenya', Decimal('33.65'), 2020),
#  ('Lesotho', Decimal('33.65'), 2015),
#  ('Lesotho', Decimal('33.65'), 2016),
#  ('Lesotho', Decimal('33.65'), 2017),
#  ('Lesotho', Decimal('33.65'), 2018),
#  ('Lesotho', Decimal('16.88'), 2019),
#  ('Lesotho', Decimal('33.65'), 2020),
#  ('Liberia', Decimal('33.65'), 2015),
#  ('Liberia', Decimal('3.08'), 2016),
#  ('Liberia', Decimal('5.95'), 2017),
#  ('Liberia', Decimal('33.65'), 2018),
#  ('Liberia', Decimal('33.65'), 2019),
#  ('Liberia', Decimal('33.65'), 2020),
#  ('Madagascar', Decimal('1.79'), 2015),
#  ('Madagascar', Decimal('33.65'), 2016),
#  ('Madagascar', Decimal('33.65'), 2017),
#  ('Madagascar', Decimal('33.65'), 2018),
#  ('Madagascar', Decimal('33.65'), 2019),
#  ('Madagascar', Decimal('33.65'), 2020),
#  ('Malawi', Decimal('33.65'), 2015),
#  ('Malawi', Decimal('33.65'), 2016),
#  ('Malawi', Decimal('3.54'), 2017),
#  ('Malawi', Decimal('33.65'), 2018),
#  ('Malawi', Decimal('33.65'), 2019),
#  ('Malawi', Decimal('0.91'), 2020),
#  ('Mali', Decimal('7.73'), 2015),
#  ('Mali', Decimal('1.37'), 2016),
#  ('Mali', Decimal('7.41'), 2017),
#  ('Mali', Decimal('1.62'), 2018),
#  ('Mali', Decimal('33.65'), 2019),
#  ('Mali', Decimal('3.53'), 2020),
#  ('Mauritania', Decimal('33.65'), 2015),
#  ('Mauritania', Decimal('33.65'), 2016),
#  ('Mauritania', Decimal('10.34'), 2017),
#  ('Mauritania', Decimal('33.65'), 2018),
#  ('Mauritania', Decimal('10.42'), 2019),
#  ('Mauritania', Decimal('33.65'), 2020),
#  ('Mauritius', Decimal('7.41'), 2015),
#  ('Mauritius', Decimal('6.81'), 2016),
#  ('Mauritius', Decimal('6.75'), 2017),
#  ('Mauritius', Decimal('6.43'), 2018),
#  ('Mauritius', Decimal('6.33'), 2019),
#  ('Mauritius', Decimal('8.63'), 2020),
#  ('Mayotte', Decimal('33.65'), 2015),
#  ('Mayotte', Decimal('33.65'), 2016),
#  ('Mayotte', Decimal('33.65'), 2017),
#  ('Mayotte', Decimal('33.65'), 2018),
#  ('Mayotte', Decimal('33.65'), 2019),
#  ('Mayotte', Decimal('33.65'), 2020),
#  ('Mozambique', Decimal('3.43'), 2015),
#  ('Mozambique', Decimal('33.65'), 2016),
#  ('Mozambique', Decimal('33.65'), 2017),
#  ('Mozambique', Decimal('33.65'), 2018),
#  ('Mozambique', Decimal('33.65'), 2019),
#  ('Mozambique', Decimal('33.65'), 2020),
#  ('Namibia', Decimal('33.65'), 2015),
#  ('Namibia', Decimal('23.35'), 2016),
#  ('Namibia', Decimal('33.65'), 2017),
#  ('Namibia', Decimal('19.88'), 2018),
#  ('Namibia', Decimal('33.65'), 2019),
#  ('Namibia', Decimal('33.65'), 2020),
#  ('Niger', Decimal('33.65'), 2015),
#  ('Niger', Decimal('33.65'), 2016),
#  ('Niger', Decimal('7.77'), 2017),
#  ('Niger', Decimal('33.65'), 2018),
#  ('Niger', Decimal('33.65'), 2019),
#  ('Niger', Decimal('33.65'), 2020),
#  ('Nigeria', Decimal('4.31'), 2015),
#  ('Nigeria', Decimal('7.06'), 2016),
#  ('Nigeria', Decimal('8.39'), 2017),
#  ('Nigeria', Decimal('33.65'), 2018),
#  ('Nigeria', Decimal('10.70'), 2019),
#  ('Nigeria', Decimal('33.65'), 2020),
#  ('Réunion', Decimal('33.65'), 2015),
#  ('Réunion', Decimal('33.65'), 2016),
#  ('Réunion', Decimal('33.65'), 2017),
#  ('Réunion', Decimal('33.65'), 2018),
#  ('Réunion', Decimal('33.65'), 2019),
#  ('Réunion', Decimal('33.65'), 2020),
#  ('Rwanda', Decimal('33.65'), 2015),
#  ('Rwanda', Decimal('33.65'), 2016),
#  ('Rwanda', Decimal('11.88'), 2017),
#  ('Rwanda', Decimal('10.76'), 2018),
#  ('Rwanda', Decimal('11.24'), 2019),
#  ('Rwanda', Decimal('11.83'), 2020),
#  ('Saint Helena', Decimal('33.65'), 2015),
#  ('Saint Helena', Decimal('33.65'), 2016),
#  ('Saint Helena', Decimal('33.65'), 2017),
#  ('Saint Helena', Decimal('33.65'), 2018),
#  ('Saint Helena', Decimal('33.65'), 2019),
#  ('Saint Helena', Decimal('33.65'), 2020),
#  ('Sao Tome and Principe', Decimal('33.65'), 2015),
#  ('Sao Tome and Principe', Decimal('33.65'), 2016),
#  ('Sao Tome and Principe', Decimal('33.65'), 2017),
#  ('Sao Tome and Principe', Decimal('33.65'), 2018),
#  ('Sao Tome and Principe', Decimal('33.65'), 2019),
#  ('Sao Tome and Principe', Decimal('33.65'), 2020),
#  ('Senegal', Decimal('6.76'), 2015),
#  ('Senegal', Decimal('4.46'), 2016),
#  ('Senegal', Decimal('4.08'), 2017),
#  ('Senegal', Decimal('3.57'), 2018),
#  ('Senegal', Decimal('2.86'), 2019),
#  ('Senegal', Decimal('33.65'), 2020),
#  ('Seychelles', Decimal('4.15'), 2015),
#  ('Seychelles', Decimal('3.96'), 2016),
#  ('Seychelles', Decimal('3.71'), 2017),
#  ('Seychelles', Decimal('3.53'), 2018),
#  ('Seychelles', Decimal('2.97'), 2019),
#  ('Sierra Leone', Decimal('33.65'), 2015),
#  ('Sierra Leone', Decimal('33.65'), 2016),
#  ('Sierra Leone', Decimal('33.65'), 2017),
#  ('Sierra Leone', Decimal('3.19'), 2018),
#  ('Sierra Leone', Decimal('33.65'), 2019),
#  ('Sierra Leone', Decimal('33.65'), 2020),
#  ('Somalia', Decimal('33.65'), 2015),
#  ('Somalia', Decimal('33.65'), 2016),
#  ('Somalia', Decimal('33.65'), 2017),
#  ('Somalia', Decimal('33.65'), 2018),
#  ('Somalia', Decimal('18.83'), 2019),
#  ('Somalia', Decimal('33.65'), 2020),
#  ('South Africa', Decimal('22.87'), 2015),
#  ('South Africa', Decimal('24.02'), 2016),
#  ('South Africa', Decimal('23.99'), 2017),
#  ('South Africa', Decimal('24.22'), 2018),
#  ('South Africa', Decimal('25.54'), 2019),
#  ('South Africa', Decimal('24.34'), 2020),
#  ('South Sudan', Decimal('33.65'), 2015),
#  ('South Sudan', Decimal('33.65'), 2016),
#  ('South Sudan', Decimal('33.65'), 2017),
#  ('South Sudan', Decimal('33.65'), 2018),
#  ('South Sudan', Decimal('33.65'), 2019),
#  ('South Sudan', Decimal('33.65'), 2020),
#  ('Togo', Decimal('2.20'), 2015),
#  ('Togo', Decimal('33.65'), 2016),
#  ('Togo', Decimal('3.74'), 2017),
#  ('Togo', Decimal('33.65'), 2018),
#  ('Togo', Decimal('33.65'), 2019),
#  ('Togo', Decimal('33.65'), 2020),
#  ('Uganda', Decimal('33.65'), 2015),
#  ('Uganda', Decimal('33.65'), 2016),
#  ('Uganda', Decimal('3.64'), 2017),
#  ('Uganda', Decimal('33.65'), 2018),
#  ('Uganda', Decimal('33.65'), 2019),
#  ('Uganda', Decimal('33.65'), 2020),
#  ('United Republic of Tanzania', Decimal('33.65'), 2015),
#  ('United Republic of Tanzania', Decimal('33.65'), 2016),
#  ('United Republic of Tanzania', Decimal('33.65'), 2017),
#  ('United Republic of Tanzania', Decimal('33.65'), 2018),
#  ('United Republic of Tanzania', Decimal('33.65'), 2019),
#  ('United Republic of Tanzania', Decimal('33.65'), 2020),
#  ('Zambia', Decimal('33.65'), 2015),
#  ('Zambia', Decimal('33.65'), 2016),
#  ('Zambia', Decimal('8.52'), 2017),
#  ('Zambia', Decimal('5.03'), 2018),
#  ('Zambia', Decimal('5.54'), 2019),
#  ('Zambia', Decimal('6.03'), 2020),
#  ('Zimbabwe', Decimal('33.65'), 2015),
#  ('Zimbabwe', Decimal('33.65'), 2016),
#  ('Zimbabwe', Decimal('33.65'), 2017),
#  ('Zimbabwe', Decimal('33.65'), 2018),
#  ('Zimbabwe', Decimal('7.37'), 2019),
#  ('Zimbabwe', Decimal('33.65'), 2020)]

# %% [markdown]
# ### Task 4
#
# Now that we have the query constructed, let's create a VIEW of that query. Name the VIEW, `united_nations.Country_Unemployment_Rate`.

# %%
# %%sql
# # Add your code here
# CREATE VIEW united_nations.Country_Unemployment_Rate AS
# SELECT
#     E.Country_name,
#     IFNULL(Pct_unemployment,33.65) AS Pct_unemployment_imputed,
#     time_period
# FROM
#     Economic_Indicators E
# INNER JOIN
#     Geographic_Location G
# ON
#     E.Country_name = G.Country_name
# WHERE
#     region = 'Sub-Saharan Africa'
# Out:
#  * mysql+pymysql://root:***@localhost:3306/united_nations
# 0 rows affected.
# []

# %% [markdown]
# ### Task 5
#
# Finally, let's have a look at the VIEW.

# %%
# %%sql
# # Add your code here
# SELECT
#     *
# FROM
#     united_nations.Country_Unemployment_Rate
# Out:
#  * mysql+pymysql://root:***@localhost:3306/united_nations
# 297 rows affected.
# [('Angola', Decimal('33.65'), 2015),
#  ('Angola', Decimal('33.65'), 2016),
#  ('Angola', Decimal('33.65'), 2017),
#  ('Angola', Decimal('33.65'), 2018),
#  ('Angola', Decimal('16.50'), 2019),
#  ('Angola', Decimal('33.65'), 2020),
#  ('Benin', Decimal('33.65'), 2015),
#  ('Benin', Decimal('33.65'), 2016),
#  ('Benin', Decimal('33.65'), 2017),
#  ('Benin', Decimal('1.47'), 2018),
#  ('Benin', Decimal('33.65'), 2019),
#  ('Benin', Decimal('33.65'), 2020),
#  ('Botswana', Decimal('33.65'), 2015),
#  ('Botswana', Decimal('33.65'), 2016),
#  ('Botswana', Decimal('33.65'), 2017),
#  ('Botswana', Decimal('33.65'), 2018),
#  ('Botswana', Decimal('20.09'), 2019),
#  ('Botswana', Decimal('21.02'), 2020),
#  ('Burkina Faso', Decimal('33.65'), 2015),
#  ('Burkina Faso', Decimal('33.65'), 2016),
#  ('Burkina Faso', Decimal('33.65'), 2017),
#  ('Burkina Faso', Decimal('4.69'), 2018),
#  ('Burkina Faso', Decimal('33.65'), 2019),
#  ('Burkina Faso', Decimal('33.65'), 2020),
#  ('Burundi', Decimal('33.65'), 2015),
#  ('Burundi', Decimal('33.65'), 2016),
#  ('Burundi', Decimal('33.65'), 2017),
#  ('Burundi', Decimal('33.65'), 2018),
#  ('Burundi', Decimal('33.65'), 2019),
#  ('Burundi', Decimal('1.03'), 2020),
#  ('Cabo Verde', Decimal('31.31'), 2015),
#  ('Cabo Verde', Decimal('33.65'), 2016),
#  ('Cabo Verde', Decimal('12.24'), 2017),
#  ('Cabo Verde', Decimal('12.17'), 2018),
#  ('Cabo Verde', Decimal('11.29'), 2019),
#  ('Cabo Verde', Decimal('33.65'), 2020),
#  ('Cameroon', Decimal('33.65'), 2015),
#  ('Cameroon', Decimal('33.65'), 2016),
#  ('Cameroon', Decimal('33.65'), 2017),
#  ('Cameroon', Decimal('33.65'), 2018),
#  ('Cameroon', Decimal('33.65'), 2019),
#  ('Cameroon', Decimal('33.65'), 2020),
#  ('Central African Republic', Decimal('33.65'), 2015),
#  ('Central African Republic', Decimal('33.65'), 2016),
#  ('Central African Republic', Decimal('33.65'), 2017),
#  ('Central African Republic', Decimal('33.65'), 2018),
#  ('Central African Republic', Decimal('33.65'), 2019),
#  ('Central African Republic', Decimal('33.65'), 2020),
#  ('Chad', Decimal('33.65'), 2015),
#  ('Chad', Decimal('33.65'), 2016),
#  ('Chad', Decimal('33.65'), 2017),
#  ('Chad', Decimal('1.13'), 2018),
#  ('Chad', Decimal('33.65'), 2019),
#  ('Chad', Decimal('33.65'), 2020),
#  ('Comoros', Decimal('33.65'), 2015),
#  ('Comoros', Decimal('33.65'), 2016),
#  ('Comoros', Decimal('33.65'), 2017),
#  ('Comoros', Decimal('33.65'), 2018),
#  ('Comoros', Decimal('33.65'), 2019),
#  ('Congo', Decimal('33.65'), 2015),
#  ('Congo', Decimal('33.65'), 2016),
#  ('Congo', Decimal('33.65'), 2017),
#  ('Congo', Decimal('33.65'), 2018),
#  ('Congo', Decimal('33.65'), 2019),
#  ('Congo', Decimal('33.65'), 2020),
#  ("Côte d'Ivoire", Decimal('33.65'), 2015),
#  ("Côte d'Ivoire", Decimal('33.65'), 2016),
#  ("Côte d'Ivoire", Decimal('33.65'), 2017),
#  ("Côte d'Ivoire", Decimal('33.65'), 2018),
#  ("Côte d'Ivoire", Decimal('33.65'), 2019),
#  ("Côte d'Ivoire", Decimal('33.65'), 2020),
#  ('Democratic Republic of the Congo', Decimal('33.65'), 2015),
#  ('Democratic Republic of the Congo', Decimal('33.65'), 2016),
#  ('Democratic Republic of the Congo', Decimal('33.65'), 2017),
#  ('Democratic Republic of the Congo', Decimal('33.65'), 2018),
#  ('Democratic Republic of the Congo', Decimal('33.65'), 2019),
#  ('Democratic Republic of the Congo', Decimal('33.65'), 2020),
#  ('Djibouti', Decimal('33.65'), 2015),
#  ('Djibouti', Decimal('33.65'), 2016),
#  ('Djibouti', Decimal('26.06'), 2017),
#  ('Djibouti', Decimal('33.65'), 2018),
#  ('Djibouti', Decimal('33.65'), 2019),
#  ('Djibouti', Decimal('33.65'), 2020),
#  ('Equatorial Guinea', Decimal('33.65'), 2015),
#  ('Equatorial Guinea', Decimal('33.65'), 2016),
#  ('Equatorial Guinea', Decimal('33.65'), 2017),
#  ('Eritrea', Decimal('33.65'), 2015),
#  ('Eritrea', Decimal('33.65'), 2016),
#  ('Eswatini', Decimal('33.65'), 2015),
#  ('Eswatini', Decimal('22.72'), 2016),
#  ('Eswatini', Decimal('33.65'), 2017),
#  ('Eswatini', Decimal('33.65'), 2018),
#  ('Eswatini', Decimal('33.65'), 2019),
#  ('Eswatini', Decimal('33.65'), 2020),
#  ('Ethiopia', Decimal('33.65'), 2015),
#  ('Ethiopia', Decimal('33.65'), 2016),
#  ('Ethiopia', Decimal('33.65'), 2017),
#  ('Ethiopia', Decimal('33.65'), 2018),
#  ('Ethiopia', Decimal('33.65'), 2019),
#  ('Ethiopia', Decimal('33.65'), 2020),
#  ('Gabon', Decimal('33.65'), 2015),
#  ('Gabon', Decimal('33.65'), 2016),
#  ('Gabon', Decimal('33.65'), 2017),
#  ('Gabon', Decimal('33.65'), 2018),
#  ('Gabon', Decimal('33.65'), 2019),
#  ('Gabon', Decimal('33.65'), 2020),
#  ('Gambia', Decimal('33.65'), 2015),
#  ('Gambia', Decimal('33.65'), 2016),
#  ('Gambia', Decimal('33.65'), 2017),
#  ('Gambia', Decimal('33.65'), 2018),
#  ('Gambia', Decimal('33.65'), 2019),
#  ('Gambia', Decimal('33.65'), 2020),
#  ('Ghana', Decimal('6.81'), 2015),
#  ('Ghana', Decimal('33.65'), 2016),
#  ('Ghana', Decimal('3.37'), 2017),
#  ('Ghana', Decimal('33.65'), 2018),
#  ('Ghana', Decimal('33.65'), 2019),
#  ('Ghana', Decimal('33.65'), 2020),
#  ('Guinea', Decimal('33.65'), 2015),
#  ('Guinea', Decimal('33.65'), 2016),
#  ('Guinea', Decimal('33.65'), 2017),
#  ('Guinea', Decimal('33.65'), 2018),
#  ('Guinea', Decimal('5.02'), 2019),
#  ('Guinea', Decimal('33.65'), 2020),
#  ('Guinea-Bissau', Decimal('33.65'), 2015),
#  ('Guinea-Bissau', Decimal('33.65'), 2016),
#  ('Guinea-Bissau', Decimal('33.65'), 2017),
#  ('Guinea-Bissau', Decimal('3.20'), 2018),
#  ('Guinea-Bissau', Decimal('33.65'), 2019),
#  ('Guinea-Bissau', Decimal('33.65'), 2020),
#  ('Kenya', Decimal('33.65'), 2015),
#  ('Kenya', Decimal('2.76'), 2016),
#  ('Kenya', Decimal('33.65'), 2017),
#  ('Kenya', Decimal('33.65'), 2018),
#  ('Kenya', Decimal('5.01'), 2019),
#  ('Kenya', Decimal('33.65'), 2020),
#  ('Lesotho', Decimal('33.65'), 2015),
#  ('Lesotho', Decimal('33.65'), 2016),
#  ('Lesotho', Decimal('33.65'), 2017),
#  ('Lesotho', Decimal('33.65'), 2018),
#  ('Lesotho', Decimal('16.88'), 2019),
#  ('Lesotho', Decimal('33.65'), 2020),
#  ('Liberia', Decimal('33.65'), 2015),
#  ('Liberia', Decimal('3.08'), 2016),
#  ('Liberia', Decimal('5.95'), 2017),
#  ('Liberia', Decimal('33.65'), 2018),
#  ('Liberia', Decimal('33.65'), 2019),
#  ('Liberia', Decimal('33.65'), 2020),
#  ('Madagascar', Decimal('1.79'), 2015),
#  ('Madagascar', Decimal('33.65'), 2016),
#  ('Madagascar', Decimal('33.65'), 2017),
#  ('Madagascar', Decimal('33.65'), 2018),
#  ('Madagascar', Decimal('33.65'), 2019),
#  ('Madagascar', Decimal('33.65'), 2020),
#  ('Malawi', Decimal('33.65'), 2015),
#  ('Malawi', Decimal('33.65'), 2016),
#  ('Malawi', Decimal('3.54'), 2017),
#  ('Malawi', Decimal('33.65'), 2018),
#  ('Malawi', Decimal('33.65'), 2019),
#  ('Malawi', Decimal('0.91'), 2020),
#  ('Mali', Decimal('7.73'), 2015),
#  ('Mali', Decimal('1.37'), 2016),
#  ('Mali', Decimal('7.41'), 2017),
#  ('Mali', Decimal('1.62'), 2018),
#  ('Mali', Decimal('33.65'), 2019),
#  ('Mali', Decimal('3.53'), 2020),
#  ('Mauritania', Decimal('33.65'), 2015),
#  ('Mauritania', Decimal('33.65'), 2016),
#  ('Mauritania', Decimal('10.34'), 2017),
#  ('Mauritania', Decimal('33.65'), 2018),
#  ('Mauritania', Decimal('10.42'), 2019),
#  ('Mauritania', Decimal('33.65'), 2020),
#  ('Mauritius', Decimal('7.41'), 2015),
#  ('Mauritius', Decimal('6.81'), 2016),
#  ('Mauritius', Decimal('6.75'), 2017),
#  ('Mauritius', Decimal('6.43'), 2018),
#  ('Mauritius', Decimal('6.33'), 2019),
#  ('Mauritius', Decimal('8.63'), 2020),
#  ('Mayotte', Decimal('33.65'), 2015),
#  ('Mayotte', Decimal('33.65'), 2016),
#  ('Mayotte', Decimal('33.65'), 2017),
#  ('Mayotte', Decimal('33.65'), 2018),
#  ('Mayotte', Decimal('33.65'), 2019),
#  ('Mayotte', Decimal('33.65'), 2020),
#  ('Mozambique', Decimal('3.43'), 2015),
#  ('Mozambique', Decimal('33.65'), 2016),
#  ('Mozambique', Decimal('33.65'), 2017),
#  ('Mozambique', Decimal('33.65'), 2018),
#  ('Mozambique', Decimal('33.65'), 2019),
#  ('Mozambique', Decimal('33.65'), 2020),
#  ('Namibia', Decimal('33.65'), 2015),
#  ('Namibia', Decimal('23.35'), 2016),
#  ('Namibia', Decimal('33.65'), 2017),
#  ('Namibia', Decimal('19.88'), 2018),
#  ('Namibia', Decimal('33.65'), 2019),
#  ('Namibia', Decimal('33.65'), 2020),
#  ('Niger', Decimal('33.65'), 2015),
#  ('Niger', Decimal('33.65'), 2016),
#  ('Niger', Decimal('7.77'), 2017),
#  ('Niger', Decimal('33.65'), 2018),
#  ('Niger', Decimal('33.65'), 2019),
#  ('Niger', Decimal('33.65'), 2020),
#  ('Nigeria', Decimal('4.31'), 2015),
#  ('Nigeria', Decimal('7.06'), 2016),
#  ('Nigeria', Decimal('8.39'), 2017),
#  ('Nigeria', Decimal('33.65'), 2018),
#  ('Nigeria', Decimal('10.70'), 2019),
#  ('Nigeria', Decimal('33.65'), 2020),
#  ('Réunion', Decimal('33.65'), 2015),
#  ('Réunion', Decimal('33.65'), 2016),
#  ('Réunion', Decimal('33.65'), 2017),
#  ('Réunion', Decimal('33.65'), 2018),
#  ('Réunion', Decimal('33.65'), 2019),
#  ('Réunion', Decimal('33.65'), 2020),
#  ('Rwanda', Decimal('33.65'), 2015),
#  ('Rwanda', Decimal('33.65'), 2016),
#  ('Rwanda', Decimal('11.88'), 2017),
#  ('Rwanda', Decimal('10.76'), 2018),
#  ('Rwanda', Decimal('11.24'), 2019),
#  ('Rwanda', Decimal('11.83'), 2020),
#  ('Saint Helena', Decimal('33.65'), 2015),
#  ('Saint Helena', Decimal('33.65'), 2016),
#  ('Saint Helena', Decimal('33.65'), 2017),
#  ('Saint Helena', Decimal('33.65'), 2018),
#  ('Saint Helena', Decimal('33.65'), 2019),
#  ('Saint Helena', Decimal('33.65'), 2020),
#  ('Sao Tome and Principe', Decimal('33.65'), 2015),
#  ('Sao Tome and Principe', Decimal('33.65'), 2016),
#  ('Sao Tome and Principe', Decimal('33.65'), 2017),
#  ('Sao Tome and Principe', Decimal('33.65'), 2018),
#  ('Sao Tome and Principe', Decimal('33.65'), 2019),
#  ('Sao Tome and Principe', Decimal('33.65'), 2020),
#  ('Senegal', Decimal('6.76'), 2015),
#  ('Senegal', Decimal('4.46'), 2016),
#  ('Senegal', Decimal('4.08'), 2017),
#  ('Senegal', Decimal('3.57'), 2018),
#  ('Senegal', Decimal('2.86'), 2019),
#  ('Senegal', Decimal('33.65'), 2020),
#  ('Seychelles', Decimal('4.15'), 2015),
#  ('Seychelles', Decimal('3.96'), 2016),
#  ('Seychelles', Decimal('3.71'), 2017),
#  ('Seychelles', Decimal('3.53'), 2018),
#  ('Seychelles', Decimal('2.97'), 2019),
#  ('Sierra Leone', Decimal('33.65'), 2015),
#  ('Sierra Leone', Decimal('33.65'), 2016),
#  ('Sierra Leone', Decimal('33.65'), 2017),
#  ('Sierra Leone', Decimal('3.19'), 2018),
#  ('Sierra Leone', Decimal('33.65'), 2019),
#  ('Sierra Leone', Decimal('33.65'), 2020),
#  ('Somalia', Decimal('33.65'), 2015),
#  ('Somalia', Decimal('33.65'), 2016),
#  ('Somalia', Decimal('33.65'), 2017),
#  ('Somalia', Decimal('33.65'), 2018),
#  ('Somalia', Decimal('18.83'), 2019),
#  ('Somalia', Decimal('33.65'), 2020),
#  ('South Africa', Decimal('22.87'), 2015),
#  ('South Africa', Decimal('24.02'), 2016),
#  ('South Africa', Decimal('23.99'), 2017),
#  ('South Africa', Decimal('24.22'), 2018),
#  ('South Africa', Decimal('25.54'), 2019),
#  ('South Africa', Decimal('24.34'), 2020),
#  ('South Sudan', Decimal('33.65'), 2015),
#  ('South Sudan', Decimal('33.65'), 2016),
#  ('South Sudan', Decimal('33.65'), 2017),
#  ('South Sudan', Decimal('33.65'), 2018),
#  ('South Sudan', Decimal('33.65'), 2019),
#  ('South Sudan', Decimal('33.65'), 2020),
#  ('Togo', Decimal('2.20'), 2015),
#  ('Togo', Decimal('33.65'), 2016),
#  ('Togo', Decimal('3.74'), 2017),
#  ('Togo', Decimal('33.65'), 2018),
#  ('Togo', Decimal('33.65'), 2019),
#  ('Togo', Decimal('33.65'), 2020),
#  ('Uganda', Decimal('33.65'), 2015),
#  ('Uganda', Decimal('33.65'), 2016),
#  ('Uganda', Decimal('3.64'), 2017),
#  ('Uganda', Decimal('33.65'), 2018),
#  ('Uganda', Decimal('33.65'), 2019),
#  ('Uganda', Decimal('33.65'), 2020),
#  ('United Republic of Tanzania', Decimal('33.65'), 2015),
#  ('United Republic of Tanzania', Decimal('33.65'), 2016),
#  ('United Republic of Tanzania', Decimal('33.65'), 2017),
#  ('United Republic of Tanzania', Decimal('33.65'), 2018),
#  ('United Republic of Tanzania', Decimal('33.65'), 2019),
#  ('United Republic of Tanzania', Decimal('33.65'), 2020),
#  ('Zambia', Decimal('33.65'), 2015),
#  ('Zambia', Decimal('33.65'), 2016),
#  ('Zambia', Decimal('8.52'), 2017),
#  ('Zambia', Decimal('5.03'), 2018),
#  ('Zambia', Decimal('5.54'), 2019),
#  ('Zambia', Decimal('6.03'), 2020),
#  ('Zimbabwe', Decimal('33.65'), 2015),
#  ('Zimbabwe', Decimal('33.65'), 2016),
#  ('Zimbabwe', Decimal('33.65'), 2017),
#  ('Zimbabwe', Decimal('33.65'), 2018),
#  ('Zimbabwe', Decimal('7.37'), 2019),
#  ('Zimbabwe', Decimal('33.65'), 2020)]

# %% [markdown]
# ## Solutions

# %% [markdown]
# ### Task 1

# %%
# %%sql
#
# SELECT
#     loc.Country_name,
#     eco.Time_period,
#     eco.Pct_unemployment
# FROM
#     united_nations.Geographic_Location as loc
# LEFT JOIN united_nations.Economic_Indicators as eco
# ON eco.Country_name = loc.Country_name;
#
# # Use LIMIT if you think the results set will be too large

# %% [markdown]
# ### Task 2

# %%
# %%sql
#
# SELECT
#     loc.Country_name,
#     eco.Time_period,
#     eco.Pct_unemployment
# FROM
#     united_nations.Geographic_Location as loc
# LEFT JOIN united_nations.Economic_Indicators as eco
# ON eco.Country_name = loc.Country_name
# WHERE REGION = 'Sub-Saharan Africa';
# Out:
#  * mysql+pymysql://root:***@localhost:3306/united_nations
# 297 rows affected.
# [('Angola', 2015, None),
#  ('Angola', 2016, None),
#  ('Angola', 2017, None),
#  ('Angola', 2018, None),
#  ('Angola', 2019, Decimal('16.50')),
#  ('Angola', 2020, None),
#  ('Benin', 2015, None),
#  ('Benin', 2016, None),
#  ('Benin', 2017, None),
#  ('Benin', 2018, Decimal('1.47')),
#  ('Benin', 2019, None),
#  ('Benin', 2020, None),
#  ('Botswana', 2015, None),
#  ('Botswana', 2016, None),
#  ('Botswana', 2017, None),
#  ('Botswana', 2018, None),
#  ('Botswana', 2019, Decimal('20.09')),
#  ('Botswana', 2020, Decimal('21.02')),
#  ('Burkina Faso', 2015, None),
#  ('Burkina Faso', 2016, None),
#  ('Burkina Faso', 2017, None),
#  ('Burkina Faso', 2018, Decimal('4.69')),
#  ('Burkina Faso', 2019, None),
#  ('Burkina Faso', 2020, None),
#  ('Burundi', 2015, None),
#  ('Burundi', 2016, None),
#  ('Burundi', 2017, None),
#  ('Burundi', 2018, None),
#  ('Burundi', 2019, None),
#  ('Burundi', 2020, Decimal('1.03')),
#  ('Cabo Verde', 2015, Decimal('31.31')),
#  ('Cabo Verde', 2016, None),
#  ('Cabo Verde', 2017, Decimal('12.24')),
#  ('Cabo Verde', 2018, Decimal('12.17')),
#  ('Cabo Verde', 2019, Decimal('11.29')),
#  ('Cabo Verde', 2020, None),
#  ('Cameroon', 2015, None),
#  ('Cameroon', 2016, None),
#  ('Cameroon', 2017, None),
#  ('Cameroon', 2018, None),
#  ('Cameroon', 2019, None),
#  ('Cameroon', 2020, None),
#  ('Central African Republic', 2015, None),
#  ('Central African Republic', 2016, None),
#  ('Central African Republic', 2017, None),
#  ('Central African Republic', 2018, None),
#  ('Central African Republic', 2019, None),
#  ('Central African Republic', 2020, None),
#  ('Chad', 2015, None),
#  ('Chad', 2016, None),
#  ('Chad', 2017, None),
#  ('Chad', 2018, Decimal('1.13')),
#  ('Chad', 2019, None),
#  ('Chad', 2020, None),
#  ('Comoros', 2015, None),
#  ('Comoros', 2016, None),
#  ('Comoros', 2017, None),
#  ('Comoros', 2018, None),
#  ('Comoros', 2019, None),
#  ('Congo', 2015, None),
#  ('Congo', 2016, None),
#  ('Congo', 2017, None),
#  ('Congo', 2018, None),
#  ('Congo', 2019, None),
#  ('Congo', 2020, None),
#  ("Côte d'Ivoire", 2015, None),
#  ("Côte d'Ivoire", 2016, None),
#  ("Côte d'Ivoire", 2017, None),
#  ("Côte d'Ivoire", 2018, None),
#  ("Côte d'Ivoire", 2019, None),
#  ("Côte d'Ivoire", 2020, None),
#  ('Democratic Republic of the Congo', 2015, None),
#  ('Democratic Republic of the Congo', 2016, None),
#  ('Democratic Republic of the Congo', 2017, None),
#  ('Democratic Republic of the Congo', 2018, None),
#  ('Democratic Republic of the Congo', 2019, None),
#  ('Democratic Republic of the Congo', 2020, None),
#  ('Djibouti', 2015, None),
#  ('Djibouti', 2016, None),
#  ('Djibouti', 2017, Decimal('26.06')),
#  ('Djibouti', 2018, None),
#  ('Djibouti', 2019, None),
#  ('Djibouti', 2020, None),
#  ('Equatorial Guinea', 2015, None),
#  ('Equatorial Guinea', 2016, None),
#  ('Equatorial Guinea', 2017, None),
#  ('Eritrea', 2015, None),
#  ('Eritrea', 2016, None),
#  ('Eswatini', 2015, None),
#  ('Eswatini', 2016, Decimal('22.72')),
#  ('Eswatini', 2017, None),
#  ('Eswatini', 2018, None),
#  ('Eswatini', 2019, None),
#  ('Eswatini', 2020, None),
#  ('Ethiopia', 2015, None),
#  ('Ethiopia', 2016, None),
#  ('Ethiopia', 2017, None),
#  ('Ethiopia', 2018, None),
#  ('Ethiopia', 2019, None),
#  ('Ethiopia', 2020, None),
#  ('Gabon', 2015, None),
#  ('Gabon', 2016, None),
#  ('Gabon', 2017, None),
#  ('Gabon', 2018, None),
#  ('Gabon', 2019, None),
#  ('Gabon', 2020, None),
#  ('Gambia', 2015, None),
#  ('Gambia', 2016, None),
#  ('Gambia', 2017, None),
#  ('Gambia', 2018, None),
#  ('Gambia', 2019, None),
#  ('Gambia', 2020, None),
#  ('Ghana', 2015, Decimal('6.81')),
#  ('Ghana', 2016, None),
#  ('Ghana', 2017, Decimal('3.37')),
#  ('Ghana', 2018, None),
#  ('Ghana', 2019, None),
#  ('Ghana', 2020, None),
#  ('Guinea', 2015, None),
#  ('Guinea', 2016, None),
#  ('Guinea', 2017, None),
#  ('Guinea', 2018, None),
#  ('Guinea', 2019, Decimal('5.02')),
#  ('Guinea', 2020, None),
#  ('Guinea-Bissau', 2015, None),
#  ('Guinea-Bissau', 2016, None),
#  ('Guinea-Bissau', 2017, None),
#  ('Guinea-Bissau', 2018, Decimal('3.20')),
#  ('Guinea-Bissau', 2019, None),
#  ('Guinea-Bissau', 2020, None),
#  ('Kenya', 2015, None),
#  ('Kenya', 2016, Decimal('2.76')),
#  ('Kenya', 2017, None),
#  ('Kenya', 2018, None),
#  ('Kenya', 2019, Decimal('5.01')),
#  ('Kenya', 2020, None),
#  ('Lesotho', 2015, None),
#  ('Lesotho', 2016, None),
#  ('Lesotho', 2017, None),
#  ('Lesotho', 2018, None),
#  ('Lesotho', 2019, Decimal('16.88')),
#  ('Lesotho', 2020, None),
#  ('Liberia', 2015, None),
#  ('Liberia', 2016, Decimal('3.08')),
#  ('Liberia', 2017, Decimal('5.95')),
#  ('Liberia', 2018, None),
#  ('Liberia', 2019, None),
#  ('Liberia', 2020, None),
#  ('Madagascar', 2015, Decimal('1.79')),
#  ('Madagascar', 2016, None),
#  ('Madagascar', 2017, None),
#  ('Madagascar', 2018, None),
#  ('Madagascar', 2019, None),
#  ('Madagascar', 2020, None),
#  ('Malawi', 2015, None),
#  ('Malawi', 2016, None),
#  ('Malawi', 2017, Decimal('3.54')),
#  ('Malawi', 2018, None),
#  ('Malawi', 2019, None),
#  ('Malawi', 2020, Decimal('0.91')),
#  ('Mali', 2015, Decimal('7.73')),
#  ('Mali', 2016, Decimal('1.37')),
#  ('Mali', 2017, Decimal('7.41')),
#  ('Mali', 2018, Decimal('1.62')),
#  ('Mali', 2019, None),
#  ('Mali', 2020, Decimal('3.53')),
#  ('Mauritania', 2015, None),
#  ('Mauritania', 2016, None),
#  ('Mauritania', 2017, Decimal('10.34')),
#  ('Mauritania', 2018, None),
#  ('Mauritania', 2019, Decimal('10.42')),
#  ('Mauritania', 2020, None),
#  ('Mauritius', 2015, Decimal('7.41')),
#  ('Mauritius', 2016, Decimal('6.81')),
#  ('Mauritius', 2017, Decimal('6.75')),
#  ('Mauritius', 2018, Decimal('6.43')),
#  ('Mauritius', 2019, Decimal('6.33')),
#  ('Mauritius', 2020, Decimal('8.63')),
#  ('Mayotte', 2015, None),
#  ('Mayotte', 2016, None),
#  ('Mayotte', 2017, None),
#  ('Mayotte', 2018, None),
#  ('Mayotte', 2019, None),
#  ('Mayotte', 2020, None),
#  ('Mozambique', 2015, Decimal('3.43')),
#  ('Mozambique', 2016, None),
#  ('Mozambique', 2017, None),
#  ('Mozambique', 2018, None),
#  ('Mozambique', 2019, None),
#  ('Mozambique', 2020, None),
#  ('Namibia', 2015, None),
#  ('Namibia', 2016, Decimal('23.35')),
#  ('Namibia', 2017, None),
#  ('Namibia', 2018, Decimal('19.88')),
#  ('Namibia', 2019, None),
#  ('Namibia', 2020, None),
#  ('Niger', 2015, None),
#  ('Niger', 2016, None),
#  ('Niger', 2017, Decimal('7.77')),
#  ('Niger', 2018, None),
#  ('Niger', 2019, None),
#  ('Niger', 2020, None),
#  ('Nigeria', 2015, Decimal('4.31')),
#  ('Nigeria', 2016, Decimal('7.06')),
#  ('Nigeria', 2017, Decimal('8.39')),
#  ('Nigeria', 2018, None),
#  ('Nigeria', 2019, Decimal('10.70')),
#  ('Nigeria', 2020, None),
#  ('Réunion', 2015, None),
#  ('Réunion', 2016, None),
#  ('Réunion', 2017, None),
#  ('Réunion', 2018, None),
#  ('Réunion', 2019, None),
#  ('Réunion', 2020, None),
#  ('Rwanda', 2015, None),
#  ('Rwanda', 2016, None),
#  ('Rwanda', 2017, Decimal('11.88')),
#  ('Rwanda', 2018, Decimal('10.76')),
#  ('Rwanda', 2019, Decimal('11.24')),
#  ('Rwanda', 2020, Decimal('11.83')),
#  ('Saint Helena', 2015, None),
#  ('Saint Helena', 2016, None),
#  ('Saint Helena', 2017, None),
#  ('Saint Helena', 2018, None),
#  ('Saint Helena', 2019, None),
#  ('Saint Helena', 2020, None),
#  ('Sao Tome and Principe', 2015, None),
#  ('Sao Tome and Principe', 2016, None),
#  ('Sao Tome and Principe', 2017, None),
#  ('Sao Tome and Principe', 2018, None),
#  ('Sao Tome and Principe', 2019, None),
#  ('Sao Tome and Principe', 2020, None),
#  ('Senegal', 2015, Decimal('6.76')),
#  ('Senegal', 2016, Decimal('4.46')),
#  ('Senegal', 2017, Decimal('4.08')),
#  ('Senegal', 2018, Decimal('3.57')),
#  ('Senegal', 2019, Decimal('2.86')),
#  ('Senegal', 2020, None),
#  ('Seychelles', 2015, Decimal('4.15')),
#  ('Seychelles', 2016, Decimal('3.96')),
#  ('Seychelles', 2017, Decimal('3.71')),
#  ('Seychelles', 2018, Decimal('3.53')),
#  ('Seychelles', 2019, Decimal('2.97')),
#  ('Sierra Leone', 2015, None),
#  ('Sierra Leone', 2016, None),
#  ('Sierra Leone', 2017, None),
#  ('Sierra Leone', 2018, Decimal('3.19')),
#  ('Sierra Leone', 2019, None),
#  ('Sierra Leone', 2020, None),
#  ('Somalia', 2015, None),
#  ('Somalia', 2016, None),
#  ('Somalia', 2017, None),
#  ('Somalia', 2018, None),
#  ('Somalia', 2019, Decimal('18.83')),
#  ('Somalia', 2020, None),
#  ('South Africa', 2015, Decimal('22.87')),
#  ('South Africa', 2016, Decimal('24.02')),
#  ('South Africa', 2017, Decimal('23.99')),
#  ('South Africa', 2018, Decimal('24.22')),
#  ('South Africa', 2019, Decimal('25.54')),
#  ('South Africa', 2020, Decimal('24.34')),
#  ('South Sudan', 2015, None),
#  ('South Sudan', 2016, None),
#  ('South Sudan', 2017, None),
#  ('South Sudan', 2018, None),
#  ('South Sudan', 2019, None),
#  ('South Sudan', 2020, None),
#  ('Togo', 2015, Decimal('2.20')),
#  ('Togo', 2016, None),
#  ('Togo', 2017, Decimal('3.74')),
#  ('Togo', 2018, None),
#  ('Togo', 2019, None),
#  ('Togo', 2020, None),
#  ('Uganda', 2015, None),
#  ('Uganda', 2016, None),
#  ('Uganda', 2017, Decimal('3.64')),
#  ('Uganda', 2018, None),
#  ('Uganda', 2019, None),
#  ('Uganda', 2020, None),
#  ('United Republic of Tanzania', 2015, None),
#  ('United Republic of Tanzania', 2016, None),
#  ('United Republic of Tanzania', 2017, None),
#  ('United Republic of Tanzania', 2018, None),
#  ('United Republic of Tanzania', 2019, None),
#  ('United Republic of Tanzania', 2020, None),
#  ('Zambia', 2015, None),
#  ('Zambia', 2016, None),
#  ('Zambia', 2017, Decimal('8.52')),
#  ('Zambia', 2018, Decimal('5.03')),
#  ('Zambia', 2019, Decimal('5.54')),
#  ('Zambia', 2020, Decimal('6.03')),
#  ('Zimbabwe', 2015, None),
#  ('Zimbabwe', 2016, None),
#  ('Zimbabwe', 2017, None),
#  ('Zimbabwe', 2018, None),
#  ('Zimbabwe', 2019, Decimal('7.37')),
#  ('Zimbabwe', 2020, None)]

# %% [markdown]
# ### Task 3

# %%
# %%sql
#
# SELECT
#     loc.Country_name,
#     eco.Time_period,
#     IFNULL (eco.Pct_unemployment,33.65) as Pct_unemployment_imputed
# FROM
#     united_nations.Geographic_Location as loc
# LEFT JOIN united_nations.Economic_Indicators as eco
# ON eco.Country_name = loc.Country_name
# WHERE REGION = 'Sub-Saharan Africa';

# %% [markdown]
# ### Task 4

# %%
# %%sql
#
# CREATE VIEW united_nations.Country_Unemployment_Rate
# AS
#
# SELECT
#     loc.Country_name,
#     eco.Time_period,
#     IFNULL (eco.Pct_unemployment,33.65) as PCT_unemployment_imputed
# FROM
#     united_nations.Geographic_Location as loc
# LEFT JOIN united_nations.Economic_Indicators as eco
# ON eco.Country_name = loc.Country_name
# WHERE REGION = 'Sub-Saharan Africa';

# %% [markdown]
# ### Task 5

# %%
# %%sql
#
# SELECT *
# FROM
#     united_nations.Country_unemployment_Rate
# LIMIT 10;

# %% [markdown]
# ## Summary

# %% [markdown]
# In this notebook, we created a join with the `Economic_Indicators` table and the `Geographical_Locations` table. This allowed us to filter our data by `Region`, specifically the `Sub-Saharan African` region. We then imputed the Null values in the `Pct_unemployment` column. Finally, we saved this complex query in a VIEW and named that VIEW `united_nations.Country_unemployment_Rate`.

# %% [markdown]
# #
#
# <div align="center" style=" font-size: 80%; text-align: center; margin: 0 auto">
# <img src="https://raw.githubusercontent.com/Explore-AI/Pictures/master/ExploreAI_logos/EAI_Blue_Dark.png"  style="width:200px";/>
# </div>
