# %% [markdown]
# <div align="right" style=" font-size: 80%; text-align: center; margin: 0 auto">
# <img src="https://raw.githubusercontent.com/Explore-AI/Pictures/master/ExploreAI_logos/Logo blue_dark.png"  style="width:25px" align="right";/>
# </div>

# %% [markdown]
# # Subquery in FROM
# © ExploreAI Academy

# %% [markdown]
# > ⚠️ This notebook will not run on Google Colab because it cannot connect to a local database. Please make sure that this notebook is running on the same local machine as your MySQL Workbench installation and MySQL `united_nations` database.

# %% [markdown]
# ## Description

# %% [markdown]
# In this lesson we will use a subquery like a temporary table, meaning we will do a calculation, and then reference the result of that calculation in another query.

# %% [markdown]
# ## Learning objectives
#
# In this train we will learn:
# - How to create a query using the FROM clause.

# %% [markdown]
# ## Connecting to our MySQL database
#
# Using our `Access_to_Basic_Services` table in our `united_nations` database we created in MySQL Workbench, we want to answer some questions about our dataset. We can apply the same queries we used in MySQL Workbench in this notebook if we connect to our MySQL server by running the cells below.
#
# Note that before, for this tutorial, we will already have worked through the lessons where the `united_nations.Basic_Services` table, `united_nations.Economic_Indicators` table, and the `united_nations.Geographic_Locations` table have been created.

# %%
# Load and activate the SQL extension to allow us to execute SQL in a Jupyter notebook. 
# If you get an error here, make sure that mysql and pymysql are installed correctly. 

# %load_ext sql
# Out:
# The sql extension is already loaded. To reload it, use:
#   %reload_ext sql

# %%
# Establish a connection to the local database using the '%sql' magic command.
# Replace 'password' with our connection password and `db_name` with our database name. 
# If you get an error here, please make sure the database name or password is correct.

# %sql mysql+pymysql://root:Omar2003negm*@localhost:3306/united_nations
# Out:
# 'Connected: root@united_nations'

# %% [markdown]
# To make a query, we add the `%%sql` command to the start of a cell, create one open line then the query like below, and run the cell.

# %%
# %%sql
#
# SELECT
#     *
# FROM
#     Access_to_Basic_Services
# LIMIT 5;
# Out:
#  * mysql+pymysql://root:***@localhost:3306/united_nations
# 5 rows affected.
# [('Central and Southern Asia', 'Central Asia', 'Kazakhstan', 2015, Decimal('94.67'), Decimal('98.00'), Decimal('17.542806'), Decimal('184.39'), Decimal('2699700.00'), Decimal('4.93')),
#  ('Central and Southern Asia', 'Central Asia', 'Kazakhstan', 2016, Decimal('94.67'), Decimal('98.00'), Decimal('17.794055'), Decimal('137.28'), Decimal('2699700.00'), Decimal('4.96')),
#  ('Central and Southern Asia', 'Central Asia', 'Kazakhstan', 2017, Decimal('95.00'), Decimal('98.00'), Decimal('18.037776'), Decimal('166.81'), Decimal('2699700.00'), Decimal('4.90')),
#  ('Central and Southern Asia', 'Central Asia', 'Kazakhstan', 2018, Decimal('95.00'), Decimal('98.00'), Decimal('18.276452'), Decimal('179.34'), Decimal('2699700.00'), Decimal('4.85')),
#  ('Central and Southern Asia', 'Central Asia', 'Kazakhstan', 2019, Decimal('95.00'), Decimal('98.00'), Decimal('18.513673'), Decimal('181.67'), Decimal('2699700.00'), Decimal('4.80'))]

# %% [markdown]
# ## Exercise

# %% [markdown]
# In this exercise. We will use a subquery to answer the following question: What is the average GDP and population for countries with unemployment rates above 5%?

# %% [markdown]
# ### Creating the subquery
# Construct the subquery that displays the average GDP and average population of countries for 2020. The query should have the following columns: `Country_name`, `Avg_GDP`, `Avg_Population`.

# %%
# %%sql
# # Add your code here
# SELECT
#     Country_name,
#     Est_gdp_in_billions,
#     Est_population_in_millions
# FROM
#      Economic_Indicators
# Out:
#  * mysql+pymysql://root:***@localhost:3306/united_nations
# 1048 rows affected.
# [('Afghanistan', Decimal('20.00'), Decimal('33.753499')),
#  ('Afghanistan', Decimal('18.02'), Decimal('34.636207')),
#  ('Afghanistan', Decimal('18.90'), Decimal('35.643418')),
#  ('Afghanistan', Decimal('18.42'), Decimal('36.686784')),
#  ('Afghanistan', Decimal('18.90'), Decimal('37.769499')),
#  ('Afghanistan', Decimal('20.14'), Decimal('38.972230')),
#  ('Algeria', Decimal('165.98'), Decimal('39.543154')),
#  ('Algeria', Decimal('160.03'), Decimal('40.339329')),
#  ('Algeria', Decimal('170.10'), Decimal('41.136546')),
#  ('Algeria', Decimal('174.91'), Decimal('41.927007')),
#  ('Algeria', Decimal('171.77'), Decimal('42.705368')),
#  ('Algeria', Decimal('145.01'), Decimal('43.451666')),
#  ('American Samoa', Decimal('0.67'), Decimal('0.051368')),
#  ('American Samoa', Decimal('0.67'), Decimal('0.050448')),
#  ('American Samoa', Decimal('0.61'), Decimal('0.049463')),
#  ('American Samoa', Decimal('0.64'), Decimal('0.048424')),
#  ('American Samoa', Decimal('0.65'), Decimal('0.047321')),
#  ('American Samoa', Decimal('0.72'), Decimal('0.046189')),
#  ('Angola', Decimal('87.22'), Decimal('28.127721')),
#  ('Angola', Decimal('49.84'), Decimal('29.154746')),
#  ('Angola', Decimal('68.97'), Decimal('30.208628')),
#  ('Angola', Decimal('77.79'), Decimal('31.273533')),
#  ('Angola', Decimal('69.31'), Decimal('32.353588')),
#  ('Angola', Decimal('53.62'), Decimal('33.428486')),
#  ('Anguilla', None, None),
#  ('Anguilla', None, None),
#  ('Anguilla', None, None),
#  ('Antigua and Barbuda', Decimal('1.34'), Decimal('0.089941')),
#  ('Antigua and Barbuda', Decimal('1.44'), Decimal('0.090564')),
#  ('Antigua and Barbuda', Decimal('1.47'), Decimal('0.091119')),
#  ('Argentina', Decimal('594.75'), Decimal('43.131966')),
#  ('Argentina', Decimal('557.53'), Decimal('43.590368')),
#  ('Argentina', Decimal('643.63'), Decimal('44.044811')),
#  ('Argentina', Decimal('524.82'), Decimal('44.494502')),
#  ('Argentina', Decimal('447.75'), Decimal('44.938712')),
#  ('Argentina', Decimal('385.54'), Decimal('45.376763')),
#  ('Armenia', Decimal('10.55'), Decimal('2.878595')),
#  ('Armenia', Decimal('10.55'), Decimal('2.865835')),
#  ('Armenia', Decimal('11.53'), Decimal('2.851923')),
#  ('Armenia', Decimal('12.46'), Decimal('2.836557')),
#  ('Armenia', Decimal('13.62'), Decimal('2.820602')),
#  ('Armenia', Decimal('12.64'), Decimal('2.805608')),
#  ('Aruba', Decimal('2.96'), Decimal('0.104257')),
#  ('Aruba', Decimal('2.98'), Decimal('0.104874')),
#  ('Australia', Decimal('1350.62'), Decimal('23.815995')),
#  ('Australia', Decimal('1206.54'), Decimal('24.190907')),
#  ('Australia', Decimal('1326.52'), Decimal('24.594202')),
#  ('Australia', Decimal('1428.29'), Decimal('24.966643')),
#  ('Australia', Decimal('1392.23'), Decimal('25.340217')),
#  ('Australia', Decimal('1326.90'), Decimal('25.655289')),
#  ('Azerbaijan', Decimal('53.07'), Decimal('9.649341')),
#  ('Azerbaijan', Decimal('37.87'), Decimal('9.757812')),
#  ('Azerbaijan', Decimal('40.87'), Decimal('9.854033')),
#  ('Azerbaijan', Decimal('47.11'), Decimal('9.939771')),
#  ('Azerbaijan', Decimal('48.17'), Decimal('10.024283')),
#  ('Azerbaijan', Decimal('42.69'), Decimal('10.093121')),
#  ('Bahamas', None, None),
#  ('Bahamas', None, None),
#  ('Bahamas', None, None),
#  ('Bahamas', None, None),
#  ('Bahamas', None, None),
#  ('Bahrain', Decimal('31.05'), Decimal('1.362142')),
#  ('Bahrain', Decimal('32.23'), Decimal('1.409661')),
#  ('Bahrain', Decimal('35.47'), Decimal('1.456834')),
#  ('Bahrain', Decimal('37.80'), Decimal('1.487340')),
#  ('Bahrain', Decimal('38.65'), Decimal('1.494188')),
#  ('Bahrain', Decimal('34.72'), Decimal('1.477469')),
#  ('Bangladesh', Decimal('195.08'), Decimal('157.830000')),
#  ('Bangladesh', Decimal('265.24'), Decimal('159.784568')),
#  ('Bangladesh', Decimal('293.75'), Decimal('161.793964')),
#  ('Bangladesh', Decimal('321.38'), Decimal('163.683958')),
#  ('Bangladesh', Decimal('351.24'), Decimal('165.516222')),
#  ('Bangladesh', Decimal('373.90'), Decimal('167.420951')),
#  ('Barbados', Decimal('4.72'), Decimal('0.278083')),
#  ('Barbados', Decimal('4.83'), Decimal('0.278649')),
#  ('Barbados', Decimal('4.98'), Decimal('0.279187')),
#  ('Barbados', Decimal('5.10'), Decimal('0.279688')),
#  ('Barbados', Decimal('5.32'), Decimal('0.280180')),
#  ('Barbados', Decimal('4.67'), Decimal('0.280693')),
#  ('Belize', Decimal('2.21'), Decimal('0.359871')),
#  ('Belize', Decimal('2.26'), Decimal('0.367313')),
#  ('Belize', Decimal('2.29'), Decimal('0.374693')),
#  ('Belize', Decimal('2.31'), Decimal('0.382066')),
#  ('Belize', Decimal('2.42'), Decimal('0.389095')),
#  ('Belize', Decimal('2.08'), Decimal('0.394921')),
#  ('Benin', Decimal('11.39'), Decimal('10.932783')),
#  ('Benin', Decimal('11.82'), Decimal('11.260085')),
#  ('Benin', Decimal('12.70'), Decimal('11.596779')),
#  ('Benin', Decimal('14.26'), Decimal('11.940683')),
#  ('Benin', Decimal('14.39'), Decimal('12.290444')),
#  ('Benin', Decimal('15.65'), Decimal('12.643123')),
#  ('Bermuda', Decimal('6.65'), Decimal('0.065237')),
#  ('Bermuda', Decimal('6.90'), Decimal('0.064554')),
#  ('Bermuda', Decimal('7.14'), Decimal('0.063873')),
#  ('Bermuda', Decimal('7.23'), Decimal('0.063918')),
#  ('Bermuda', Decimal('7.42'), Decimal('0.063911')),
#  ('Bermuda', Decimal('6.89'), Decimal('0.063893')),
#  ('Bhutan', Decimal('2.00'), Decimal('0.743274')),
#  ('Bhutan', Decimal('2.16'), Decimal('0.749761')),
#  ('Bhutan', Decimal('2.45'), Decimal('0.756121')),
#  ('Bhutan', Decimal('2.45'), Decimal('0.762096')),
#  ('Bhutan', Decimal('2.54'), Decimal('0.767459')),
#  ('Bhutan', Decimal('2.33'), Decimal('0.772506')),
#  ('Bolivia (Plurinational State of)', None, None),
#  ('Bolivia (Plurinational State of)', None, None),
#  ('Bolivia (Plurinational State of)', None, None),
#  ('Bolivia (Plurinational State of)', None, None),
#  ('Bolivia (Plurinational State of)', None, None),
#  ('Bolivia (Plurinational State of)', None, None),
#  ('Botswana', Decimal('13.53'), Decimal('2.305171')),
#  ('Botswana', Decimal('15.08'), Decimal('2.352416')),
#  ('Botswana', Decimal('16.11'), Decimal('2.401840')),
#  ('Botswana', Decimal('17.03'), Decimal('2.451409')),
#  ('Botswana', Decimal('16.70'), Decimal('2.499702')),
#  ('Botswana', Decimal('14.93'), Decimal('2.546402')),
#  ('Brazil', Decimal('1802.21'), Decimal('205.188205')),
#  ('Brazil', Decimal('1795.70'), Decimal('206.859578')),
#  ('Brazil', Decimal('2063.51'), Decimal('208.504960')),
#  ('Brazil', Decimal('1916.95'), Decimal('210.166592')),
#  ('Brazil', Decimal('1873.27'), Decimal('211.782878')),
#  ('Brazil', Decimal('1448.56'), Decimal('213.196304')),
#  ('British Virgin Islands', None, Decimal('0.029366')),
#  ('British Virgin Islands', None, Decimal('0.029739')),
#  ('British Virgin Islands', None, Decimal('0.030060')),
#  ('British Virgin Islands', None, Decimal('0.030335')),
#  ('British Virgin Islands', None, Decimal('0.030610')),
#  ('British Virgin Islands', None, Decimal('0.030910')),
#  ('Brunei Darussalam', Decimal('12.93'), Decimal('0.421437')),
#  ('Brunei Darussalam', Decimal('11.40'), Decimal('0.425994')),
#  ('Brunei Darussalam', Decimal('12.13'), Decimal('0.430276')),
#  ('Brunei Darussalam', Decimal('13.57'), Decimal('0.434274')),
#  ('Brunei Darussalam', Decimal('13.47'), Decimal('0.438048')),
#  ('Brunei Darussalam', Decimal('12.01'), Decimal('0.441725')),
#  ('Burkina Faso', Decimal('11.83'), Decimal('18.718019')),
#  ('Burkina Faso', Decimal('12.83'), Decimal('19.275498')),
#  ('Burkina Faso', Decimal('14.11'), Decimal('19.835858')),
#  ('Burkina Faso', Decimal('15.89'), Decimal('20.392723')),
#  ('Burkina Faso', Decimal('16.18'), Decimal('20.951639')),
#  ('Burkina Faso', Decimal('17.93'), Decimal('21.522626')),
#  ('Burundi', Decimal('3.10'), Decimal('10.727148')),
#  ('Burundi', Decimal('2.64'), Decimal('10.903327')),
#  ('Burundi', Decimal('2.71'), Decimal('11.155593')),
#  ('Burundi', Decimal('2.66'), Decimal('11.493472')),
#  ('Burundi', Decimal('2.58'), Decimal('11.874838')),
#  ('Burundi', Decimal('2.65'), Decimal('12.220227')),
#  ('Cabo Verde', Decimal('1.60'), Decimal('0.552166')),
#  ('Cabo Verde', Decimal('1.66'), Decimal('0.558394')),
#  ('Cabo Verde', Decimal('1.77'), Decimal('0.564954')),
#  ('Cabo Verde', Decimal('1.97'), Decimal('0.571202')),
#  ('Cabo Verde', Decimal('1.98'), Decimal('0.577030')),
#  ('Cabo Verde', Decimal('1.70'), Decimal('0.582640')),
#  ('Cambodia', Decimal('18.05'), Decimal('15.417523')),
#  ('Cambodia', Decimal('20.02'), Decimal('15.624584')),
#  ('Cambodia', Decimal('22.18'), Decimal('15.830689')),
#  ('Cambodia', Decimal('24.57'), Decimal('16.025238')),
#  ('Cambodia', Decimal('27.09'), Decimal('16.207746')),
#  ('Cambodia', Decimal('25.87'), Decimal('16.396860')),
#  ('Cameroon', Decimal('32.21'), Decimal('23.012646')),
#  ('Cameroon', Decimal('33.81'), Decimal('23.711630')),
#  ('Cameroon', Decimal('36.10'), Decimal('24.393181')),
#  ('Cameroon', Decimal('39.97'), Decimal('25.076747')),
#  ('Cameroon', Decimal('39.67'), Decimal('25.782341')),
#  ('Cameroon', Decimal('40.77'), Decimal('26.491087')),
#  ('Canada', Decimal('1556.51'), Decimal('35.702908')),
#  ('Canada', Decimal('1527.99'), Decimal('36.109487')),
#  ('Canada', Decimal('1649.27'), Decimal('36.545236')),
#  ('Canada', Decimal('1725.33'), Decimal('37.065084')),
#  ('Canada', Decimal('1742.02'), Decimal('37.601230')),
#  ('Canada', Decimal('1645.42'), Decimal('38.037204')),
#  ('Cayman Islands', Decimal('4.71'), Decimal('0.060911')),
#  ('Cayman Islands', Decimal('4.91'), Decimal('0.062255')),
#  ('Central African Republic', Decimal('1.70'), Decimal('4.819333')),
#  ('Central African Republic', Decimal('1.83'), Decimal('4.904177')),
#  ('Central African Republic', Decimal('2.07'), Decimal('4.996741')),
#  ('Central African Republic', Decimal('2.22'), Decimal('5.094780')),
#  ('Central African Republic', Decimal('2.22'), Decimal('5.209324')),
#  ('Central African Republic', Decimal('2.33'), Decimal('5.343020')),
#  ('Chad', Decimal('10.95'), Decimal('14.140274')),
#  ('Chad', Decimal('10.10'), Decimal('14.592585')),
#  ('Chad', Decimal('10.00'), Decimal('15.085884')),
#  ('Chad', Decimal('11.24'), Decimal('15.604210')),
#  ('Chad', Decimal('11.31'), Decimal('16.126866')),
#  ('Chad', Decimal('10.72'), Decimal('16.644701')),
#  ('Chile', Decimal('242.50'), Decimal('17.870124')),
#  ('Chile', Decimal('249.30'), Decimal('18.083879')),
#  ('Chile', Decimal('276.36'), Decimal('18.368577')),
#  ('Chile', Decimal('295.40'), Decimal('18.701450')),
#  ('Chile', Decimal('278.58'), Decimal('19.039485')),
#  ('Chile', Decimal('252.73'), Decimal('19.300315')),
#  ('China', Decimal('11061.55'), Decimal('1379.860000')),
#  ('China', Decimal('11233.28'), Decimal('1387.790000')),
#  ('China', Decimal('12310.41'), Decimal('1396.215000')),
#  ('China', Decimal('13894.82'), Decimal('1402.760000')),
#  ('China', Decimal('14279.94'), Decimal('1407.745000')),
#  ('China', Decimal('14687.67'), Decimal('1411.100000')),
#  ('Colombia', Decimal('293.48'), Decimal('47.119728')),
#  ('Colombia', Decimal('282.83'), Decimal('47.625955')),
#  ('Colombia', Decimal('311.88'), Decimal('48.351671')),
#  ('Colombia', Decimal('334.20'), Decimal('49.276961')),
#  ('Colombia', Decimal('323.11'), Decimal('50.187406')),
#  ('Colombia', Decimal('270.30'), Decimal('50.930662')),
#  ('Comoros', Decimal('0.97'), Decimal('0.730216')),
#  ('Comoros', Decimal('1.01'), Decimal('0.746232')),
#  ('Comoros', Decimal('1.08'), Decimal('0.761664')),
#  ('Comoros', Decimal('1.19'), Decimal('0.776313')),
#  ('Comoros', Decimal('1.20'), Decimal('0.790986')),
#  ('Congo', None, None),
#  ('Congo', None, None),
#  ('Congo', None, None),
#  ('Congo', None, None),
#  ('Congo', None, None),
#  ('Congo', None, None),
#  ('Cook Islands', None, None),
#  ('Cook Islands', None, None),
#  ('Cook Islands', None, None),
#  ('Cook Islands', None, None),
#  ('Cook Islands', None, None),
#  ('Cook Islands', None, None),
#  ('Costa Rica', Decimal('56.44'), Decimal('4.895242')),
#  ('Costa Rica', Decimal('58.85'), Decimal('4.945205')),
#  ('Costa Rica', Decimal('60.52'), Decimal('4.993842')),
#  ('Costa Rica', Decimal('62.42'), Decimal('5.040734')),
#  ('Costa Rica', Decimal('64.42'), Decimal('5.084532')),
#  ('Costa Rica', Decimal('62.16'), Decimal('5.123105')),
#  ("Côte d'Ivoire", None, None),
#  ("Côte d'Ivoire", None, None),
#  ("Côte d'Ivoire", None, None),
#  ("Côte d'Ivoire", None, None),
#  ("Côte d'Ivoire", None, None),
#  ("Côte d'Ivoire", None, None),
#  ('Cuba', Decimal('87.13'), Decimal('11.339894')),
#  ('Cuba', Decimal('91.37'), Decimal('11.342012')),
#  ('Cuba', Decimal('96.85'), Decimal('11.336405')),
#  ('Cuba', Decimal('100.05'), Decimal('11.328244')),
#  ('Cuba', Decimal('103.43'), Decimal('11.316697')),
#  ('Cuba', Decimal('107.35'), Decimal('11.300698')),
#  ('Curaçao', None, None),
#  ('Curaçao', None, None),
#  ('Curaçao', None, None),
#  ('Cyprus', Decimal('19.91'), Decimal('1.187280')),
#  ('Cyprus', Decimal('21.05'), Decimal('1.197881')),
#  ('Cyprus', Decimal('22.95'), Decimal('1.208523')),
#  ('Cyprus', Decimal('25.60'), Decimal('1.218831')),
#  ('Cyprus', Decimal('25.94'), Decimal('1.228836')),
#  ('Cyprus', Decimal('25.01'), Decimal('1.237537')),
#  ("Democratic People's Republic of Korea", None, None),
#  ("Democratic People's Republic of Korea", None, None),
#  ("Democratic People's Republic of Korea", None, None),
#  ("Democratic People's Republic of Korea", None, None),
#  ("Democratic People's Republic of Korea", None, None),
#  ("Democratic People's Republic of Korea", None, None),
#  ('Democratic Republic of the Congo', None, None),
#  ('Democratic Republic of the Congo', None, None),
#  ('Democratic Republic of the Congo', None, None),
#  ('Democratic Republic of the Congo', None, None),
#  ('Democratic Republic of the Congo', None, None),
#  ('Democratic Republic of the Congo', None, None),
#  ('Djibouti', Decimal('2.42'), Decimal('1.006259')),
#  ('Djibouti', Decimal('2.60'), Decimal('1.023261')),
#  ('Djibouti', Decimal('2.76'), Decimal('1.040233')),
#  ('Djibouti', Decimal('2.91'), Decimal('1.057198')),
#  ('Djibouti', Decimal('3.09'), Decimal('1.073994')),
#  ('Djibouti', Decimal('3.18'), Decimal('1.090156')),
#  ('Dominica', Decimal('0.54'), Decimal('0.070007')),
#  ('Dominica', Decimal('0.58'), Decimal('0.070075')),
#  ('Dominica', Decimal('0.52'), Decimal('0.070403')),
#  ('Dominican Republic', Decimal('71.16'), Decimal('10.405832')),
#  ('Dominican Republic', Decimal('75.70'), Decimal('10.527592')),
#  ('Dominican Republic', Decimal('80.00'), Decimal('10.647244')),
#  ('Dominican Republic', Decimal('85.56'), Decimal('10.765531')),
#  ('Dominican Republic', Decimal('88.94'), Decimal('10.881882')),
#  ('Dominican Republic', Decimal('78.84'), Decimal('10.999664')),
#  ('Ecuador', Decimal('99.29'), Decimal('16.195902')),
#  ('Ecuador', Decimal('99.94'), Decimal('16.439585')),
#  ('Ecuador', Decimal('104.30'), Decimal('16.696944')),
#  ('Ecuador', Decimal('107.56'), Decimal('17.015672')),
#  ('Ecuador', Decimal('108.11'), Decimal('17.343740')),
#  ('Ecuador', Decimal('99.29'), Decimal('17.588595')),
#  ('Egypt', None, None),
#  ('Egypt', None, None),
#  ('Egypt', None, None),
#  ('Egypt', None, None),
#  ('Egypt', None, None),
#  ('Egypt', None, None),
#  ('El Salvador', Decimal('23.44'), Decimal('6.231066')),
#  ('El Salvador', Decimal('24.19'), Decimal('6.250510')),
#  ('El Salvador', Decimal('24.98'), Decimal('6.266654')),
#  ('El Salvador', Decimal('26.02'), Decimal('6.276342')),
#  ('El Salvador', Decimal('26.88'), Decimal('6.280217')),
#  ('El Salvador', Decimal('24.56'), Decimal('6.292731')),
#  ('Equatorial Guinea', Decimal('13.19'), Decimal('1.346973')),
#  ('Equatorial Guinea', Decimal('11.24'), Decimal('1.398927')),
#  ('Equatorial Guinea', Decimal('12.20'), Decimal('1.450694')),
#  ('Eritrea', None, Decimal('3.340006')),
#  ('Eritrea', None, Decimal('3.365287')),
#  ('Eswatini', Decimal('4.06'), Decimal('1.133936')),
#  ('Eswatini', Decimal('3.82'), Decimal('1.142524')),
#  ('Eswatini', Decimal('4.40'), Decimal('1.151390')),
#  ('Eswatini', Decimal('4.67'), Decimal('1.160428')),
#  ('Eswatini', Decimal('4.50'), Decimal('1.169613')),
#  ('Eswatini', Decimal('3.98'), Decimal('1.180655')),
#  ('Ethiopia', Decimal('64.59'), Decimal('102.471895')),
#  ('Ethiopia', Decimal('74.30'), Decimal('105.293228')),
#  ('Ethiopia', Decimal('81.77'), Decimal('108.197950')),
#  ('Ethiopia', Decimal('84.27'), Decimal('111.129438')),
#  ('Ethiopia', Decimal('95.91'), Decimal('114.120594')),
#  ('Ethiopia', Decimal('107.66'), Decimal('117.190911')),
#  ('Falkland Islands (Malvinas)', None, None),
#  ('Falkland Islands (Malvinas)', None, None),
#  ('Falkland Islands (Malvinas)', None, None),
#  ('Falkland Islands (Malvinas)', None, None),
#  ('Falkland Islands (Malvinas)', None, None),
#  ('Falkland Islands (Malvinas)', None, None),
#  ('Fiji', Decimal('4.68'), Decimal('0.917200')),
#  ('Fiji', Decimal('4.93'), Decimal('0.918371')),
#  ('Fiji', Decimal('5.35'), Decimal('0.919019')),
#  ('Fiji', Decimal('5.58'), Decimal('0.918996')),
#  ('Fiji', Decimal('5.48'), Decimal('0.918465')),
#  ('Fiji', Decimal('4.48'), Decimal('0.920422')),
#  ('French Guiana', None, None),
#  ('French Guiana', None, None),
#  ('French Guiana', None, None),
#  ('French Guiana', None, None),
#  ('French Guiana', None, None),
#  ('French Guiana', None, None),
#  ('French Polynesia', Decimal('5.33'), Decimal('0.291787')),
#  ('French Polynesia', Decimal('5.50'), Decimal('0.293541')),
#  ('French Polynesia', Decimal('5.83'), Decimal('0.295450')),
#  ('French Polynesia', Decimal('6.14'), Decimal('0.297606')),
#  ('French Polynesia', Decimal('6.00'), Decimal('0.299717')),
#  ('French Polynesia', Decimal('5.71'), Decimal('0.301920')),
#  ('Gabon', Decimal('14.38'), Decimal('2.028517')),
#  ('Gabon', Decimal('14.02'), Decimal('2.086206')),
#  ('Gabon', Decimal('14.93'), Decimal('2.140215')),
#  ('Gabon', Decimal('16.87'), Decimal('2.192012')),
#  ('Gabon', Decimal('16.87'), Decimal('2.242785')),
#  ('Gabon', Decimal('15.31'), Decimal('2.292573')),
#  ('Gambia', None, None),
#  ('Gambia', None, None),
#  ('Gambia', None, None),
#  ('Gambia', None, None),
#  ('Gambia', None, None),
#  ('Gambia', None, None),
#  ('Georgia', Decimal('14.95'), Decimal('3.725276')),
#  ('Georgia', Decimal('15.14'), Decimal('3.727505')),
#  ('Georgia', Decimal('16.24'), Decimal('3.728004')),
#  ('Georgia', Decimal('17.60'), Decimal('3.726549')),
#  ('Georgia', Decimal('17.47'), Decimal('3.720161')),
#  ('Georgia', Decimal('15.84'), Decimal('3.722716')),
#  ('Ghana', Decimal('49.41'), Decimal('28.870939')),
#  ('Ghana', Decimal('56.17'), Decimal('29.554303')),
#  ('Ghana', Decimal('60.41'), Decimal('30.222262')),
#  ('Ghana', Decimal('67.30'), Decimal('30.870641')),
#  ('Ghana', Decimal('68.34'), Decimal('31.522290')),
#  ('Ghana', Decimal('70.04'), Decimal('32.180401')),
#  ('Greenland', Decimal('2.50'), Decimal('0.056114')),
#  ('Greenland', Decimal('2.71'), Decimal('0.056186')),
#  ('Greenland', Decimal('2.85'), Decimal('0.056171')),
#  ('Greenland', Decimal('3.06'), Decimal('0.056023')),
#  ('Greenland', Decimal('2.99'), Decimal('0.056225')),
#  ('Greenland', Decimal('3.08'), Decimal('0.056367')),
#  ('Grenada', Decimal('1.00'), Decimal('0.118980')),
#  ('Grenada', Decimal('1.06'), Decimal('0.119966')),
#  ('Grenada', Decimal('1.13'), Decimal('0.120921')),
#  ('Guadeloupe', None, None),
#  ('Guadeloupe', None, None),
#  ('Guadeloupe', None, None),
#  ('Guadeloupe', None, None),
#  ('Guadeloupe', None, None),
#  ('Guadeloupe', None, None),
#  ('Guam', Decimal('5.80'), Decimal('0.167978')),
#  ('Guam', Decimal('5.90'), Decimal('0.168346')),
#  ('Guam', Decimal('6.01'), Decimal('0.168606')),
#  ('Guam', Decimal('6.06'), Decimal('0.168678')),
#  ('Guam', Decimal('6.37'), Decimal('0.168624')),
#  ('Guam', Decimal('5.89'), Decimal('0.169231')),
#  ('Guatemala', Decimal('62.19'), Decimal('15.567419')),
#  ('Guatemala', Decimal('66.05'), Decimal('15.827690')),
#  ('Guatemala', Decimal('71.65'), Decimal('16.087418')),
#  ('Guatemala', Decimal('73.33'), Decimal('16.346950')),
#  ('Guatemala', Decimal('77.17'), Decimal('16.604026')),
#  ('Guatemala', Decimal('77.63'), Decimal('16.858333')),
#  ('Guinea', Decimal('8.79'), Decimal('11.625998')),
#  ('Guinea', Decimal('8.60'), Decimal('11.930985')),
#  ('Guinea', Decimal('10.32'), Decimal('12.240789')),
#  ('Guinea', Decimal('11.86'), Decimal('12.554864')),
#  ('Guinea', Decimal('13.44'), Decimal('12.877539')),
#  ('Guinea', Decimal('14.18'), Decimal('13.205153')),
#  ('Guinea-Bissau', Decimal('1.05'), Decimal('1.788919')),
#  ('Guinea-Bissau', Decimal('1.18'), Decimal('1.834552')),
#  ('Guinea-Bissau', Decimal('1.35'), Decimal('1.879826')),
#  ('Guinea-Bissau', Decimal('1.50'), Decimal('1.924955')),
#  ('Guinea-Bissau', Decimal('1.44'), Decimal('1.970457')),
#  ('Guinea-Bissau', Decimal('1.43'), Decimal('2.015828')),
#  ('Guyana', Decimal('4.28'), Decimal('0.755031')),
#  ('Guyana', Decimal('4.48'), Decimal('0.759087')),
#  ('Guyana', Decimal('4.75'), Decimal('0.763252')),
#  ('Guyana', Decimal('4.79'), Decimal('0.785514')),
#  ('Guyana', Decimal('5.17'), Decimal('0.798753')),
#  ('Guyana', Decimal('5.47'), Decimal('0.797202')),
#  ('Haiti', Decimal('14.83'), Decimal('10.563757')),
#  ('Haiti', Decimal('13.99'), Decimal('10.713849')),
#  ('Haiti', Decimal('15.04'), Decimal('10.863543')),
#  ('Haiti', Decimal('16.46'), Decimal('11.012421')),
#  ('Haiti', Decimal('14.79'), Decimal('11.160438')),
#  ('Haiti', Decimal('14.51'), Decimal('11.306801')),
#  ('Honduras', Decimal('20.98'), Decimal('9.294505')),
#  ('Honduras', Decimal('21.72'), Decimal('9.460798')),
#  ('Honduras', Decimal('23.14'), Decimal('9.626842')),
#  ('Honduras', Decimal('24.07'), Decimal('9.792850')),
#  ('Honduras', Decimal('25.09'), Decimal('9.958829')),
#  ('Honduras', Decimal('23.83'), Decimal('10.121763')),
#  ('India', Decimal('2103.59'), Decimal('1322.866505')),
#  ('India', Decimal('2294.80'), Decimal('1338.636340')),
#  ('India', Decimal('2651.47'), Decimal('1354.195680')),
#  ('India', Decimal('2702.93'), Decimal('1369.003306')),
#  ('India', Decimal('2831.55'), Decimal('1383.112050')),
#  ('India', Decimal('2667.69'), Decimal('1396.387127')),
#  ('Indonesia', Decimal('860.85'), Decimal('259.091970')),
#  ('Indonesia', Decimal('931.88'), Decimal('261.850182')),
#  ('Indonesia', Decimal('1015.62'), Decimal('264.498852')),
#  ('Indonesia', Decimal('1042.27'), Decimal('267.066843')),
#  ('Indonesia', Decimal('1119.10'), Decimal('269.582878')),
#  ('Indonesia', Decimal('1058.69'), Decimal('271.857970')),
#  ('Iran (Islamic Republic of)', None, None),
#  ('Iran (Islamic Republic of)', None, None),
#  ('Iran (Islamic Republic of)', None, None),
#  ('Iran (Islamic Republic of)', None, None),
#  ('Iran (Islamic Republic of)', None, None),
#  ('Iran (Islamic Republic of)', None, None),
#  ('Iraq', Decimal('166.77'), Decimal('37.757813')),
#  ('Iraq', Decimal('166.60'), Decimal('38.697943')),
#  ('Iraq', Decimal('187.22'), Decimal('39.621162')),
#  ('Iraq', Decimal('227.37'), Decimal('40.590700')),
#  ('Iraq', Decimal('233.64'), Decimal('41.563520')),
#  ('Iraq', Decimal('184.37'), Decimal('42.556984')),
#  ('Israel', Decimal('303.41'), Decimal('8.380100')),
#  ('Israel', Decimal('322.10'), Decimal('8.546000')),
#  ('Israel', Decimal('358.25'), Decimal('8.713300')),
#  ('Israel', Decimal('376.69'), Decimal('8.882800')),
#  ('Israel', Decimal('402.47'), Decimal('9.054000')),
#  ('Israel', Decimal('413.27'), Decimal('9.215100')),
#  ('Jamaica', Decimal('14.19'), Decimal('2.794445')),
#  ('Jamaica', Decimal('14.08'), Decimal('2.802695')),
#  ('Jamaica', Decimal('14.81'), Decimal('2.808376')),
#  ('Jamaica', Decimal('15.73'), Decimal('2.811835')),
#  ('Jamaica', Decimal('15.83'), Decimal('2.813773')),
#  ('Jamaica', Decimal('13.81'), Decimal('2.820436')),
#  ('Japan', Decimal('4444.93'), Decimal('127.141000')),
#  ('Japan', Decimal('5003.68'), Decimal('127.076000')),
#  ('Japan', Decimal('4930.84'), Decimal('126.972000')),
#  ('Japan', Decimal('5037.84'), Decimal('126.811000')),
#  ('Japan', Decimal('5123.32'), Decimal('126.633000')),
#  ('Japan', Decimal('5040.11'), Decimal('126.261000')),
#  ('Jordan', Decimal('38.59'), Decimal('9.494246')),
#  ('Jordan', Decimal('39.89'), Decimal('9.964656')),
#  ('Jordan', Decimal('41.61'), Decimal('10.215381')),
#  ('Jordan', Decimal('43.37'), Decimal('10.459865')),
#  ('Jordan', Decimal('44.99'), Decimal('10.698683')),
#  ('Jordan', Decimal('44.18'), Decimal('10.928721')),
#  ('Kazakhstan', Decimal('184.39'), Decimal('17.542806')),
#  ('Kazakhstan', Decimal('137.28'), Decimal('17.794055')),
#  ('Kazakhstan', Decimal('166.81'), Decimal('18.037776')),
#  ('Kazakhstan', Decimal('179.34'), Decimal('18.276452')),
#  ('Kazakhstan', Decimal('181.67'), Decimal('18.513673')),
#  ('Kazakhstan', Decimal('171.08'), Decimal('18.755666')),
#  ('Kenya', Decimal('70.12'), Decimal('46.851488')),
#  ('Kenya', Decimal('74.82'), Decimal('47.894670')),
#  ('Kenya', Decimal('82.04'), Decimal('48.948137')),
#  ('Kenya', Decimal('92.20'), Decimal('49.953304')),
#  ('Kenya', Decimal('100.38'), Decimal('50.951450')),
#  ('Kenya', Decimal('100.67'), Decimal('51.985780')),
#  ('Kiribati', Decimal('0.17'), Decimal('0.116707')),
#  ('Kiribati', Decimal('0.18'), Decimal('0.118513')),
#  ('Kiribati', Decimal('0.19'), Decimal('0.120362')),
#  ('Kiribati', Decimal('0.20'), Decimal('0.122261')),
#  ('Kiribati', Decimal('0.18'), Decimal('0.124241')),
#  ('Kiribati', Decimal('0.18'), Decimal('0.126463')),
#  ('Kuwait', Decimal('114.57'), Decimal('3.908743')),
#  ('Kuwait', Decimal('109.42'), Decimal('4.048085')),
#  ('Kuwait', Decimal('120.71'), Decimal('4.124904')),
#  ('Kuwait', Decimal('138.18'), Decimal('4.317185')),
#  ('Kuwait', Decimal('136.20'), Decimal('4.441100')),
#  ('Kuwait', Decimal('105.96'), Decimal('4.360444')),
#  ('Kyrgyzstan', None, None),
#  ('Kyrgyzstan', None, None),
#  ('Kyrgyzstan', None, None),
#  ('Kyrgyzstan', None, None),
#  ('Kyrgyzstan', None, None),
#  ('Kyrgyzstan', None, None),
#  ("Lao People's Democratic Republic", None, None),
#  ("Lao People's Democratic Republic", None, None),
#  ("Lao People's Democratic Republic", None, None),
#  ("Lao People's Democratic Republic", None, None),
#  ("Lao People's Democratic Republic", None, None),
#  ("Lao People's Democratic Republic", None, None),
#  ('Lebanon', Decimal('49.93'), Decimal('6.398940')),
#  ('Lebanon', Decimal('51.15'), Decimal('6.258619')),
#  ('Lebanon', Decimal('53.03'), Decimal('6.109252')),
#  ('Lebanon', Decimal('54.90'), Decimal('5.950839')),
#  ('Lebanon', Decimal('51.95'), Decimal('5.781907')),
#  ('Lebanon', Decimal('31.71'), Decimal('5.662923')),
#  ('Lesotho', Decimal('2.36'), Decimal('2.118521')),
#  ('Lesotho', Decimal('2.11'), Decimal('2.143872')),
#  ('Lesotho', Decimal('2.31'), Decimal('2.170617')),
#  ('Lesotho', Decimal('2.55'), Decimal('2.198017')),
#  ('Lesotho', Decimal('2.45'), Decimal('2.225702')),
#  ('Lesotho', Decimal('2.23'), Decimal('2.254100')),
#  ('Liberia', Decimal('3.23'), Decimal('4.612329')),
#  ('Liberia', Decimal('3.40'), Decimal('4.706097')),
#  ('Liberia', Decimal('3.39'), Decimal('4.796631')),
#  ('Liberia', Decimal('3.42'), Decimal('4.889391')),
#  ('Liberia', Decimal('3.32'), Decimal('4.985289')),
#  ('Liberia', Decimal('3.04'), Decimal('5.087584')),
#  ('Libya', Decimal('48.72'), Decimal('6.192235')),
#  ('Libya', Decimal('49.91'), Decimal('6.282196')),
#  ('Libya', Decimal('67.16'), Decimal('6.378261')),
#  ('Libya', Decimal('76.68'), Decimal('6.477793')),
#  ('Libya', Decimal('69.25'), Decimal('6.569088')),
#  ('Libya', Decimal('50.36'), Decimal('6.653942')),
#  ('Madagascar', Decimal('11.32'), Decimal('24.850912')),
#  ('Madagascar', Decimal('11.85'), Decimal('25.501941')),
#  ('Madagascar', Decimal('13.18'), Decimal('26.169542')),
#  ('Madagascar', Decimal('13.76'), Decimal('26.846541')),
#  ('Madagascar', Decimal('14.10'), Decimal('27.533134')),
#  ('Madagascar', Decimal('13.05'), Decimal('28.225177')),
#  ('Malawi', Decimal('6.37'), Decimal('16.938942')),
#  ('Malawi', Decimal('5.43'), Decimal('17.405624')),
#  ('Malawi', Decimal('8.94'), Decimal('17.881167')),
#  ('Malawi', Decimal('9.88'), Decimal('18.367883')),
#  ('Malawi', Decimal('11.03'), Decimal('18.867337')),
#  ('Malawi', Decimal('12.18'), Decimal('19.377061')),
#  ('Malaysia', Decimal('301.35'), Decimal('31.068833')),
#  ('Malaysia', Decimal('301.26'), Decimal('31.526418')),
#  ('Malaysia', Decimal('319.11'), Decimal('31.975806')),
#  ('Malaysia', Decimal('358.79'), Decimal('32.399271')),
#  ('Malaysia', Decimal('365.18'), Decimal('32.804020')),
#  ('Malaysia', Decimal('337.34'), Decimal('33.199993')),
#  ('Maldives', Decimal('4.11'), Decimal('0.435582')),
#  ('Maldives', Decimal('4.38'), Decimal('0.454252')),
#  ('Maldives', Decimal('4.75'), Decimal('0.472442')),
#  ('Maldives', Decimal('5.30'), Decimal('0.489758')),
#  ('Maldives', Decimal('5.61'), Decimal('0.504508')),
#  ('Maldives', Decimal('3.75'), Decimal('0.514438')),
#  ('Mali', Decimal('13.10'), Decimal('18.112907')),
#  ('Mali', Decimal('14.03'), Decimal('18.700106')),
#  ('Mali', Decimal('15.37'), Decimal('19.311355')),
#  ('Mali', Decimal('17.07'), Decimal('19.934298')),
#  ('Mali', Decimal('17.28'), Decimal('20.567424')),
#  ('Mali', Decimal('17.47'), Decimal('21.224040')),
#  ('Marshall Islands', Decimal('0.18'), Decimal('0.049410')),
#  ('Marshall Islands', Decimal('0.20'), Decimal('0.048329')),
#  ('Marshall Islands', Decimal('0.21'), Decimal('0.047187')),
#  ('Marshall Islands', Decimal('0.22'), Decimal('0.045989')),
#  ('Marshall Islands', Decimal('0.23'), Decimal('0.044728')),
#  ('Marshall Islands', Decimal('0.24'), Decimal('0.043413')),
#  ('Martinique', None, None),
#  ('Martinique', None, None),
#  ('Martinique', None, None),
#  ('Martinique', None, None),
#  ('Martinique', None, None),
#  ('Martinique', None, None),
#  ('Mauritania', Decimal('6.17'), Decimal('3.946220')),
#  ('Mauritania', Decimal('6.40'), Decimal('4.051890')),
#  ('Mauritania', Decimal('6.80'), Decimal('4.160015')),
#  ('Mauritania', Decimal('7.47'), Decimal('4.270712')),
#  ('Mauritania', Decimal('8.07'), Decimal('4.383849')),
#  ('Mauritania', Decimal('8.41'), Decimal('4.498604')),
#  ('Mauritius', Decimal('12.01'), Decimal('1.262605')),
#  ('Mauritius', Decimal('12.59'), Decimal('1.263473')),
#  ('Mauritius', Decimal('13.71'), Decimal('1.264613')),
#  ('Mauritius', Decimal('14.74'), Decimal('1.265303')),
#  ('Mauritius', Decimal('14.44'), Decimal('1.265711')),
#  ('Mauritius', Decimal('11.40'), Decimal('1.265740')),
#  ('Mayotte', None, None),
#  ('Mayotte', None, None),
#  ('Mayotte', None, None),
#  ('Mayotte', None, None),
#  ('Mayotte', None, None),
#  ('Mayotte', None, None),
#  ('Mexico', Decimal('1171.87'), Decimal('120.149897')),
#  ('Mexico', Decimal('1078.49'), Decimal('121.519221')),
#  ('Mexico', Decimal('1158.91'), Decimal('122.839258')),
#  ('Mexico', Decimal('1222.41'), Decimal('124.013861')),
#  ('Mexico', Decimal('1269.01'), Decimal('125.085311')),
#  ('Mexico', Decimal('1090.52'), Decimal('125.998302')),
#  ('Micronesia (Federated States of)', None, None),
#  ('Micronesia (Federated States of)', None, None),
#  ('Micronesia (Federated States of)', None, None),
#  ('Micronesia (Federated States of)', None, None),
#  ('Micronesia (Federated States of)', None, None),
#  ('Mongolia', Decimal('11.62'), Decimal('2.964749')),
#  ('Mongolia', Decimal('11.18'), Decimal('3.029555')),
#  ('Mongolia', Decimal('11.48'), Decimal('3.096030')),
#  ('Mongolia', Decimal('13.18'), Decimal('3.163991')),
#  ('Mongolia', Decimal('14.21'), Decimal('3.232430')),
#  ('Mongolia', Decimal('13.31'), Decimal('3.294335')),
#  ('Montserrat', None, None),
#  ('Montserrat', None, None),
#  ('Montserrat', None, None),
#  ('Montserrat', None, None),
#  ('Montserrat', None, None),
#  ('Montserrat', None, None),
#  ('Morocco', Decimal('110.41'), Decimal('34.680458')),
#  ('Morocco', Decimal('111.57'), Decimal('35.107264')),
#  ('Morocco', Decimal('118.54'), Decimal('35.528115')),
#  ('Morocco', Decimal('127.34'), Decimal('35.927511')),
#  ('Morocco', Decimal('128.92'), Decimal('36.304408')),
#  ('Morocco', Decimal('121.35'), Decimal('36.688772')),
#  ('Mozambique', Decimal('15.95'), Decimal('26.843246')),
#  ('Mozambique', Decimal('11.94'), Decimal('27.696493')),
#  ('Mozambique', Decimal('13.22'), Decimal('28.569441')),
#  ('Mozambique', Decimal('14.85'), Decimal('29.423878')),
#  ('Mozambique', Decimal('15.39'), Decimal('30.285595')),
#  ('Mozambique', Decimal('14.03'), Decimal('31.178239')),
#  ('Myanmar', Decimal('63.05'), Decimal('51.483949')),
#  ('Myanmar', Decimal('60.29'), Decimal('51.892349')),
#  ('Myanmar', Decimal('61.45'), Decimal('52.288341')),
#  ('Myanmar', Decimal('67.14'), Decimal('52.666014')),
#  ('Myanmar', Decimal('68.70'), Decimal('53.040212')),
#  ('Myanmar', Decimal('78.93'), Decimal('53.423198')),
#  ('Namibia', Decimal('11.34'), Decimal('2.282704')),
#  ('Namibia', Decimal('10.72'), Decimal('2.323352')),
#  ('Namibia', Decimal('12.90'), Decimal('2.364534')),
#  ('Namibia', Decimal('13.68'), Decimal('2.405680')),
#  ('Namibia', Decimal('12.54'), Decimal('2.446644')),
#  ('Namibia', Decimal('10.58'), Decimal('2.489098')),
#  ('Nauru', Decimal('0.09'), Decimal('0.011185')),
#  ('Nauru', Decimal('0.10'), Decimal('0.011437')),
#  ('Nauru', Decimal('0.11'), Decimal('0.011682')),
#  ('Nauru', Decimal('0.12'), Decimal('0.011924')),
#  ('Nauru', Decimal('0.12'), Decimal('0.012132')),
#  ('Nauru', Decimal('0.11'), Decimal('0.012315')),
#  ('Nepal', Decimal('24.36'), Decimal('27.610325')),
#  ('Nepal', Decimal('24.52'), Decimal('27.861186')),
#  ('Nepal', Decimal('28.97'), Decimal('28.183426')),
#  ('Nepal', Decimal('33.11'), Decimal('28.506712')),
#  ('Nepal', Decimal('34.19'), Decimal('28.832496')),
#  ('Nepal', Decimal('33.43'), Decimal('29.348627')),
#  ('New Caledonia', Decimal('8.74'), Decimal('0.269460')),
#  ('New Caledonia', Decimal('8.72'), Decimal('0.270220')),
#  ('New Caledonia', Decimal('9.17'), Decimal('0.270810')),
#  ('New Caledonia', Decimal('9.85'), Decimal('0.271170')),
#  ('New Caledonia', Decimal('9.44'), Decimal('0.271230')),
#  ('New Caledonia', Decimal('9.44'), Decimal('0.271130')),
#  ('New Zealand', Decimal('178.06'), Decimal('4.609400')),
#  ('New Zealand', Decimal('188.84'), Decimal('4.714100')),
#  ('New Zealand', Decimal('206.62'), Decimal('4.813600')),
#  ('New Zealand', Decimal('211.95'), Decimal('4.900600')),
#  ('New Zealand', Decimal('213.43'), Decimal('4.979200')),
#  ('New Zealand', Decimal('211.73'), Decimal('5.090200')),
#  ('Nicaragua', Decimal('12.76'), Decimal('6.298598')),
#  ('Nicaragua', Decimal('13.29'), Decimal('6.389235')),
#  ('Nicaragua', Decimal('13.79'), Decimal('6.480532')),
#  ('Nicaragua', Decimal('13.03'), Decimal('6.572233')),
#  ('Nicaragua', Decimal('12.60'), Decimal('6.663924')),
#  ('Nicaragua', Decimal('12.59'), Decimal('6.755895')),
#  ('Niger', Decimal('9.68'), Decimal('20.128124')),
#  ('Niger', Decimal('10.40'), Decimal('20.921743')),
#  ('Niger', Decimal('11.19'), Decimal('21.737922')),
#  ('Niger', Decimal('12.81'), Decimal('22.577058')),
#  ('Niger', Decimal('12.92'), Decimal('23.443393')),
#  ('Niger', Decimal('13.74'), Decimal('24.333639')),
#  ('Nigeria', Decimal('493.03'), Decimal('183.995785')),
#  ('Nigeria', Decimal('404.65'), Decimal('188.666931')),
#  ('Nigeria', Decimal('375.75'), Decimal('193.495907')),
#  ('Nigeria', Decimal('421.74'), Decimal('198.387623')),
#  ('Nigeria', Decimal('448.12'), Decimal('203.304492')),
#  ('Nigeria', Decimal('432.20'), Decimal('208.327405')),
#  ('Niue', None, None),
#  ('Niue', None, None),
#  ('Niue', None, None),
#  ('Niue', None, None),
#  ('Niue', None, None),
#  ('Niue', None, None),
#  ('Northern Mariana Islands', Decimal('0.91'), Decimal('0.051514')),
#  ('Northern Mariana Islands', Decimal('1.23'), Decimal('0.051133')),
#  ('Northern Mariana Islands', Decimal('1.56'), Decimal('0.050729')),
#  ('Northern Mariana Islands', Decimal('1.30'), Decimal('0.050304')),
#  ('Northern Mariana Islands', Decimal('1.18'), Decimal('0.049858')),
#  ('Northern Mariana Islands', None, Decimal('0.049587')),
#  ('Oman', Decimal('78.71'), Decimal('4.191776')),
#  ('Oman', Decimal('75.13'), Decimal('4.398070')),
#  ('Oman', Decimal('80.86'), Decimal('4.541854')),
#  ('Oman', Decimal('91.51'), Decimal('4.601157')),
#  ('Oman', Decimal('88.06'), Decimal('4.602768')),
#  ('Oman', Decimal('75.91'), Decimal('4.543399')),
#  ('Pakistan', Decimal('270.56'), Decimal('210.969298')),
#  ('Pakistan', Decimal('313.63'), Decimal('213.524840')),
#  ('Pakistan', Decimal('339.21'), Decimal('216.379655')),
#  ('Pakistan', Decimal('356.13'), Decimal('219.731479')),
#  ('Pakistan', Decimal('320.91'), Decimal('223.293280')),
#  ('Pakistan', Decimal('300.43'), Decimal('227.196741')),
#  ('Palau', Decimal('0.28'), Decimal('0.017794')),
#  ('Palau', Decimal('0.30'), Decimal('0.017816')),
#  ('Palau', Decimal('0.29'), Decimal('0.017837')),
#  ('Palau', Decimal('0.28'), Decimal('0.017864')),
#  ('Palau', Decimal('0.28'), Decimal('0.017916')),
#  ('Palau', Decimal('0.25'), Decimal('0.017972')),
#  ('Panama', Decimal('54.09'), Decimal('3.957099')),
#  ('Panama', Decimal('57.91'), Decimal('4.026336')),
#  ('Panama', Decimal('62.20'), Decimal('4.096063')),
#  ('Panama', Decimal('64.93'), Decimal('4.165255')),
#  ('Panama', Decimal('66.98'), Decimal('4.232532')),
#  ('Panama', Decimal('53.98'), Decimal('4.294396')),
#  ('Papua New Guinea', Decimal('21.72'), Decimal('8.682174')),
#  ('Papua New Guinea', Decimal('20.76'), Decimal('8.899169')),
#  ('Papua New Guinea', Decimal('22.74'), Decimal('9.114796')),
#  ('Papua New Guinea', Decimal('24.11'), Decimal('9.329227')),
#  ('Papua New Guinea', Decimal('24.75'), Decimal('9.542486')),
#  ('Papua New Guinea', Decimal('23.85'), Decimal('9.749640')),
#  ('Paraguay', Decimal('36.21'), Decimal('6.177950')),
#  ('Paraguay', Decimal('36.09'), Decimal('6.266615')),
#  ('Paraguay', Decimal('39.00'), Decimal('6.355404')),
#  ('Paraguay', Decimal('40.23'), Decimal('6.443328')),
#  ('Paraguay', Decimal('37.93'), Decimal('6.530026')),
#  ('Paraguay', Decimal('35.43'), Decimal('6.618695')),
#  ('Peru', Decimal('189.81'), Decimal('30.711863')),
#  ('Peru', Decimal('191.90'), Decimal('31.132779')),
#  ('Peru', Decimal('211.01'), Decimal('31.605486')),
#  ('Peru', Decimal('222.60'), Decimal('32.203944')),
#  ('Peru', Decimal('228.32'), Decimal('32.824861')),
#  ('Peru', Decimal('201.71'), Decimal('33.304756')),
#  ('Philippines', Decimal('306.45'), Decimal('103.031365')),
#  ('Philippines', Decimal('318.63'), Decimal('104.875266')),
#  ('Philippines', Decimal('328.48'), Decimal('106.738501')),
#  ('Philippines', Decimal('346.84'), Decimal('108.568836')),
#  ('Philippines', Decimal('376.82'), Decimal('110.380804')),
#  ('Philippines', Decimal('361.75'), Decimal('112.190977')),
#  ('Puerto Rico', Decimal('103.38'), Decimal('3.473232')),
#  ('Puerto Rico', Decimal('104.34'), Decimal('3.406672')),
#  ('Puerto Rico', Decimal('103.45'), Decimal('3.325286')),
#  ('Puerto Rico', Decimal('100.96'), Decimal('3.193354')),
#  ('Puerto Rico', Decimal('105.13'), Decimal('3.193694')),
#  ('Puerto Rico', Decimal('103.02'), Decimal('3.281538')),
#  ('Qatar', Decimal('161.74'), Decimal('2.414573')),
#  ('Qatar', Decimal('151.73'), Decimal('2.595166')),
#  ('Qatar', Decimal('161.10'), Decimal('2.711755')),
#  ('Qatar', Decimal('183.33'), Decimal('2.766732')),
#  ('Qatar', Decimal('175.84'), Decimal('2.807235')),
#  ('Qatar', Decimal('144.41'), Decimal('2.760385')),
#  ('Republic of Korea', None, None),
#  ('Republic of Korea', None, None),
#  ('Republic of Korea', None, None),
#  ('Republic of Korea', None, None),
#  ('Republic of Korea', None, None),
#  ('Republic of Korea', None, None),
#  ('Réunion', None, None),
#  ('Réunion', None, None),
#  ('Réunion', None, None),
#  ('Réunion', None, None),
#  ('Réunion', None, None),
#  ('Réunion', None, None),
#  ('Rwanda', Decimal('8.54'), Decimal('11.642959')),
#  ('Rwanda', Decimal('8.69'), Decimal('11.930899')),
#  ('Rwanda', Decimal('9.25'), Decimal('12.230339')),
#  ('Rwanda', Decimal('9.64'), Decimal('12.531808')),
#  ('Rwanda', Decimal('10.36'), Decimal('12.835028')),
#  ('Rwanda', Decimal('10.18'), Decimal('13.146362')),
#  ('Saint Barthélemy', None, None),
#  ('Saint Barthélemy', None, None),
#  ('Saint Barthélemy', None, None),
#  ('Saint Barthélemy', None, None),
#  ('Saint Barthélemy', None, None),
#  ('Saint Barthélemy', None, None),
#  ('Saint Helena', None, None),
#  ('Saint Helena', None, None),
#  ('Saint Helena', None, None),
#  ('Saint Helena', None, None),
#  ('Saint Helena', None, None),
#  ('Saint Helena', None, None),
#  ('Saint Kitts and Nevis', None, None),
#  ('Saint Kitts and Nevis', None, None),
#  ('Saint Kitts and Nevis', None, None),
#  ('Saint Lucia', None, None),
#  ('Saint Lucia', None, None),
#  ('Saint Lucia', None, None),
#  ('Saint Lucia', None, None),
#  ('Saint Lucia', None, None),
#  ('Saint Lucia', None, None),
#  ('Saint Martin (French Part)', None, None),
#  ('Saint Martin (French Part)', None, None),
#  ('Saint Martin (French Part)', None, None),
#  ('Saint Martin (French Part)', None, None),
#  ('Saint Martin (French Part)', None, None),
#  ('Saint Martin (French Part)', None, None),
#  ('Saint Pierre and Miquelon', None, None),
#  ('Saint Pierre and Miquelon', None, None),
#  ('Saint Pierre and Miquelon', None, None),
#  ('Saint Pierre and Miquelon', None, None),
#  ('Saint Pierre and Miquelon', None, None),
#  ('Saint Pierre and Miquelon', None, None),
#  ('Saint Vincent and the Grenadines', None, None),
#  ('Saint Vincent and the Grenadines', None, None),
#  ('Saint Vincent and the Grenadines', None, None),
#  ('Saint Vincent and the Grenadines', None, None),
#  ('Samoa', Decimal('0.82'), Decimal('0.203571')),
#  ('Samoa', Decimal('0.84'), Decimal('0.205544')),
#  ('Samoa', Decimal('0.88'), Decimal('0.207630')),
#  ('Samoa', Decimal('0.88'), Decimal('0.209701')),
#  ('Samoa', Decimal('0.91'), Decimal('0.211905')),
#  ('Samoa', Decimal('0.87'), Decimal('0.214929')),
#  ('Sao Tome and Principe', Decimal('0.32'), Decimal('0.201124')),
#  ('Sao Tome and Principe', Decimal('0.35'), Decimal('0.204632')),
#  ('Sao Tome and Principe', Decimal('0.38'), Decimal('0.208036')),
#  ('Sao Tome and Principe', Decimal('0.41'), Decimal('0.211344')),
#  ('Sao Tome and Principe', Decimal('0.43'), Decimal('0.214599')),
#  ('Sao Tome and Principe', Decimal('0.47'), Decimal('0.218641')),
#  ('Saudi Arabia', Decimal('654.27'), Decimal('32.749848')),
#  ('Saudi Arabia', Decimal('644.94'), Decimal('33.416270')),
#  ('Saudi Arabia', Decimal('688.59'), Decimal('34.193122')),
#  ('Saudi Arabia', Decimal('816.58'), Decimal('35.018133')),
#  ('Saudi Arabia', Decimal('803.62'), Decimal('35.827362')),
#  ('Saudi Arabia', Decimal('703.37'), Decimal('35.997107')),
#  ('Senegal', Decimal('17.77'), Decimal('14.356181')),
#  ('Senegal', Decimal('19.04'), Decimal('14.751356')),
#  ('Senegal', Decimal('21.00'), Decimal('15.157793')),
#  ('Senegal', Decimal('23.12'), Decimal('15.574909')),
#  ('Senegal', Decimal('23.40'), Decimal('16.000781')),
#  ('Senegal', Decimal('24.49'), Decimal('16.436120')),
#  ('Seychelles', Decimal('1.42'), Decimal('0.093419')),
#  ('Seychelles', Decimal('1.49'), Decimal('0.094677')),
#  ('Seychelles', Decimal('1.57'), Decimal('0.095843')),
#  ('Seychelles', Decimal('1.64'), Decimal('0.096762')),
#  ('Seychelles', Decimal('1.68'), Decimal('0.097625')),
#  ('Sierra Leone', Decimal('4.22'), Decimal('7.314773')),
#  ('Sierra Leone', Decimal('3.67'), Decimal('7.493913')),
#  ('Sierra Leone', Decimal('3.72'), Decimal('7.677565')),
#  ('Sierra Leone', Decimal('4.09'), Decimal('7.861281')),
#  ('Sierra Leone', Decimal('4.08'), Decimal('8.046828')),
#  ('Sierra Leone', Decimal('4.06'), Decimal('8.233970')),
#  ('Singapore', Decimal('308.00'), Decimal('5.535002')),
#  ('Singapore', Decimal('318.83'), Decimal('5.607283')),
#  ('Singapore', Decimal('343.19'), Decimal('5.612253')),
#  ('Singapore', Decimal('377.00'), Decimal('5.638676')),
#  ('Singapore', Decimal('375.47'), Decimal('5.703569')),
#  ('Singapore', Decimal('345.30'), Decimal('5.685807')),
#  ('Sint Maarten (Dutch part)', Decimal('1.25'), Decimal('0.038825')),
#  ('Sint Maarten (Dutch part)', Decimal('1.26'), Decimal('0.039969')),
#  ('Sint Maarten (Dutch part)', Decimal('1.19'), Decimal('0.040574')),
#  ('Solomon Islands', Decimal('1.31'), Decimal('0.612660')),
#  ('Solomon Islands', Decimal('1.38'), Decimal('0.628102')),
#  ('Solomon Islands', Decimal('1.47'), Decimal('0.643634')),
#  ('Solomon Islands', Decimal('1.62'), Decimal('0.659249')),
#  ('Solomon Islands', Decimal('1.62'), Decimal('0.674993')),
#  ('Solomon Islands', Decimal('1.54'), Decimal('0.691191')),
#  ('Somalia', Decimal('5.33'), Decimal('13.763906')),
#  ('Somalia', Decimal('5.53'), Decimal('14.292847')),
#  ('Somalia', Decimal('5.61'), Decimal('14.864221')),
#  ('Somalia', Decimal('5.86'), Decimal('15.411094')),
#  ('Somalia', Decimal('6.49'), Decimal('15.981300')),
#  ('Somalia', Decimal('6.88'), Decimal('16.537016')),
#  ('South Africa', Decimal('346.71'), Decimal('55.876504')),
#  ('South Africa', Decimal('323.59'), Decimal('56.422274')),
#  ('South Africa', Decimal('381.45'), Decimal('56.641209')),
#  ('South Africa', Decimal('404.16'), Decimal('57.339635')),
#  ('South Africa', Decimal('388.53'), Decimal('58.087055')),
#  ('South Africa', Decimal('337.62'), Decimal('58.801927')),
#  ('South Sudan', Decimal('12.00'), Decimal('11.194299')),
#  ('South Sudan', None, Decimal('11.066105')),
#  ('South Sudan', None, Decimal('10.658226')),
#  ('South Sudan', None, Decimal('10.395329')),
#  ('South Sudan', None, Decimal('10.447666')),
#  ('South Sudan', None, Decimal('10.606227')),
#  ('Sri Lanka', Decimal('85.14'), Decimal('20.970000')),
#  ('Sri Lanka', Decimal('88.01'), Decimal('21.203000')),
#  ('Sri Lanka', Decimal('94.38'), Decimal('21.444000')),
#  ('Sri Lanka', Decimal('94.49'), Decimal('21.670000')),
#  ('Sri Lanka', Decimal('89.01'), Decimal('21.803000')),
#  ('Sri Lanka', Decimal('85.35'), Decimal('21.919000')),
#  ('State of Palestine', None, None),
#  ('State of Palestine', None, None),
#  ('State of Palestine', None, None),
#  ('State of Palestine', None, None),
#  ('State of Palestine', None, None),
#  ('State of Palestine', None, None),
#  ('Sudan', Decimal('84.99'), Decimal('38.171178')),
#  ('Sudan', Decimal('102.94'), Decimal('39.377169')),
#  ('Sudan', Decimal('129.72'), Decimal('40.679828')),
#  ('Sudan', Decimal('32.33'), Decimal('41.999059')),
#  ('Sudan', Decimal('32.34'), Decimal('43.232093')),
#  ('Sudan', Decimal('27.03'), Decimal('44.440486')),
#  ('Suriname', Decimal('5.13'), Decimal('0.575475')),
#  ('Suriname', Decimal('3.32'), Decimal('0.581453')),
#  ('Suriname', Decimal('3.59'), Decimal('0.587559')),
#  ('Suriname', Decimal('4.00'), Decimal('0.593715')),
#  ('Suriname', Decimal('4.02'), Decimal('0.600301')),
#  ('Suriname', Decimal('2.91'), Decimal('0.607065')),
#  ('Syrian Arab Republic', Decimal('16.47'), Decimal('19.205178')),
#  ('Syrian Arab Republic', Decimal('12.60'), Decimal('18.964252')),
#  ('Syrian Arab Republic', Decimal('16.37'), Decimal('18.983373')),
#  ('Syrian Arab Republic', Decimal('21.35'), Decimal('19.333463')),
#  ('Syrian Arab Republic', Decimal('22.44'), Decimal('20.098251')),
#  ('Syrian Arab Republic', Decimal('11.08'), Decimal('20.772595')),
#  ('Tajikistan', Decimal('8.27'), Decimal('8.524063')),
#  ('Tajikistan', Decimal('6.99'), Decimal('8.725318')),
#  ('Tajikistan', Decimal('7.54'), Decimal('8.925525')),
#  ('Tajikistan', Decimal('7.77'), Decimal('9.128132')),
#  ('Tajikistan', Decimal('8.30'), Decimal('9.337003')),
#  ('Tajikistan', Decimal('8.13'), Decimal('9.543207')),
#  ('Thailand', Decimal('401.30'), Decimal('70.294397')),
#  ('Thailand', Decimal('413.37'), Decimal('70.607037')),
#  ('Thailand', Decimal('456.36'), Decimal('70.898202')),
#  ('Thailand', Decimal('506.75'), Decimal('71.127802')),
#  ('Thailand', Decimal('544.08'), Decimal('71.307763')),
#  ('Thailand', Decimal('499.68'), Decimal('71.475664')),
#  ('Timor-Leste', Decimal('1.59'), Decimal('1.205813')),
#  ('Timor-Leste', Decimal('1.65'), Decimal('1.224562')),
#  ('Timor-Leste', Decimal('1.60'), Decimal('1.243235')),
#  ('Timor-Leste', Decimal('1.56'), Decimal('1.261845')),
#  ('Timor-Leste', Decimal('2.03'), Decimal('1.280438')),
#  ('Timor-Leste', Decimal('2.16'), Decimal('1.299995')),
#  ('Togo', Decimal('4.18'), Decimal('7.473229')),
#  ('Togo', Decimal('6.03'), Decimal('7.661354')),
#  ('Togo', Decimal('6.40'), Decimal('7.852795')),
#  ('Togo', Decimal('7.11'), Decimal('8.046679')),
#  ('Togo', Decimal('7.22'), Decimal('8.243094')),
#  ('Togo', Decimal('7.57'), Decimal('8.442580')),
#  ('Tokelau', None, None),
#  ('Tokelau', None, None),
#  ('Tokelau', None, None),
#  ('Tokelau', None, None),
#  ('Tokelau', None, None),
#  ('Tokelau', None, None),
#  ('Tonga', Decimal('0.44'), Decimal('0.106122')),
#  ('Tonga', Decimal('0.42'), Decimal('0.105707')),
#  ('Tonga', Decimal('0.46'), Decimal('0.105415')),
#  ('Tonga', Decimal('0.49'), Decimal('0.105150')),
#  ('Tonga', Decimal('0.51'), Decimal('0.104951')),
#  ('Tonga', Decimal('0.48'), Decimal('0.105254')),
#  ('Trinidad and Tobago', Decimal('26.85'), Decimal('1.460177')),
#  ('Trinidad and Tobago', Decimal('23.50'), Decimal('1.469330')),
#  ('Trinidad and Tobago', Decimal('23.80'), Decimal('1.478607')),
#  ('Trinidad and Tobago', Decimal('24.32'), Decimal('1.504709')),
#  ('Trinidad and Tobago', Decimal('23.85'), Decimal('1.519955')),
#  ('Trinidad and Tobago', Decimal('21.06'), Decimal('1.518147')),
#  ('Tunisia', Decimal('45.78'), Decimal('11.557779')),
#  ('Tunisia', Decimal('44.36'), Decimal('11.685667')),
#  ('Tunisia', Decimal('42.16'), Decimal('11.811443')),
#  ('Tunisia', Decimal('42.69'), Decimal('11.933041')),
#  ('Tunisia', Decimal('41.91'), Decimal('12.049314')),
#  ('Tunisia', Decimal('42.54'), Decimal('12.161723')),
#  ('Türkiye', None, None),
#  ('Türkiye', None, None),
#  ('Türkiye', None, None),
#  ('Türkiye', None, None),
#  ('Türkiye', None, None),
#  ('Türkiye', None, None),
#  ('Turkmenistan', Decimal('35.80'), Decimal('5.766431')),
#  ('Turkmenistan', Decimal('36.17'), Decimal('5.868561')),
#  ('Turkmenistan', Decimal('37.93'), Decimal('5.968383')),
#  ('Turkmenistan', Decimal('40.77'), Decimal('6.065066')),
#  ('Turkmenistan', Decimal('45.23'), Decimal('6.158420')),
#  ('Turkmenistan', None, Decimal('6.250438')),
#  ('Turks and Caicos Islands', Decimal('0.94'), Decimal('0.036538')),
#  ('Turks and Caicos Islands', Decimal('1.03'), Decimal('0.038246')),
#  ('Turks and Caicos Islands', Decimal('1.02'), Decimal('0.039844')),
#  ('Turks and Caicos Islands', Decimal('1.11'), Decimal('0.041487')),
#  ('Tuvalu', Decimal('0.04'), Decimal('0.010877')),
#  ('Tuvalu', Decimal('0.04'), Decimal('0.010852')),
#  ('Tuvalu', Decimal('0.05'), Decimal('0.010828')),
#  ('Tuvalu', Decimal('0.05'), Decimal('0.010865')),
#  ('Tuvalu', Decimal('0.05'), Decimal('0.010956')),
#  ('Tuvalu', Decimal('0.06'), Decimal('0.011069')),
#  ('Uganda', Decimal('32.39'), Decimal('37.477356')),
#  ('Uganda', Decimal('29.20'), Decimal('38.748299')),
#  ('Uganda', Decimal('30.74'), Decimal('40.127085')),
#  ('Uganda', Decimal('32.93'), Decimal('41.515395')),
#  ('Uganda', Decimal('35.35'), Decimal('42.949080')),
#  ('Uganda', Decimal('37.60'), Decimal('44.404611')),
#  ('United Arab Emirates', Decimal('370.28'), Decimal('8.916899')),
#  ('United Arab Emirates', Decimal('369.26'), Decimal('8.994263')),
#  ('United Arab Emirates', Decimal('390.52'), Decimal('9.068296')),
#  ('United Arab Emirates', Decimal('427.05'), Decimal('9.140169')),
#  ('United Arab Emirates', Decimal('417.99'), Decimal('9.211657')),
#  ('United Arab Emirates', Decimal('349.47'), Decimal('9.287289')),
#  ('United Republic of Tanzania', None, None),
#  ('United Republic of Tanzania', None, None),
#  ('United Republic of Tanzania', None, None),
#  ('United Republic of Tanzania', None, None),
#  ('United Republic of Tanzania', None, None),
#  ('United Republic of Tanzania', None, None),
#  ('United States of America', None, None),
#  ('United States of America', None, None),
#  ('United States of America', None, None),
#  ('United States of America', None, None),
#  ('United States of America', None, None),
#  ('United States of America', None, None),
#  ('United States Virgin Islands', None, None),
#  ('United States Virgin Islands', None, None),
#  ('United States Virgin Islands', None, None),
#  ('United States Virgin Islands', None, None),
#  ('United States Virgin Islands', None, None),
#  ('United States Virgin Islands', None, None),
#  ('Uruguay', Decimal('53.27'), Decimal('3.402818')),
#  ('Uruguay', Decimal('57.24'), Decimal('3.413766')),
#  ('Uruguay', Decimal('64.23'), Decimal('3.422200')),
#  ('Uruguay', Decimal('64.52'), Decimal('3.427042')),
#  ('Uruguay', Decimal('61.23'), Decimal('3.428409')),
#  ('Uruguay', Decimal('53.56'), Decimal('3.429086')),
#  ...]

# %% [markdown]
# ### Creating the main query
# Construct a query that filters out countries with unemployment rates above 5%. The query should include the following columns: `Country_name`, `Est_gdp_in_billions`,  `Est_population_in_millions`.

# %%
# %%sql
# # Add your code here
# SELECT
#     *
# FROM
#      Economic_Indicators
# WHERE
#     Time_Period = 2020
#     AND
#     Pct_unemployment <= 5
# Out:
#  * mysql+pymysql://root:***@localhost:3306/united_nations
# 20 rows affected.
# [('Burundi', 2020, Decimal('2.65'), Decimal('12.220227'), Decimal('1.03')),
#  ('Indonesia', 2020, Decimal('1058.69'), Decimal('271.857970'), Decimal('4.25')),
#  ('Israel', 2020, Decimal('413.27'), Decimal('9.215100'), Decimal('4.17')),
#  ('Japan', 2020, Decimal('5040.11'), Decimal('126.261000'), Decimal('2.81')),
#  ('Kazakhstan', 2020, Decimal('171.08'), Decimal('18.755666'), Decimal('4.89')),
#  ('Malawi', 2020, Decimal('12.18'), Decimal('19.377061'), Decimal('0.91')),
#  ('Malaysia', 2020, Decimal('337.34'), Decimal('33.199993'), Decimal('4.54')),
#  ('Mali', 2020, Decimal('17.47'), Decimal('21.224040'), Decimal('3.53')),
#  ('Mexico', 2020, Decimal('1090.52'), Decimal('125.998302'), Decimal('4.44')),
#  ('Myanmar', 2020, Decimal('78.93'), Decimal('53.423198'), Decimal('1.48')),
#  ('New Zealand', 2020, Decimal('211.73'), Decimal('5.090200'), Decimal('4.60')),
#  ('Oman', 2020, Decimal('75.91'), Decimal('4.543399'), Decimal('2.94')),
#  ('Palau', 2020, Decimal('0.25'), Decimal('0.017972'), Decimal('0.77')),
#  ('Philippines', 2020, Decimal('361.75'), Decimal('112.190977'), Decimal('2.52')),
#  ('Qatar', 2020, Decimal('144.41'), Decimal('2.760385'), Decimal('0.14')),
#  ('Singapore', 2020, Decimal('345.30'), Decimal('5.685807'), Decimal('4.10')),
#  ('Thailand', 2020, Decimal('499.68'), Decimal('71.475664'), Decimal('1.10')),
#  ('Trinidad and Tobago', 2020, Decimal('21.06'), Decimal('1.518147'), Decimal('4.21')),
#  ('United Arab Emirates', 2020, Decimal('349.47'), Decimal('9.287289'), Decimal('4.29')),
#  ('Vanuatu', 2020, Decimal('0.90'), Decimal('0.311685'), Decimal('4.05'))]

# %% [markdown]
# ### Combining the queries
#
# Using the query and the subquery, determine the average GDP and population for countries with unemployment rates above 5%. Group the results by `Country_name`.

# %%
# %%sql
# # Add your code here
# SELECT
#     Country_name,
#     AVG(Est_gdp_in_billions) AS AVG_GDP,
#     AVG(Est_population_in_millions) AS AVG_POP
# FROM
#      (
#         SELECT
#             *
#         FROM
#          Economic_Indicators
#         WHERE
#             Time_Period = 2020
#             AND
#             Pct_unemployment > 5
#      ) E
# GROUP BY
#     Country_Name
# Out:
#  * mysql+pymysql://root:***@localhost:3306/united_nations
# 37 rows affected.
# [('Afghanistan', Decimal('20.140000'), Decimal('38.9722300000')),
#  ('Argentina', Decimal('385.540000'), Decimal('45.3767630000')),
#  ('Armenia', Decimal('12.640000'), Decimal('2.8056080000')),
#  ('Australia', Decimal('1326.900000'), Decimal('25.6552890000')),
#  ('Azerbaijan', Decimal('42.690000'), Decimal('10.0931210000')),
#  ('Bhutan', Decimal('2.330000'), Decimal('0.7725060000')),
#  ('Botswana', Decimal('14.930000'), Decimal('2.5464020000')),
#  ('Brazil', Decimal('1448.560000'), Decimal('213.1963040000')),
#  ('Brunei Darussalam', Decimal('12.010000'), Decimal('0.4417250000')),
#  ('Canada', Decimal('1645.420000'), Decimal('38.0372040000')),
#  ('Chile', Decimal('252.730000'), Decimal('19.3003150000')),
#  ('China', Decimal('14687.670000'), Decimal('1411.1000000000')),
#  ('Colombia', Decimal('270.300000'), Decimal('50.9306620000')),
#  ('Costa Rica', Decimal('62.160000'), Decimal('5.1231050000')),
#  ('Cyprus', Decimal('25.010000'), Decimal('1.2375370000')),
#  ('Dominican Republic', Decimal('78.840000'), Decimal('10.9996640000')),
#  ('Ecuador', Decimal('99.290000'), Decimal('17.5885950000')),
#  ('El Salvador', Decimal('24.560000'), Decimal('6.2927310000')),
#  ('Georgia', Decimal('15.840000'), Decimal('3.7227160000')),
#  ('Honduras', Decimal('23.830000'), Decimal('10.1217630000')),
#  ('India', Decimal('2667.690000'), Decimal('1396.3871270000')),
#  ('Jamaica', Decimal('13.810000'), Decimal('2.8204360000')),
#  ('Jordan', Decimal('44.180000'), Decimal('10.9287210000')),
#  ('Kiribati', Decimal('0.180000'), Decimal('0.1264630000')),
#  ('Mauritius', Decimal('11.400000'), Decimal('1.2657400000')),
#  ('Mongolia', Decimal('13.310000'), Decimal('3.2943350000')),
#  ('New Caledonia', Decimal('9.440000'), Decimal('0.2711300000')),
#  ('Panama', Decimal('53.980000'), Decimal('4.2943960000')),
#  ('Paraguay', Decimal('35.430000'), Decimal('6.6186950000')),
#  ('Peru', Decimal('201.710000'), Decimal('33.3047560000')),
#  ('Rwanda', Decimal('10.180000'), Decimal('13.1463620000')),
#  ('Saudi Arabia', Decimal('703.370000'), Decimal('35.9971070000')),
#  ('South Africa', Decimal('337.620000'), Decimal('58.8019270000')),
#  ('Sri Lanka', Decimal('85.350000'), Decimal('21.9190000000')),
#  ('Uruguay', Decimal('53.560000'), Decimal('3.4290860000')),
#  ('Uzbekistan', Decimal('59.890000'), Decimal('34.2320500000')),
#  ('Zambia', Decimal('18.110000'), Decimal('18.9277150000'))]

# %% [markdown]
# ## Solutions

# %% [markdown]
# ### Creating the subquery

# %%
# %%sql
#
# SELECT
#     Country_name,
#     Est_gdp_in_billions,
#     Est_population_in_millions
# FROM
#     Economic_Indicators
# WHERE
#     Pct_unemployment > 5
#     AND Time_period = 2020;
# Out:
#  * mysql+pymysql://root:***@localhost:3306/united_nations
# 37 rows affected.
# [('Afghanistan', Decimal('20.14'), Decimal('38.972230')),
#  ('Argentina', Decimal('385.54'), Decimal('45.376763')),
#  ('Armenia', Decimal('12.64'), Decimal('2.805608')),
#  ('Australia', Decimal('1326.90'), Decimal('25.655289')),
#  ('Azerbaijan', Decimal('42.69'), Decimal('10.093121')),
#  ('Bhutan', Decimal('2.33'), Decimal('0.772506')),
#  ('Botswana', Decimal('14.93'), Decimal('2.546402')),
#  ('Brazil', Decimal('1448.56'), Decimal('213.196304')),
#  ('Brunei Darussalam', Decimal('12.01'), Decimal('0.441725')),
#  ('Canada', Decimal('1645.42'), Decimal('38.037204')),
#  ('Chile', Decimal('252.73'), Decimal('19.300315')),
#  ('China', Decimal('14687.67'), Decimal('1411.100000')),
#  ('Colombia', Decimal('270.30'), Decimal('50.930662')),
#  ('Costa Rica', Decimal('62.16'), Decimal('5.123105')),
#  ('Cyprus', Decimal('25.01'), Decimal('1.237537')),
#  ('Dominican Republic', Decimal('78.84'), Decimal('10.999664')),
#  ('Ecuador', Decimal('99.29'), Decimal('17.588595')),
#  ('El Salvador', Decimal('24.56'), Decimal('6.292731')),
#  ('Georgia', Decimal('15.84'), Decimal('3.722716')),
#  ('Honduras', Decimal('23.83'), Decimal('10.121763')),
#  ('India', Decimal('2667.69'), Decimal('1396.387127')),
#  ('Jamaica', Decimal('13.81'), Decimal('2.820436')),
#  ('Jordan', Decimal('44.18'), Decimal('10.928721')),
#  ('Kiribati', Decimal('0.18'), Decimal('0.126463')),
#  ('Mauritius', Decimal('11.40'), Decimal('1.265740')),
#  ('Mongolia', Decimal('13.31'), Decimal('3.294335')),
#  ('New Caledonia', Decimal('9.44'), Decimal('0.271130')),
#  ('Panama', Decimal('53.98'), Decimal('4.294396')),
#  ('Paraguay', Decimal('35.43'), Decimal('6.618695')),
#  ('Peru', Decimal('201.71'), Decimal('33.304756')),
#  ('Rwanda', Decimal('10.18'), Decimal('13.146362')),
#  ('Saudi Arabia', Decimal('703.37'), Decimal('35.997107')),
#  ('South Africa', Decimal('337.62'), Decimal('58.801927')),
#  ('Sri Lanka', Decimal('85.35'), Decimal('21.919000')),
#  ('Uruguay', Decimal('53.56'), Decimal('3.429086')),
#  ('Uzbekistan', Decimal('59.89'), Decimal('34.232050')),
#  ('Zambia', Decimal('18.11'), Decimal('18.927715'))]

# %% [markdown]
# This table simply filters the `Economic_Indicators` table to only display countries with unemployment > 5. This is the input table the main query will use.

# %% [markdown]
# ### Creating the main query

# %%
# %%sql
#
# SELECT
#     Country_name,
#     AVG(Est_gdp_in_billions) AS Avg_GDP,
#     AVG(Est_population_in_millions) AS Avg_Population
# FROM
#     Economic_Indicators
# GROUP BY
#     Country_name;
# Out:
#  * mysql+pymysql://root:***@localhost:3306/united_nations
# 182 rows affected.
# [('Afghanistan', Decimal('19.063333'), Decimal('36.2436061667')),
#  ('Algeria', Decimal('164.633333'), Decimal('41.5171783333')),
#  ('American Samoa', Decimal('0.660000'), Decimal('0.0488688333')),
#  ('Angola', Decimal('67.791667'), Decimal('30.7577836667')),
#  ('Anguilla', None, None),
#  ('Antigua and Barbuda', Decimal('1.416667'), Decimal('0.0905413333')),
#  ('Argentina', Decimal('525.670000'), Decimal('44.2628536667')),
#  ('Armenia', Decimal('11.891667'), Decimal('2.8431866667')),
#  ('Aruba', Decimal('2.970000'), Decimal('0.1045655000')),
#  ('Australia', Decimal('1338.516667'), Decimal('24.7605421667')),
#  ('Azerbaijan', Decimal('44.963333'), Decimal('9.8863935000')),
#  ('Bahamas', None, None),
#  ('Bahrain', Decimal('34.986667'), Decimal('1.4479390000')),
#  ('Bangladesh', Decimal('300.098333'), Decimal('162.6716105000')),
#  ('Barbados', Decimal('4.936667'), Decimal('0.2794133333')),
#  ('Belize', Decimal('2.261667'), Decimal('0.3779931667')),
#  ('Benin', Decimal('13.368333'), Decimal('11.7773161667')),
#  ('Bermuda', Decimal('7.038333'), Decimal('0.0642310000')),
#  ('Bhutan', Decimal('2.321667'), Decimal('0.7585361667')),
#  ('Bolivia (Plurinational State of)', None, None),
#  ('Botswana', Decimal('15.563333'), Decimal('2.4261566667')),
#  ('Brazil', Decimal('1816.700000'), Decimal('209.2830861667')),
#  ('British Virgin Islands', None, Decimal('0.0301700000')),
#  ('Brunei Darussalam', Decimal('12.585000'), Decimal('0.4319590000')),
#  ('Burkina Faso', Decimal('14.795000'), Decimal('20.1160605000')),
#  ('Burundi', Decimal('2.723333'), Decimal('11.3957675000')),
#  ('Cabo Verde', Decimal('1.780000'), Decimal('0.5677310000')),
#  ('Cambodia', Decimal('22.963333'), Decimal('15.9171066667')),
#  ('Cameroon', Decimal('37.088333'), Decimal('24.7446053333')),
#  ('Canada', Decimal('1641.090000'), Decimal('36.8435248333')),
#  ('Cayman Islands', Decimal('4.810000'), Decimal('0.0615830000')),
#  ('Central African Republic', Decimal('2.061667'), Decimal('5.0612291667')),
#  ('Chad', Decimal('10.720000'), Decimal('15.3657533333')),
#  ('Chile', Decimal('265.811667'), Decimal('18.5606383333')),
#  ('China', Decimal('12911.278333'), Decimal('1397.5783333333')),
#  ('Colombia', Decimal('302.633333'), Decimal('48.9153971667')),
#  ('Comoros', Decimal('1.090000'), Decimal('0.7610822000')),
#  ('Congo', None, None),
#  ('Cook Islands', None, None),
#  ('Costa Rica', Decimal('60.801667'), Decimal('5.0137766667')),
#  ("Côte d'Ivoire", None, None),
#  ('Cuba', Decimal('97.696667'), Decimal('11.3273250000')),
#  ('Curaçao', None, None),
#  ('Cyprus', Decimal('23.410000'), Decimal('1.2131480000')),
#  ("Democratic People's Republic of Korea", None, None),
#  ('Democratic Republic of the Congo', None, None),
#  ('Djibouti', Decimal('2.826667'), Decimal('1.0485168333')),
#  ('Dominica', Decimal('0.546667'), Decimal('0.0701616667')),
#  ('Dominican Republic', Decimal('80.033333'), Decimal('10.7046241667')),
#  ('Ecuador', Decimal('103.081667'), Decimal('16.8800730000')),
#  ('Egypt', None, None),
#  ('El Salvador', Decimal('25.011667'), Decimal('6.2662533333')),
#  ('Equatorial Guinea', Decimal('12.210000'), Decimal('1.3988646667')),
#  ('Eritrea', None, Decimal('3.3526465000')),
#  ('Eswatini', Decimal('4.238333'), Decimal('1.1564243333')),
#  ('Ethiopia', Decimal('84.750000'), Decimal('109.7340026667')),
#  ('Falkland Islands (Malvinas)', None, None),
#  ('Fiji', Decimal('5.083333'), Decimal('0.9187455000')),
#  ('French Guiana', None, None),
#  ('French Polynesia', Decimal('5.751667'), Decimal('0.2966701667')),
#  ('Gabon', Decimal('15.396667'), Decimal('2.1637180000')),
#  ('Gambia', None, None),
#  ('Georgia', Decimal('16.206667'), Decimal('3.7250351667')),
#  ('Ghana', Decimal('61.945000'), Decimal('30.5368060000')),
#  ('Greenland', Decimal('2.865000'), Decimal('0.0561810000')),
#  ('Grenada', Decimal('1.063333'), Decimal('0.1199556667')),
#  ('Guadeloupe', None, None),
#  ('Guam', Decimal('6.005000'), Decimal('0.1685771667')),
#  ('Guatemala', Decimal('71.336667'), Decimal('16.2153060000')),
#  ('Guinea', Decimal('11.198333'), Decimal('12.4058880000')),
#  ('Guinea-Bissau', Decimal('1.325000'), Decimal('1.9024228333')),
#  ('Guyana', Decimal('4.823333'), Decimal('0.7764731667')),
#  ('Haiti', Decimal('14.936667'), Decimal('10.9368015000')),
#  ('Honduras', Decimal('23.138333'), Decimal('9.7092645000')),
#  ('India', Decimal('2542.005000'), Decimal('1360.7001680000')),
#  ('Indonesia', Decimal('1004.735000'), Decimal('265.6581158333')),
#  ('Iran (Islamic Republic of)', None, None),
#  ('Iraq', Decimal('194.328333'), Decimal('40.1313536667')),
#  ('Israel', Decimal('362.698333'), Decimal('8.7985500000')),
#  ('Jamaica', Decimal('14.741667'), Decimal('2.8085933333')),
#  ('Japan', Decimal('4930.120000'), Decimal('126.8156666667')),
#  ('Jordan', Decimal('42.105000'), Decimal('10.2935920000')),
#  ('Kazakhstan', Decimal('170.095000'), Decimal('18.1534046667')),
#  ('Kenya', Decimal('86.705000'), Decimal('49.4308048333')),
#  ('Kiribati', Decimal('0.183333'), Decimal('0.1214245000')),
#  ('Kuwait', Decimal('120.840000'), Decimal('4.2000768333')),
#  ('Kyrgyzstan', None, None),
#  ("Lao People's Democratic Republic", None, None),
#  ('Lebanon', Decimal('48.778333'), Decimal('6.0270800000')),
#  ('Lesotho', Decimal('2.335000'), Decimal('2.1851381667')),
#  ('Liberia', Decimal('3.300000'), Decimal('4.8462201667')),
#  ('Libya', Decimal('60.346667'), Decimal('6.4255858333')),
#  ('Madagascar', Decimal('12.876667'), Decimal('26.5212078333')),
#  ('Malawi', Decimal('8.971667'), Decimal('18.1396690000')),
#  ('Malaysia', Decimal('330.505000'), Decimal('32.1623901667')),
#  ('Maldives', Decimal('4.650000'), Decimal('0.4784966667')),
#  ('Mali', Decimal('15.720000'), Decimal('19.6416883333')),
#  ('Marshall Islands', Decimal('0.213333'), Decimal('0.0465093333')),
#  ('Martinique', None, None),
#  ('Mauritania', Decimal('7.220000'), Decimal('4.2185483333')),
#  ('Mauritius', Decimal('13.148333'), Decimal('1.2645741667')),
#  ('Mayotte', None, None),
#  ('Mexico', Decimal('1165.201667'), Decimal('123.2676416667')),
#  ('Micronesia (Federated States of)', None, None),
#  ('Mongolia', Decimal('12.496667'), Decimal('3.1301816667')),
#  ('Montserrat', None, None),
#  ('Morocco', Decimal('119.688333'), Decimal('35.7060880000')),
#  ('Mozambique', Decimal('14.230000'), Decimal('28.9994820000')),
#  ('Myanmar', Decimal('66.593333'), Decimal('52.4656771667')),
#  ('Namibia', Decimal('11.960000'), Decimal('2.3853353333')),
#  ('Nauru', Decimal('0.108333'), Decimal('0.0117791667')),
#  ('Nepal', Decimal('29.763333'), Decimal('28.3904620000')),
#  ('New Caledonia', Decimal('9.226667'), Decimal('0.2706700000')),
#  ('New Zealand', Decimal('201.771667'), Decimal('4.8511833333')),
#  ('Nicaragua', Decimal('13.010000'), Decimal('6.5267361667')),
#  ('Niger', Decimal('11.790000'), Decimal('22.1903131667')),
#  ('Nigeria', Decimal('429.248333'), Decimal('196.0296905000')),
#  ('Niue', None, None),
#  ('Northern Mariana Islands', Decimal('1.236000'), Decimal('0.0505208333')),
#  ('Oman', Decimal('81.696667'), Decimal('4.4798373333')),
#  ('Pakistan', Decimal('316.811667'), Decimal('218.5158821667')),
#  ('Palau', Decimal('0.280000'), Decimal('0.0178665000')),
#  ('Panama', Decimal('60.015000'), Decimal('4.1286135000')),
#  ('Papua New Guinea', Decimal('22.988333'), Decimal('9.2195820000')),
#  ('Paraguay', Decimal('37.481667'), Decimal('6.3986696667')),
#  ('Peru', Decimal('207.558333'), Decimal('31.9639481667')),
#  ('Philippines', Decimal('339.828333'), Decimal('107.6309581667')),
#  ('Puerto Rico', Decimal('103.380000'), Decimal('3.3122960000')),
#  ('Qatar', Decimal('163.025000'), Decimal('2.6759743333')),
#  ('Republic of Korea', None, None),
#  ('Réunion', None, None),
#  ('Rwanda', Decimal('9.443333'), Decimal('12.3862325000')),
#  ('Saint Barthélemy', None, None),
#  ('Saint Helena', None, None),
#  ('Saint Kitts and Nevis', None, None),
#  ('Saint Lucia', None, None),
#  ('Saint Martin (French Part)', None, None),
#  ('Saint Pierre and Miquelon', None, None),
#  ('Saint Vincent and the Grenadines', None, None),
#  ('Samoa', Decimal('0.866667'), Decimal('0.2088800000')),
#  ('Sao Tome and Principe', Decimal('0.393333'), Decimal('0.2097293333')),
#  ('Saudi Arabia', Decimal('718.561667'), Decimal('34.5336403333')),
#  ('Senegal', Decimal('21.470000'), Decimal('15.3795233333')),
#  ('Seychelles', Decimal('1.560000'), Decimal('0.0956652000')),
#  ('Sierra Leone', Decimal('3.973333'), Decimal('7.7713883333')),
#  ('Singapore', Decimal('344.631667'), Decimal('5.6304316667')),
#  ('Sint Maarten (Dutch part)', Decimal('1.233333'), Decimal('0.0397893333')),
#  ('Solomon Islands', Decimal('1.490000'), Decimal('0.6516381667')),
#  ('Somalia', Decimal('5.950000'), Decimal('15.1417306667')),
#  ('South Africa', Decimal('363.676667'), Decimal('57.1947673333')),
#  ('South Sudan', Decimal('12.000000'), Decimal('10.7279753333')),
#  ('Sri Lanka', Decimal('89.396667'), Decimal('21.5015000000')),
#  ('State of Palestine', None, None),
#  ('Sudan', Decimal('68.225000'), Decimal('41.3166355000')),
#  ('Suriname', Decimal('3.828333'), Decimal('0.5909280000')),
#  ('Syrian Arab Republic', Decimal('16.718333'), Decimal('19.5595186667')),
#  ('Tajikistan', Decimal('7.833333'), Decimal('9.0305413333')),
#  ('Thailand', Decimal('470.256667'), Decimal('70.9518108333')),
#  ('Timor-Leste', Decimal('1.765000'), Decimal('1.2526480000')),
#  ('Togo', Decimal('6.418333'), Decimal('7.9532885000')),
#  ('Tokelau', None, None),
#  ('Tonga', Decimal('0.466667'), Decimal('0.1054331667')),
#  ('Trinidad and Tobago', Decimal('23.896667'), Decimal('1.4918208333')),
#  ('Tunisia', Decimal('43.240000'), Decimal('11.8664945000')),
#  ('Türkiye', None, None),
#  ('Turkmenistan', Decimal('39.180000'), Decimal('6.0128831667')),
#  ('Turks and Caicos Islands', Decimal('1.025000'), Decimal('0.0390287500')),
#  ('Tuvalu', Decimal('0.048333'), Decimal('0.0109078333')),
#  ('Uganda', Decimal('33.035000'), Decimal('40.8703043333')),
#  ('United Arab Emirates', Decimal('387.428333'), Decimal('9.1030955000')),
#  ('United Republic of Tanzania', None, None),
#  ('United States of America', None, None),
#  ('United States Virgin Islands', None, None),
#  ('Uruguay', Decimal('59.008333'), Decimal('3.4205535000')),
#  ('Uzbekistan', Decimal('67.808333'), Decimal('32.7173166667')),
#  ('Vanuatu', Decimal('0.856667'), Decimal('0.2938803333')),
#  ('Venezuela (Bolivarian Republic of)', None, None),
#  ('Viet Nam', None, None),
#  ('Wallis and Futuna Islands', None, None),
#  ('Yemen', None, None),
#  ('Zambia', Decimal('22.635000'), Decimal('17.5763550000')),
#  ('Zimbabwe', Decimal('22.598333'), Decimal('14.9058666667'))]

# %% [markdown]
# Note that this query calculates the averages for **all** years, and for **all** countries.

# %% [markdown]
# ### Combining the queries

# %%
# %%sql
#
# SELECT
#     Country_name,
#     AVG(Est_gdp_in_billions) AS Avg_GDP,
#     AVG(Est_population_in_millions) AS Avg_Population
# FROM
#     (SELECT
#         Country_name,
#         Est_gdp_in_billions,
#         Est_population_in_millions
#     FROM
#         Economic_Indicators
#     WHERE
#         Pct_unemployment > 5
#         AND Time_period = 2020) AS FilteredCountries
# GROUP BY
#     Country_name;
# Out:
#  * mysql+pymysql://root:***@localhost:3306/united_nations
# 37 rows affected.
# [('Afghanistan', Decimal('20.140000'), Decimal('38.9722300000')),
#  ('Argentina', Decimal('385.540000'), Decimal('45.3767630000')),
#  ('Armenia', Decimal('12.640000'), Decimal('2.8056080000')),
#  ('Australia', Decimal('1326.900000'), Decimal('25.6552890000')),
#  ('Azerbaijan', Decimal('42.690000'), Decimal('10.0931210000')),
#  ('Bhutan', Decimal('2.330000'), Decimal('0.7725060000')),
#  ('Botswana', Decimal('14.930000'), Decimal('2.5464020000')),
#  ('Brazil', Decimal('1448.560000'), Decimal('213.1963040000')),
#  ('Brunei Darussalam', Decimal('12.010000'), Decimal('0.4417250000')),
#  ('Canada', Decimal('1645.420000'), Decimal('38.0372040000')),
#  ('Chile', Decimal('252.730000'), Decimal('19.3003150000')),
#  ('China', Decimal('14687.670000'), Decimal('1411.1000000000')),
#  ('Colombia', Decimal('270.300000'), Decimal('50.9306620000')),
#  ('Costa Rica', Decimal('62.160000'), Decimal('5.1231050000')),
#  ('Cyprus', Decimal('25.010000'), Decimal('1.2375370000')),
#  ('Dominican Republic', Decimal('78.840000'), Decimal('10.9996640000')),
#  ('Ecuador', Decimal('99.290000'), Decimal('17.5885950000')),
#  ('El Salvador', Decimal('24.560000'), Decimal('6.2927310000')),
#  ('Georgia', Decimal('15.840000'), Decimal('3.7227160000')),
#  ('Honduras', Decimal('23.830000'), Decimal('10.1217630000')),
#  ('India', Decimal('2667.690000'), Decimal('1396.3871270000')),
#  ('Jamaica', Decimal('13.810000'), Decimal('2.8204360000')),
#  ('Jordan', Decimal('44.180000'), Decimal('10.9287210000')),
#  ('Kiribati', Decimal('0.180000'), Decimal('0.1264630000')),
#  ('Mauritius', Decimal('11.400000'), Decimal('1.2657400000')),
#  ('Mongolia', Decimal('13.310000'), Decimal('3.2943350000')),
#  ('New Caledonia', Decimal('9.440000'), Decimal('0.2711300000')),
#  ('Panama', Decimal('53.980000'), Decimal('4.2943960000')),
#  ('Paraguay', Decimal('35.430000'), Decimal('6.6186950000')),
#  ('Peru', Decimal('201.710000'), Decimal('33.3047560000')),
#  ('Rwanda', Decimal('10.180000'), Decimal('13.1463620000')),
#  ('Saudi Arabia', Decimal('703.370000'), Decimal('35.9971070000')),
#  ('South Africa', Decimal('337.620000'), Decimal('58.8019270000')),
#  ('Sri Lanka', Decimal('85.350000'), Decimal('21.9190000000')),
#  ('Uruguay', Decimal('53.560000'), Decimal('3.4290860000')),
#  ('Uzbekistan', Decimal('59.890000'), Decimal('34.2320500000')),
#  ('Zambia', Decimal('18.110000'), Decimal('18.9277150000'))]

# %% [markdown]
# Using the subquery filters the data first into a derived table, which the main query uses to aggregate with.

# %% [markdown]
# ## Summary

# %% [markdown]
# In this lesson, we used a subquery to determine the average GDP and populations of countries where the unemployment rate is above 5%. We made use of the `FROM` clause. In essence, the subquery in the `FROM` clause can be thought of as creating an intermediate or derived table for the main query to operate upon, even if this table exists only for the duration of the query execution.

# %% [markdown]
# #
#
# <div align="center" style=" font-size: 80%; text-align: center; margin: 0 auto">
# <img src="https://raw.githubusercontent.com/Explore-AI/Pictures/master/ExploreAI_logos/EAI_Blue_Dark.png"  style="width:200px";/>
# </div>
