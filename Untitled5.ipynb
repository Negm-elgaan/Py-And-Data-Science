# %%
pip install opencv-python
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import cv2
import matplotlib.pyplot as plt

image = cv2.imread("C:\\Users\\omarh\\Pictures\\Screenshots\\Screenshot (267).png")

cv2.imshow('Image Window' , image)
cv2.waitKey(0)
cv2.destroyAllWindows()

# %%
grey_image = cv2.cvtColor(image , cv2.COLOR_BGR2GRAY)

cv2.imwrite('gray_example.jpg', grey_image)

cv2.imshow('Grayscale Image', grey_image)
cv2.waitKey(0)
cv2.destroyAllWindows()

# %%
img_orange = cv2.applyColorMap(grey_image , cv2.COLORMAP_AUTUMN)

# %%
plt.subplot(1,2,1), plt.imshow(grey_image , cmap="gray"), plt.title("Grayscale")
plt.subplot(1,2,2), plt.imshow(cv2.cvtColor(img_orange , cv2.COLOR_BGR2RGB)), plt.title("Orange scale")
plt.show()
